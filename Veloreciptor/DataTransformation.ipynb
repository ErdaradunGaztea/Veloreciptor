# %%
import pandas as pd
import json
from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentPoolEmbeddings, Sentence
import torch
import re
import numpy as np

# %%
emb = WordEmbeddings('pl')

# %%
with open("recipes_pretty.json") as file:
    data = json.load(file)

# %% [markdown]
# # Wyrazy kluczowe

# %%
temp = Sentence('jedzenie jednostka narzędzie')
emb.embed(temp)
jedzenie = temp[0].embedding
jednostka = temp[1].embedding
narzedzie = temp[2].embedding

# %% [markdown]
# # Przykładowy składnik

# %% [markdown]
# ### Przygotowanie

# %%
ingredient = Sentence(data[0]["ingredients"][0][0])

# %%
emb.embed(ingredient)
# Out:
# [Sentence: "3 łyżeczki soku z limonki
#  " - 6 Tokens]

# %%
for i in ingredient:
    print(i, i.embedding[:5])
# Out:
# Token: 1 3 tensor([ 0.2346,  0.2216,  0.0498, -0.7787,  0.3949], device='cuda:0')
# Token: 2 łyżeczki tensor([-0.1335,  0.2546,  0.0863, -1.0030,  0.3891], device='cuda:0')
# Token: 3 soku tensor([-0.3744, -0.0344, -0.4256, -0.9503,  0.4655], device='cuda:0')
# Token: 4 z tensor([-0.1382, -0.0861, -0.0652, -0.1541, -0.0471], device='cuda:0')
# Token: 5 limonki tensor([-0.4339,  0.4223, -0.4476, -0.9961,  0.3207], device='cuda:0')
#  oken: 6 tensor([0., 0., 0., 0., 0.], device='cuda:0')

# %% [markdown]
# ### Odległość L2 od słowa "jedzenie"

# %%
for i in ingredient:
    print(torch.norm(i.embedding - jedzenie))
# Out:
# tensor(5.8111, device='cuda:0')
# tensor(5.0761, device='cuda:0')
# tensor(5.6460, device='cuda:0')
# tensor(5.0353, device='cuda:0')
# tensor(5.4801, device='cuda:0')
# tensor(4.6423, device='cuda:0')

# %% [markdown]
# ###  Podobieństwo cosinusowe od słowa jedzenie

# %%
def cos(v,u): return (v @ u)/v.norm()/u.norm()

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, jedzenie))
# Out:
# Token: 1 3
# tensor(0.1270, device='cuda:0')
# Token: 2 łyżeczki
# tensor(0.4890, device='cuda:0')
# Token: 3 soku
# tensor(0.4162, device='cuda:0')
# Token: 4 z
# tensor(0.1661, device='cuda:0')
# Token: 5 limonki
# tensor(0.3724, device='cuda:0')

# %% [markdown]
# ###  Podobieństwo cosinusowe od słowa jednostka

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, jednostka))
# Out:
# Token: 1 3
# tensor(0.1691, device='cuda:0')
# Token: 2 łyżeczki
# tensor(0.0952, device='cuda:0')
# Token: 3 soku
# tensor(0.1207, device='cuda:0')
# Token: 4 z
# tensor(0.0962, device='cuda:0')
# Token: 5 limonki
# tensor(0.1066, device='cuda:0')

# %% [markdown]
# ### Pod. do narzędzie

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, narzedzie))
# Out:
# Token: 1 3
# tensor(0.1972, device='cuda:0')
# Token: 2 łyżeczki
# tensor(0.3519, device='cuda:0')
# Token: 3 soku
# tensor(0.1850, device='cuda:0')
# Token: 4 z
# tensor(0.0672, device='cuda:0')
# Token: 5 limonki
# tensor(0.1857, device='cuda:0')

# %%
for d in data:
    for i in d['ingredients']:
        print(i[0].split())
# Out:
# ['3', 'łyżeczki', 'soku', 'z', 'limonki']
# ['1/2', 'szklanki', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['2', 'łyżki', 'miodu']
# ['2', 'łyżeczki', 'imbiru']
# ['300ml', 'jogurtu', 'naturalnego', '2%']
# ['10', 'owoców', 'lychee']
# ['2', 'banany']
# ['200g', 'ananasa']
# ['1', 'szklanka', 'kruszonego', 'lodu']
# ['miód']
# ['1', 'szklanka', 'wody', 'kokosowej']
# ['1', 'szklanka', 'owoców', 'mango', '(świeżych', 'lub', 'mrożonych)']
# ['1', 'obrany', 'banan']
# ['200g', 'jogurtu', 'greckiego']
# ['1', 'łyżka', 'cukru', 'brązowego']
# ['2', 'szklanki', 'puree', 'z', 'mango']
# ['1/2', 'szklanki', 'mleczka', 'kokosowego']
# ['2', 'łyżeczki', 'brązowego', 'cukru']
# ['1', 'szklanka', 'wody', 'mineralnej', 'niegazowanej']
# ['4', 'łyżki', 'stołowe', 'nasion', 'Chia']
# ['2', 'łyżeczki', 'soku', 'z', 'limonki']
# ['100ml', 'wody', 'kokosowej']
# ['100g', 'jogurtu', 'naturalnego']
# ['1/2', 'mango']
# ['150g', 'truskawek']
# ['lód']
# ['Napój', 'Mango', 'Rubicon', 'Deluxe']
# ['1/2', 'cytryny']
# ['6', 'mandarynek']
# ['125g', 'ananasa']
# ['1', 'szklanka', 'soku', 'jabłkowego']
# ['30ml', 'Rumu', 'Tanduay']
# ['60ml', 'Wina', 'Sake', '-', 'Gekkeikan', 'Haiku']
# ['30ml', 'syropu', 'z', 'trawy', 'cytrynowej']
# ['90ml', 'świeżo', 'zaparzonej', 'zielonej', 'herbaty']
# ['kilka', 'kostek', 'lodu']
# []
# ['Dodatki', 'do', 'dekoracji:']
# ['imbir,', 'mięta,', 'cytryna']
# ['200ml', 'Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['100ml', 'zielonej', 'herbaty']
# ['kilka', 'kostek', 'lodu']
# ['*świeże', 'mango', 'i', 'kilka', 'listków', 'mięty', 'do', 'dekoracji']
# ['1', 'paczka', 'zupy', 'AnSungTangMyun']
# ['50g', 'pasty', 'do', 'sosów', 'Barilla', 'Arabiata']
# ['8g', 'bazy', 'do', 'zupy', 'w', 'proszku']
# ['100g', 'małży', 'z', 'krótkimi', 'szyjkami', '(4', 'szt.)']
# ['100g', 'małży', '(4', 'szt.)']
# ['20g', 'mątwy']
# ['60g', 'krewetek', '(3', 'szt.)']
# ['2g', 'ostrej', 'papryczki', 'chili', '(1/4', 'szt.)']
# ['6', 'pomidorków', 'koktajlowych']
# ['1', 'cały', 'ząbek', 'czosnku']
# ['18ml', 'białego', 'wina']
# ['8ml', 'oliwy', 'z', 'oliwek']
# ['300ml', 'wody']
# ['natka', 'pietruszki']
# ['200g', 'makaronu', 'wieloziarnistego', 'Bali', 'Kitchen']
# ['2', 'łyżki', 'oleju', 'arachidowego']
# ['50g', 'fasoli', 'czerwonej']
# ['50g', 'liści', 'sałaty']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['50g', 'wędzonego,', 'smażonego', 'Tofu', '(w', 'paski)']
# ['2', 'łyżki', 'Mirinu']
# ['2', 'łyżki', 'sosu', 'sojowego', 'słodkiego']
# ['1', 'łyżeczka', 'imbiru', 'w', 'proszku']
# ['według', 'uznania:', 'odrobina', 'soku', 'z', 'limetki', '/', 'sól', '/', 'pieprz']
# ['250', 'g', 'fasoli', 'białej']
# ['500', 'g', 'żeberek', 'wieprzowych']
# ['250', 'g', 'wędzonego', 'boczku']
# ['2', 'marchewki']
# ['1', 'pietruszka']
# ['kawałek', 'selera']
# ['3', 'ziela', 'angielskie']
# ['1', 'listek', 'laurowy']
# ['1', 'duża', 'cebula']
# ['1', 'ząbek', 'czosnku']
# ['3', '-', '4', 'ziemniaki']
# ['1', 'łyżka', 'majeranku']
# ['700', 'g', 'kalafiora']
# ['2', 'średnie', 'ziemniaki']
# ['2', 'kalarepy']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['kmin', 'rzymski']
# ['kolendra']
# ['sól']
# ['pieprz']
# ['oliwa', 'extra', 'virgin']
# ['1', 'litr', 'bulionu']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'zielonej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['60', 'g', 'bakłażana']
# ['150', 'g', 'polędwicy', 'wołowej']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['2', 'ćwiartki', 'z', 'kurczaka']
# ['500', 'g', 'ryżu', 'kleistego', 'Q', 'Rice']
# ['15', 'g', 'imbiru']
# ['10', 'g', 'smażonej', 'cebuli']
# ['5', 'g', 'jagód', 'goji']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['1/2', 'łyżeczki', 'soli']
# ['1', 'łyżka', 'oleju', 'do', 'smażenia']
# ['2', 'łyżki', 'chińskiej', 'wódki', 'ryżowej', '/', 'lub', 'polskiej', 'czystej', 'wódki']
# ['300', 'ml', 'wody']
# ['1', 'szklanka', 'fasoli']
# ['500', '-', '600', 'ml', 'bulionu', 'drobiowego', 'lub', 'jarzynowego']
# ['2', 'średnie', 'marchewki,', 'obrane', 'i', 'pokrojone', 'w', 'cienkie', 'plasterki']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'średnia', 'cebula,', 'pokrojona', 'w', 'drobną', 'kosteczkę']
# ['2', 'łyżki', 'mąki', 'pszennej']
# ['sól']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# []
# ['Pesto:', '•', 'garść', 'rukoli', 'lub', 'bazylii']
# ['3', 'łyżki', 'tartego', 'parmezanu', '/lub', 'grana', 'padano']
# ['1', 'łyżeczka', 'orzeszków', 'pinii', '/lub', 'pestek', 'dyni']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek', 'extra', 'virgin']
# ['1/2', 'małego', 'ząbka', 'czosnku']
# ['sól']
# ['pieprz']
# ['2', 'większe', 'pory', '(tylko', 'białe', 'części)']
# ['30', 'dag', 'piersi', 'z', 'kurczaka']
# ['15', 'dag', 'makaronu', 'udong']
# ['4', 'szklanki', 'bulionu', 'mięsnego']
# ['2', 'łyżki', 'masła']
# ['4', 'łyżki', 'jasnego', 'sosu', 'sojowego']
# ['1', 'łyżeczka', 'cukru']
# ['cytryna']
# ['400g', 'chudej', 'wołowiny']
# ['6', 'ząbków', 'czosnku']
# ['250g', 'pędów', 'bambusa']
# ['4', 'łyżki', 'ciemnego', 'sosu', 'sojowego']
# ['3', 'łyżki', 'oleju']
# ['1', 'łyżka', 'mąki', 'ziemniaczanej']
# ['3', 'łyżki', 'sezamu', 'białego']
# ['3', 'łyżki', 'szczypiorku']
# ['1', 'podwójny', 'filet', 'z', 'kurczaka']
# ['5', 'łyżek', 'oleju']
# ['200g', 'prażonej', 'cebulki']
# ['przyprawa', 'do', 'drobiu']
# ['przyprawy:', 'sól,', 'pieprz,', 'papryka']
# ['250', 'g', 'ryżu', 'kleistego']
# ['1', 'litr', 'mleka']
# ['100', 'g', 'cukru']
# ['kilka', 'liści', 'mięty']
# ['1', 'x', 'cytryna']
# ['1', 'szczypta', 'soli']
# ['500', 'g', 'truskawek', 'świeżych']
# ['5', 'kostek', 'czekolady', 'gorzkiej']
# ['3', 'duże', 'placki', 'tortilli', 'pszennej']
# ['1', 'słoik', 'tuńczyka', 'w', 'oliwie']
# ['150', 'g', 'kukurydzy']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['300', 'g', 'marynowanych', 'ostrych', 'papryczek']
# ['150', 'g', 'tartej', 'mozzarelli', 'lub', 'sera', 'żółtego']
# ['4', 'łyżki', 'majonezu']
# ['2', 'łyżeczki', 'musztardy']
# ['400', 'g', '(puszka)', 'krojonych', 'pomidorów']
# ['1/4', 'zielonej', 'papryki']
# ['2', 'łyżki', 'marynowanej', 'papryczki', 'jalapeño']
# ['1/2', 'łyżeczki', 'sproszkowanego', 'czosnku']
# ['sól']
# ['pieprz']
# ['2', 'łyżki', 'cukru']
# ['3', 'łyżki', 'octu', 'spirytusowego']
# ['2', 'cebulki', 'szalotki']
# ['1', 'łyżeczka', 'mąki', 'ziemniaczanej']
# ['łyżka', 'posiekanej', 'kolendry']
# ['200', 'g', 'tofu']
# ['2', 'porcje', 'rukoli']
# ['1', 'awokado']
# ['sól']
# ['świeżo', 'zmielony', 'pieprz']
# ['oliwa', 'extra', 'virgine']
# ['sok', 'z', 'cytryny']
# ['2', 'łyżki', 'masła']
# ['3', 'jajka']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['grzanki', 'z', 'chleba', 'żytniego', 'posmarowane', 'masłem']
# ['340', 'g', 'mąki', 'z', 'orzechów', '(nerkowce', 'i', 'migdały)']
# ['1', 'łyżka', 'cynamonu', 'cejlońskiego']
# ['2', 'łyżeczki', 'sody', 'oczyszczonej', '/lub', 'proszku', 'do', 'pieczenia']
# ['szczypta', 'soli', 'himalajskiej', '/lub', 'morskiej']
# ['20-30', 'g', 'cukru', 'palmowego']
# ['175', 'g', 'musu', 'jabłkowego']
# ['50', 'g', 'oleju', 'rzepakowego']
# ['2', 'jajka']
# ['1', 'łyżeczka', 'cukru', 'waniliowego']
# ['4', 'łyżki', 'perełek', 'tapioki']
# ['10', 'łyżek', 'cytrynowego', 'syropu', 'do', 'kawy']
# ['2', 'saszetki', 'herbaty', 'malinowej']
# ['1', 'szklanka', 'mleka']
# ['Kilka', 'łyżek', 'miodu']
# ['mięta', 'do', 'dekoracji']
# ['12', 'tortilli', 'taco', '(kukurydziane/pszenne/razowe)']
# ['4', 'kacze', 'udka']
# ['125', 'ml', 'białego,', 'wytrawnego', 'wina']
# ['2', 'świeże', 'mango']
# ['1', 'limonka']
# ['1/2', 'ostrej', 'papryczki', 'chili']
# ['sałata', 'lodowa']
# ['sos', 'Hoisin', '(2-3', 'łyżki', 'stołowe)']
# ['sól']
# ['pieprz']
# ['100', 'g', 'makaronu', 'sojowego']
# ['12', 'ugotowanych', 'lub', 'usmażonych', 'krewetek']
# ['200', 'g', 'truskawek']
# ['4', 'łyżki', 'posiekanych', 'solonych', 'pistacji']
# ['1/3', 'szklanki', 'świeżych', 'listków', 'mięty']
# ['Sos:', '•', 'sok', 'z', '2', 'limonek']
# ['2', 'pełne', 'łyżki', 'miodu']
# ['1', 'łyżka', 'tartego', 'świeżego', 'imbiru']
# ['200g', 'mielonej', 'wieprzowiny']
# ['20g', 'drobno', 'posiekanej', 'cebuli', 'dymki']
# ['20g', 'drobno', 'posiekanej', 'cebuli']
# ['20g', 'małej', 'kukurydzy', 'groszkowej']
# ['20g', 'selera', 'naciowego']
# ['20g', 'grzybów', 'shiitake', '(namoczonych', 'w', 'wodzie)']
# ['20g', 'marchwi']
# ['1', 'główka', 'sałaty', 'lodowej']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['1', 'drobno', 'posiekana', 'papryczka', 'chili', '(opcjonalnie)']
# []
# ['Składniki', 'na', 'sos:', '•', '2', 'łyżki', 'stołowe', 'sosu', 'ostrygowego']
# ['2', 'łyżki', 'stołowe', 'sosu', 'po', 'pekińsku']
# ['2', 'łyżki', 'stołowe', 'wina', 'ryżowego']
# ['3', 'łyżki', 'stołowe', 'wody']
# ['350', 'g', 'udek', 'z', 'kurczaka']
# ['200', 'g', 'świeżego', 'makaronu', 'jajecznego']
# ['1/2', 'ogórka', 'pokrojonego', 'w', 'cienkie', 'paski']
# ['1', 'duża', 'marchew,', 'obrana', 'i', 'pokrojona', 'w', 'cienkie', 'paski']
# []
# ['•', '2', 'łyżki', 'stołowe', 'sosu', 'ostrygowego', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'stołowe', 'sosu', 'sojowego', 'słodkiego', 'do', 'pierożków', 'Lee', 'Kum', 'Kee']
# ['50', 'g', 'kasztanów', 'jadalnych', 'z', 'puszki', 'w', 'wodzie,', 'pokrojonych', 'w', 'plastry', '(opcjonalnie)']
# []
# ['•', '2', 'łyżki', 'stołowe', 'sosu', 'do', 'pierożków', 'Lee', 'Kum', 'Kee']
# ['120g', 'makaronu', 'Mie', 'lub', 'z', 'warzywami']
# ['200g', 'filetu', 'z', 'kurczaka']
# ['1', 'łyżka', 'mąki', 'pszennej']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['1/2', 'małego', 'brokuła']
# ['1', 'cebula']
# ['1', 'czerwona', 'papryka']
# ['1', 'mała', 'puszka', 'kukurydzy']
# ['1', 'łyżka', 'sezamu', 'czarnego']
# ['2-3', 'łyżki', 'stołowe', 'sosu', 'teriyaki', '(ilość', 'sosu', 'może', 'się', 'zmieniać', 'w', 'zależności', 'od', 'ilości', 'użytych', 'składników']
# ['100', 'g', 'makaronu', 'sojowego']
# ['200', 'g', 'krewetek', 'black', 'tiger', '/', 'lub', '150', 'g', 'pokrojonej', 'w', 'kosteczkę', 'piersi', 'kurczaka']
# ['1', 'mango']
# ['1,5', 'łyżki', 'startego', 'imbiru']
# ['2', 'duże', 'ząbki', 'czosnku']
# ['1', 'papryczka', 'chili']
# ['1', 'łyżka', 'oleju', 'kokosowego']
# ['3', 'łyżki', 'sezamu']
# ['0,5', 'szklanki', 'listków', 'mięty']
# ['1', 'łyżka', 'liści', 'kolendry']
# []
# ['Sos:', '•', 'sok', 'z', '2', 'limonek']
# ['2', 'łyżki', 'cukru', 'trzcinowego']
# ['1', 'łyżka', 'sosu', 'ostrygowego', '/lub', '2', 'łyżki', 'sojowego']
# ['Chińska', 'mieszanka', 'warzyw', '330g']
# ['2', 'filety', 'z', 'piersi', 'kaczki']
# ['250', 'chińskiego', 'makaronu', 'jajecznego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['2', 'łyżki', 'octu']
# ['2', 'łyżki', 'oleju']
# ['1', 'łyżeczka', 'cukru']
# ['szczypta', 'imbiru', 'w', 'proszku']
# ['szczypta', 'ostrej', 'papryki']
# ['szczypta', 'słodkiej', 'papryki']
# ['szczypta', 'gałki', 'muszkatołowej']
# ['szczypta', 'cynamonu']
# ['sól']
# ['pieprz']
# ['80', 'g', 'makaronu', 'Chow', 'Mein']
# ['170', 'g', 'wołowiny']
# ['1', 'ząbek', 'czosnku']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1/4', 'pora']
# ['1/2', 'czerwonej', 'papryki']
# ['3', 'pieczarki']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['szczypta', 'cukru']
# ['3', 'łyżki', 'ciemnego', 'sosu', 'sojowego', '+', '2', 'łyżki', 'wody']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['5', 'łyżek', 'stołowych', 'sosu', 'hoisin']
# ['500g', 'żeberek']
# ['1', 'łyżka', 'stołowa', 'sosu', 'sojowego', 'jasnego']
# ['250g', 'piersi', 'z', 'kurczaka', 'pokrojonej', 'w', 'kostkę']
# ['1', 'zielona', 'papryka', 'pokrojona', 'w', 'kostkę']
# ['75g', 'pieczarek', 'pokrojonych', 'w', 'kostkę']
# ['1', 'łyżka', 'oleju']
# ['50g', 'sosu', 'stir-fry', 'z', 'czarnej', 'fasoli', 'i', 'czosnku', 'Lee', 'Kum', 'Kee']
# ['250g', 'pokrojonego', 'w', 'kostkę', 'kurczaka', '(pierś', 'lub', 'udko)']
# ['50g', 'groszku', 'cukrowego']
# ['75g', 'kolb', 'kukurydzy', 'baby']
# ['1', 'łyżka', 'oleju']
# ['70g', 'sosu', 'stir-fry', 'miodowo-sojowego', 'Lee', 'Kum', 'Kee']
# ['1', 'filet', 'z', 'kurczaka']
# ['2', 'łyżki', 'mąki']
# ['2', 'łyżki', 'oleju']
# ['1', 'cebula']
# ['1', 'ząbek', 'czosnku']
# ['3', 'marchewki']
# ['1', 'papryka', 'czerwona', 'lub', 'zielona']
# ['mała', 'puszka', 'pędów', 'bambusa']
# ['1', 'łyżka', 'białego', 'octu', 'winnego']
# ['1', 'łyżka', 'cukru']
# ['2', 'łyżki', 'koncentratu', 'pomidorowego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['sól']
# ['pieprz']
# ['250g', 'pokrojonej', 'w', 'kostkę', 'piersi', 'kurczaka']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['4', 'cebulki', 'dymki,', 'posiekane']
# ['30g', 'prażonych', 'orzechów', 'nerkowca']
# ['1', 'łyżka', 'oleju']
# ['60g', 'sosu', 'stir-fry', 'Kurczak', 'Kung', 'Pao', 'Lee', 'Kum', 'Kee']
# ['180g', 'surowych,', 'obranych', 'krewetek', 'królewskich']
# ['1', 'łyżka', 'oleju']
# ['30g', 'szparagów,', 'ciętych', '(4', 'cm)']
# ['70g', 'sosu', 'stir-fry', 'pomidorowo-czosnkowego', 'Lee', 'Kum', 'Kee']
# ['4', 'całe', 'leszcze', 'morskie,', 'oczyszczone,', 'bez', 'płetw']
# ['400g', 'średniej', 'wielkości', 'ziemniaków,', '(podgotowanych', 'w', 'gorącej', 'wodzie', '5-7', 'minut)']
# ['1', 'świeżo', 'posiekany', 'rozmaryn']
# ['4', 'łyżki', 'sosu', 'Teriyaki', 'Lee', 'Kum', 'Kee']
# ['4', 'łyżki', 'sosu', 'Chili', 'czosnkowego', 'Lee', 'Kum', 'Kee']
# ['3', 'łyżeczki', 'lekkiej', 'oliwy', 'z', 'oliwek']
# ['sól', 'i', 'pieprz']
# ['mały', 'pęczek', 'świeżego', 'koperku', '(niewielka', 'ilość', 'zarezerwowana', 'do', 'dekoracji)']
# ['2', 'opakowania', 'ekstra', 'mocnego', 'tofu', '(396', 'g', 'każde)']
# ['olej,', 'np.', 'słonecznikowy', 'albo', 'rzepakowy']
# ['Marynata']
# ['2', 'łyżki', 'sosu', 'sojowego', 'Light', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'oleju', 'sezamowego', 'Lee', 'Kum', 'Kee']
# ['2', 'średnie', 'ząbki', 'czosnku,', 'starte', 'lub', 'zmiażdżone']
# ['2', 'łyżki', 'startego', 'świeżego', 'imbiru']
# ['Glazura']
# ['2', 'łyżeczki', 'sosu', 'sojowego', 'Light', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'sosu', 'chilli', 'czosnkowego', 'Lee', 'Kum', 'Kee']
# ['Do', 'podania']
# ['Ogórek,', 'mięta,', 'miękkie', 'bułeczki', 'i', 'liście', 'sałaty.']
# ['300g', 'zielonej', 'fasolki', 'szparagowej']
# ['olej', 'arachidowy']
# ['75g', 'mielonej', 'wieprzowiny']
# ['2', 'łyżki', 'wina', 'ryżowego', 'do', 'gotowania']
# ['1', 'łyżka', 'sosu', 'sojowego']
# ['1', 'papryczka', 'chili', '(drobno', 'pokrojona)']
# ['2', 'łyżki', 'posiekanej', 'chińskiej', 'kapusty', 'bok', 'choy']
# ['panierka', 'Tempura']
# ['1', 'cukinia', '175', 'g']
# ['1', 'bakłażan', '250', 'g']
# ['150', 'g', 'małych', 'pieczarek']
# ['1', 'pęczek', 'dymki']
# ['1', 'l', 'oleju', 'słonecznikowego']
# ['sos', 'sojowy', '(do', 'maczania)']
# ['500g', 'ryżu', 'do', 'sushi']
# ['1', 'opakowanie', 'alg', 'Nori', 'do', 'sushi']
# ['Zalewa', 'octowa:', '•', '8', 'łyżek', 'octu', 'ryżowego']
# ['3-4', 'łyżki', 'cukru']
# ['łyżka', 'sosu', 'sojowego']
# ['mata', 'bambusowa', 'do', 'sushi']
# ['Dodatki:', '•', '200g', 'świeżego', '(najlepiej', 'surowego', 'lub', 'wędzonego)', 'filetu', 'z', 'łososia']
# ['dojrzały', 'owoc', 'awokadu']
# ['pęczek', 'szczypiorku']
# ['marynowany', 'imbir', '(ze', 'słoika)', 'według', 'uznania']
# ['pasta', 'wasabi']
# ['ryż', 'do', 'Sushi']
# ['algi', 'do', 'Sushi']
# ['sos', 'sojowy', 'japoński']
# ['ocet', 'ryżowy', 'do', 'sushi']
# ['imbir', 'do', 'sushi']
# ['pasta', 'wasabi']
# ['mata', 'bambusowa']
# ['warzywa,', 'ryby,', 'owoce', 'morza', '(wedle', 'uznania)']
# ['300', 'g', 'filetu', 'z', 'łososia']
# ['mały', 'pęczek', 'zielonych', 'szparagów']
# ['4', 'małe', 'dymki']
# ['3', 'łyżki', 'oliwy']
# ['duża', 'garść', 'małych', 'listków', 'botwinki', '/lub', 'szpinaku']
# ['170', 'g', 'makaronu', 'Udong']
# ['2', 'łyżki', 'sezamu']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# []
# ['Marynata', 'i', 'sos', 'teriyaki:', '•', '6', 'łyżek', 'sosu', 'sojowego']
# ['2', 'łyżki', 'brązowego', 'cukru']
# ['1', 'łyżka', 'soku', 'z', 'limonki']
# ['3', 'łyżeczki', 'startego', 'imbiru']
# ['1', 'ząbek', 'czosnku,', 'drobno', 'starty']
# ['1', 'pierś', 'z', 'kurczaka']
# ['400g', 'makaronu', 'U-Dong']
# ['330g', 'chińskiej', 'mieszanki', 'warzyw']
# ['227g', 'pędów', 'bambusa', '(w', 'plastrach)']
# ['165ml', 'sosu', 'słodko-kwaśnego', 'Lee', 'Kum', 'Kee']
# ['150g', 'makaronu', 'Udong']
# ['150g', 'mieszanki', 'surowych', 'owoców', 'morza', '(rozmrożonych', 'i', 'odcedzonych)']
# ['50g', 'posiekanej', 'cebuli']
# ['50g', 'posiekanej', 'marchwi']
# ['1', 'papryczka', 'chili,', 'pokrojona', 'w', 'plastry,', 'bez', 'nasion']
# ['1', 'łyżka', 'stołowa', 'oleju', 'roślinnego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'ostrygowego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'z', 'czarnym', 'pieprzem']
# ['200', 'g', 'filetu', 'z', 'łososia', 'bez', 'skóry', 'i', 'ości']
# ['100', 'g', 'makaronu', 'ryżowego']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['1', 'papryczka', 'chili']
# ['1,5', 'łyżki', 'startego', 'imbiru']
# ['2', 'łyżki', 'sezamu']
# ['2', 'łyżki', 'pasty', 'miso']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['1', 'limonka']
# ['1/2', 'łyżeczki', 'cukru']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['świeża', 'kolendra']
# ['800g', 'filetu', 'z', 'łososia']
# ['1', 'łyżka', 'oliwy']
# ['Marynata:']
# ['6', 'łyżek', 'sosu', 'sojowego']
# ['8', 'łyżek', 'sosu', 'teriyaki']
# ['2', 'łyżki', 'miodu', 'lipowego']
# ['1', 'czubata', 'łyżeczka', 'imbiru', '(mielonego', 'lub', 'świeżo', 'startego', '-', '1,5cm)']
# ['2', 'duże', 'żabki', 'czosnku', '(przeciśnięte', 'przez', 'praskę', 'i', 'roztarte', 'z', 'solą)']
# ['sól', 'i', 'pieprz']
# ['Tempura', 'Samlip']
# ['olej', 'kokosowy']
# ['surowe', 'krewetki', '24', 'szt.']
# ['mąka', 'pszenna', '1', 'szklanka']
# ['sól']
# ['woda']
# ['Bulion:', '•', '1kg', 'kości', 'wieprzowych']
# ['1kg', 'kości', 'drobiowych']
# ['4', 'cebulki', 'szalotki']
# ['10cm', 'korzenia', 'imbiru']
# ['pół', 'główki', 'czosnku']
# ['2', 'marchewki']
# ['albi', 'Konbu', '(płat)']
# ['100ml', 'sosu', 'sojowego']
# ['80ml', 'wina', 'ryżowego', 'Sake']
# ['Dodatki:', '•', '300g', 'suszonych', 'grzybów', 'Shiitake']
# ['500g', 'świeżego', 'makaronu', 'Ramen']
# ['szczypiorek']
# ['6', 'jajek']
# ['algi', 'Nori']
# ['opcjonalnie:', '•', '200g', 'kapusty', 'Bok', 'Choy', '•', 'kiełki', 'fasoli', 'mung']
# ['1/2', 'dużego', 'bakłażana']
# ['1/2', 'szklanki', 'kuskusu']
# ['1/2', 'szklanki', 'bulionu', 'warzywnego']
# ['sok', 'z', 'ćwiartki', 'cytryny']
# ['1', 'pełna', 'łyżka', 'posiekanej', 'świeżej', 'mięty']
# ['60', 'g', 'sera', 'koziego', 'pokrojonego', 'na', 'kawałki', '(lub', 'sera', 'feta)']
# ['100', 'g', 'pomidorków', 'koktajlowych,', 'przekrojonych', 'na', 'połówki']
# ['oliwa', 'z', 'oliwek']
# ['2', 'kalmary']
# ['100', 'g', 'kiełbaski', 'chorizo']
# ['2', 'puszki', 'pomidorów', 'obranych,', 'pokrojonych']
# ['gałązka', 'rozmarynu']
# ['2', 'ząbki', 'czosnku']
# ['400', 'g', 'fasolki', 'białej']
# ['1', 'szklanka', 'ryżu', 'kleistego']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['sok', 'wyciśnięty', 'z', '1', 'limonki']
# ['skórka', 'starta', 'z', '1', 'limonki']
# ['4', 'łyżki', 'cukru', 'trzcinowego']
# ['1', 'x', 'laska', 'wanilii']
# ['1', 'x', 'mango']
# ['kilka', 'listków', 'świeżej', 'mięty']
# ['3', 'łyżki', 'białego', 'sezamu']
# ['2', 'papryki', '(żółta', 'i', 'czerwona)']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1/3', 'szklanki', 'kuskusu']
# ['gorący', 'bulion', 'warzywny', '(około', '1/3', 'szklanki)']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['6', 'pomidorków', 'koktajlowych,', 'przekrojonych', 'na', 'połówki']
# ['2', '-', '3', 'łyżki', 'orzeszków', 'pinii,', 'grillowanych', 'na', 'suchej', 'patelni']
# ['8', 'kosteczek', 'sera', 'feta']
# ['75g', 'masła']
# ['75g', 'mąki', 'orkiszowej']
# ['400', 'ml', 'bitej', 'śmietany']
# ['1', 'laska', 'wanilii']
# ['1', 'szklanka', 'puree', 'z', 'mango']
# ['opcjonalnie:', 'owoce', 'do', 'dekoracji', '(np.', 'truskawki,', 'ananas,', 'kiwi)']
# ['200ml', 'bitej', 'śmietany']
# ['30ml', 'kremu', 'kokosowego']
# ['10g', 'płatków', 'żelatyny']
# ['200g', 'puree', 'z', 'mango']
# ['50g', 'cukru']
# ['1', 'szklanka', 'ciecierzycy']
# ['1', 'cebula']
# ['1', 'łyżka', 'startego', 'imbiru']
# ['1', 'ząbek', 'czosnku,', 'starty']
# ['300', 'g', 'obranej', 'dyni']
# ['1/2', 'szklanki', 'pasty', 'pomidorowej']
# ['150', 'ml', 'mleka', 'kokosowego']
# ['garść', 'szpinaku']
# ['200', 'g', 'pomidorków', 'koktajlowych']
# []
# ['Przyprawy', '(po', 'łyżce):', '•', 'mielony', 'kminy', '•', 'kurkuma', '•', 'mielona', 'kolendra', '•', 'mielony', 'cynamon', '•', 'słodka', 'papryka', '•', 'ostra', 'papryka', '•', 'kardamon', 'zielony']
# ['500g', 'łopatki', 'wieprzowej']
# ['1/2', 'papryki', 'czerwonej']
# ['1/2', 'papryki', 'zielonej']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['1/2', 'szklanki', 'pędów', 'bambusa']
# ['1', 'łyżeczka', 'pasty', 'curry', '(w', 'zależności', 'od', 'preferowanej', 'ostrości,', 'żółta', '-', 'najłagodniejsza)']
# ['olej', 'do', 'smażenia']
# ['Składniki', 'na', 'sos:', '•', '1', 'łyżka', 'sezamu', 'białego']
# ['2', 'łyżki', 'miodu']
# ['2', 'łyżki', 'ciemnego', 'sosu', 'sojowego']
# ['6', 'łyżek', 'wody']
# ['sok', 'z', '1', 'limonki']
# ['1', 'łyżeczka', 'mąki']
# ['Zupa', 'Tom', 'Yum', 'THAI', 'PRIDE']
# ['Pędy', 'bambusa', 'THAI', 'PRIDE']
# ['Grzyby', 'Shiitake', 'DIAMOND']
# ['Makaron', 'ryżowy', '3', 'mm', 'FARMER']
# ['Mleczko', 'kokosowe', 'AROY-D']
# ['krewetki', 'lub', 'pierś', 'z', 'kurczaka', 'lub', 'filet', 'z', 'łososia']
# ['100', 'g', 'makarony', 'ryżowego', '(3mm', '/', '5mm)']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['3', 'ząbki', 'czosnku']
# ['1', 'pierś', 'z', 'kurczaka', 'lub', '8', 'krewetek', '(obranych)', 'lub', '100g', 'tofu']
# ['2', 'jajka']
# ['100ml', 'sosu', 'Pad', 'Thai']
# ['1', 'szklanka', 'kiełków', 'fasoli', 'mung', 'Diamond']
# ['2', 'cebule', 'dymka', 'lub', '1', 'pęczek', 'szczypiorku']
# ['Makaron:', '•100', 'g', 'makaronu', 'ryżowego', '(płaskiego', 'i', 'szerokiego,', '5', 'mm)']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['3', 'ząbki', 'czosnku']
# ['1', 'pierś', 'kurczaka', 'pokrojona', 'w', 'małą', 'kosteczkę']
# ['2', 'jajka']
# ['1', 'szklanka', 'kiełków', 'fasoli', 'mung']
# ['2', 'cebule', 'dymka', 'lub', '1', 'pęczek', 'szczypiorku', '(biała', 'i', 'jasnozielona', 'część)']
# []
# ['Sos:', '•', '4', 'łyżki', 'sosu', 'rybnego']
# ['2', 'łyżki', 'soku', 'z', 'limonki']
# ['2', 'łyżki', 'pasty', 'z', 'tamaryndowca']
# ['3', 'pełne', 'łyżki', 'cukru']
# ['1', 'łyżka', 'sosu', 'sriracha', '(lub', '1/2', 'łyżki', 'płatków', 'chili)']
# ['2', 'łyżki', 'prażonych', 'orzeszków', 'ziemnych']
# ['1', 'pierś', 'z', 'kurczaka']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['2', 'cm', 'imbiru']
# ['1', 'papryczka', 'chili']
# ['łodyga', 'trawy', 'cytrynowej']
# ['1/2', 'limonki']
# ['1', 'łyżka', 'zielonej', 'pasty', 'curry']
# ['2', 'łyżki', 'sosu', 'worcester']
# ['3', 'łyżki', 'sosu', 'rybnego']
# ['sól']
# ['pieprz', 'czarny']
# ['3', 'piersi', 'z', 'kurczaka']
# ['100', 'ml', 'sosu', 'Satay']
# ['Oliwa', 'z', 'oliwek', 'extra', 'virgin']
# ['200', 'g', 'ryżu', 'kleistego', 'Q', 'Rice']
# ['100', 'g', 'cukru,']
# ['1', 'litr', 'mleka,']
# ['250', 'g', 'gorzkiej', 'czekolady,']
# ['szczypta', 'mielonego', 'cynamonu']
# ['1', 'szklanka', 'mleczka', 'kokosowego']
# ['1', 'szklanka', 'mleczka', 'migdałowego']
# ['1/3', 'szklanki', 'nasion', 'Chia']
# ['1/3', 'szklanki', 'płatków', 'kokosowych']
# ['4', 'łyżki', 'syropu', 'klonowego']
# ['2', 'szklanki', 'puree', 'z', 'mango', '(Kesar)']
# ['2', 'płaskie', 'łyżeczki', 'żelatyny', 'w', 'proszku']
# ['2', 'łyżki', 'ciepłej', 'wody']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['40', 'g', 'cukru']
# ['2', 'łyżki', 'rumu']
# ['2', 'łyżki', 'białego', 'wina']
# ['1', 'szklanka', 'płatków', 'owsianych', 'górskich']
# ['2', 'łyżki', 'wiórków', 'kokosowych']
# ['200', 'ml', 'mleczka', 'kokosowego']
# ['2', 'łyżki', 'cukru']
# ['50', 'g', 'czekolady', 'mlecznej', 'lub', 'deserowej']
# ['maliny']
# ['10', 'owoców', 'lychee']
# ['mix', 'sałat', '(1/2', 'opakowania)']
# ['1', 'kulka', 'sera', 'mozarella']
# ['oliwa', 'z', 'oliwek']
# ['miód']
# ['sól']
# ['ocet', 'jabłkowy']
# ['1/2', 'szklanki', 'oliwek', 'czarnych']
# ['Makaron:', '•', '200', 'g', 'makaronu', 'ryżowego']
# ['1', 'cukinia', 'pokrojona', 'na', 'kawałki']
# ['4', 'łyżki', 'orzeszków', 'ziemnych']
# ['1', '-', '2', 'duże', 'czerwone', 'papryczki', 'chili']
# ['2', 'gałązki', 'szczypiorku']
# ['listki', 'świeżej', 'mięty', 'i', 'kolendry', '(po', 'pół', 'szklanki)']
# []
# ['Sos:', '•', '1', 'ząbek', 'czosnku,', 'drobno', 'starty']
# ['2', 'łyżki', 'sosu', 'rybnego', '(lub', 'sojowego)']
# ['sok', 'z', '1', 'limonki']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['1', 'łyżka', 'brązowego', 'cukru']
# ['100', 'g', 'makaronu', 'ryżowego']
# ['1', 'pęczek', 'botwinki', '(młodej', 'z', 'małymi', 'buraczkami)']
# ['2', 'łyżki', 'oleju', 'kokosowego']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1', 'ząbek', 'czosnku']
# ['4', 'łyżki', 'sezamu']
# ['100', 'g', 'tofu']
# ['2', 'młode', 'cebule', 'ze', 'szczypiorem', '(dymki)']
# ['5', 'łyżek', 'sosu', 'sojowego']
# ['łyżeczka', 'syropu', 'klonowego']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['1', 'łyżeczka', 'ostrego', 'sosu', 'Sriracha']
# ['garść', 'świeżej', 'mięty']
# ['0,5kg', 'filetów', 'z', 'kurczaka']
# ['1', 'tajska', 'papryczka', 'chili', '(prik', 'chee', 'fa),', 'cienko', 'pokrojona']
# ['1', 'łyżka', 'stołowa', 'cukru']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'rybnego']
# ['1', 'filiżanka', 'mleczka', 'kokosowego']
# ['1/4', 'filiżanki', 'liści', 'słodkiej', 'bazylii']
# ['8', 'liści', 'limonki', 'kaffir,', 'drobno', 'posiekanych']
# ['1/3', 'łyżki', 'stołowej', 'jasnego', 'sosu', 'sojowego']
# ['2', 'łyżki', 'stołowe', 'pasty', 'curry', 'panang']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'żółtej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['60', 'g', 'ziemniaków']
# ['150', 'g', 'mięsa', 'drobiowego']
# ['60', 'g', 'cebuli']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['1', 'pierś', 'z', 'kurczaa']
# ['3', 'liście', 'limonki', 'kafir']
# ['1-2', 'łyżki', 'pasty', 'Panang']
# ['1', 'łyżeczka', 'sosu', 'rybnego']
# ['1', 'łyżeczka', 'cukru', 'trzcinowego', 'lub', 'palmowego']
# ['1', 'łyżka', 'oleju']
# ['100', 'ml', 'mleczka', 'kokosowego']
# ['2', 'liście', 'limonki', 'kafir,', 'pocięte', 'w', 'paski']
# ['papryczka', 'chili,', 'pociętę', 'w', 'krążki']
# ['ryż', 'jaśminowy', 'do', 'podania']
# ['250g', 'makaronu', 'ryżowego']
# ['200ml', 'mleczka', 'kokosowego']
# ['3-4', 'świeże', 'grzyby', 'Shiitake']
# ['1', 'mango']
# ['3', 'łyżki', 'sosu', 'śliwkowego']
# ['2', 'piersi', 'z', 'kurczaka', '(umyte', 'i', 'oczyszczone', 'z', 'błon)']
# ['1', 'zielona', 'papryczka', 'chili']
# ['2', 'ząbki', 'czosnku']
# ['3-4', 'łyżki', 'oleju']
# ['kilka', 'listków', 'bazylii']
# ['200g', 'makaronu', 'ryżowego']
# ['2', 'ząbki', 'czosnku']
# ['1', 'papryczka', 'chili']
# ['3-4', 'łyżki', 'sosu', 'sojowego']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['garść', 'posiekanej', 'kolendry']
# ['4', 'kawałki', 'mięsa', 'z', 'udek', 'z', 'kurczaka', '(bez', 'skóry', 'i', 'kości)']
# ['sól']
# ['pieprz']
# ['przyprawa', '5', 'smaków']
# ['słodki', 'sos', 'chili', '(1-2', 'łyżki', 'stołowe)']
# ['sezam', 'biały']
# ['kolendra', 'do', 'dekoracji', '(opcjonalnie)']
# ['2', 'podwójne', 'filety', 'z', 'kurczaka']
# ['2', 'łyżki', 'pasty', 'Tom', 'Yum', 'Thai', 'Pride']
# ['sos', 'sojowy', 'Lee', 'Kum', 'Kee']
# ['sos', 'rybny', 'Cock']
# ['mleko', 'kokosowe', 'Bonasia']
# ['papryka', 'chili']
# ['czosnek']
# ['makaron', 'ryżowy', '3mm', 'Farmer']
# ['orzechy', 'pinii']
# ['Składniki', 'na', 'pudding:', '•', '800ml', 'mleczka', 'kokosowego']
# ['1/3', 'szklanki', 'tapioki']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['szczypta', 'soli']
# []
# ['Składniki', 'na', 'mus', 'truskawkowy:', '•', '2', 'szklanki', 'truskawek']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['sok', 'z', 'połowy', 'cytryny']
# ['800', 'ml', 'mleczka', 'kokosowego']
# ['1/3', 'szklanki', 'perełek', 'z', 'tapioki']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['szczypta', 'soli']
# ['1', 'mango']
# ['400ml', 'mleczka', 'kokosowego']
# ['400ml', 'mleka']
# ['80g', 'tapioki']
# ['1', 'łyżeczka', 'pasty', 'z', 'wanilii', 'lub', 'ziarenka', 'z', '1', 'laski', 'wanilii']
# ['2', 'łyżki', 'cukru']
# ['konfitura', 'malinowa']
# ['300g', 'tofu']
# ['20', 'owoców', 'lychee']
# ['1', 'puszka', 'pomidorów']
# ['400ml', 'mleczka', 'kokosowego']
# ['3', 'marchewki']
# ['2', 'szalotki']
# ['1', 'łyżeczka', 'nasion', 'kminku']
# ['1,5', 'łyżeczki', 'nasion', 'gorczycy']
# ['1', 'łyżeczka', 'nasion', 'kolendry']
# ['1', 'łyżeczka', 'kurkumy']
# ['1', 'łyżeczka', 'płatków', 'chili']
# ['1', 'łyżeczka', 'świeżego,', 'startego', 'imbiru']
# ['2', 'ząbki', 'czosnku']
# ['liść', 'laurowy']
# ['olej']
# ['sól']
# ['200g', 'wiśni']
# ['100ml', 'wody']
# ['2-3', 'łyżki', 'cukru', 'kokosowego']
# ['15g', 'tapioki']
# ['szczypta', 'cynamonu']
# ['1', 'goździk']
# ['4-5', 'sztuk', 'kardamonu']
# ['300ml', 'kawy', 'espresso']
# ['2', 'łyżki', 'żelatyny']
# ['cukier']
# ['1/2', 'szklanki', 'tapioki']
# ['2', 'szklanki', 'wody']
# ['konfitura', 'malinowa']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'czerwonej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['150', 'g', 'mięsa', 'drobiowego']
# ['60', 'g', 'pędów', 'bambusa', 'Thai', 'Pride']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['1', 'antrykot', 'wołowy']
# ['1', 'garść', 'migdałów']
# ['1', 'garść', 'białego', 'sezamu']
# ['1', 'papryka', 'czerwona']
# ['1', 'papryczka', 'chilli']
# ['1', 'ząbek', 'czosnku']
# ['kawałek', 'imbiru']
# ['1', 'sałata', 'rzymska']
# ['100g', 'makaronu', 'ryżowego']
# ['1', 'garść', 'kiełków', 'fasoli', 'mung']
# ['1', 'łyżka', 'mielonej', 'trawy', 'cytrynowej']
# ['2-3', 'łyżki', 'sosu', 'teryiaki']
# ['olej', 'arachidowy']
# ['1', 'łyżka', 'sosu', 'rybnego']
# ['1', 'czerwona', 'cebula']
# ['2', 'łyżki', 'sosu', 'ostrygowego']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['świeża', 'kolendra']
# ['800', 'ml', 'mleczka', 'koksowego']
# ['¾', 'szklanki', 'tapioki']
# ['1', 'laska', 'wanilii']
# ['3-4', 'łyżki', 'cukru']
# ['2', 'płaskie', 'łyżeczki', 'agaru']
# ['szczypta', 'soli', 'himalajskiej', 'lub', 'morskiej']
# ['100', 'g', 'gorzkiej', 'czekolady', '90%']
# ['1', 'łyżeczka', 'oleju', 'kokosowego']
# ['1', 'łyżka', 'oleju', 'kokosowego']
# ['1', 'ząbek', 'czosnku']
# ['1/2', 'cebuli', 'cukrowej']
# ['łodyga', 'selera', 'naciowego', 'lub', 'pora']
# ['500', 'g', 'marchewki']
# ['2', 'łyżeczki', 'startego', 'imbiru']
# ['1', 'łyżka', 'masła', 'orzechowego']
# ['1/2', 'łyżeczki', 'chili', 'w', 'proszku']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['szczypta', 'cynamonu']
# ['600', 'ml', 'bulionu', 'jarzynowego']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['100g', 'tofu']
# ['1', 'łyżka', 'czarnego', 'sezamu']
# ['świeża', 'kolendra']
# ['250g', 'tofu', 'Mo-Ri']
# ['olej', 'do', 'smażenia']
# ['2', 'łyżki', 'cukru']
# ['125ml', 'jasnego', 'sosu', 'sojowego']
# ['1', 'łyżeczka', 'ciemnego', 'sosu', 'sojowego']
# ['2', 'ząbki', 'czosnku']
# ['15', 'świeżych', 'grzybów', 'shiitake']
# ['czarny', 'pieprz']
# ['1', 'małe', 'czerwone', 'chili']
# ['10', 'arkuszy', 'papieru', 'ryżowego']
# ['1', 'średniej', 'wielkości', 'ogórek']
# ['1', 'papryka', 'czerwona']
# ['1', 'papryka', 'żółta']
# ['1', 'awokado']
# ['sól', 'i', 'pieprz', 'do', 'smaku']
# ['olej']
# ['150', 'g', 'wołowiny', '(np.', 'z', 'udźca)']
# ['80', 'g', 'makaronu', 'sojowego']
# ['4', 'suszone', 'grzybki', 'chińskie', 'Mun']
# ['0,5', 'łyżeczki', 'curry', 'w', 'proszku']
# ['0,5', 'łyżeczki', 'kurkumy']
# ['0,5', 'łyżeczki', 'płatków', 'chilli']
# ['2', 'łyżki', 'sosu', 'rybnego']
# ['1', 'łyżka', 'cukru']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['2', 'ząbki', 'czosnku,', 'drobno', 'posiekane']
# ['1', 'cebula', '(pół', 'drobno', 'posiekanej', 'i', 'pół', 'pokrojonej', 'w', '"piórka")']
# ['1', 'gałązka', 'trawy', 'cytrynowej', '(biała', 'część)', 'bardzo', 'drobno', 'posiekana']
# ['3', 'łyżki', 'mleczka', 'kokosowego']
# ['1', 'łyżka', 'orzeszków', 'ziemnych,', 'posiekanych']
# ['0,5', 'łyżeczki', 'drobno', 'posiekanej,', 'pikantnej', 'papryczki', 'chilli']
# ['sos', 'sojowy', 'do', 'podania']
# ['500g', 'piersi', 'z', 'kurczaka', '(pokrojona', 'w', 'kostkę)']
# ['1', 'cebula', '(pokrojona', 'w', 'kostkę)']
# ['3', 'łyżki', 'trawy', 'cytrynowej', '(posiekana)']
# ['2', 'łyżki', 'sosu', 'rybnego']
# ['2', 'papryczki', 'chilli', '(drobno', 'posiekana)']
# ['4', 'łyżki', 'oleju', 'arachidowego']
# ['3', 'łyżki', 'cukru']
# ['4', 'ząbki', 'czosnku', '(drobno', 'posiekane)']
# ['1', 'szczypiorek', '(drobno', 'posiekany)']
# ['1', 'łyżka', 'przyprawy', 'curry']
# ['ryż', 'jaśminowy', 'naturalny']
# ['200', 'ml', 'wody', 'kokosowej']
# ['200', 'ml', 'mleczka', 'kokosowego']
# ['1', 'ogórek', 'świeży']
# ['6', 'rzodkiewek']
# ['świeży', 'sok', 'z', 'połowy', 'cytryny']
# ['2', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['szczypta', 'soli']
# ['szczypta', 'pieprzu']
# ['2', 'filety', 'śledziowe', '(w', 'oleju', '/lub', 'marynowane', 'w', 'occie', '/lub', 'wypłukanych', 'solonych)']
# ['2', 'łyżeczki', 'posiekanej', 'natki']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['1', 'łyżeczka', 'musztardy']
# ['1', 'łyżeczka', 'soku', 'z', 'cytryny']
# ['szczypta', 'brązowego', 'cukru']
# ['2', 'łyżki', 'marynowanej', 'ostrej', 'jalapeño']
# ['3', 'łyżki', 'marynowanych', 'podgrzybków']
# ['1', 'łyżka', 'cebulki', 'marynowanej']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['olej', 'lniany']
# ['700', 'g', 'drobnych', 'ziemniaków']
# ['200', 'ml', 'jogurtu', 'naturalnego']
# ['2', 'łyżki', 'pasty', 'harissa']
# ['30', 'ml', 'oliwy']
# ['2', 'łyżki', 'migdałów', 'w', 'słupkach']
# ['30', 'ml', 'soku', 'z', 'limonki']
# ['1/2', 'szklanki', 'nasion', 'granatu']
# ['2', 'szt.', 'zielonej', 'części', 'dymki']
# ['sól']
# ['pieprz']
# ['listki', 'mięty', 'do', 'dekoracji']
# ['jajka', '5', 'sztuk']
# ['soczewica', '100', 'g']
# ['cebula', 'czerwona', '50', 'g']
# ['papryczka', 'jalapeno', 'marynowana', '50', 'g']
# ['majonez', '1⁄2', 'szklanki']
# ['musztarda', 'Dijon', '10', 'g']
# ['sól']
# ['pieprz']
# ['natka', 'pietruszki']
# ['500', 'g', 'ciecierzycy']
# ['1', 'czerwona', 'papryka']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['1/2', 'łyżeczki', 'cukru']
# ['3', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'łyżeczka', 'płatków', 'chili']
# ['mała', 'szczypta', 'soli']
# ['1/2', 'łyżeczki', 'mielonego', 'pieprzu']
# ['1', 'ząbek', 'czosnku']
# ['1/3', 'młodej', 'cebuli']
# ['1', 'pomidor']
# ['3', 'łyżki', 'posiekanego', 'koperku']
# ['4', 'łyżki', 'posiekanej', 'natki', 'pietruszki']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['kilka', 'listków', 'mięty']
# ['2', 'łyżeczki', 'oleju', 'rzepakowego']
# ['1', 'duża', 'cebula,', 'przekrojona', 'na', 'połowę', 'i', 'pokrojona', 'w', 'cienkie', 'plasterki']
# ['3', 'ząbki', 'czosnku,', 'pokrojone', 'w', 'plasterki']
# ['1', 'łyżka', 'harissy,', 'lub', 'innego', 'pikantnego', 'sosu', 'np.', 'tabasco']
# ['1', 'łyżeczka', 'mielonej', 'kolendry']
# ['150', 'ml', 'bulionu', 'warzywnego', 'lub', 'drobiowego']
# ['400', 'g', 'ciecierzycy', 'Doyal']
# ['800', 'g', 'krojonych', 'pomidorów']
# ['2', 'małe', 'cukinie,', 'pokrojone', 'w', 'drobną', 'kostkę']
# ['200', 'g', 'młodego', 'szpinaku']
# ['4', 'łyżki', 'posiekanych', 'listków', 'kolendry']
# ['4', 'duże', 'jajka']
# ['sól,', 'pieprz', 'i', 'cukier', 'do', 'smaku']
# ['1', 'papryka', 'czerwona']
# ['1', 'papryka', 'zielona']
# ['1', 'papryka', 'żółta']
# ['2', 'czerwone', 'cebule']
# ['4', 'łyżeczki', 'pasty', 'harissa']
# ['4', 'gałązki', 'świeżej', 'mięty']
# ['1', 'tuszka', 'kurczaka']
# ['sól', 'morska']
# ['pieprz', 'czarny']
# ['czerwony', 'ocet', 'winny']
# ['1', 'szklanka', 'ugotowanej', 'kaszy', 'jaglanej']
# ['1', 'szklanka', 'ciecierzycy']
# ['1', 'por', '(biała', 'część)']
# ['2', 'łyżki', 'oliwy']
# ['1/2', 'łyżeczki', 'soli']
# ['1/2', 'łyżeczki', 'kuminu']
# ['1/2', 'łyżeczki', 'papryki']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1', 'duży', 'ząbek', 'czosnku']
# ['kilka', 'gałązek', 'natki', 'pietruszki']
# []
# ['Sos', 'pomidorowy:', '•', '400', 'g', 'krojonych', 'pomidorów']
# ['1', 'ząbek', 'czosnku']
# ['2', 'łyżeczki', 'oliwy']
# ['szczypta', 'soli']
# ['szczypta', 'cukru']
# ['szczypta', 'pieprzu']
# ['kawałek', 'papryczki', 'chili']
# ['kilka', 'liści', 'bazylii']
# []
# ['Dodatkowo:', '•', '1', 'cukinia']
# ['2', 'łyżki', 'natki', 'pietruszki']
# ['2', 'małe', 'bataty']
# ['1', 'ząbek', 'czosnku']
# ['150', 'g', 'ciecierzycy']
# ['oliwa', 'extra', 'virgin']
# ['80', 'g', 'szpinaku']
# ['100', 'g', 'fety']
# ['2', 'łyżki', 'krojonych', 'pomidorów', 'z', 'puszki', '/lub', '1/2', 'świeżego', 'pomidora']
# ['papryczka', 'chili']
# ['sól']
# ['pieprz']
# ['1', 'łyżeczka', 'kminu', 'rzymskiego']
# ['1/2', 'łyżeczki', 'suszonego', 'oregano']
# ['1/2', 'łyżeczki', 'czerwonej', 'papryki', 'słodkiej']
# ['1/3', 'łyżeczki', 'papryki', 'ostrej']
# ['1/3', 'łyżeczki', 'papryki', 'wędzonej']
# ['świeża', 'kolendra']
# ['jogurt', 'naturalny']
# ['4', 'filety', 'z', 'łososia', '(każdy', 'filet', 'po', 'około', '100', '-', '150g)']
# ['pasta', 'harissa']
# ['oliwa', 'z', 'oliwek']
# ['sól']
# ['400-500', 'g', 'ciecierzycy']
# ['1', 'łyżka', 'oliwy', 'extra', 'virgin']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'oleju', 'kokosowego', '/lub', 'masła']
# ['2', 'ziemniaki']
# ['1', 'łyżeczka', 'mielonego', 'kminu', 'rzymskiego']
# ['500', 'ml', 'bulionu', 'lub', 'rosołu']
# ['50', 'ml', 'śmietanki', '30%']
# ['płatki', 'chili']
# ['mielony', 'kmin', 'rzymski']
# ['świeża', 'kolendra/lub', 'natka', 'pietruszki']
# ['2', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1', 'mała', 'cebula,', 'pokrojona', 'w', 'drobną', 'kosteczkę']
# ['250', 'g', 'ziemniaków,', 'obranych', 'i', 'pokrojonych', 'w', 'około', '1,5', 'cm', 'kosteczkę']
# ['2', 'małe', 'ząbki', 'czosnku,', 'pokrojone', 'w', 'plasterki']
# ['1/2', 'łyżeczki', 'słodkiej', 'papryki', 'w', 'proszku']
# ['szczypta', 'pikantnego', 'pieprzu', 'cayenne']
# ['sok', 'z', '1/2', 'cytryny']
# ['200', 'g', 'pomidorów', 'wraz', 'z', 'sosem', 'pomidorowym', '(pokrojonych,', 'bez', 'skórek)']
# ['1/2', 'kostki', 'bulionowej', '(rybnej', 'lub', 'jarzynowej)']
# ['100', 'g', 'surowych,', 'obranych', 'krewetek']
# ['150', 'g', 'ciecierzycy,', 'odsączonej']
# ['250', 'g', 'filetów', 'soli', 'bez', 'ości', 'i', 'skóry,', 'pokrojonych', 'w', 'około', '5', 'cm', 'kawałki']
# ['2', 'łyżki', 'posiekanej', 'natki', 'pietruszki']
# ['1/2', 'cebuli']
# ['1/2', 'łyżki', 'masła']
# ['1/2', 'łyżki', 'oliwy']
# ['2', 'ząbki', 'czosnku']
# ['1', 'papryka']
# ['100', 'g', 'kaszy', 'bulgur']
# ['sól']
# ['pieprz']
# ['2', 'łyżeczki', 'słodkiej', 'papryki']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'szklanka', 'bulionu']
# ['400', 'g', 'białej', 'fasoli']
# ['1', 'puszka', 'krojonych', 'pomidorów']
# ['1/3', 'cukinii']
# ['1', 'łyżka', 'sosu', 'ostrygowego']
# ['2', 'garście', 'szpinaku']
# ['50', 'g', 'suszonych', 'grzybów']
# ['1', 'kg', 'kiszonej', 'kapusty']
# ['2', 'szklanki', 'bulionu']
# ['2', 'duże', 'cebule']
# ['400g', 'białej', 'fasoli']
# ['olej', 'roślinny', '(np.', 'rzepakowy,', 'słonecznikowy)']
# ['sól']
# ['pieprz']
# ['2', 'listki', 'laurowe']
# ['4', 'ziela', 'angielskie']
# ['2', 'łyżki', 'suszonego', 'majeranku']
# ['1', 'łyżka', 'mąki']
# ['4', 'jajka']
# ['3', 'łyżki', 'marynowanej', 'zielonej', 'papryczki', 'jalapeño']
# ['1', 'łyżka', 'drobno', 'posiekanego', 'szczypiorku']
# ['1', 'łyżeczka', 'oliwy', 'extra', 'virgin']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['2', 'łyżki', 'majonezu']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['szczypta', 'cukru']
# ['majonez', '(dodatkowo', 'do', 'dekoracji)']
# ['szczypiorek', '(dodatkowo', 'do', 'dekoracji)']
# ['5', 'łyżek', 'sezamu']
# ['2', 'łyżki', 'oliwy']
# ['200g', 'ciecierzycy', 'w', 'zalewie']
# ['2', 'ząbki', 'czosnku']
# ['sok', 'z', 'połówki', 'cytryny']
# ['100', 'ml', 'zimnej', 'zalewy', 'z', 'ciecierzycy']
# ['świeża', 'kolendra']
# ['pieprz,', 'sól,', 'papryka', 'słodka']
# ['3', 'łyżki', 'pasty', 'harissa']
# ['150g', 'masła']
# ['200g', 'sera', 'Mozarella']
# ['1', 'cebula']
# ['1', 'ciabatta']
# ['szczypiorek']
# ['2', 'duże', 'kromki', 'chleba', 'z', 'ziarnami', 'zbóż']
# ['10', 'mrożonych', 'lub', 'świeżych,', 'ugotowanych', '(różowych)', 'krewetek,', 'obranych', 'i', 'bez', 'ogonków']
# ['1', 'łyżeczka', 'oliwy', 'o', 'smaku', 'chilli']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'ząbek', 'czosnku,', 'drobno', 'posiekany']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['1/2', 'puszki', 'białej', 'fasoli']
# ['sól']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['500', 'g', 'suszonej', 'ciecierzycy']
# ['pęczek', 'zielonej', 'pietruszki']
# ['2', 'średnie', 'cebule']
# ['3', 'ząbki', 'czosnku']
# ['3', 'łyżki', 'przyprawy', 'do', 'falafela', '(kolendra,', 'kmin,', 'pieprz,', 'ziele', 'angielskie,', 'cynamon,', 'goździki,', 'imbir,', 'gałka', 'muszkatałowa,', 'mahlab)']
# ['łyżka', 'soli']
# ['łyżeczka', 'sody']
# ['kilka', 'łyżek', 'wody']
# ['olej', 'do', 'smażenia']
# ['400', 'g', 'polędwiczek', 'kurczaka', '(lub', 'całych', 'filetów)']
# ['1', 'czerwona', 'cebula']
# ['1', 'czerwona', 'papryka']
# ['1', 'limonka']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'łyżeczka', 'wędzonej', 'papryki', 'w', 'proszku']
# ['1', 'łyżka', 'marynowanej', 'papryczki', 'jalapeño']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['Dodatki:', '•', '4', 'placki', 'Tortilli']
# ['Guacamole']
# ['1', 'pomidor']
# ['cebula']
# ['50', 'g', 'tartego', 'sera', 'cheddar']
# ['gęsta', 'kwaśna', 'śmietana']
# ['świeża', 'kolendra']
# ['250', 'g', 'filetu', 'z', 'dorsza']
# ['80', 'g', 'kiełbaski', 'chorizo']
# ['2', 'małe', 'szalotki']
# ['120', 'g', 'ciecierzycy']
# ['300', 'ml', 'pasaty', 'pomidorowej']
# ['sól']
# ['pieprz']
# ['szczypta', 'cukru']
# ['300', 'g', 'cukinii']
# ['2', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['1', 'ząbek', 'czosnku']
# ['1/2', 'łyżeczki', 'skórki', 'z', 'cytryny']
# ['150', 'ml', 'bulionu', 'jarzynowego', '/lub', 'drobiowego']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['150', 'g', 'kuskusu']
# ['1/3', 'szklanki', 'listków', 'mięty']
# ['100', 'g', 'sera', 'feta']
# ['1', 'szklanka', 'fasoli', 'białej', '(fasolę', 'wcześniej', 'namoczyć)']
# ['1/2', 'pora']
# ['1', 'łyżeczkę', 'mielonego', 'kminu']
# ['skórka', 'z', 'połowy', 'cytryny']
# ['olej']
# ['4', 'laski', 'selera']
# ['2', 'ziemniaki']
# ['2', 'łyżki', 'pasty', 'Harissa']
# ['2', 'liście', 'laurowe']
# ['1,5-2', 'l', 'bulionu']
# ['sok', 'z', 'połowy', 'cytryny']
# ['pęczek', 'kolendry']
# ['sól']
# ['pieprz', 'czarny']
# ['2', 'cukinie']
# ['1', 'cebula']
# ['140', 'g', 'pomidorów', 'suszonych', 'w', 'zalewie']
# ['2', 'ząbki', 'czosnku']
# ['150', 'g', 'świeżego', 'szpinaku']
# ['200', 'g', 'koziego', 'sera', '(rolada)']
# ['450', 'g', 'pomidorów', 'z', 'puszki']
# ['szczypta', 'cynamonu']
# ['1', 'łyżeczka', 'suszonego', 'oregano']
# ['1/2', 'łyżeczki', 'wędzonej', 'słodkiej', 'papryki']
# ['brązowy', 'cukier']
# ['miód']
# ['syrop', 'z', 'agawy', '(opcjonalnie)']
# ['2', 'łyżki', 'harissy']
# ['sól']
# ['pieprz']
# ['oliwa', 'z', 'oliwek']
# ['250g', 'mielonej', 'wieprzowiny']
# ['¼', 'łyżeczki', 'sody', 'oczyszczonej']
# ['2', 'łyżki', 'pasty', 'harissa', 'Le', 'Phare', 'du', 'Cap', 'Bon']
# ['2', 'łyżki', 'posiekanej', 'kolendry']
# ['2', 'bułki', 'do', 'burgerów']
# ['majonez']
# ['sałata']
# ['plastry', 'pomidora']
# ['1', 'czerwona', 'cebula']
# ['sos', 'tzatziki', '/', 'sos', 'chili']
# ['sól', 'i', 'pieprz', 'do', 'smaku']
# ['1,5', 'litra', 'bulionu', 'warzywnego']
# ['liść', 'laurowy']
# ['2', 'cm', 'kawałek', 'imbiru']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['2', 'łyżki', 'sosu', 'rybnego']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['szczypta', 'cukru']
# ['1/2', 'bulwy', 'kopru', 'włoskiego']
# ['150', 'g', 'pieczarek']
# ['1', 'kapustka', 'pak', 'choi', '(lub', 'garść', 'szpinaku)']
# ['100', 'g', 'makaronu', 'Chow', 'Mien', 'Bali', 'Kitchen']
# ['350', 'g', 'polędwicy', 'z', 'dorsza']
# ['1', 'łyżeczka', 'posiekanej', 'papryczki', 'chili']
# ['świeża', 'kolendra', '(lub', 'szczypiorek)']
# ['200g', 'białego', 'ryżu']
# ['300ml', 'mleczka', 'kokosowego']
# ['pół', 'łyżeczki', 'soli']
# ['100', 'g', 'makaronu', 'Mie', 'Goreng/Chow', 'Mien/z', 'mąką', 'z', 'fasoli', 'i', 'kukurydzy']
# ['1', 'pojedyncza', 'pierś', 'kurczaka']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['2', 'ząbki', 'czosnku']
# ['2', 'łyżki', 'oleju', 'roślinnego', '(kokosowego', 'lub', 'z', 'orzeszków', 'ziemnych)']
# ['8', 'szparagów']
# ['6', 'pieczarek']
# ['3', 'łyżki', 'posiekanej', 'dymki', 'lub', 'szczypiorku']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# []
# ['Sos:', '•', '5', 'łyżek', 'sosu', 'sojowego', 'jasnego']
# ['3', 'łyżki', 'wody']
# ['3', 'łyżki', 'soku', 'z', 'limonki/lub', 'cytryny/lub', 'octu', 'ryżowego']
# ['3', 'łyżki', 'cukru']
# ['1/2', 'łyżeczki', 'mąki', 'ziemniaczanej']
# ['150', 'g', 'makaronu']
# ['150', 'g', 'krewetek']
# ['1/2', 'pęczka', 'szparagów']
# ['100', 'g', 'pomidorków', 'koktajlowych']
# ['3', 'ząbki', 'czosnku']
# ['1', 'łyżeczka', 'suszonego', 'oregano']
# ['3', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['2', 'łyżki', 'masła']
# ['4', 'łyżki', 'białego', 'wytrawnego', 'wina']
# ['świeża', 'bazylia/natka', 'pietruszki/', 'lub', 'tymianek']
# ['tarty', 'parmezan']
# ['150', 'g', 'makaronu', 'z', 'warzywami', 'Bali', 'Kitchen']
# ['50', 'g', 'szpinaku']
# ['0,5', 'dojrzałego', 'dużego', 'awokado', '/lub', '1', 'małe']
# ['2', 'łyżki', 'soku', 'z', 'limonki']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'ząbek', 'czosnku,', 'pokrojony', 'na', 'plasterki']
# ['3', 'łyżki', 'posiekanych', 'liści', 'świeżego', 'estragonu']
# ['2', '-', '3', 'czubate', 'łyżki', 'serka', 'mascarpone']
# ['tarty', 'Parmezan']
# ['pomidorki', 'koktajlowe']
# ['1', 'pojedynczy', 'filet', 'kurczaka']
# ['2', 'łyżeczki', 'mąki', 'ziemniaczanej']
# ['100', 'g', 'makaronu', 'Chow', 'Mien/Mie', 'Bali', 'Kitchen']
# ['ćwiartka', 'cebuli']
# ['2', 'ząbki', 'czosnku']
# ['1/2', 'marchewki']
# ['1/2', 'brokuła']
# ['kawałek', 'papryczki', 'chili']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['3', 'łyżki', 'orzechów', 'nerkowca']
# ['1/4', 'szklanki', 'wody']
# ['3', 'łyżki', 'sosu', 'sojowego']
# ['1/2', 'łyżeczki', 'cukru', 'trzcinowego']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['200g', 'makaronu', 'z', 'morinagą', 'Bali', 'Kitchen']
# ['200g', 'krewetek']
# ['odrobinę', 'oleju', 'do', 'smażenia']
# ['1', 'posiekana', 'papryczka', 'chili']
# ['1', 'ząbek', 'czosnku,', 'posiekany']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['1/2', 'papryki', 'żółtej', 'pokrojonej', 'w', 'kostkę']
# ['1/2', 'papryki', 'zielonej', 'pokrojonej', 'w', 'kostkę']
# ['30g', 'imbiru,', 'posiekanego']
# ['3', 'łyżki', 'słodkiego', 'sosu', 'sojowego']
# ['odrobina', 'soku', 'z', 'cytryny']
# ['odrobina', 'sosu', 'rybnego']
# ['1', 'łyżka', 'prażonego', 'sezamu']
# ['200g', 'makaronu', 'z', 'czarnym', 'sezamem', 'Bali', 'Kitchen']
# ['2', 'łyżki', 'oleju', 'sezamowego', 'Diamond']
# ['2', 'łyżki', 'oleju', 'arachidowego']
# ['3', 'ząbki', 'czosnku,', 'posiekane']
# ['20g', 'imbiru,', 'pokrojonego', 'w', 'małą', 'kostkę']
# ['200g', 'ugotowanych', 'krewetek']
# ['1', 'czerwona', 'cebula']
# ['posiekane', 'liście', 'kolendry']
# ['1', 'łyżka', 'prażonych', 'nasion', 'czarnego', 'sezamu']
# ['sól', 'i', 'pieprz']
# ['około', '1,5', 'szklanki', 'truskawek']
# ['150', 'g', 'makaronu', 'chilli', 'Bali', 'Kitchen']
# ['1', 'łagodna', 'czerwona', 'papryczka', 'chili,', 'bez', 'pestek,', 'posiekana']
# ['2', 'łyżki', 'masła']
# ['1/3', 'szklanki', 'śmietanki', 'kremowej', '30%']
# ['0,5', 'szklanki', 'drobno', 'tartego', 'parmezanu']
# ['0,5', 'szklanki', 'liści', 'bazylii', 'i', 'mięty']
# ['1', 'łyżka', 'sosu', 'Worcester']
# ['80', 'g', 'makaronu', 'chili']
# ['170', 'g', 'wołowiny']
# ['1', 'ząbek', 'czosnku']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1/4', 'pora']
# ['1/2', 'czerwonej', 'papryki']
# ['3', 'pieczarki']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['szczypta', 'cukru']
# ['3', 'łyżki', 'ciemnego', 'sosu', 'sojowego', '+', '2', 'łyżki', 'wody']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['80', 'g', 'makaronu', 'pszennego', 'z', 'czarnym', 'sezamem']
# ['2', 'pomidory', 'malinowe']
# ['miseczka', 'kurek']
# ['2', 'ząbki', 'czosnku']
# ['5', 'łyżek', 'pokrojonej', 'w', 'kosteczkę', 'cebuli']
# ['2', 'łyżki', 'masła']
# ['2', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['sól']
# ['świeżo', 'zmielony', 'pieprz']
# ['150', 'g', 'filetu', 'z', 'dorsza']
# ['1', 'łyżka', 'roztopionego', 'masła']
# ['125', 'g', 'makaronu', 'pszennego', 'z', 'czarnym', 'sezamem']
# ['80', 'ml', 'śmietanki', 'kremówki']
# ['skórka', 'starta', 'z', '1', 'cytryny']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['garść', 'rukoli']
# ['cząstki', 'cytryny', 'do', 'podania']
# ['1', 'opakowanie', 'zupki', 'krewetkowej', 'w', 'kubku']
# ['150ml', 'mleczka', 'kokosowego']
# ['owoce', 'lychee', '(wg', 'uznania)']
# ['1', 'opakowanie', 'zupki', 'Shin', 'Ramyun']
# ['1', 'opakowanie', 'sosu', 'serowego', 'do', 'nachosów']
# ['sos', 'do', 'salsy']
# ['100g', 'sera', 'mozzarella']
# ['50g', 'boczku']
# ['30g', 'cebuli']
# ['50g', 'kiełek']
# ['1', 'łyżeczka', 'kremu', 'balsamicznego']
# ['2', 'paczki', 'zupki', 'Neoguri', '(ostra', '/', 'łagodna)']
# ['1', 'szklanka', 'suszonych', 'krewetek']
# ['60g', 'szpinaku']
# ['1/2', 'zielonej', 'cebuli']
# ['2', 'łyżeczki', 'pasty', 'sojowej']
# ['2-3', 'łyżeczki', 'rozdrobnionego', 'czosnku']
# ['6', 'szklanek', 'wody']
# ['jasny', 'sos', 'sojowy']
# ['0,5', 'szklanki', 'mąki', 'z', 'ryżu', 'kleistego']
# ['0,5', 'szklanki', 'zimnej', 'wody']
# ['2', 'łyżki', 'cukru']
# ['1', 'łyżka', 'słodkiego', 'kakao']
# ['tabliczka', 'czekolady', 'o', 'dużej', 'zawartości', 'kakao', '(60%', 'lub', 'więcej)']
# ['1/3', 'szklanki', 'śmietany', 'kremówki']
# ['2', 'łyżki', 'masła']
# ['3', 'jajka']
# ['1/2', 'łyżeczki', 'soli']
# ['1', 'łyżeczka', 'cukru']
# ['2', 'garści', 'cebulki', 'dymki,', 'posiekanej']
# ['1/2', 'marchewki,', 'drobno', 'pokrojonej']
# ['3', 'łyżki', 'oleju']
# ['3', 'łyżki', 'naturalnego', 'jogurtu', 'lub', 'majonezu']
# ['1', 'łyżka', 'sosu', 'chili', 'ostrego']
# ['1', 'kg', 'kapusty', 'pekińskiej']
# ['2', 'średnie', 'cebulę']
# ['pół', 'pęczka', 'szczypiorku']
# ['200g', 'soli']
# ['250ml', 'wody']
# ['Zaprawa:']
# ['30g', 'płatków', 'chili']
# ['3', 'duże', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'startego', 'imbiru']
# ['1', 'łyżka', 'jasnego', 'sosu', 'sojowego']
# ['½', 'łyżki', 'sosu', 'rybnego']
# ['1', '½', 'łyżki', 'cukru']
# ['2', 'łyżki', 'prażonych', 'nasion', 'białego', 'sezamu']
# ['1', 'szklanka', 'ciepłego', 'mleka']
# ['2', 'szklanki', 'mąki']
# ['2', 'łyżki', 'cukru']
# ['2', 'łyżeczki', 'suszonych', 'drożdży']
# ['szczypta', 'soli']
# ['1', 'łyżka', 'oleju']
# ['brązowy', 'cukier']
# ['parę', 'łyżek', 'posiekanych', 'orzeszków', '(włoskich,', 'laskowych', 'lub', 'ziemnych)']
# ['1', 'łyżeczka', 'cynamonu']
# ['1', 'opakowanie', 'zupki', 'Chapaghetti']
# ['1', 'opakowanie', 'zupki', 'Neoguri', '(ostra', '/', 'łagodna)']
# ['6', 'szklanek', 'wody', '(ok.', '1,1l)']
# ['340', 'g', 'tofu']
# ['200', 'g', 'gorzkiej', 'czekolady']
# ['1/2', 'szklanki', 'wody']
# ['1/2', 'szklanki', 'cukru']
# ['dodatki', 'smakowe', 'np.', '1', 'łyżeczka', 'ekstraktu', 'z', 'wanilii,', '1', 'łyżka', 'likieru', 'pomarańczowego,', '1/3', 'łyżeczki', 'cynamonu,', 'szczypta', 'ostrej', 'papryki']
# ['45', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['25', 'ml', 'świeżego', 'soku', 'z', 'limonki']
# ['30', 'ml', 'syropu', 'cukrowego']
# ['8-10', 'liście', 'tajskiej', 'bazylii']
# ['"kropla', 'wody"']
# ['20', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['30', 'ml', 'syropu', 'z', 'lychee']
# ['50', 'ml', 'wina', 'musującego']
# ['opcjonalnie:', 'szczypta', 'gazowanego', 'napoju', 'cytrynowego']
# ['45', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['15', 'ml', 'syropu', 'cynamonowego']
# ['60', 'ml', 'soku', 'pomarańczowego']
# ['60', 'ml', 'czerwonego', 'wina']
# ['"kropla', 'limonki"']
# ['150-200ml', 'Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['80ml', 'tequili']
# ['80ml', 'likieru', 'pomarańczowego', 'triple', 'sec']
# ['sok', 'z', '1/2', 'limonki']
# ['1', 'łyżka', 'cukru']
# ['*dodatkowo', '2', 'łyżeczki', 'cukru', 'do', 'dekoracji']
# ['kilka', 'kostek', 'lodu']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['cukier']
# ['125', 'ml', 'spirytusu', '95%']
# ['500ml', 'wody', 'kokosowej']
# ['2', 'szt.', 'limonki']
# ['2', 'szt.', 'grejpfruta', 'czerwonego']
# ['syrop', 'z', 'agawy']
# ['1', 'szt.', 'mango']
# ['1/2', 'melona']
# ['świeża', 'mięta']
# ['lód']
# ['rabarbar', '4', 'łodygi']
# ['woda', '1', 'litr']
# ['cukier', 'palmowy', '50', 'g']
# ['cytryna', '1⁄2', 'sztuki']
# ['melisa']
# ['lód']
# ['200g', 'ananasa', '(obranego', 'i', 'pokrojonego', 'w', 'kostkę)']
# ['1', 'dojrzałe', 'mango']
# ['100-150g', 'truskawek']
# ['100', 'ml', 'wody', 'kokosowej', 'z', 'mango']
# ['kostki', 'lodu', '(opcjonalnie)']
# ['200ml', 'wody', 'kokosowej', 'z', 'ananasem']
# ['100ml', 'mleka']
# ['4', 'plastry', 'ananasa']
# ['1', 'łyżeczka', 'kakao']
# ['2', 'limonki']
# ['2', 'łyżki', 'stołowe', 'gruboziarnistego', 'cukru', 'lub', 'soli']
# ['2', 'szklanki', 'puree', 'z', 'mango']
# ['1', '1/2', 'szklanki', 'Tequili']
# ['1', '1/2', 'szklanki', 'likieru', 'Triple', 'Sec']
# ['1/4', 'szklanki', 'cukru']
# ['40cl', 'czystej', 'wódki']
# ['sok', 'z', '1/2', 'limonki']
# ['Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['grenadina']
# ['1', 'banan']
# ['1', 'owoc', 'z', 'granatu']
# ['200', 'ml', 'wody', 'kokosowej', 'z', 'granatem']
# ['30', 'ml', 'ciemnego', 'rumu', 'lub', 'whisky']
# ['1', 'limonka']
# ['150', 'ml', 'Rubicon', 'Deluxe', 'Napój', 'Guawa']
# ['kilka', 'kostek', 'lodu']
# ['gazowana', 'woda', 'mineralna']
# ['2', 'szklanki', 'soku', 'ananasowego']
# ['1', 'szklanka', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['Sok', 'z', '1/2', 'pomarańczy']
# ['Sok', 'z', '1/2', 'limonki']
# ['1', 'cząstka', 'limonki']
# ['45ml', 'Rumu', 'Malibu']
# ['45ml', 'napoju', 'Rubicon', 'Deluxe', 'Lychee']
# ['45ml', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['1', 'cząstka', 'limonki']
# ['45ml', 'wino', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['2', 'łyżeczki', 'brązowego', 'cukru']
# ['8', 'liści', 'mięty']
# ['1/2', 'limonki']
# ['kruszony', 'lód']
# ['100-150ml', 'gazowanej', 'wody', 'mineralnej']
# ['15ml', 'Wina', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['30ml', 'czystej', 'wódki']
# ['15ml', 'soku', 'z', 'limonki']
# ['140ml', 'Wina', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['60ml', 'ginu']
# ['3', 'dojrzałe', 'banany']
# ['250ml', 'wody', 'kokosowej']
# ['1/2', 'cytryny']
# ['150g', 'świeżego', 'ananasa']
# ['250ml', 'wody', 'kokosowej']
# ['limonka']
# ['kilka', 'listków', 'mięty']
# ['lód']

# %%
jednostki = [
    'łyżeczki',
    'łyżki',
    'szklanki',
    'szczypta',
    'ząbek',
    'garść',
    'l',
    'ml',
    'g',
    'kawałki',
    'puszka',
    'opakowanie',
    'karton',
    'filiżanka',
    'gałązka',
    'cząstka',
    'liści',
    'plastry',
    'sztuk'
]
nie_jednostki = [
    'jogurtu',
    'owoców',
    'banany',
    'ostrej',
    'czerwonej',
    'piersi',
    'szparagów',
    'kapustka',
    'cukier',
    'świeżego',
    'dojrzałe',
    'Rumu',
    'dojrzałe',
    'czystej',
    'smakowe',
    'tequili',
    'limonki'
]
jednostki = Sentence(" ".join(jednostki))
nie_jednostki = Sentence(" ".join(nie_jednostki))
emb.embed(jednostki)
emb.embed(nie_jednostki)
# Out:
# [Sentence: "jogurtu owoców banany ostrej czerwonej piersi szparagów kapustka cukier świeżego dojrzałe Rumu dojrzałe czystej smakowe tequili limonki" - 17 Tokens]

# %%
X_jed = torch.cat([j.embedding for j in jednostki]).reshape(19,300)
X_njed = torch.cat([j.embedding for j in nie_jednostki]).reshape(17,300)

# %%
def knn(Y):
    mask = Y.norm(dim=1) != 0

    cos_sim_jed = X_jed @ Y[mask,:].T / (X_jed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)
    cos_sim_njed = X_njed @ Y[mask,:].T / (X_njed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)

    ret = torch.zeros(Y.shape[0], dtype=torch.bool).to(torch.device('cuda'))

    ret[mask] = (cos_sim_jed.max(0)[0] > cos_sim_njed.max(0)[0]) & (cos_sim_jed.max(0)[0] > 0.5)
    return ret

# %%
def sentenceToMat(s):
    s = Sentence(s)
    emb.embed(s)
    r = torch.cat([i.embedding for i in s])
    return r.reshape(int(r.shape[0]/300), 300)

# %%
knn(sentenceToMat('1 łyżka bezalkoholowy z guawą i imbirem mega'))
# Out:
# tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')

# %%
for d in data:
    for i in d['ingredients']:
        knn(sentence)
# Out:
# tensor([[ 0.2346,  0.2216,  0.0498,  ...,  0.0324, -0.0897,  0.1845],
#         [-0.1335,  0.2546,  0.0863,  ...,  0.0548, -0.0453,  0.2652],
#         [-0.3744, -0.0344, -0.4256,  ...,  0.0160,  0.0595,  0.1967],
#         [-0.1382, -0.0861, -0.0652,  ..., -0.0801, -0.2138, -0.2443],
#         [-0.4339,  0.4223, -0.4476,  ..., -0.1537,  0.2591,  0.2551],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.0938,  0.1546,  0.1199,  ...,  0.0672, -0.1122,  0.0197],
#         [-0.2510, -0.3749, -0.4399,  ..., -0.1340,  0.1896,  0.3422],
#         ...,
#         [ 0.0420,  0.3535,  0.0200,  ..., -0.1521,  0.1627,  0.0068],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# tensor([[ 0.2346,  0.2216,  0.0498,  ...,  0.0324, -0.0897,  0.1845],
#         [-0.2585, -0.0234,  0.3021,  ..., -0.2089, -0.2373,  0.1062],
#         [-0.0214,  0.1023, -0.3503,  ..., -0.4848, -0.2072,  0.0522],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# tensor([[ 2.3462e-01,  2.2162e-01,  4.9802e-02, -7.7868e-01,  3.9490e-01,
#           3.1159e-01,  2.3989e-01, -3.1720e-01,  2.8903e-01, -9.8343e-02,
#           2.0729e-01,  2.7700e-01, -2.5799e-01, -9.9531e-02,  2.5768e-02,
#           5.9690e-01,  3.0987e-01, -1.4581e-01, -2.1489e-01, -1.4865e-01,
#           4.8954e-01,  1.6712e-01, -4.3692e-01, -2.1794e-01, -2.5761e-01,
#           1.4157e-01,  2.1723e-01,  2.5251e-02, -1.0280e-02, -1.2354e-01,
#          -1.4962e-01,  3.9082e-01, -2.6389e-01, -7.9428e-02, -4.8509e-02,
#           3.7556e-02, -2.4551e-01,  9.0713e-02,  9.7563e-03,  2.1869e-01,
#           1.7356e-01,  8.1598e-03,  4.5689e-01, -3.4847e-01, -1.1041e-01,
#          -2.1824e-01, -8.7593e-02,  1.7100e-01, -5.2089e-01, -1.7557e-01,
#          -1.7977e-01, -2.3295e-01, -4.2326e-02,  2.1405e-01,  4.3717e-02,
#          -3.2047e-02, -7.6352e-02, -1.3669e-01,  2.7131e-01,  7.6224e-02,
#           2.2803e-01, -7.0010e-02, -3.8845e-02, -2.2205e-01, -2.2849e-01,
#          -3.3177e-01,  5.5544e-01,  1.2799e-02, -2.5422e-01, -1.7634e-01,
#           1.6436e-01, -4.0349e-02,  8.3237e-02, -3.0872e-01,  3.5638e-01,
#          -3.5657e-02, -1.3609e-01,  1.3013e-01,  1.7508e-01,  9.3749e-02,
#          -1.1069e-01,  4.1609e-01, -2.2712e-01,  8.2808e-02,  8.4315e-02,
#           1.9634e-01, -1.6421e-01, -1.6542e-01,  1.6629e-01,  1.6235e-01,
#          -2.1404e-01, -7.0381e-02, -3.0032e-01,  3.1909e-02, -7.3139e-02,
#           4.6755e-02,  2.7252e-01,  1.7328e-01, -3.7633e-02,  2.2275e-02,
#           3.3120e-01, -9.9048e-02, -1.8356e-01,  1.3191e-01,  3.6949e-01,
#          -1.3385e-01, -9.6904e-03, -5.5156e-01,  1.1778e-01, -8.2773e-02,
#          -2.8476e-02, -3.6396e-01, -8.0465e-02,  1.5396e-01,  1.7516e-01,
#           2.6339e-01, -2.7008e-01, -3.2341e-01, -5.4439e-01,  6.4581e-02,
#          -9.4686e-02, -9.2664e-02, -1.0234e-01,  1.9848e-01, -1.1466e-01,
#           1.2556e-01,  1.9115e-01,  2.0494e-01,  2.5525e-01,  2.4035e-02,
#           2.3401e-01,  1.9943e-01,  3.7365e-01,  1.7182e-01, -4.5736e-01,
#          -3.1672e-02, -2.2858e-01, -3.9894e-02, -2.0080e-02, -2.0222e-01,
#           7.5969e-02, -1.1025e-01,  1.1688e-03,  7.8405e-01, -8.0727e-02,
#           2.1774e-01, -9.2607e-02, -1.8956e-01,  2.5109e-01, -6.0107e-02,
#          -8.4754e-02, -2.5160e-01, -3.1545e-02, -4.3152e-02,  5.2665e-02,
#          -9.4511e-02, -1.8625e-01,  3.0572e-01, -4.8146e-01,  5.9002e-02,
#          -1.9052e-01, -3.9904e-01,  9.6515e-02,  2.1740e-01,  1.2612e-02,
#           4.5428e-02, -1.4274e-01,  5.4771e-02,  1.4055e-02,  5.7669e-02,
#           2.8166e-01, -1.8463e-02,  1.0727e-01, -1.5893e-01,  2.1191e-01,
#          -4.5214e-01,  3.0519e-01, -4.8025e-01,  5.5674e-01,  4.4831e-02,
#           2.4647e-01, -6.4495e-01, -1.4995e-01,  2.8625e-02,  1.2789e-01,
#          -8.8031e-02, -1.9531e-01, -2.6204e-01, -3.4492e-02,  1.1981e-01,
#           5.5794e-02,  2.1526e-03,  2.9217e-02, -7.3336e-02, -4.7284e-01,
#           6.0268e-03, -1.4729e-01, -1.5919e-01,  3.1733e-01, -4.2633e-03,
#           1.1039e-01, -2.2598e-01, -1.2487e-01,  4.1026e-01, -6.3621e-03,
#           1.3273e-02,  4.3078e-01,  6.7443e-01,  4.0151e-01, -2.9584e-01,
#          -2.3929e-01,  2.2743e-02,  1.0788e-01,  1.0407e-01,  1.8980e-01,
#           2.5857e-01,  3.4096e-02,  3.9594e-02,  3.1583e-01, -4.7217e-01,
#          -4.4918e-01,  6.1491e-02, -2.9008e-01,  1.3985e-01, -2.8827e-01,
#          -2.5892e-02,  1.7242e-01,  6.0120e-02,  2.8929e-01, -8.9458e-03,
#          -2.9642e-01,  1.9988e-01, -9.5990e-02, -4.0580e-02,  5.8906e-02,
#           1.4481e-01,  1.4340e-01,  3.4325e-01, -4.2738e-02,  3.4823e-01,
#          -2.0769e-01, -2.5746e-01, -6.2691e-03, -5.2271e-03,  4.4172e-01,
#           9.6180e-02,  3.9896e-02, -3.8725e-02,  2.2070e-01, -2.0248e-01,
#          -1.3319e-01, -3.6416e-01, -6.2901e-02, -3.3789e-01,  4.9122e-01,
#           3.2188e-01, -1.7031e-01,  1.1599e-01, -2.3554e-01,  3.2020e-01,
#           9.1068e-02,  5.7802e-02,  2.2681e-01, -1.6334e-01, -2.1520e-01,
#          -1.0419e-01,  1.6292e-01,  8.7218e-02,  2.2012e-01, -6.5802e-02,
#          -4.6124e-01,  9.6348e-02,  5.8245e-01, -8.9078e-02, -6.5155e-03,
#           1.5744e-01,  3.2005e-01, -7.2661e-02,  1.6951e-01, -1.7694e-01,
#           2.9776e-01, -2.7446e-01,  3.8068e-01, -2.4589e-01,  2.0477e-01,
#           8.8016e-03,  2.1690e-01,  2.9831e-01,  1.4863e-01,  6.7528e-02,
#           2.2580e-01,  4.3857e-01,  9.4968e-02, -2.4837e-02,  6.1711e-03,
#           4.0849e-02,  1.5239e-01,  3.2432e-02, -8.9681e-02,  1.8451e-01],
#         [-1.3346e-01,  2.5460e-01,  8.6335e-02, -1.0030e+00,  3.8913e-01,
#           2.4820e-01, -3.6280e-01, -1.7185e-01,  1.0385e-02,  3.7950e-01,
#          -2.6873e-01,  2.9899e-01,  3.0313e-01,  5.5610e-01,  8.4350e-03,
#           1.9779e-01,  4.5578e-01,  2.5655e-02, -3.3979e-01,  4.4790e-02,
#           1.5553e-01, -2.5254e-01, -2.0832e-01, -3.9133e-01, -1.8415e-01,
#          -9.3706e-03, -2.7010e-01,  2.2198e-01, -1.7462e-01,  2.9740e-01,
#          -3.3338e-03, -2.7789e-02,  5.0093e-01, -4.4790e-01,  1.7594e-01,
#           4.3039e-01,  1.9778e-01,  7.7273e-02, -2.1580e-02,  4.2063e-01,
#          -4.0755e-01,  1.1495e-01, -2.4263e-01, -8.0403e-01,  3.4725e-01,
#          -4.3673e-01,  7.9651e-02, -5.8211e-02, -4.6302e-02, -6.9428e-01,
#           7.6525e-02,  3.8970e-01,  1.8716e-01, -1.1853e-01, -2.5494e-02,
#          -2.1162e-01, -2.2257e-01, -5.1479e-01,  4.1455e-01,  1.8146e-01,
#           9.6649e-02, -3.3013e-02, -7.0691e-02, -7.6050e-02,  5.8469e-01,
#          -4.2669e-01, -1.0960e-01,  6.3864e-01, -3.9582e-01,  2.2880e-01,
#          -6.1430e-02, -1.3847e-01,  2.0503e-01, -3.1842e-01,  3.9993e-02,
#           2.8167e-01, -4.9841e-01,  9.4225e-02, -8.7299e-02,  3.8570e-01,
#           2.4412e-01, -3.3757e-01, -5.6438e-02, -8.5845e-02, -2.1281e-01,
#          -3.1915e-01,  3.2800e-01,  9.3075e-02,  4.3390e-02,  3.5072e-01,
#           3.2963e-01,  2.1970e-01,  3.2787e-02, -4.2185e-01,  2.5937e-01,
#           6.5142e-01,  2.4151e-02,  3.7216e-02,  3.1359e-01, -2.4065e-01,
#          -6.2681e-01,  1.3773e-01, -4.1689e-02, -1.0329e-01,  2.7485e-01,
#          -5.5885e-01, -1.2589e-01, -1.4680e-01,  8.0678e-01, -4.2878e-01,
#           7.0787e-02,  1.6877e-01,  1.7027e-01,  4.8500e-02, -9.3247e-02,
#           3.7366e-01, -3.0623e-01,  1.2873e-02,  2.8593e-01, -3.4532e-02,
#           1.6430e-01, -4.1867e-01,  2.9649e-01,  1.0322e-01,  3.5445e-01,
#           4.2231e-01, -3.1474e-01, -2.1861e-01,  3.7684e-01,  5.5689e-02,
#           3.1750e-01, -1.3833e-01,  2.6224e-02, -1.6484e-01, -7.6845e-02,
#          -1.9513e-01,  2.6859e-02,  2.0654e-02,  9.6678e-02, -1.2944e-01,
#           2.4563e-01,  7.1144e-02, -1.1039e-01,  1.6344e-02, -2.6050e-01,
#           8.2105e-01,  3.0363e-01, -2.2360e-02,  2.9223e-01, -6.3371e-01,
#          -2.1958e-01,  2.4598e-01,  2.4497e-01,  5.5439e-01, -5.7600e-01,
#           2.9660e-01,  2.2496e-01,  1.4313e-01,  2.7111e-01, -3.9913e-02,
#          -5.3874e-01,  1.4625e-01,  1.2862e-01,  3.8422e-01, -2.2619e-02,
#          -5.5625e-01, -3.4748e-01, -4.5233e-02, -1.4661e-02, -6.4186e-01,
#           2.3517e-01,  3.8939e-01, -5.1717e-01,  6.0737e-01,  2.3576e-01,
#          -3.2965e-02,  1.4792e-01, -3.9478e-02, -4.4010e-01, -8.5812e-02,
#           4.4836e-01, -5.0008e-01,  4.7797e-01, -9.2002e-02,  3.6426e-01,
#           8.7593e-02,  3.2947e-01,  3.1314e-01, -1.3342e-01, -9.4119e-02,
#          -2.1247e-02, -2.0623e-01, -2.2843e-01,  3.3524e-01, -1.2781e-01,
#          -1.0653e-01,  1.0385e-02, -6.3187e-01,  2.8028e-01,  6.2510e-02,
#          -2.6931e-01, -4.1414e-01,  4.3695e-01, -6.9939e-01, -3.7109e-01,
#           3.5429e-01,  5.0037e-02, -2.6744e-02,  6.9701e-02,  1.3340e-01,
#           1.3767e-02,  1.5161e-01, -1.4214e-01,  6.3754e-01, -3.6410e-01,
#           3.1500e-01, -1.9453e-01,  4.7790e-01,  1.9378e-01, -1.9708e-01,
#          -2.8619e-01,  3.9923e-02, -3.6222e-01,  3.9231e-01,  3.9846e-01,
#           6.1028e-02, -1.0471e-01,  2.3224e-01,  4.8602e-01, -2.2482e-01,
#          -1.6227e-01, -3.1442e-01,  5.4166e-01,  1.1231e-01, -5.4100e-02,
#           2.2361e-01,  5.2806e-02,  4.2068e-02, -2.7583e-02,  2.2350e-01,
#          -3.3421e-01, -4.3100e-01, -4.9848e-02,  1.0157e-01,  3.1793e-01,
#          -3.1863e-01, -1.8927e-02,  5.4795e-01,  5.8741e-01,  3.0141e-01,
#          -1.2372e-02,  1.8586e-01, -1.9009e-01,  1.6603e-01, -1.6896e-01,
#           2.6691e-01, -3.8225e-02,  1.8441e-01,  2.7537e-01, -2.0517e-01,
#           2.4979e-01,  1.5502e-01, -4.5162e-01,  1.3385e-01, -2.7122e-01,
#          -3.2326e-01, -1.0875e-01, -2.5072e-01, -1.1322e-01,  1.9121e-01,
#           2.1674e-01, -3.8452e-01,  6.6338e-01,  5.9964e-01, -3.3132e-01,
#           5.0235e-01, -9.7589e-02,  3.3852e-01, -1.0774e-01,  1.3536e-01,
#          -4.9262e-01, -9.2273e-02, -5.1123e-02,  3.1916e-01, -4.0062e-01,
#           1.1356e-01, -7.5975e-04,  1.3689e-01, -3.4795e-01, -6.9984e-02,
#          -6.1194e-01,  1.9122e-01,  3.9273e-01, -8.0492e-02, -1.7855e-02,
#           7.6783e-02,  1.0297e-01,  5.4842e-02, -4.5281e-02,  2.6515e-01],
#         [-2.8437e-01,  1.2910e-01, -9.2801e-02, -9.3346e-01,  3.5688e-01,
#           2.4402e-01,  5.4172e-02, -2.3846e-01, -7.0265e-01,  1.6932e-01,
#           1.6927e-01, -3.6146e-01, -2.0015e-01,  1.6217e-01, -3.6187e-02,
#           4.3713e-02,  5.4693e-01, -5.1408e-01,  5.0954e-02,  1.6943e-01,
#           3.7982e-01,  1.2005e-01,  1.3549e-03, -5.1792e-01, -5.6252e-02,
#          -7.9332e-02, -1.8463e-01, -4.5272e-01, -2.5282e-01, -2.8349e-01,
#           2.3760e-01,  1.1472e-01,  5.3089e-02, -2.3119e-01,  4.1828e-02,
#          -2.4108e-01, -3.1289e-01,  2.7491e-01,  3.4016e-01,  2.9268e-01,
#          -2.3497e-01,  1.8241e-01, -6.1065e-02, -3.6226e-01,  6.0340e-01,
#          -1.9658e-01,  9.2981e-02,  6.5694e-02,  8.5441e-02, -2.7006e-01,
#           3.4742e-01,  2.1516e-01,  3.0761e-01, -3.1523e-02,  1.9426e-01,
#           6.0204e-02, -2.6947e-01, -7.3184e-01,  4.5499e-01,  5.1531e-01,
#          -1.8087e-01, -3.3580e-01, -1.5348e-01, -7.4343e-01, -1.6481e-01,
#          -1.6554e-01,  2.7288e-02,  4.1094e-01, -3.8463e-01,  1.2818e-01,
#           1.6650e-01,  3.2643e-01,  3.2669e-02, -1.4369e-01,  3.3218e-01,
#           4.9355e-01, -3.7535e-01, -1.6599e-01,  4.8874e-01,  4.7954e-01,
#           2.2450e-01, -1.6582e-01,  1.1040e-01, -7.5851e-02,  3.9057e-01,
#          -5.2055e-01,  3.4989e-01,  4.1846e-01,  4.2179e-02, -3.3278e-02,
#          -2.1897e-01, -6.1175e-02, -3.0184e-01, -5.5402e-02,  5.3530e-01,
#           3.9674e-01, -3.8119e-01, -2.5553e-01,  3.9402e-01, -6.4952e-01,
#          -3.9702e-01,  1.4285e-01,  4.7143e-03,  1.2555e-01,  6.5425e-02,
#          -2.9760e-01, -2.8515e-01, -3.8351e-03,  3.7689e-01, -3.6152e-01,
#           3.9414e-01, -1.9389e-01, -2.1752e-01,  1.0954e-01, -8.5284e-02,
#           2.4353e-01,  1.1239e-02, -2.2688e-01,  6.9950e-02, -1.7050e-01,
#           3.5691e-01, -2.4552e-01,  1.3312e-01,  1.8303e-01,  1.2186e-01,
#           4.6281e-01,  5.2586e-01,  2.0168e-02,  3.2351e-01, -9.6694e-02,
#           3.9013e-01, -3.9035e-01,  2.0860e-01, -9.6356e-02,  1.4678e-01,
#          -1.3106e-01, -2.5088e-01, -1.6953e-03,  3.3137e-01, -2.2310e-01,
#           6.2493e-01,  4.4742e-01,  2.5121e-01,  1.3023e-01, -4.1611e-01,
#           3.6642e-01, -1.2144e-01, -2.0687e-01,  4.3445e-01, -4.2051e-02,
#           6.2502e-01,  1.4489e-01, -1.5176e-01,  4.2520e-01, -3.4383e-01,
#          -6.8701e-02, -2.5075e-01, -1.3282e-02,  2.6499e-01, -9.1483e-02,
#          -2.8525e-01, -2.1888e-01,  2.9014e-01,  6.7623e-02,  1.8852e-01,
#          -1.5752e-01, -4.0789e-01,  6.8135e-01, -2.8170e-01, -2.6873e-01,
#           1.5426e-02, -5.8604e-01,  1.8991e-01,  4.8824e-01,  1.3850e-01,
#           5.1900e-02,  1.8982e-01,  6.1056e-01,  4.5927e-01,  7.3605e-02,
#           1.9158e-02, -6.9160e-02,  1.0001e-01,  2.4171e-01,  1.3120e-01,
#           7.7640e-02,  5.2676e-01, -3.3479e-01,  3.0977e-03,  3.5885e-01,
#           1.1468e-01, -2.4938e-01, -3.4875e-01,  3.1189e-01,  3.2269e-01,
#          -5.9135e-02,  1.9599e-01, -8.6392e-01,  1.8920e-01, -7.9821e-02,
#          -7.6231e-02, -1.2673e-01,  7.8209e-01, -5.2779e-01, -8.9613e-02,
#           1.3907e-01,  4.4751e-01,  4.9407e-01,  9.6136e-02,  1.8275e-01,
#           5.0015e-01,  2.4642e-01,  7.6833e-04,  3.5383e-02, -2.1333e-01,
#          -1.4726e-01, -3.4832e-01, -2.6325e-01,  6.3523e-02,  1.1455e-02,
#          -1.4047e-01,  9.3232e-02, -4.1569e-01,  4.2536e-01,  4.1614e-01,
#           3.7292e-01, -2.4881e-01,  2.5041e-01,  2.4901e-01, -4.6924e-01,
#           1.6863e-02,  5.9200e-02, -5.6343e-02,  3.1637e-01, -2.7747e-01,
#          -1.8834e-01, -2.1209e-02,  9.2441e-02, -2.3498e-01,  1.0451e-01,
#          -1.7308e-01,  1.2269e-01,  5.5873e-02,  7.1388e-02,  2.3749e-01,
#          -8.1153e-01, -3.4907e-01,  2.5968e-01,  4.7518e-01, -3.3298e-01,
#          -8.4228e-02,  2.7419e-01,  2.4894e-01,  4.0038e-01, -3.9270e-01,
#           7.4290e-02, -9.7331e-02, -2.7348e-01, -2.1534e-01,  1.4624e-01,
#           2.8711e-01,  9.4427e-02,  7.9029e-02,  3.3656e-01,  1.4117e-01,
#          -1.0743e-01, -2.2576e-01, -2.2762e-01, -4.3854e-01, -1.6428e-02,
#           6.9341e-01, -1.5176e-01,  6.9826e-01, -3.6558e-02, -5.7719e-01,
#           5.0912e-01,  9.1409e-02,  6.5384e-02,  2.2414e-01,  3.1141e-01,
#          -3.3007e-01, -6.8711e-01,  4.1243e-01,  3.3258e-02, -3.2885e-01,
#           2.7564e-01, -5.6593e-01,  3.3960e-02, -5.0833e-01, -3.4225e-01,
#          -7.6005e-01,  1.8989e-01,  1.0623e+00, -1.1787e-04, -1.6368e-01,
#          -1.4935e-01,  1.8600e-01, -1.5509e-02,  4.9594e-01, -1.8169e-01]],
#        device='cuda:0')

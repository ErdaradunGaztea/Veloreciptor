# %%
import pandas as pd
import json
import flair
from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentPoolEmbeddings, Sentence
import torch
import re
import numpy as np

# %%
cuda = torch.device('cuda')
cpu = torch.device('cpu')

# %%
device = cpu

# %%
flair.device = device

# %%
emb = WordEmbeddings('pl')

# %%
with open("recipes_pretty.json") as file:
    data = json.load(file)

# %%
data
# Out:
# [{'link': ['https://kkpolska.pl/przepis/98/tropikalny_drink_bezalkoholowy_z_guawa_i_imbirem_.html'],
#   'title': ['Tropikalny drink bezalkoholowy z guawą i imbirem '],
#   'photo_link': ['images/przepisy/guawa_imbir.jpg'],
#   'ingredients': [['3 łyżeczki soku z limonki \r'],
#    ['1/2 szklanki napoju Rubicon Deluxe Guawa \r'],
#    ['2 łyżki miodu \r'],
#    ['2 łyżeczki imbiru ']],
#   'preparation': ['Wszystkie składniki umieścić w blenderze i zmiksować. Tropikalny drink bardzo dobrze smakuje schłodzony. ']},
#  {'link': ['https://kkpolska.pl/przepis/38/tropikalne_smoothie_z_lychee.html'],
#   'title': ['Tropikalne smoothie z lychee'],
#   'photo_link': ['images/przepisy/smoothie_lychee.jpg'],
#   'ingredients': [['300ml jogurtu naturalnego 2%\r'],
#    ['10 owoców lychee\r'],
#    ['2 banany\r'],
#    ['200g ananasa\r'],
#    ['1 szklanka kruszonego lodu\r'],
#    ['miód']],
#   'preparation': ['1. Banany, lychee, ananasa pokroić na mniejsze kawałki.\r\n2. Owoce zalać jogurtem, dodać kruszony lód.\r\n3. Całość zmiksować blenderem do połączenia składników.\r\n4. Opcjonalnie do smaku dodać miód']},
#  {'link': ['https://kkpolska.pl/przepis/2/smoothie_z_owocami_mango_i_woda_kokosowa.html'],
#   'title': ['Smoothie z owocami mango i wodą kokosową'],
#   'photo_link': ['images/przepisy/indonezjamango_1.png'],
#   'ingredients': [['1 szklanka wody kokosowej\r'],
#    ['1 szklanka owoców mango (świeżych lub mrożonych)\r'],
#    ['1 obrany banan\r'],
#    ['200g jogurtu greckiego\r'],
#    ['1 łyżka cukru brązowego']],
#   'preparation': ['1. Wszystkie składniki zmiksować w blenderze. (Jeśli smoothie będzie zbyt gęste, należy dodać większą ilość wody kokosowej)']},
#  {'link': ['https://kkpolska.pl/przepis/51/smoothie_z_nasionami_chia_i_puree_z_mango.html'],
#   'title': ['Smoothie z nasionami Chia i puree z mango'],
#   'photo_link': ['images/przepisy/smoothie_chia.jpg'],
#   'ingredients': [['2 szklanki puree z mango\r'],
#    ['1/2 szklanki mleczka kokosowego\r'],
#    ['2 łyżeczki brązowego cukru\r'],
#    ['1 szklanka wody mineralnej niegazowanej\r'],
#    ['4 łyżki stołowe nasion Chia\r'],
#    ['2 łyżeczki soku z limonki']],
#   'preparation': ['1. W mikserze wymieszać wszystkie składniki podane w przepisie.\r\n2. Całość schłodzić w lodówce.\r\n\xa0\nUWAGA 1: Jeśli smoothie będzie zbyt gęste należy dodać wodę i delikatnie rozcieńczyć.\r\nUWAGA2: Jeśli smoothie będzie zbyt mało słodkie należy dodać większą ilość brązowego cukru.']},
#  {'link': ['https://kkpolska.pl/przepis/105/smoothie_truskawkowe_z_woda_kokosowa_.html'],
#   'title': ['Smoothie truskawkowe z wodą kokosową '],
#   'photo_link': ['images/przepisy/smoothie-truskawka_woda_kokosowa.jpg'],
#   'ingredients': [['100ml wody kokosowej \r'],
#    ['100g jogurtu naturalnego \r'],
#    ['1/2 mango \r'],
#    ['150g truskawek \r'],
#    ['lód ']],
#   'preparation': ['Wszystkie składniki miksujemy przy pomocy blendera na gładkie smoothie. Przelewamy do szklanki, dodajemy kostki lodu (zamiast dodawania kostek lodu smoothie można schłodzić w lodówce). ']},
#  {'link': ['https://kkpolska.pl/przepis/91/smoothie_mango_z_ananasem_i_mandarynka_.html'],
#   'title': ['Smoothie mango z ananasem i mandarynką '],
#   'photo_link': ['images/przepisy/smoothie.png'],
#   'ingredients': [['Napój Mango Rubicon Deluxe \r'],
#    ['1/2 cytryny \r'],
#    ['6 mandarynek \r'],
#    ['125g ananasa \r'],
#    ['1 szklanka soku jabłkowego ']],
#   'preparation': ['W kielichu blendera umieścić obranego i pokrojonego w kostkę ananasa, wyciśnięty sok z 1/2 cytryny oraz sok z 6 mandarynek. Następnie dodać 1 szklankę soku jabłkowego i 2 szklanki Napoju Mango Rubicon Deluxe. Wszystkie składniki zmiksować. Jeśli Smoothie będzie zbyt gęste można dodać więcej soku jabłkowego lub napoju Mango. \n*zamiast ananasa można użyć 125g melona żółtego \n*zamiast mandarynek można użyć soku z 2 pomarańczy ']},
#  {'link': ['https://kkpolska.pl/przepis/76/napoj_alkoholowy_-_azjatycka_mrozona_herbata.html'],
#   'title': ['Napój alkoholowy - Azjatycka mrożona herbata'],
#   'photo_link': ['images/przepisy/mrozona_herbata.jpg'],
#   'ingredients': [['30ml Rumu Tanduay\r'],
#    ['60ml Wina Sake - Gekkeikan Haiku\r'],
#    ['30ml syropu z trawy cytrynowej\r'],
#    ['90ml świeżo zaparzonej zielonej herbaty\r'],
#    ['kilka kostek lodu\r'],
#    ['\r'],
#    ['Dodatki do dekoracji:\r'],
#    ['imbir, mięta, cytryna']],
#   'preparation': ['1. Napełnij szklankę kostkami lodu.\r\n2. Dodaj pozostałe skłądniki\r\n3. Dobrze wymieszaj wszystkie składniki z lodem.\r\n4. Udekoruj wybranymi dodatkami.']},
#  {'link': ['https://kkpolska.pl/przepis/94/zielona_herbata_z_dodatkiem_napoju_mango_.html'],
#   'title': ['Zielona herbata z dodatkiem napoju Mango '],
#   'photo_link': ['images/przepisy/mangotea.png'],
#   'ingredients': [['200ml Rubicon Deluxe Napój Mango \r'],
#    ['100ml zielonej herbaty \r'],
#    ['kilka kostek lodu \r'],
#    ['*świeże mango i kilka listków mięty do dekoracji ']],
#   'preparation': ['Szklankę typu highball (long) napełnić lodem, dodać napój mango oraz zieloną herbatę i wymieszać. Dodać liście mięty oraz plaster świeżego mango do dekoracji. ']},
#  {'link': ['https://kkpolska.pl/przepis/54/zupa_ansungtangmyun_cioppino.html'],
#   'title': ['Zupa AnSungTangMyun Cioppino'],
#   'photo_link': {},
#   'ingredients': [['1 paczka zupy AnSungTangMyun\r'],
#    ['50g pasty do sosów Barilla Arabiata\r'],
#    ['8g bazy do zupy w proszku\r'],
#    ['100g małży z krótkimi szyjkami (4 szt.)\r'],
#    ['100g małży (4 szt.)\r'],
#    ['20g mątwy\r'],
#    ['60g krewetek (3 szt.)\r'],
#    ['2g ostrej papryczki chili (1/4 szt.)\r'],
#    ['6 pomidorków koktajlowych\r'],
#    ['1 cały ząbek czosnku\r'],
#    ['18ml białego wina\r'],
#    ['8ml oliwy z oliwek\r'],
#    ['300ml wody\r'],
#    ['natka pietruszki']],
#   'preparation': ['1. Umyj małże w słonej wodzie i ugotowuj je. Przykryj pokrywką lub umieść je w miejscu z dala od światła słonecznego.\r\n2. Usuń skórkę z pomidorów koktajlowych i pokrój je na 4 równe części, a następnie posiekaj na kawałki o grubości 2 mm.\r\n3. Umyj i pokrój ostrą papryczkę i czosnek.\r\n4. Umyj i obierz krewetki. Wytnij mątwy w rozmiarze 1,5 x 6 cm.\r\n5. Nasmaruj garnek oliwą z oliwek. Podsmaż zmiażdżony czosnek i ostrą paprykę, a następnie smaż wszystko na małym ogniu przez około 1,5 minuty (aż poczujesz zapach).\r\n6. Usmaż małże, małże krótkoszyjne, mątwe i krewetki na dużym ogniu. Gdy małże się otworzą dodaj białe wino i smaż jeszcze przez 1 minutę.\r\n7. Dodaj 2 pomidorki cherry i sos Barilla Arabiata, a następnie smaż przez kolejną minutę.\r\n8. Gdy alkohol odparuje, wlej wodę (300ml) i zagotuj. Dodaj zupę AnSungTangMyun i bazę do zupy w proszku, gotuj przez 4 minuty.\r\n9. Przelej zupę do miski i polej oliwą, \xa0następnie pokrojoną natką pietruszki.']},
#  {'link': ['https://kkpolska.pl/przepis/77/salatka_azjatycka_z_makaronem.html'],
#   'title': ['Sałatka azjatycka z makaronem'],
#   'photo_link': ['images/przepisy/salatka.jpg'],
#   'ingredients': [['200g makaronu wieloziarnistego Bali Kitchen\r'],
#    ['2 łyżki oleju arachidowego\r'],
#    ['50g fasoli czerwonej\r'],
#    ['50g liści sałaty\r'],
#    ['1/2 papryki czerwonej pokrojonej w kostkę\r'],
#    ['50g wędzonego, smażonego Tofu (w paski)\r'],
#    ['2 łyżki Mirinu\r'],
#    ['2 łyżki sosu sojowego słodkiego\r'],
#    ['1 łyżeczka imbiru w proszku\r'],
#    ['według uznania: odrobina soku z limetki / sól / pieprz']],
#   'preparation': ['1. Makaron przygotować według sposobu przyrządzania podanego na opakowaniu.\r\n2. Wszystkie składniki wymieszać razem i według gustu przyprawić solą, pieprzem i sokiem z limetki.\r\n3. Gotowe!']},
#  {'link': ['https://kkpolska.pl/przepis/148/zupa_fasolowa.html'],
#   'title': ['Zupa fasolowa'],
#   'photo_link': ['images/przepisy/fasolowa_01_0.jpg'],
#   'ingredients': [['250 g fasoli białej\r'],
#    ['500 g żeberek wieprzowych\r'],
#    ['250 g wędzonego boczku\r'],
#    ['2 marchewki\r'],
#    ['1 pietruszka\r'],
#    ['kawałek selera\r'],
#    ['3 ziela angielskie\r'],
#    ['1 listek laurowy\r'],
#    ['1 duża cebula\r'],
#    ['1 ząbek czosnku\r'],
#    ['3 - 4 ziemniaki\r'],
#    ['1 łyżka majeranku']],
#   'preparation': ['Odcedzić fasolę. Do dużego garnka włożyć pokrojone na 2 - 3 kawałki żeberka, wlać 2,5 litra wody, dodać fasolę oraz łyżeczkę soli. Zagotować, zszumować, zmniejszyć ogień i gotować pod przykryciem przez około 1 godzinę i 15 minut. Dodać 1 obraną marchewkę (drugą obrać, zetrzeć na tarce o dużych oczkach i odłożyć na później), obraną pietruszkę, kawałek korzenia selera oraz ziela angielskie i listek laurowy. Gotować przez 15 minut. Odkroić skórkę z boczku, wykroić białe chrząstki, pokroić w kosteczkę. Włożyć na patelnię i co chwilę mieszając podsmażyć na złoty kolor. Dodać pokrojoną w kosteczkę cebulę i mieszając smażyć przez 5 minut. Pod koniec dodać rozgnieciony czosnek. Przełożyć do garnka z wywarem wypłukując patelnię częścią wywaru. Do zupy dodać startą marchewkę, doprawić świeżo zmielonym pieprzem i w razie potrzeby solą. Gotować 10 minut. Ziemniaki obrać i pokroić w kosteczkę, dodać do zupy. Gotować przez 0,5 godziny. Na koniec dodać majeranek i chwilę gotować.']},
#  {'link': ['https://kkpolska.pl/przepis/111/zupa_z_pieczonego_kalafiora_i_kalarepy_z_mleczkiem_kokosowym_.html'],
#   'title': ['Zupa z pieczonego kalafiora i kalarepy z mleczkiem kokosowym '],
#   'photo_link': ['images/przepisy/zupa_kalafior_mleczko.jpg'],
#   'ingredients': [['700 g kalafiora\r'],
#    ['2 średnie ziemniaki\r'],
#    ['2 kalarepy\r'],
#    ['1 cebula\r'],
#    ['2 ząbki czosnku\r'],
#    ['kmin rzymski\r'],
#    ['kolendra\r'],
#    ['sól\r'],
#    ['pieprz\r'],
#    ['oliwa extra virgin\r'],
#    ['1 litr bulionu\r'],
#    ['250 ml mleczka kokosowego']],
#   'preparation': ['1. Piekarnik nagrzać do\xa0190 stopni C. Dużą blachę z wyłożyć papierem do pieczenia.\r\n2. Kalafiora pokroić na różyczki, ziemniaki obrać i pokroić w kosteczkę, kalarepki obrać i pokroić na kawałki, cebulę obrać i pokroić w większą kostkę, czosnek obrać i przepołowić.\r\n3. Warzywa włożyć do miski, doprawić solą, pieprzem, posypać łyżeczką kminu rzymskiego, dodać pół łyżeczki kolendry oraz skropić 2 łyżkami oliwy, wymieszać, wyłożyć na blaszkę. Piec przez\xa040 minut.\r\n5. Wszystkie upieczone warzywa włożyć do garnka, zalać gorącym bulionem i zagotować. Gotować przez około 3 minuty, następnie zmiksować z dodatkiem mleczka.\r\n6. Przelać do garnka, dodać około 2 łyżeczek kminu rzymskiego (lub więcej, zależnie od preferencji) i wymieszać. ']},
#  {'link': ['https://kkpolska.pl/przepis/12/zielona_paste_curry_z_poledwica_wolowa.html'],
#   'title': ['Zieloną pastę curry z polędwicą wołową'],
#   'photo_link': {},
#   'ingredients': [['15 ml oleju do woka Thai Pride\r'],
#    ['40 g zielonej pasty curry Thai Pride\r'],
#    ['40 ml wody\r'],
#    ['60 g bakłażana\r'],
#    ['150 g polędwicy wołowej\r'],
#    ['160 ml mleczka kokosowego Diamond\r'],
#    ['20 g liści bazylii\r'],
#    ['5 g czerwonej papryczki chili']],
#   'preparation': ['1. Polędwicę wołową pokroić w plastry i obsmażyć na rozgrzanym woku.\r\n2. Dodać zieloną pastę curry i wymieszać z mięsem.\r\n3. Następnie dodać wodę i zagotować.\r\n4. Pokroić bakłażana w plastry, dodać go do woka wraz z mleczkiem kokosowym, całość ponownie zagotować.\r\n5. Gotowe danie udekorować liśćmi bazyli oraz papryką chili.\r\n6. Danie można podawać z ryżem, makaronem ryżowym bądź z makaronem sojowym']},
#  {'link': ['https://kkpolska.pl/przepis/157/smazony_ryz_kleisty_z_kurczakiem_i_olejem_sezamowym.html'],
#   'title': ['Smażony ryż kleisty z kurczakiem i olejem sezamowym'],
#   'photo_link': ['images/przepisy/ryz-kleisty-z-kurczakiem.jpg'],
#   'ingredients': [['2 ćwiartki z kurczaka \r'],
#    ['500 g ryżu kleistego Q Rice \r'],
#    ['15 g imbiru \r'],
#    ['10 g smażonej cebuli \r'],
#    ['5 g jagód goji \r'],
#    ['2 łyżki oleju sezamowego \r'],
#    ['2 łyżki sosu sojowego \r'],
#    ['1/2 łyżeczki soli \r'],
#    ['1 łyżka oleju do smażenia \r'],
#    ['2 łyżki chińskiej wódki ryżowej / lub polskiej czystej wódki \r'],
#    ['300 ml wody ']],
#   'preparation': ['Ryż przygotować według instrukcji na opakowaniu. Umyć kurczaka, usunąć kości i zbędne żyłki tłuszczu, osuszyć ręcznikiem papierowym, następnie delikatnie naciąć mięso na całej powierzchni (od strony wewnętrznej - nie od strony skóry), w ten sposób mięso na całej powierzchni będzie równej grubości. \n* Można wykorzystać mięso z indyka, które już jest bez kości. Należy pamiętać, by mięso nie było zbyt grube. \nImbir umyć, pokroić ze skórą na bardzo cienkie plasterki. Goję wymoczyć w ciepłej wodzie. \nRozgrzać patelnię, smażyć kurczaka do uzyskania złocistego koloru (smażyć obie strony), zdjąć kurczaka z patelni i pokroić na małe kawałki. Na patelnię wlać olej do smażenia (jeśli po smażeniu\xa0 kurczaka zostało wystarczająco dużo oleju do smażenia imbiru, to nie trzeba dolewać), rozgrzać, jak olej będzie ciepły, wrzucić imbir do smażenia, w tym czasie zmniejszyć ogień i spokojnie smażyć imbir, aż uzyska złocisty kolor (to jest bardzo ważny krok, ponieważ na tym polega cała sztuka w tym daniu). Włożyć kurczaka na patelnię, dolać olej sezamowy, wymieszać dokładnie, dolać wodę, przykryć pokrywką i dusić kurczaka przez 5 minut. Następnie odkryć pokrywkę, żeby woda trochę wyparowała (jeśli okazało się, że woda całkowicie już wyparowała, trzeba dolać 3 łyżki, żeby się nie przypaliło). Dodać smażoną cebulę, wymieszać dokładnie, wlać sos sojowy, wymieszać i próbować czy potrawa jest wystarczająco słona, jeśli nie - dosolić. Dolać wódkę, wymieszać i dodać jagody goji oraz ryż kleisty ugotowany, staranie wymieszać wszystkie składniki, żeby kawałki kurczaka były równomiernie wymieszane z ryżem. ']},
#  {'link': ['https://kkpolska.pl/przepis/150/zupa_fasolowa_z_pesto.html'],
#   'title': ['Zupa fasolowa z pesto'],
#   'photo_link': ['images/przepisy/fasolowa_z_pesto02.jpg'],
#   'ingredients': [['1 szklanka fasoli\r'],
#    ['500 - 600 ml bulionu drobiowego lub jarzynowego\r'],
#    ['2 średnie marchewki, obrane i pokrojone w cienkie plasterki\r'],
#    ['1 łyżka oliwy z oliwek\r'],
#    ['1 średnia cebula, pokrojona w drobną kosteczkę\r'],
#    ['2 łyżki mąki pszennej\r'],
#    ['sól\r'],
#    ['świeżo zmielony czarny pieprz'],
#    ['\r'],
#    ['Pesto:  • garść rukoli lub bazylii\r'],
#    ['3 łyżki tartego parmezanu /lub grana padano\r'],
#    ['1 łyżeczka orzeszków pinii /lub pestek dyni\r'],
#    ['4 łyżki oliwy z oliwek extra virgin\r'],
#    ['1/2 małego ząbka czosnku\r'],
#    ['sól\r'],
#    ['pieprz']],
#   'preparation': ['W garnku zagotować 500 ml bulionu i dodać marchewkę, ugotować ją do miękkości. Na małej patelni na oliwie zeszklić cebulę, dodać mąkę i chwilę razem podsmażyć mieszając. Zdjąć z ognia i dolewać po jednej łyżce bulionu (w sumie około 10 - 15 łyżek), mieszając aż mąka się w nim rozprowadzi. Zawartość patelni wlać do garnka z bulionem i marchewką, następnie dodać\xa0 fasolkę wraz z częścią zalewy. Zupę zagotować i doprawić solą oraz pieprzem. \nPesto: Zmiksować wszystkie składniki blenderem lub utrzeć w moździerzu. \nFasolową podawać gorącą, skropioną pesto i z dodatkiem pieczywa. ']},
#  {'link': ['https://kkpolska.pl/przepis/129/zupa_z_pora_z_makaronem_udong.html'],
#   'title': ['Zupa z pora z makaronem Udong'],
#   'photo_link': ['images/przepisy/udon_pory.jpg'],
#   'ingredients': [['2 większe pory (tylko białe części) \r'],
#    ['30 dag piersi z kurczaka  \r'],
#    ['15 dag makaronu udong  \r'],
#    ['4 szklanki bulionu mięsnego \r'],
#    ['2 łyżki masła  \r'],
#    ['4 łyżki jasnego sosu sojowego  \r'],
#    ['1 łyżeczka cukru  \r'],
#    ['cytryna  ']],
#   'preparation': ['Cytrynę dokładnie wyszorować, ściąć ostrym nożem cienką skórkę i pokroić na cieniutkie paseczki. Z owocu wycisnąć sok. Pory dokładnie umyć pod bieżącą wodą i pokroić na cienkie, ukośne plasterki. Mięso kurczaka pokroić na cienkie paski. Zagotować 2 litry osolonej wody. Włożyć do niej makaron, zamieszać, doprowadzić do wrzenia i gotować 5 minut. Odcedzić, przelać zimną wodą, następnie przetrzeć dłonią. W rondlu rozgrzać masło, wrzucić pory i smażyć cały czas mieszając przez 3-4 minuty, aż się lekko zeszklą. Dodać sos sojowy, cukier i sok z cytryny. Wlać wrzący bulion, wrzucić mięso, zamieszać i gotować na średnim ogniu 10-15 minut, aż mięso i pory będą miękkie. Do ugotowanej zupy dodać makaron. Podawać ze skórką cytrynową. ']},
#  {'link': ['https://kkpolska.pl/przepis/41/wolowina_z_czosnkiem_i_pedami_bambusa.html'],
#   'title': ['Wołowina z czosnkiem i pędami bambusa'],
#   'photo_link': ['images/przepisy/wolowina_czosnek.jpg'],
#   'ingredients': [['400g chudej wołowiny\r'],
#    ['6 ząbków czosnku\r'],
#    ['250g pędów bambusa\r'],
#    ['4 łyżki ciemnego sosu sojowego\r'],
#    ['3 łyżki oleju\r'],
#    ['1 łyżka mąki ziemniaczanej\r'],
#    ['3 łyżki sezamu białego\r'],
#    ['3 łyżki szczypiorku']],
#   'preparation': ['1. Mięso opłukać, osuszyć, pokroić na cienkie paseczki.\r\n2. Czosnek obrać. 4 ząbki pokroić w cienkie plasterki, dodać do mięsa, zalać sosem sojowym, odstawić na 2 godziny. 2 pozostałe ząbki czosnku rozetrzeć.\r\n3. Rozgrzać olej na patelni, obsmażyć mięso, zmniejszyć ogień, dodać odsączone pędy bambusa, utarty czosnek, kilka łyżek wody. Dusić kilka minut.\r\n4. Mąkę wymieszać dokładnie ze szklanką wody i dodać do mięsa.\r\n5. Dusić wszystko razem kilka minut, jeśli istnieje taka potrzeba podlać niewielką ilością wody, doprawić sosem sojowym.\r\n6. Posypać uprażonymi nasionami sezamu i posiekanym szczypiorkiem.\n\xa0\nDanie podawać z ryżem lub z makaronem szklistym.']},
#  {'link': ['https://kkpolska.pl/przepis/69/zapiekany_filet_z_kurczaka_z_prazona_cebulka.html'],
#   'title': ['Zapiekany filet z kurczaka z prażoną cebulką'],
#   'photo_link': ['images/przepisy/zapiekany.jpg'],
#   'ingredients': [['1 podwójny filet z kurczaka\r'],
#    ['5 łyżek oleju\r'],
#    ['200g prażonej cebulki\r'],
#    ['przyprawa do drobiu\r'],
#    ['przyprawy: sól, pieprz, papryka']],
#   'preparation': ['1. Filet z kurczaka dokładnie umyć i osuszyć. Podzielić na mniejsze kawałki (według uznania).\r\n2. Mięso rozbić delikatnie tłuczkiem owiniętym w folie.\r\n3. Rozbite mięso połączyć ze wszystkimi wybranymi przyprawami z obu stron, przykryć folią spożywczą i odstawić na bok.\r\n4. Na duży talerz wlać olej. Stronę, która ma być na wierzchu namoczyć obficie w oleju.\r\n5. Blachę do pieczenia wyłożyć papierem do pieczenia i ułożyć na niej mięso suchą stronę do dołu.\r\n6. Wierzch mięsa posypać obficie cebulką prażoną.\r\n7. Blachę wstawić do nagrzanego do 180 stopni piekarnika i zapiekać przez ok. 30 minut.\n\xa0\nUWAGA! Filet znakomieci smakuje z sałatką i frytkami.']},
#  {'link': ['https://kkpolska.pl/przepis/160/ryz_cytrynowo_-_mietowy_na_mleku_z_truskawkami_.html'],
#   'title': ['Ryż cytrynowo - miętowy na mleku z truskawkami '],
#   'photo_link': ['images/przepisy/p6166512.jpg'],
#   'ingredients': [['250 g ryżu kleistego \r'],
#    ['1 litr mleka \r'],
#    ['100 g cukru \r'],
#    ['kilka liści mięty \r'],
#    ['1 x cytryna \r'],
#    ['1 szczypta soli\r'],
#    ['500 g truskawek świeżych\r'],
#    ['5 kostek czekolady gorzkiej']],
#   'preparation': ['Cytrynę wyszorować, ściąć z niej skórkę. Do garnka wlać mleko, wrzucić skórkę cytrynową i miętę. Gotować na wolnym ogniu do 10 minut, pilnować, by mleko nie wykipiało. Odcedzić na sicie i wlać ponownie do garnka, dodać cukier i zagotować. Ryż przepłukać na sicie i dodać do gotującego się mleka. Gotować na małym ogniu, często mieszać, ryż należy tak długo gotować, aż będzie miękki i kleisty.\xa0Truskawki umyć, odszypułkować, można pokroić w części. Do pucharków nakładać warstwę ryżu, truskawki, ryż i truskawki, górę deseru posypać startą gorzką czekoladą. ']},
#  {'link': ['https://kkpolska.pl/przepis/134/roladki_z_tortilli_z_tunczykiem_i_jalapeno.html'],
#   'title': ['Roladki z tortilli z tuńczykiem i Jalapeno'],
#   'photo_link': ['images/przepisy/roladki_z_tortilli_01.jpg'],
#   'ingredients': [['3 duże placki tortilli pszennej\r'],
#    ['1 słoik tuńczyka w oliwie\r'],
#    ['150 g kukurydzy\r'],
#    ['4 łyżki posiekanego szczypiorku\r'],
#    ['300 g marynowanych ostrych papryczek\r'],
#    ['150 g tartej mozzarelli lub sera żółtego\r'],
#    ['4 łyżki majonezu\r'],
#    ['2 łyżeczki musztardy']],
#   'preparation': ['Tuńczyka nieco odsączyć z oliwy, włożyć do miski, dodać odsączoną kukurydzę, posiekany szczypiorek, posiekane ostre papryczki, starty ser, majonez i musztardę. Doprawić solą i pieprzem, wymieszać. Rozsmarować na 3 tortillach, zwinąć w roladkę i pokroić na około 2 - 3 cm kawałki. Ułożyć na półmisku i udekorować natką. ']},
#  {'link': ['https://kkpolska.pl/przepis/136/pikantna_salsa_pomidorowa.html'],
#   'title': ['Pikantna salsa pomidorowa'],
#   'photo_link': ['images/przepisy/salsa_do_chipsow_nachos_01.jpg'],
#   'ingredients': [['400 g (puszka) krojonych pomidorów\r'],
#    ['1/4 zielonej papryki\r'],
#    [' 2 łyżki marynowanej papryczki jalapeño\r'],
#    ['1/2 łyżeczki sproszkowanego czosnku\r'],
#    ['sól\r'],
#    ['pieprz\r'],
#    ['2 łyżki cukru\r'],
#    ['3 łyżki octu spirytusowego\r'],
#    ['2 cebulki szalotki\r'],
#    ['1 łyżeczka mąki ziemniaczanej\r'],
#    ['łyżka posiekanej kolendry']],
#   'preparation': ['1. Do rondelka włożyć pomidory z puszki wraz z całą zalewą, dodać pokrojoną w małą kosteczkę zieloną paprykę, odcedzoną i posiekaną jalapeño, czosnek, szczyptę soli i szczyptę pieprzu, cukier oraz ocet.\r\n2. Zagotować, następnie gotować bez przykrycia przez około 10 minut, co chwilę mieszając.\r\n3. Dodać obraną i drobno posiekaną cebulkę i gotować jeszcze przez 2 minuty.\r\n4. Na koniec dodać mąkę ziemniaczaną (przez sitko), wymieszać i zagotować.\r\n5. Ostudzić przed podaniem. Dodać kolendrę. ']},
#  {'link': ['https://kkpolska.pl/przepis/139/jajecznica_z_tofu.html'],
#   'title': ['Jajecznica z tofu'],
#   'photo_link': ['images/przepisy/jajecznica-tofu-awokado-01.jpg'],
#   'ingredients': [['200 g tofu\r'],
#    ['2 porcje rukoli\r'],
#    ['1 awokado\r'],
#    ['sól\r'],
#    ['świeżo zmielony pieprz\r'],
#    ['oliwa extra virgine\r'],
#    ['sok z cytryny\r'],
#    ['2 łyżki masła\r'],
#    ['3 jajka\r'],
#    ['1 łyżka posiekanego szczypiorku\r'],
#    ['grzanki z chleba żytniego posmarowane masłem']],
#   'preparation': ['Tofu wyjąć z opakowania i odsączyć z wody jeśli jest wilgotne i bardzo miękkie. Rukolę opłukać, osuszyć i ułożyć na dwóch talerzykach. Awokado obrać, pokroić na kawałki, położyć na rukoli, skropić sokiem z cytryny, doprawić solą, pieprzem i polać oliwą extra vergine. W tosterze zrobić grzanki z chleba i po ostudzeniu posmarować masłem. Tofu pokroić w kosteczkę. Posypać solą, pieprzem i położyć na patelni z rozgrzanym masłem. Smażyć na niedużym ogniu przez około 1 - 2 minuty z każdej strony (jeśli chcemy, możemy je smażyć aż do zrumienienia). Tofu przesunąć na bok patelni, a w wolne miejsce wbić jajka, delikatnie zamieszać, doprawić solą, pieprzem i szczypiorkiem. Gdy jajka się zetną od razu odstawić patelnię z ognia. Zawartość patelni przełożyć na sałatkę z rukoli i awokado. Podawać z grzankami.']},
#  {'link': ['https://kkpolska.pl/przepis/156/_bezglutenowe_muffinki_z_orzechow_nerkowca_migdalow_i_prazonych_jablek.html'],
#   'title': [' Bezglutenowe Muffinki z orzechów nerkowca, migdałów i prażonych jabłek'],
#   'photo_link': ['images/przepisy/muffinki.jpg'],
#   'ingredients': [['340 g mąki z orzechów (nerkowce i migdały)\r'],
#    ['1 łyżka cynamonu cejlońskiego\r'],
#    ['2 łyżeczki sody oczyszczonej /lub proszku do pieczenia\r'],
#    ['szczypta soli himalajskiej /lub morskiej\r'],
#    ['20-30 g cukru palmowego\r'],
#    ['175 g musu jabłkowego\r'],
#    ['50 g oleju rzepakowego\r'],
#    ['2 jajka\r'],
#    ['1 łyżeczka cukru waniliowego']],
#   'preparation': ['Do mąki z orzechów i migdałów dodać cynamon, sól, sodę, wymieszać. W osobnej misce zmiksować mus jabłkowy, jajka oraz cukier waniliowy, dodać mąkę wymieszaną wcześniej z cynamonem, solą i sodą, wymieszać. Ciasto przelać do foremek na Muffinki (do ok ¾ wysokości foremki). Piec w temperaturze 180 stopni C (grzałka góra-dół) przez ok. 25 min']},
#  {'link': ['https://kkpolska.pl/przepis/9/tajwanska_herbata_z_tapioki_-_bubble_tea.html'],
#   'title': ['Tajwańska herbata z tapioki - Bubble Tea'],
#   'photo_link': ['images/przepisy/herbata z tapioki - Bubble Tea.jpg'],
#   'ingredients': [['4 łyżki perełek tapioki\r'],
#    ['10 łyżek cytrynowego syropu do kawy\r'],
#    ['2 saszetki herbaty malinowej\r'],
#    ['1 szklanka mleka\r'],
#    ['Kilka łyżek miodu\r'],
#    [' mięta do dekoracji']],
#   'preparation': ['1. Przed ugotowaniem, perełki tapioki zalej syropem cytrynowym i pozostaw na co najmniej 10 minut.\r\n2. Do wrzącej, posłodzonej wody wrzuć tapiokę.\r\n3. Kiedy kuleczki wypłyną na powierzchnie, gotuj je przez 15 minut (lub do czasu aż staną się przezroczyste).\r\n4. Odstaw na 15 minut do ostygnięcia i odcedź perełki.\r\n5. Zaparz herbatę (na jedną szklankę wody wykorzystaj przynajmniej 2 saszetki herbaty)\r\n6. Zaparzoną herbate wymieszaj z pozostałymi składnikami.\r\n7. Gotowy napój przelej do szklanek z tapioką\r\n8. Schłodź napój i gotowe!\nUWAGA: Przed podaniem napój można udekorować miętą oraz dodać do niego kilka kostek lodu.']},
#  {'link': ['https://kkpolska.pl/przepis/17/tacos_z_kaczka_salsa_mango_i_sosem_hoisin.html'],
#   'title': ['Tacos z kaczką, salsą, mango i sosem Hoisin'],
#   'photo_link': ['images/przepisy/tacos_hoisin.jpg'],
#   'ingredients': [['12 tortilli taco (kukurydziane/pszenne/razowe)\r'],
#    ['4 kacze udka\r'],
#    ['125 ml białego, wytrawnego wina\r'],
#    ['2 świeże mango\r'],
#    ['1 limonka\r'],
#    ['1/2 ostrej papryczki chili\r'],
#    ['sałata lodowa\r'],
#    ['sos Hoisin (2-3 łyżki stołowe)\r'],
#    ['sól\r'],
#    ['pieprz']],
#   'preparation': ['KACZKA:\n\r\n1. Piekarnik nagrzać do temperatury 150 stopni.\r\n2. Udka doprawić solą oraz pieprzem.\r\n3. Mięso włożyć do formy żaroodpornej (skórką do dołu), wlać wino, przykryć pokrywką i wstawić do piekarnika. Piec przez około 1,5 godziny\r\n4. Po upływie tego czasu przewrócić mięso na druga stronę (skórką do góry) i piec kolejne 1,5 godziny.\r\n5. Po upływie tego czasu mięso ostrożnie wyjąć, ostudzić i obrać z kości.\r\n6. Kawałki mięsa poszarpać na włókna na desce do krojenia (najłatwiej to zrobić dwoma widelcami).\nSALSA MANGO:\r\n1. Mango obrać, pokroić na paseczki, skropić limonką, dodać drobno posiekaną papryczkę chili.\r\n2. Wszystko wymieszać.\r\n3. Do garnka przelać sos hoisin, dodać mięso, wymieszać i delikatnie podgrzać.\r\n4. Umyć i poszatkować sałaę lodową.\r\n5. Taco podgrzać według sposobu przygotowania na opakowaniu.\r\n6. Nadziewać taco nakładając kolejno: sałatę, mięso w sosie hoisin oraz salsę mango']},
#  {'link': ['https://kkpolska.pl/przepis/127/salatka_z_truskawkami_krewetkami_i_makaronem_sojowym.html'],
#   'title': ['Sałatka z truskawkami, krewetkami i makaronem sojowym'],
#   'photo_link': ['images/przepisy/kluski_z_truskawkami_02_1.jpg'],
#   'ingredients': [['100 g makaronu sojowego\r'],
#    ['12 ugotowanych lub usmażonych krewetek\r'],
#    ['200 g truskawek\r'],
#    ['4 łyżki posiekanych solonych pistacji\r'],
#    ['1/3 szklanki świeżych listków mięty\r'],
#    ['Sos:   • sok z 2 limonek\r'],
#    ['2 pełne łyżki miodu\r'],
#    ['1 łyżka tartego świeżego imbiru']],
#   'preparation': ['1. Składniki sosu wymieszać w miseczce.\r\n2. Makaron przygotować zgodnie z instrukcją na opakowaniu i pokroić nożyczkami na około 7 cm kawałki.\r\n3. Włożyć do salaterki, dodać krewetki, posypać\xa0pistacjami i delikatnie wymieszać z truskawkami, miętą i winegretem (najlepiej polać nim sałatkę\xa0przed samym podaniem, aby nie został wchłonięty przez makaron). ']},
#  {'link': ['https://kkpolska.pl/przepis/32/mielona_wieprzowina_w_salacie_(san_choy_bao).html'],
#   'title': ['Mielona wieprzowina w sałacie (San Choy Bao)'],
#   'photo_link': ['images/przepisy/mielona_wieprzowina.jpg'],
#   'ingredients': [['200g mielonej wieprzowiny\r'],
#    ['20g drobno posiekanej cebuli dymki\r'],
#    ['20g drobno posiekanej cebuli\r'],
#    ['20g małej kukurydzy groszkowej\r'],
#    ['20g selera naciowego\r'],
#    ['20g grzybów shiitake (namoczonych w wodzie)\r'],
#    ['20g marchwi\r'],
#    ['1 główka sałaty lodowej\r'],
#    ['2 łyżki stołowe oleju roślinnego\r'],
#    ['2 łyżki oleju sezamowego\r'],
#    ['1 drobno posiekana papryczka chili (opcjonalnie)'],
#    ['\r'],
#    ['Składniki na sos: • 2 łyżki stołowe sosu ostrygowego\r'],
#    ['2 łyżki stołowe sosu po pekińsku\r'],
#    ['2 łyżki stołowe wina ryżowego\r'],
#    ['3 łyżki stołowe wody']],
#   'preparation': ['1. Przygotować sałatę lodową, oddzielając jej liście i przycinając je do okrągłego kształtu. Umyć je i odstawić.\r\n2. Drobno posiekać wszystkie warzywa.\r\n3. W woku lub patelni, ustawionym na średnim ogniu, podsmażyć obie cebule i mieloną wieprzowinę przez 5 minut, ciągle mieszając, a następnie dodać pozostałe warzywa oraz sos ostrygowy i sos po pekińsku.\r\n4. Dusić przez 10 minut lub do momentu wygotowania sosu, aż wszystkie składniki będą całkowicie ugotowane.\r\n5. Podać przygotowaną sałatę. Na każdym liściu sałaty umieścić łyżkę stołową usmażonego dania.']},
#  {'link': ['https://kkpolska.pl/przepis/60/makaron_z_kurczakiem_na_zimno.html'],
#   'title': ['Makaron z kurczakiem na zimno'],
#   'photo_link': ['images/przepisy/559250_729e5f3594fd4ea5b9b67f04fa9ad71d_mv2_3.png'],
#   'ingredients': [['350 g udek z kurczaka\r'],
#    ['200 g świeżego makaronu jajecznego\r'],
#    ['1/2 ogórka pokrojonego w cienkie paski\r'],
#    ['1 duża marchew, obrana i pokrojona w cienkie paski'],
#    ['\r'],
#    [' • 2 łyżki stołowe sosu ostrygowego Lee Kum Kee\r'],
#    ['2 łyżki stołowe sosu sojowego słodkiego do pierożków Lee Kum Kee\r'],
#    ['50 g kasztanów jadalnych z puszki w wodzie, pokrojonych w plastry (opcjonalnie)'],
#    ['\r'],
#    [' • 2 łyżki stołowe sosu do pierożków Lee Kum Kee']],
#   'preparation': ['1. W miseczce przygotować marynatę z sosu ostrygowego oraz sosu sojowego słodkiego.\r\n1. Udka z kurczaka marynować w przygotowanej marynacie przez 30 minut.\r\n2. Piec na grillu lub smażyć na patelni przez 15-20 minut, do całkowitego usmażenia mięsa, a następnie pokroić w paski lub w kostkę i odstawić.\r\n3. Wymieszać pozostałe składniki z sosem do pierożków Lee Kum Kee.\r\n4. Podawać z udkami z kurczaka.']},
#  {'link': ['https://kkpolska.pl/przepis/16/makaron_z_kurczakiem_i_warzywami_w_sosie_teriyaki.html'],
#   'title': ['Makaron z kurczakiem i warzywami w sosie Teriyaki'],
#   'photo_link': ['images/przepisy/Makaron z kurczakiem teriyaki i warzywami.jpg'],
#   'ingredients': [['120g makaronu Mie lub z warzywami\r'],
#    ['200g filetu z kurczaka\r'],
#    ['1 łyżka mąki pszennej\r'],
#    ['2 łyżki oleju roślinnego\r'],
#    ['1/2 małego brokuła\r'],
#    ['1 cebula\r'],
#    ['1 czerwona papryka\r'],
#    ['1 mała puszka kukurydzy\r'],
#    ['1 łyżka sezamu czarnego\r'],
#    ['2-3 łyżki stołowe sosu teriyaki (ilość sosu może się zmieniać w zależności od ilości użytych składników']],
#   'preparation': ['1. Ugotować makaron zgodnie z instrukcją na opakowaniu\r\n2. Filet z kurczaka pokroić w kostkę, dorprawić solą oraz pieprzem, wymieszać z mąką\r\n3. Rozgrzać patelnię (najlepiej głęboką), wlać olej i gdy będzie gorący włożyć kurczaka. Na większym ogniu smażyć przez około 2-3 minuty, następnie dodać pokrojoną w piórka cebulę i smażyć dalej około 1 minutę, mieszając cały czas.\r\n4. Dodać pokrojonego na małe różyczki brokuła oraz pokrojoną w kostkę paprykę. Smażyć około 2-3 minuty (do momentu aż warzywa nieco zmiękną), dodać kukurydzę.\r\n5. Dodać ugotowany wcześniej makaron i smażyć przez około 1 minutę.\r\n6. Wlać sos teriyaki, wszystko dokładnie wymieszać, chwilę podgrzewać (cały czas mieszając)\r\n7. Gotowe danie posypać sezamem.\nDanie można modyfikować dodając inne warzywa (np. marchew) lub zmieniając kokurydzę z puszki na mini kolby kukurydzy DIAMOND.\nJeśli preferujesz pikantne smaki, można dodać posiekaną papryczkę chili']},
#  {'link': ['https://kkpolska.pl/przepis/124/makaron_sojowy_z_mango_i_krewetkami.html'],
#   'title': ['Makaron sojowy z Mango i krewetkami'],
#   'photo_link': ['images/przepisy/makaron_sojowy_z_mango_krewetkami_02.jpg'],
#   'ingredients': [['100 g makaronu sojowego\r'],
#    ['200 g krewetek black tiger / lub 150 g pokrojonej w kosteczkę piersi kurczaka \r'],
#    ['1 mango\r'],
#    ['1,5 łyżki startego imbiru\r'],
#    ['2 duże ząbki czosnku\r'],
#    ['1 papryczka chili\r'],
#    ['1 łyżka oleju kokosowego\r'],
#    ['3 łyżki sezamu\r'],
#    ['0,5 szklanki listków mięty\r'],
#    ['1 łyżka liści kolendry'],
#    ['\r'],
#    ['Sos:  • sok z 2 limonek\r'],
#    ['2 łyżki cukru trzcinowego\r'],
#    ['1 łyżka sosu ostrygowego /lub 2 łyżki sojowego']],
#   'preparation': ['Makaron przygotować według instrukcji na opakowaniu. Krewetki oczyścić (jeśli jest taka potrzeba), opłukać i osuszyć. Mango obrać, odciąć miąższ przy pestce, pokroić w kostkę. \n\xa0\nSos: wycisnąć sok z limonek i wymieszać z cukrem oraz sosem ostrygowym lub sojowym, odstawić. \nImbir i czosnek obrać i zetrzeć na drobnej tarce. Papryczkę chili pokroić w małą kosteczkę. Na głębokiej patelni lub woku rozgrzać olej, włożyć imbir i czosnek, smażyć przez około 1 minutę. Dodać krewetki, smażyć przez około 2 minuty, następnie dodać papryczkę chili, sezam i smażyć przez pół minuty mieszając. Dodać makaron sojowy, wymieszać i smażyć przez 1-2 minuty. Dodać pokrojone mango i wymieszać. Przesunąć zawartość patelni na bok, przechylić patelnię i w powstały dołek wlać składniki sosu. Trzymać patelnię cały czas przechyloną tak, aby sos w dołku podgrzewał się na ogniu i redukował. Pogotować go przez około 15-30 sekund, aż zgęstnieje, następnie rozprowadzić po całej patelni, wymieszać. Posypać miętą i kolendrą. ']},
#  {'link': ['https://kkpolska.pl/przepis/140/makaron_jajeczny_z_kaczka_i_warzywami.html'],
#   'title': ['Makaron jajeczny z kaczką i warzywami'],
#   'photo_link': ['images/przepisy/kaczka.jpg'],
#   'ingredients': [['Chińska mieszanka warzyw 330g \r'],
#    ['2 filety z piersi kaczki \r'],
#    ['250 chińskiego makaronu jajecznego\r'],
#    ['2 łyżki sosu sojowego \r'],
#    ['2 łyżki octu \r'],
#    ['2 łyżki oleju \r'],
#    ['1 łyżeczka cukru \r'],
#    ['szczypta imbiru w proszku \r'],
#    ['szczypta ostrej papryki \r'],
#    ['szczypta słodkiej papryki \r'],
#    ['szczypta gałki muszkatołowej \r'],
#    ['szczypta cynamonu \r'],
#    ['sól \r'],
#    ['pieprz ']],
#   'preparation': ['1. Skórę na filetach kaczki naciąć w kratkę, natrzeć każdą pierś zmieszanymi przyprawami i odstawić na kilka minut do zamarynowania. Tymczasem warzywa podsmażyć na oleju, pod koniec przyprawić pieprzem, zalać sosem sojowym, octem i doprawić cukrem.\r\n2. Przygotowany zgodnie z instrukcją na opakowaniu makaron dodać do warzyw i całość podsmażyć.\r\n3. Filety z kaczki ułożyć na patelni i smażyć od strony skóry z obu stron przez 4-5 minut, a następnie włożyć do nagrzanego do temperatury 150ºC piekarnika i piec około 10 minut.\r\n4. Gorące filety pokroić w plastry i położyć na makaron z warzywami. ']},
#  {'link': ['https://kkpolska.pl/przepis/3/makaron_chow_mein_z_wolowina_i_warzywami.html'],
#   'title': ['Makaron Chow Mein z wołowiną i warzywami'],
#   'photo_link': ['images/przepisy/chowmein.png'],
#   'ingredients': [['80 g makaronu Chow Mein\r'],
#    ['170 g wołowiny\r'],
#    ['1 ząbek czosnku\r'],
#    ['1 łyżka startego świeżego imbiru\r'],
#    ['1/4 pora\r'],
#    ['1/2 czerwonej papryki\r'],
#    ['3 pieczarki\r'],
#    ['2 łyżki oleju roślinnego\r'],
#    ['szczypta zmielonego białego pieprzu\r'],
#    ['szczypta cukru\r'],
#    ['3 łyżki ciemnego sosu sojowego + 2 łyżki wody\r'],
#    ['2 łyżeczki oleju sezamowego\r'],
#    ['2 łyżki posiekanego szczypiorku']],
#   'preparation': ['1. Makaron przygotować według zaleceń na opakowaniu.\r\n2. Wołowinę pokroić w poprzek włókien na cieniutkie (2-3 mm) paseczki.\r\n3. Czosnek i imbir obrać i zetrzeć na tarce.\r\n4. Pora cieniutko posiekać, paprykę pokroić w paski, pieczarki na plasterki.\r\n5. Rozgrzać wok lub dużą patelnię, wlać olej.\r\n6. Włożyć czosnek i imbir i smażyć pół minuty, dodać wołowinę i obsmażyć przez ok. 2 minuty.\xa0\r\n7. Dodać pora, paprykę i pieczarki i smażyć mieszając przez ok. 3 minuty.\r\n8. Dodać ugotowany makaron, doprawić szczyptą białego pieprzu i cukru.\xa0\r\n9. Wlać sos sojowy i wodę. Wymieszać i podsmażać jeszcze wszystko przez ok. 2 minut.\r\n10. Doprawić olejem sezamowym i posiekanym szczypiorkiem.\nUWAGA:\xa0Zamiast mięsa wołowego można użyć innego np. drobiu.']},
#  {'link': ['https://kkpolska.pl/przepis/18/zeberka_w_sosie_hoisin.html'],
#   'title': ['Żeberka w sosie hoisin'],
#   'photo_link': ['images/przepisy/Kurczak w sosie hoisin.jpg'],
#   'ingredients': [['5 łyżek stołowych sosu hoisin\r'],
#    ['500g żeberek\r'],
#    ['1 łyżka stołowa sosu sojowego jasnego']],
#   'preparation': ['1. Do miseczki dodać sos hoisin oraz sos sojowy jasny, wymieszać.\r\n2. W tak przygotowanej marynacie obtoczyć dokładnie mięso i przełozyć do naczynia żaroodpornego.\r\n3. Piekarnik nagrzać do temperatury 200 stopni, mięso piec przez około 20 minut.\r\n4. Po upływie 20 minut mięso polaać 1 łyżką stołową sosu hoisin i piec przez kolejne 5 minut']},
#  {'link': ['https://kkpolska.pl/przepis/75/kurczak_w_sosie_z_czarnej_fasoli_i_czosnku.html'],
#   'title': ['Kurczak w sosie z czarnej fasoli i czosnku'],
#   'photo_link': ['images/przepisy/Kurczak w sosie z czarnej fasoli i czosnku.jpg'],
#   'ingredients': [['250g piersi z kurczaka pokrojonej w kostkę\r'],
#    ['1 zielona papryka pokrojona w kostkę\r'],
#    ['75g pieczarek pokrojonych w kostkę\r'],
#    ['1 łyżka oleju\r'],
#    ['50g sosu stir-fry z czarnej fasoli i czosnku Lee Kum Kee']],
#   'preparation': ['1. Olej rozgrzać na patelni lub w woku, dodać kurczaka i smażyć na średnik ogniu 5-7 minut (do momentu, aż kurczak zarumieni się na złoty kolor)\r\n2. Dodać paprykę oraz pieczarki i smażyć 3-4 minuty.\r\n3. Dodać sos z czeną fasolą i czosnkiem i gotować ok. 2 minut (cały czas mieszając)\r\n4. Danie serwować z ryżem']},
#  {'link': ['https://kkpolska.pl/przepis/73/kurczak_w_sosie_miodowo-sojowym.html'],
#   'title': ['Kurczak w sosie miodowo-sojowym'],
#   'photo_link': ['images/przepisy/Kurczak w sosie miodowo-sojowym.jpg'],
#   'ingredients': [['250g pokrojonego w kostkę kurczaka (pierś lub udko)\r'],
#    ['50g groszku cukrowego\r'],
#    ['75g kolb kukurydzy baby\r'],
#    ['1 łyżka oleju\r'],
#    ['70g sosu stir-fry miodowo-sojowego Lee Kum Kee']],
#   'preparation': ['1. Olej rozgrzać na patelni lub w woku, dodać kurczaka i smażyć na średnik ogniu ok. 5-7 minut (do momentu, aż kurczak zarumieni się na złoty kolor)\r\n2. Dodać groszek cukrowy oraz kukurydzę baby i smażyć dalej 2-3 minuty.\r\n3. Dodac sos miodowo-sojowy i gotować przez 2 minuty cały czas mieszając.\r\n4. Danie serwować z makaronem.']},
#  {'link': ['https://kkpolska.pl/przepis/40/kurczak_po_chinsku_z_pedami_bambusa.html'],
#   'title': ['Kurczak po chińsku z pędami bambusa'],
#   'photo_link': ['images/przepisy/kurczak_pedy.jpg'],
#   'ingredients': [['1 filet z kurczaka\r'],
#    ['2 łyżki mąki\r'],
#    ['2 łyżki oleju\r'],
#    ['1 cebula\r'],
#    ['1 ząbek czosnku\r'],
#    ['3 marchewki\r'],
#    ['1 papryka czerwona lub zielona\r'],
#    ['mała puszka pędów bambusa\r'],
#    ['1 łyżka białego octu winnego\r'],
#    ['1 łyżka cukru\r'],
#    ['2 łyżki koncentratu pomidorowego\r'],
#    ['2 łyżki sosu sojowego\r'],
#    ['sól\r'],
#    ['pieprz']],
#   'preparation': ['1. Mięso umyć, osuszyć, pokroić w paski, doprawić solą oraz pieprzem, obsypać mąką.\r\n2. Na patelni rozgrzać olej i obsmażyć mięso, dodać pokrojoną w piórka cebulę, czosnek i smażyć przez 3 minuty.\r\n3. Na patelnie dorzucić pokrojoną w paski paprykę oraz marchew, smażyć przez kolejne 6 minut, stale mieszać.\r\n4. Do warzyw na patelni dodać pędy bambusa, biały ocet winny, cukier. Wszystko razem zagotować, następnie zmniejszyć ogień, gotować jeszcze kilka minut. Doprawić solą oraz pieprzem do smaku jeśli jest taka potrzeba.\n\xa0\nDanie podawać z makaronem ryżowym, makaronem chińskim błyskawicznym lub z ryżem.']},
#  {'link': ['https://kkpolska.pl/przepis/74/kurczak_kung_pao.html'],
#   'title': ['Kurczak Kung Pao'],
#   'photo_link': ['images/przepisy/Kurczak Kung Pao.jpg'],
#   'ingredients': [['250g pokrojonej w kostkę piersi kurczaka\r'],
#    ['1/2 papryki czerwonej pokrojonej w kostkę\r'],
#    ['4 cebulki dymki, posiekane\r'],
#    ['30g prażonych orzechów nerkowca\r'],
#    ['1 łyżka oleju\r'],
#    ['60g sosu stir-fry Kurczak Kung Pao Lee Kum Kee']],
#   'preparation': ['1. Olej rozgrzać na patelni lub w woku, dodać kurczaka i smażyć na średnim ogniu około 5-7 minut (do momentu, aż kurczak zarumieni się na złoty kolor)\r\n2. Dodać paprykę czerwoną i cebulę, smażyć 3-4 minuty na średnim ogniu, cały czas mieszając.\r\n3. Dodać sos do kurczaka Kung Pao, dodać odrobinę wody i gotować wszystko przez ok. 2 minuty (cały czas mieszając)\r\n4. Danie podawać z ryżem']},
#  {'link': ['https://kkpolska.pl/przepis/72/krewetki_w_sosie_pomidorowo-czosnkowym.html'],
#   'title': ['Krewetki w sosie pomidorowo-czosnkowym'],
#   'photo_link': ['images/przepisy/Krewetki w sosie pomidorowo-czosnkowym.jpg'],
#   'ingredients': [['180g surowych, obranych krewetek królewskich\r'],
#    ['1 łyżka oleju\r'],
#    ['30g szparagów, ciętych (4 cm)\r'],
#    ['70g sosu stir-fry pomidorowo-czosnkowego Lee Kum Kee']],
#   'preparation': ['1. Olej rozgrzać na patelni lub w woku, dodać krewetek i szparagi, całość\xa0smażyć na średnim ogniu do momentu, aż krewetki zarumienią się na różowy kolor.\r\n2. Dodać całą saszetkę sosu pomidorowo-czosnkowego Lee Kum Kee i gotować około 1 minutę, cały czas mieszając.\r\n3.\xa0Danie serwować z ryżem lub makaronem']},
#  {'link': ['https://kkpolska.pl/przepis/83/grillowany_leszcz_morski_z_ziolami.html'],
#   'title': ['Grillowany leszcz morski z ziołami'],
#   'photo_link': ['images/przepisy/leszcz.jpg'],
#   'ingredients': [['4 całe leszcze morskie, oczyszczone, bez płetw\r'],
#    ['400g średniej wielkości ziemniaków, (podgotowanych w gorącej wodzie 5-7 minut)\r'],
#    ['1 świeżo posiekany rozmaryn\r'],
#    ['4 łyżki sosu Teriyaki Lee Kum Kee\r'],
#    ['4 łyżki sosu Chili czosnkowego Lee Kum Kee\r'],
#    ['3 łyżeczki lekkiej oliwy z oliwek\r'],
#    ['sól i pieprz\r'],
#    ['mały pęczek świeżego koperku (niewielka ilość zarezerwowana do dekoracji)']],
#   'preparation': ['1. Ostrym nożem naciąć rybę z każdej strony. Posypać odrobiną soli i świeżo zmielonym czarnym pieprzem.\r\n2. Łyżkę posiekanych ziół umieścić we wnętrzu ryby. Posmarować olejem.\r\n3. Grillować rybę na średnim ogniu. Kilka razy lekko przesmarować sosem Teriyaki w trakcie grillowania. Grillować rybę z każdej strony przez 6-8 minut. Następnie odwrócić i grillować kolejne 5 minut.\r\n4. Gdy ryba będzie gotowa, przekroić kilka ugotowanych ziemniaków, lekko posmarować oliwą z oliwek i grillować około 12 minut, aż będa złocistobrązowe. Wyjąć ziemniaki i umieścić je w misce.\r\n5. Dodać do ziemniaków trzy łyżeczki sosu chili czosnkowego Lee Kum Kee i delikatnie wymieszać. Umieścić gotową rybę na półmisku z ziemniakami. Posmarować rybę pozostałym sosem Chili Czosnkowym i posypywać świeżymi ziołami. Podawać na ciepło.\n\xa0\nWskażówka:\r\nPodgrzać grill do średniej lub "skwierczącej" temperatury. Oczyścić i lekko naoliwić stojak. Ostrożnie położyć rybę na stojaku. Ułatwi to jej obracanie. Rybę piec w całości, dbając o to, by ruszt był średnio nagrzany. Pokrywa grillowa powinna być nałożona przez większą część czasu, ponieważ utrzymuje ciepło i przyspiesza proces grillowania.']},
#  {'link': ['https://kkpolska.pl/przepis/84/grillowane_tofu_chili_czosnkowe.html'],
#   'title': ['Grillowane tofu chili czosnkowe'],
#   'photo_link': ['images/przepisy/grilowane tofu.jpg'],
#   'ingredients': [['2 opakowania ekstra mocnego tofu (396 g każde)\r'],
#    ['olej, np. słonecznikowy albo rzepakowy'],
#    ['Marynata\r'],
#    ['2 łyżki sosu sojowego Light Lee Kum Kee\r'],
#    ['2 łyżki oleju sezamowego Lee Kum Kee\r'],
#    ['2 średnie ząbki czosnku, starte lub zmiażdżone\r'],
#    ['2 łyżki startego świeżego imbiru'],
#    ['Glazura\r'],
#    ['2 łyżeczki sosu sojowego Light Lee Kum Kee\r'],
#    ['2 łyżki sosu chilli czosnkowego Lee Kum Kee'],
#    ['Do podania\r'],
#    ['Ogórek, mięta, miękkie bułeczki i liście sałaty.']],
#   'preparation': ['1. Pokroić tofu na centymetrowe plastry. Położyć tofu na papierowym ręczniku i przykryć kolejnym ręcznikiem papierowym. Obciążyć deską. Pozostawić na godzinę.\r\n2. W płytkim naczyniu wymieszać składniki marynaty, dodać tofu, obrócić, a następnie marynować przez minimum 30 minut.\r\n3. Rozpalić grill. Wyjąć tofu z marynaty i nasmarować z obu stron odrobiną oleju. Umieścić tofu na najgorętszej części grilla. Grillować po drugiej stronie przez dwie minuty lub do lekkiego zwęglenia.\r\n4. Wymieszać składniki glazury, a następnie nasmarować nią plastry grillowanego tofu tuż przed podaniem. Ułożyć na miękkich bułkach plasterki ogórka i liści mięty, dodając tofu i posypując liśćmi sałaty.']},
#  {'link': ['https://kkpolska.pl/przepis/46/fasola_szparagowa_po_syczuansku.html'],
#   'title': ['Fasola szparagowa po syczuańsku'],
#   'photo_link': ['images/przepisy/chinyfasola.png'],
#   'ingredients': [['300g zielonej fasolki szparagowej\r'],
#    ['olej arachidowy\r'],
#    ['75g mielonej wieprzowiny\r'],
#    ['2 łyżki wina ryżowego do gotowania\r'],
#    ['1 łyżka sosu sojowego\r'],
#    ['1 papryczka chili (drobno pokrojona)\r'],
#    ['2 łyżki posiekanej chińskiej kapusty bok choy']],
#   'preparation': ['1. Usunąć końce fasolki i dobrze ją wypłukać.\xa0\r\n2. W woku rozgrzać olej, wrzucić fasolkę, smażyć kilka minut mieszając, aż fasolka zmięknie i pojawią się delikatne znaki przypalenia.\xa0\r\n3. Fasolkę wyjąć z woka, dolać oleju i wrzucić mieloną wieprzowinę.\xa0\r\n4. Smażyć na dużym ogniu i dodać wino ryżowe, sos sojowy i pokrojone chili.\xa0\r\n5. Dodać posiekaną chińską kapustę.\r\n6. Wrzucić do podsmażonej wieprzowiny fasolkę, zamieszać.']},
#  {'link': ['https://kkpolska.pl/przepis/90/warzywa_w_chrupiacej_tempurze_.html'],
#   'title': ['Warzywa w chrupiącej tempurze '],
#   'photo_link': ['images/przepisy/warzywa_tempura.jpg'],
#   'ingredients': [['panierka Tempura\r'],
#    ['1 cukinia 175 g \r'],
#    ['1 bakłażan 250 g \r'],
#    ['150 g małych pieczarek \r'],
#    ['1 pęczek dymki \r'],
#    ['1 l oleju słonecznikowego \r'],
#    ['sos sojowy (do maczania) ']],
#   'preparation': ['Cukinię i bakłażana oczyścić, pokroić w plastry o grubości 1 cm, które (w zależności od wielkości) przekroić na pół lub na cztery części. Pieczarki, dymkę oczyścić i pokroić na długie kawałki o długości około 6 cm. Następnie przygotować Tempurę według przepisu zaleconego na opakowaniu (ciasto powinno mieć konsystencję gęstszą niż ciasto naleśnikowe). Olej rozgrzać w szerokim rondlu do takiego stopnia, aby po włożeniu drewnianej łyżki ukazały się na niej pęcherzyki. Kawałki warzyw porcjami moczyć w cieście, a następnie smażyć na gorącym oleju, w zależności od wielkości kawałków, przez 3-5 minut, aż będą kruche i nabiorą złocistego koloru. Odsączyć na papierze kuchennym i podawać z sosem sojowym. ']},
#  {'link': ['https://kkpolska.pl/przepis/61/sushi_maki.html'],
#   'title': ['Sushi Maki'],
#   'photo_link': ['images/przepisy/maki_2.png'],
#   'ingredients': [['500g ryżu do sushi\r'],
#    ['1 opakowanie alg Nori do sushi\r'],
#    ['Zalewa octowa: • 8 łyżek octu ryżowego\r'],
#    ['3-4 łyżki cukru\r'],
#    ['łyżka sosu sojowego\r'],
#    ['mata bambusowa do sushi\r'],
#    ['Dodatki: • 200g świeżego (najlepiej surowego lub wędzonego) filetu z łososia\r'],
#    ['dojrzały owoc awokadu\r'],
#    ['pęczek szczypiorku\r'],
#    ['marynowany imbir (ze słoika) według uznania\r'],
#    ['pasta wasabi']],
# ...
#  {'link': ['https://kkpolska.pl/przepis/29/hoddeok_-_koreanskie_placuszki_.html'],
#   'title': ['Hoddeok - koreańskie placuszki '],
#   'photo_link': ['images/przepisy/korea-placki.png'],
#   'ingredients': [['1 szklanka ciepłego mleka\r'],
#    ['2 szklanki mąki\r'],
#    ['2 łyżki cukru\r'],
#    ['2 łyżeczki suszonych drożdży\r'],
#    ['szczypta soli\r'],
#    ['1 łyżka oleju\r'],
#    ['brązowy cukier\r'],
#    ['parę łyżek posiekanych orzeszków (włoskich, laskowych lub ziemnych)\r'],
#    ['1 łyżeczka cynamonu']],
#   'preparation': ['1. Mąkę, mleko, drożdże, cukier, sól i olej wymieszać w misce i dokładnie zagnieść. 2. Przykryć ręcznikiem lub folią i odstawić na około 30 minut do wyrośnięcia.\r\n3. Wyrośnięte ciasto zagnieść ponownie i uformować z niego kulki o średnicy około 3-4 cm.\r\n4. W miseczce wymieszać cukier, orzeszki i cynamon.\r\n5. W każdej kulce z ciasta zrobić głęboki dołek i wypełnić go nadzieniem. Dokładnie zakleić (jak pyzę).\r\n6. Na rozgrzanej patelni z odrobiną oleju umieścić kulki łączeniem do dołu i smażyć aż dół się zarumieni.\r\n7. Przewróć kulki na przeciwną stronę i rozgnieć ostrożnie szpatułką, aż utworzą się z nich placuszki. Przykryć pokrywką i smażyć aż się zarumienią.']},
#  {'link': ['https://kkpolska.pl/przepis/58/chapaguri.html'],
#   'title': ['Chapaguri'],
#   'photo_link': ['images/przepisy/1467899256897.jpg'],
#   'ingredients': [['1 opakowanie zupki Chapaghetti\r'],
#    ['1 opakowanie zupki Neoguri (ostra / łagodna)\r'],
#    ['6 szklanek wody (ok. 1,1l)']],
#   'preparation': ['1. Zagotuj wodę w garnku.\r\n2. Kiedy woda zacznie się gotować, umieść w garnku oba makarony (Chapaghetti i Neoguri) oraz obie mieszanki warzyw.\r\n3. Gotuj przez ok. 4,5 minuty, odlej wodę\xa0zostawiając ok. 1/2 szklanki.\r\n4. Dodaj bazę do zupy Chapaghetti oraz torebkę z olejem roślinnym.\r\n5. Dodaj połowę torebki z bazą do zupy Neoguri i wszystko dobrze wymieszaj przez około 30 sekund.\r\n6. Przełóż na talerz i ciesz się pysznym daniem!']},
#  {'link': ['https://kkpolska.pl/przepis/137/weganski_mus_czekoladowy_z_tofu.html'],
#   'title': ['Wegański mus czekoladowy z Tofu'],
#   'photo_link': ['images/przepisy/mus_czekoladowy_z_tofu_01.jpg'],
#   'ingredients': [['340 g tofu \r'],
#    ['200 g gorzkiej czekolady\r'],
#    ['1/2 szklanki wody\r'],
#    ['1/2 szklanki cukru\r'],
#    ['dodatki smakowe np. 1 łyżeczka ekstraktu z wanilii, 1 łyżka likieru pomarańczowego, 1/3 łyżeczki cynamonu, szczypta ostrej papryki']],
#   'preparation': ['Wodę wlać do rondelka, dodać cukier i mieszając podgrzewać, aż cukier się rozpuści. Gdy syrop zacznie się gotować odstawić z ognia. Czekoladę połamać na kosteczki i roztopić. Dodać smakowe dodatki, następnie wlać gorący syrop i tofu z opakowania, wszystko zmiksować blenderem na gładki mus. Przelać do kieliszków lub szklanek i schłodzić przez pół godziny. Udekorować wiórkami czekolady lub owocami np. malinami. ']},
#  {'link': ['https://kkpolska.pl/przepis/80/mekhong_thai_sabai.html'],
#   'title': ['Mekhong Thai Sabai'],
#   'photo_link': ['images/przepisy/Mekhong Thai Sabai.jpg'],
#   'ingredients': [['45 ml Mekhong Thai Spirit\r'],
#    ['25 ml świeżego soku z limonki\r'],
#    ['30 ml syropu cukrowego\r'],
#    ['8-10 liście tajskiej bazylii\r'],
#    ['"kropla wody"']],
#   'preparation': ['1. Wszystkie składniki połączyć razem ze sobą.\r\n2. Dobrze wymieszać.\nUwaga! Tylko dla osób pełnoletnich!']},
#  {'link': ['https://kkpolska.pl/przepis/82/mekhong_siam_sparkling.html'],
#   'title': ['Mekhong Siam Sparkling'],
#   'photo_link': ['images/przepisy/Mekhong Siam Sparkling.jpg'],
#   'ingredients': [['20 ml Mekhong Thai Spirit\r'],
#    ['30 ml syropu z lychee\r'],
#    ['50 ml wina musującego\r'],
#    ['opcjonalnie: szczypta gazowanego napoju cytrynowego']],
#   'preparation': ['1. Wszystkie składniki połączyć razem ze sobą.\r\n2. Dobrze wymieszać.\nUwaga! Tylko dla osób pełnoletnich!']},
#  {'link': ['https://kkpolska.pl/przepis/81/mekhong_samui_singria.html'],
#   'title': ['Mekhong Samui Singria'],
#   'photo_link': ['images/przepisy/Mekhong Samui Singria.jpg'],
#   'ingredients': [['45 ml Mekhong Thai Spirit\r'],
#    ['15 ml syropu cynamonowego\r'],
#    ['60 ml soku pomarańczowego\r'],
#    ['60 ml czerwonego wina\r'],
#    ['"kropla limonki"']],
#   'preparation': ['1. Wszystkie składniki połączyć razem ze sobą.\r\n2. Dobrze wymieszać.\nUwaga! Tylko dla osób pełnoletnich!']},
#  {'link': ['https://kkpolska.pl/przepis/93/margarita_mango_.html'],
#   'title': ['Margarita Mango '],
#   'photo_link': ['images/przepisy/margarita.png'],
#   'ingredients': [['150-200ml Rubicon Deluxe Napój Mango \r'],
#    ['80ml tequili \r'],
#    ['80ml likieru pomarańczowego triple sec \r'],
#    ['sok z 1/2 limonki \r'],
#    ['1 łyżka cukru \r'],
#    ['*dodatkowo 2 łyżeczki cukru do dekoracji \r'],
#    ['kilka kostek lodu ']],
#   'preparation': ['Wszystkie składniki oraz kilka kostek lodu umieścić w shakerze barmańskim i dobrze wymieszać.\xa0Rozsypać cukier (dekoracja) na talerzu. Rant kieliszków zwilżyć (można to zrobić rozkrojoną limonką lub wodą), następnie odwrócić kieliszek i obtoczyć w cukrze. Zawartość shakera przelać do kieliszka. ']},
#  {'link': ['https://kkpolska.pl/przepis/112/likier_kokosowy_.html'],
#   'title': ['Likier kokosowy '],
#   'photo_link': ['images/przepisy/likier_kokosowy.jpg'],
#   'ingredients': [['400 ml mleczka kokosowego\r'],
#    ['cukier \r'],
#    ['125 ml spirytusu 95%']],
#   'preparation': ['Mleczko kokosowe wlać do rondelka, dodać 300 g cukru. Mieszając podgrzewać mleczko do rozpuszczenia cukru, zagotować. Odstawić z ognia i ostudzić. Do lekko ciepłego mleczka dodać spirytus i dokładnie wymieszać. Wlać do butelki i wstawić do lodówki do schłodzenia. Po schłodzeniu można wyjąć i trzymać w temperaturze. pokojowej. ']},
#  {'link': ['https://kkpolska.pl/przepis/104/lemoniada_z_woda_kokosowa.html'],
#   'title': ['Lemoniada z wodą kokosową'],
#   'photo_link': ['images/przepisy/lemoniada.jpg'],
#   'ingredients': [['500ml wody kokosowej \r'],
#    ['2 szt. limonki \r'],
#    ['2 szt. grejpfruta czerwonego \r'],
#    ['syrop z agawy \r'],
#    ['1 szt. mango \r'],
#    ['1/2 melona \r'],
#    ['świeża mięta \r'],
#    ['lód ']],
#   'preparation': ['Melona oraz mango obrać i pokroić w kostkę. Do blendera wlać wodę kokosową, połowę obranych i pokrojonych wcześniej owoców, wyciśnięty sok z limonek oraz grejpfrutów i syrop z agawy, całość zmiksować. Lemoniadę przelać do dzbanka lub szklanek, udekorować kawałkami mango i melona oraz listkami świeżej mięty.']},
#  {'link': ['https://kkpolska.pl/przepis/130/kompot_rabarbarowo_-karmelowy_z_cytryna.html'],
#   'title': ['Kompot rabarbarowo -karmelowy z cytryną'],
#   'photo_link': ['images/przepisy/dsc_5201-edit-2.jpg'],
#   'ingredients': [['rabarbar 4 łodygi\r'],
#    ['woda 1 litr\r'],
#    ['cukier palmowy 50 g\r'],
#    ['cytryna 1⁄2 sztuki\r'],
#    ['melisa\r'],
#    ['lód']],
#   'preparation': ['Cukier podgrzać w garnku, dodać obrany i pokrojony w kostkę rabarbar, krótko poddusić. Następnie wlać wodę i całość\xa0 zagotować. Zestawić z ognia, ostudzić, dodać połówkę cytryny, wymieszać. Kompot można odcedzić na sicie, wyciskając łyżką sok z rabarbaru. Podawać z kostkami lodu.\nJeśli kompot jest za słodki można dodać 0,5 cytryny, jeśli zbyt kwaśny - więcej cukru palmowego.']},
#  {'link': ['https://kkpolska.pl/przepis/62/koktajl_trusawkowo-ananasowy_z_woda_kokosowa_mango.html'],
#   'title': ['Koktajl trusawkowo-ananasowy z wodą kokosową mango'],
#   'photo_link': ['images/przepisy/koktajl.png'],
#   'ingredients': [['200g ananasa (obranego i pokrojonego w kostkę)\r'],
#    ['1 dojrzałe mango\r'],
#    ['100-150g truskawek\r'],
#    ['100 ml wody kokosowej z mango\r'],
#    ['kostki lodu (opcjonalnie)']],
#   'preparation': ['1. Truskawki dokładnie umyć i obrać z szypułek.\r\n2. Ananasa obrać ze skórki i wykroić jego środek, pokroić go na kawałki.\r\n3. Mango obrać, odkroić miąższ i pokroić owoc na małe kawałki.\r\n4. Włożyć wszystkie składniki do blendera.\r\n5. Wlać wodę kokosową z mango i zmiksować wszystko na gładką masę.\r\n6. Dla schłodzenia napoju można dodać kostki lodu.']},
#  {'link': ['https://kkpolska.pl/przepis/64/egzotyczny_koktajl_ananasowo-kakaowy_z_woda_kokosowa.html'],
#   'title': ['Egzotyczny koktajl ananasowo-kakaowy z wodą kokosową'],
#   'photo_link': ['images/przepisy/pina-colada-cocktail-1280.jpg'],
#   'ingredients': [['200ml wody kokosowej z ananasem\r'],
#    ['100ml mleka\r'],
#    ['4 plastry ananasa\r'],
#    ['1 łyżeczka kakao']],
#   'preparation': ['1. Ananasa obrać i wyciąć z niego środek, pokroić w kostkę.\r\n2. Wodę kokosową schłodzić w lodówce przez ok. 10 minut.\r\n3. Wszystkie składniki włożyć do jednej miski i wymieszać.\r\n4. Całość przełoż do blendera i zmiksuj na gładką masę.']},
#  {'link': ['https://kkpolska.pl/przepis/53/drink_mango_margarita.html'],
#   'title': ['Drink Mango Margarita'],
#   'photo_link': ['images/przepisy/Mango Margarita.jpg'],
#   'ingredients': [['2 limonki\r'],
#    ['2 łyżki stołowe gruboziarnistego cukru lub soli\r'],
#    ['2 szklanki puree z mango\r'],
#    ['1 1/2 szklanki Tequili\r'],
#    ['1 1/2 szklanki likieru Triple Sec\r'],
#    ['1/4 szklanki cukru']],
#   'preparation': ['1. Puree z mango wymieszać z likierem Triple Sec, Tequilą i cukrem.\r\n2. Dodać sok z limonek oraz kilka kostek lodu.\r\n3. Całość zmiksować blenderem, dodać pół łyżeczki startej skórki z limonki.\r\n4. Krawędzie szklanek ozdobić cukrem lub solą i wlać do nich napój.']},
#  {'link': ['https://kkpolska.pl/przepis/92/drink_alkoholowy_z_napojem_mango_.html'],
#   'title': ['Drink alkoholowy z Napojem Mango '],
#   'photo_link': ['images/przepisy/wodka mango.png'],
#   'ingredients': [['40cl czystej wódki \r'],
#    ['sok z 1/2 limonki \r'],
#    ['Rubicon Deluxe Napój Mango \r'],
#    ['grenadina']],
#   'preparation': ['Do szklanki wypełnionej lodem wlać wódkę oraz sok z limonki. Szklankę dopełnić napojem z Mango i dodać kilka kropel grenadiny. ']},
#  {'link': ['https://kkpolska.pl/przepis/63/koktajl_bananowo-granatowy_z_woda_kokosowa_z_granatem.html'],
#   'title': ['Koktajl bananowo-granatowy z wodą kokosową z granatem'],
#   'photo_link': ['images/przepisy/koktajlgranat.jpg'],
#   'ingredients': [['1 banan\r'],
#    ['1 owoc z granatu\r'],
#    ['200 ml wody kokosowej z granatem']],
#   'preparation': ['1. Banana obrać i pokroić w plasterki.\r\n2. Z owocu granata wyjąć pestki.\r\n3. Do blendera włożyć pokrojonego banana oraz pestki granatu.\r\n4. Całość zalać wodą kokosową z granatem i zmiksować na gładką masę.']},
#  {'link': ['https://kkpolska.pl/przepis/95/drink_alkoholowy_z_napojem_guawa_.html'],
#   'title': ['Drink alkoholowy z napojem Guawa '],
#   'photo_link': ['images/przepisy/rubico.png'],
#   'ingredients': [['30 ml ciemnego rumu lub whisky \r'],
#    ['1 limonka \r'],
#    ['150 ml Rubicon Deluxe Napój Guawa \r'],
#    ['kilka kostek lodu \r'],
#    ['gazowana woda mineralna ']],
#   'preparation': ['Do szklanki o pojemności 250 ml wlać alkohol, wrzucić kilka kostek lodu i pokrojoną w ćwiartki limonkę, którą lekko zgnieść. Dolać napoju Guawa i dopełnić szklankę gazowaną wodą mineralną.\xa0 ']},
#  {'link': ['https://kkpolska.pl/przepis/96/drink_alkoholowy_tropical_fruit_punch_.html'],
#   'title': ['Drink alkoholowy Tropical Fruit Punch '],
#   'photo_link': ['images/przepisy/bez_nazwy-1.png'],
#   'ingredients': [['2 szklanki  soku ananasowego \r'],
#    ['1 szklanka napoju Rubicon Deluxe Guawa\r'],
#    ['Sok z 1/2 pomarańczy\r'],
#    ['Sok z 1/2 limonki\r'],
#    ['1 cząstka limonki']],
#   'preparation': ['do shakera barmańskiego dodać wszystkie składniki i wymieszać. Szklankę typu highball (long) napełnić lodem i napełnić drinkiem. Udekorować limonką. ']},
#  {'link': ['https://kkpolska.pl/przepis/97/drink_alkoholowy_bridgetown_breeze_.html'],
#   'title': ['Drink alkoholowy Bridgetown Breeze '],
#   'photo_link': ['images/przepisy/guawa_lychee.png'],
#   'ingredients': [['45ml Rumu Malibu\r'],
#    ['45ml napoju Rubicon Deluxe Lychee\r'],
#    ['45ml napoju Rubicon Deluxe Guawa\r'],
#    ['1 cząstka limonki']],
#   'preparation': ['Napełnić szklankę typu highball (long) lodem. Dodać wszystkie składniki. Udekorować limonką.']},
#  {'link': ['https://kkpolska.pl/przepis/85/choya_mojito.html'],
#   'title': ['Choya Mojito'],
#   'photo_link': ['images/przepisy/Choya Mojito.jpg'],
#   'ingredients': [['45ml wino z moreli japońskiej Choya Silver\r'],
#    ['2 łyżeczki brązowego cukru\r'],
#    ['8 liści mięty\r'],
#    ['1/2 limonki\r'],
#    ['kruszony lód\r'],
#    ['100-150ml gazowanej wody mineralnej']],
#   'preparation': ['1. Limonkę umyć, pokroić na mniejsze części, włożyć do szklanki.\r\n2.\xa0Do szklanki wsypać cukier brązowy oraz liście mięty, wszystko dokładnie ubić, aby wydobyć smak mięty, sok z limonki, a cukier się rozpuścił.\r\n3.\xa0Dodać Wino i dokładnie wymieszać.\r\n4.\xa0Do szklanki wsypać kruszony lód (wypełnić szklankę prawie do pełna), następnie dodać wodę mineralną gazowaną.\xa0 ']},
#  {'link': ['https://kkpolska.pl/przepis/86/choya_kamikaze_drink.html'],
#   'title': ['Choya Kamikaze Drink'],
#   'photo_link': ['images/przepisy/Choya Kamikaze Drink.jpg'],
#   'ingredients': [['15ml Wina z moreli japońskiej Choya Silver\r'],
#    ['30ml czystej wódki\r'],
#    ['15ml soku z limonki']],
#   'preparation': ['1.\xa0Wszystkie składniki wlać do shakera koktajlowego\r\n2. Dodać kilka kostek lodu i energicznie wymieszać.\r\n3.\xa0Drinka należy przecedzić i przelać do szklanki.']},
#  {'link': ['https://kkpolska.pl/przepis/87/choya_gin_drink.html'],
#   'title': ['Choya Gin Drink'],
#   'photo_link': ['images/przepisy/Choya Gin Drink.jpg'],
#   'ingredients': [['140ml Wina z moreli japońskiej Choya Silver\r'],
#    ['60ml ginu']],
#   'preparation': ['1. Wino Choya Silver oraz Gin wlać do kieliszka martini, wymieszać.\r\n2. Można podawać z kruszonym lodem']},
#  {'link': ['https://kkpolska.pl/przepis/106/bananowe_smoothie_z_woda_kokosowa_.html'],
#   'title': ['Bananowe smoothie z wodą kokosową '],
#   'photo_link': ['images/przepisy/smoothie_banan.jpg'],
#   'ingredients': [['3 dojrzałe banany \r'],
#    ['250ml wody kokosowej \r'],
#    ['1/2 cytryny ']],
#   'preparation': ['Banana obrać i pokroić na mniejsze kawałki i przy pomocy blendera zmiksować razem z wodą kokosową i wyciśniętym sokiem z cytryny na gładką, jednolitą masę. \n*banana możesz zastąpić innymi owocami np. pomarańczą, kiwi, truskawki, mango itd.\xa0 ']},
#  {'link': ['https://kkpolska.pl/przepis/103/ananasowy_koktajl_z_woda_kokosowa_.html'],
#   'title': ['Ananasowy koktajl z wodą kokosową '],
#   'photo_link': ['images/przepisy/ananas.jpg'],
#   'ingredients': [['150g świeżego ananasa \r'],
#    ['250ml wody kokosowej \r'],
#    ['limonka \r'],
#    ['kilka listków mięty \r'],
#    ['lód ']],
#   'preparation': ['Ananasa obrać i zmiksować na gładkie puree, następnie dodać wodę kokosową i miksować do momentu uzyskania jednolitego koktajlu. Podawać z plastrami limonki, listkami mięty oraz lodem. ']}]

# %% [markdown]
# # New Dataset

# %%
with open("recipes3.json") as file:
    data = json.load(file)

# %%
for d in data:
    d['ingredients'] = [ing for ing in d['ingredients'] if ing != '']
    for i, ing in enumerate(d['ingredients']):
        d['ingredients'][i] = [ing]

# %%
data
# Out:
# [{'link': 'https://beszamel.se.pl/mielone/indycze-mielone-z-kukurydza-sprytny-przepis-na-pieczone-kotlety-z-indyka,22379/',
#   'title': 'Indycze mielone z kukurydzą: sprytny przepis na pieczone kotlety z indyka',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22426/indycze-mielone-z-kukurydza-sprytny-przepis-na-pi.jpg',
#   'ingredients': [['500 g mielonego mięsa indyczego'],
#    ['1 bułka'],
#    ['1 cebula'],
#    ['1 puszka kukurydzy konserwowej'],
#    ['2 łyżki natki pietruszki, posiekanej'],
#    ['sól i pieprz'],
#    ['oraz do panierowania'],
#    ['2 jajka rozmiar S rozmącone z 2 łyżkami wody'],
#    ['mąka'],
#    ['tarta bułka']],
#   'preparation': 'Cebulę drobno posiekać. Bułkę namoczyć w ciepłej wodzie. Kukurydzę odsączyć.\xa0\nMięso mielone przełożyć do miski, dodać posiekaną cebulę, odciśniętą bułkę, przyprawić solą i pieprzem. Wymieszać, a następnie wyrabiać przez 2 minuty.\nDo masy mięsnej dodać odsączoną kukurydzę. Wymieszać na jednorodną mieszaninę.\xa0\nZ masy mięsnej formować jednakowe okrągłe kotlety, lekko je spłaszczyć.\nKotlety panierować w mące, rozmąconym jajku i bułce.\nKotlety ułożyć na blasze wyłożonej papierem do pieczenia.\nWstawić do piekarnika rozgrzanego do 180°C i piec 30 minut.\xa0\nPodawać z sałatką z pomidorów i papryki w stylu meksykańskim.\xa0',
#   'category': 'mielone'},
#  {'link': 'https://beszamel.se.pl/alkoholowe/jak-zrobic-nalewke-z-kwiatow-czarnego-bzu,1110/',
#   'title': 'Nalewka z kwiatów czarnego bzu - sprawdzony przepis',
#   'portions': '9',
#   'photo_link': 'https://cdn21.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/18812/nalewka-z-kwiatow-czarnego-bzu.jpg',
#   'ingredients': [['50 baldachimów kwiatów czarnego bzu'],
#    ['3/4 l wody'],
#    ['3/4 kg cukru'],
#    ['2 duże cytryny'],
#    ['3 limonki'],
#    ['1 l spirytusu']],
#   'preparation': 'Najpierw gotujemy syrop: na 3/4 kg cukru dajemy 3/4 litra wody, gotujemy i studzimy. Następnie\xa0kroimy 2 duże cytryny w plastry.\nWybieramy duży słój (albo 2 mniejsze). Układamy w nim zerwane baldachy (ok. 50 sztuk), przekładając je plasterkami cytryny. Na koniec wlewamy wystudzony syrop, słój przykrywamy gazą i odstawiamy w ciepłe, słoneczne miejsce na tydzień.\nPo tygodniu przecedzamy zawartość słoja przez sito - baldachy i plastry cytryny wyrzucamy. Płyn mieszamy z sokiem wyciśniętym z 3 limonek i 1 litrem spirytusu.\nPrzelewamy do butelek, szczelnie je zamykamy i odstawiamy na miesiąc w ciemne miejsce. Od czasu do czasu butelką należy wstrząsnąć.\nAlkohol filtrujemy przez bibułę, rozlewamy do "docelowych" butelek, szczelnie zamykamy i odstawiamy na co najmniej miesiąc w chłodne i ciemne miejsce.',
#   'category': 'alkoholowe'},
#  {'link': 'https://beszamel.se.pl/zupy-miesne-i-rybne/pozywna-zupa-z-czerwonej-soczewicy-z-klopsikami-sprytny-przepis,22387/',
#   'title': 'Pożywna zupa z czerwonej soczewicy z klopsikami: sprytny przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22435/pozywna-zupa-z-czerwonej-soczewicy-z-klopsikami-s.jpg',
#   'ingredients': [['100 g czerwonej soczewicy'],
#    ['500 g przecieru pomidorowego'],
#    ['1 l bulionu drobiowego lub warzywnego'],
#    ['1 batat, słodki ziemniak, około 100 g'],
#    ['1 cebula'],
#    ['6 ząbków czosnku'],
#    ['1 cm świeżego imbiru'],
#    ['3 łyżki oleju'],
#    ['przyprawy: 1 łyżeczka kurkumy, 2 łyżeczki przyprawy curry w proszku, 1/2 łyżeczki ostrej papryki'],
#    ['sól i pieprz'],
#    ['100 ml pełnotłustego mleka kokosowego'],
#    ['300 g mięsa drobiowego']],
#   'preparation': 'W garnku z grubym dnem rozgrzać olej. Dodać starty imbir, posiekaną cebulę i przeciśnięty przez praskę czosnek oraz przyprawy. Smażyć 2 minuty.\nDodać starty batat (słodki ziemniak). Dusić 2-4 minuty.\nWlać bulion i dodać soczewicę. Doprowadzić do wrzenia, a następnie gotować na wolnym ogniu przez 20 minut.\xa0\nDodać przecier pomidorowy i mleczko kokosowe. Zagotować.\nZ mielonego mięsa wyrobionego z 4 łyżkami wody uformować klopsiki wielkości orzecha. Dodać je do gotującej zupy. Przykryć pokrywką i gotować 5 minut.\nPodawać od razu z kromką chrupiącego pieczywa.\xa0',
#   'category': 'zupy miesne i rybne'},
#  {'link': 'https://beszamel.se.pl/wytrawne-ciasta/grecka-tarta-z-ciasta-filo-ze-szpinakiem,8766/',
#   'title': 'Grecka tarta z ciasta filo ze szpinakiem [spinakopita]',
#   'portions': '6',
#   'photo_link': 'https://cdn5.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/6620/grecka-tarta-ze-szpinakiem-ciasto-filo-ze-szpinak.jpg',
#   'ingredients': [['6 arkuszy ciasta filo'],
#    ['oliwa'],
#    ['250 g szpinaku'],
#    ['200 g pokruszonego sera feta'],
#    ['2 jajka'],
#    ['cebula'],
#    ['2 ząbki czosnku'],
#    ['gałka muszkatołowa'],
#    ['sól, pieprz']],
#   'preparation': 'Formę do tarty posmaruj oliwą.\nKażdy z arkuszy ciasta filo delikatnie smaruj oliwą i wykładaj nimi formę tak, aby boki ciasta wystawały poza formę. Każdy następny arkusz możesz układać nieco na zakładkę.\nNa głębokiej patelni na łyżce oliwy podduś pokrojoną w kostkę cebulę i posiekany czosnek.\nGdy będą gotowe, dodaj opłukany i odwirowany szpinak, mieszaj delikatnie, aż szpinak „zwiędnie”, dodaj szczyptę gałki muszkatołowej i odstaw do przestygnięcia.\nLetni szpinak wymieszaj z fetą i rozkłóconym jajkiem.\nMasę dopraw solą i pieprzem, przełóż do formy.\nBrzegi ciasta lekko pognieć i pozakładaj na farsz.\nPiecz ok. 40 minut w temperaturze 180ºC.',
#   'category': 'wytrawne ciasta'},
#  {'link': 'https://beszamel.se.pl/dania-glowne-bezmiesne/kluski-szpinakowe-prosty-przepis-na-pyszne-kluski,17104/',
#   'title': 'Kluski szpinakowe: prosty przepis na pyszne kluski',
#   'portions': '4',
#   'photo_link': 'https://cdn6.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/shutterstock_564548233.jpg',
#   'ingredients': [['1 kg'],
#    ['25 dag tłustego białego sera'],
#    ['1 jajko'],
#    ['1 łyżka mąki'],
#    ['sól, pieprz, 1/2 łyżeczki tartej gałki muszkatołowej'],
#    ['3 łyżki masła'],
#    ['garść pokrojonych liści świeżej szałwii']],
#   'preparation': 'Szpinak myjemy i krótko gotujemy w małej ilości osolonej wody. Odcedzamy, dokładnie odciskamy i drobno siekamy.\nRozgniatamy ser widelcem, dodajemy szpinak, jajko, mąkę, sól, nieco pieprzu i gałkę muszkatołową. Wszystko razem zagniatamy.\xa0\nNa stolnicy posypanej mąką\xa0 formujemy z ciasta\xa0 wałeczki o średnicy około 2 cm, długości 4 cm.\nWrzucamy\xa0kluski do wrzącej wody, a kiedy wypłyną na powierzchnię, wyjmujemy\xa0 łyżką cedzakową.\nW czasie gdy\xa0kluski gotują się, rozpuszczamy na patelni masło i obsmażamy na nim krótko szałwię.\nKluski układamy na ogrzanym półmisku, polewamy gorącym masłem z szałwią.',
#   'category': 'dania glowne bezmiesne'},
#  {'link': 'https://beszamel.se.pl/weganskie/pieczone-burgery-z-pieczarek-i-fasoli-tani-przepis-dla-zaradnych,22294/',
#   'title': 'Pieczone burgery z pieczarek i fasoli: tani przepis dla zaradnych',
#   'portions': '4',
#   'photo_link': 'https://cdn3.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22311/pieczony-burger-z-pieczarek-i-fasoli.jpg',
#   'ingredients': [['3 łyżki mielonego siemienia lnianego'],
#    ['5 łyżek wody'],
#    ['1 1/2 szklanki białej fasoli z puszki, odsączonej'],
#    ['1 cebula, posiekana drobno'],
#    ['1 ząbek czosnku, posiekany'],
#    ['1/2 szklanki bułki tartej'],
#    ['1/2 szklanki płatków owsianych, zmielonych na mąkę'],
#    ['150 g pieczarek, pokrojonych drobno'],
#    ['1 szklanka świeżej natki pietruszki, posiekanej'],
#    ['1 łyżeczka oregano suszonego'],
#    ['1 łyżeczka słodkiej papryki'],
#    ['1/2 szklanki płatków owsianych do panierowania'],
#    ['sól dla smaku'],
#    ['czarny pieprz do smaku']],
#   'preparation': 'Zmielony len wymieszaj z wodą i odstaw na bok do namoczenia.\nWłóż 1/2 szklanki płatków owsianych do blendera lub robota kuchennego i zmiel w trybie pulsacyjnym na mąkę.\nZmiksuj fasolę w malakserze, aby otrzymać puree.\nNa małej patelni rozgrzej trochę oleju i podsmaż cebulę i czosnek przez około 3 minuty. Zdejmij i zachowaj na później.\nNa tej samej patelni usmaż pokrojone pieczarki.\nDo puree z fasoli dodaj namoczony len, mąkę owsianą, usmażoną cebulę z czosnkiem i pieczarki oraz wszystkie przyprawy. Wymieszaj.\nUformuj cztery duże burgery (lub 6 mniejszych).\nKażdy burger panieruj w całych płatkach owsianych.\nWyłóż blachę do pieczenia pergaminem i ułóż na niej burgery.\nPiecz przez 30 minut w temperaturze 180°C. Po pierwszych 15 minutach przewróć burgery na drugą stronę.\nPodawaj w bułce z dodatkami lub jako kotlety z surówką.',
#   'category': 'weganskie'},
#  {'link': 'https://beszamel.se.pl/pasty/pesto-z-mniszka-lekarskiego-i-migdalow,22313/',
#   'title': 'Pesto z mniszka lekarskiego i migdałów',
#   'portions': '4',
#   'photo_link': 'https://cdn20.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22331/pesto-z-mniszka-lekarskiego-i-migdalow.jpg',
#   'ingredients': [['2 szklanki ciasno upakowanych, pokrojonych liści mniszka lekarskiego, dobrze opłukanych i wysuszonych'],
#    ['1 tuzin dużych liści bazylii'],
#    ['2 ząbki czosnku'],
#    ['1 szklanka lekko prażonych migdałów lub orzechów laskowych lub orzeszków piniowych lub orzechów włoskich'],
#    ['1/2 szklanki oliwy z oliwek'],
#    ['1/2 szklanki startego sera parmezan (opcjonalnie)'],
#    ['sól i świeżo zmielony czarny pieprz']],
#   'preparation': 'Do misy malaksera dodać liście mniszka i bazylii, czosnek, orzechy i oliwę. Zmiksować.\xa0\nDodać parmezan, przyprawić solą i pieprzem. Ponownie zmiksować.\nPrzełożyć do czystych, wyparzonych słoików. W sumie będą potrzebne 3 słoiki o pojemności 0,25 l.\nPrzechowywać w lodówce.\xa0',
#   'category': 'pasty'},
#  {'link': 'https://beszamel.se.pl/salatki-z-owocami/salatka-ze-szpinaku-pomarancza-przepis-na-romantyczna-przekaske,12694/',
#   'title': 'Sałatka ze szpinaku z pomarańczą przepis na pyszną przekąskę',
#   'portions': '2',
#   'photo_link': 'https://cdn24.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/9681/salatka-ze-szpinaku-i-pomaranczy.jpg',
#   'ingredients': [['1 opakowanie'],
#    ['2 obrane i podzielone na cząstki  (najlepiej sycylijskie, krwistoczerwone) - w sezonie mogą być truskawki'],
#    ['kawałek imbiru (3 cm) obrany i starty na tarce'],
#    ['2 szalotki drobno posiekane'],
#    ['odrobina świeżego lub suszonego chili'],
#    ['czubata łyżka posiekanych orzechów ziemnych'],
#    ['kilka kropel sosu balsamico lub octu balsamicznego'],
#    ['odrobina miodu'],
#    ['kozi lub owczy serek']],
#   'preparation': 'W dużej misce wymieszaj wszystkie składniki (drobno posiekane) poza szpinakiem.\nNa półmisek wyłóż liście, a na nie za pomocą łyżki przełóż przygotowaną wcześniej masę.\nPo wierzchu posyp pokruszonym serkiem i uprażonymi orzechami.',
#   'category': 'salatki z owocami'},
#  {'link': 'https://beszamel.se.pl/kremy-i-musy/krem-do-tortu-z-serka-mascarpone-i-bitej-smietany,7970/',
#   'title': 'Krem do tortu z serka mascarpone i bitej śmietany - lekki i aksamitny',
#   'portions': '4',
#   'photo_link': 'https://cdn18.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22447/krem-do-tortu-z-serka-mascarpone-i-bitej-smietany.jpg',
#   'ingredients': [['500 ml śmietanki kremówki 30 lub 36%'],
#    ['500 g serka mascarpone'],
#    ['aromat'],
#    ['3 łyżki cukru pudru']],
#   'preparation': 'Śmietanę należy przełożyć do dużej miski. Dodać aromat oraz przesiany przez sitko cukier puder.\nUbijać mikserem, zaczynając od najwyższych obrotów, a następnie zmniejszyć prędkość, aby lepiej obserwować stan śmietany.\nDo ubitej śmietany dodać serek mascarpone i dalej miksować, aż do połączenia składników.\nKrem jest gotowy, gdy składniki stworzą jednolitą, gładką masę. W konsystencji powinien przypominać bardzo dobrze ubitą śmietanę.',
#   'category': 'kremy i musy'},
#  {'link': 'https://beszamel.se.pl/przetwory-z-mleka/domowy-serek-mascarpone-przepis-jak-wykorzystac-zapasy-smietany,22359/',
#   'title': 'Domowy serek mascarpone: przepis jak wykorzystać zapasy śmietany',
#   'portions': '4',
#   'photo_link': 'https://cdn29.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22391/domowy-serek-mascarpone.jpg',
#   'ingredients': [['400 g śmietany 30%'],
#    ['200 g śmietany 12%'],
#    ['2 łyżeczki soku cytrynowego']],
#   'preparation': 'Obie śmietany wlać do garnka, dodać sok z cytryny i wymieszać rózgą.\nGarnek wstawić do większego garnka z wodą, podgrzewać w kąpieli wodnej. Od czasu do czasu mieszać.\nPodgrzewać do temperatury 80°C lub do chwili, gdy śmietana się zetnie i powstaną grudki. Nie zagotować.\nZdjąć z ognia i wylać na sito wyłożone kilkukrotnie złożoną gazą lub muślinem (gęstym płótnem). Odstawić do ostygnięcia.\nSerek powinien odciekać co najmniej 12 godzin.\nZ tej porcji składników otrzymacie około 250 g serka mascarpone.\nGotowy serek przełożyć do czystego i wyjałowionego pojemnika. Przechowywać w lodówce do 7 dni.\xa0',
#   'category': 'przetwory z mleka'},
#  {'link': 'https://beszamel.se.pl/kuchnie-swiata/jak-zrobic-grecka-pizze-ze-szpinakiem-przepis,3681/',
#   'title': 'Grecka pizza, czyli chlebek pita zapiekany ze szpinakiem. Jak zrobić?',
#   'portions': '2',
#   'photo_link': 'https://cdn7.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/2736/jak-zrobic-grecka-pizze-ze-szpinakiem-podajemy-pr.jpg',
#   'ingredients': [['duży płaski chlebek pita'],
#    ['¼ szklanki pokrojonej w kostkę cebuli'],
#    ['¾ szklanki rozmrożonego'],
#    ['¼ szklanki rozdrobnionego sera feta'],
#    ['¼ łyżeczki oliwy z oliwek'],
#    ['¼ łyżeczki sproszkowanego czosnku'],
#    ['¼ łyżeczki czarnego pieprzu'],
#    ['sól']],
#   'preparation': 'Cebulę smaż na oliwie z oliwek około 1 minuty, dodaj szpinak i duś jeszcze 3 minuty.\nDopraw pieprzem, czosnkiem i solą.\nUłóż w formie chlebek pita, posmaruj sosem, posyp pokruszoną fetą i wstaw do piekarnika rozgrzanego do 250 stopni.\nPiecz ok. 15 minut.',
#   'category': 'kuchnie swiata'},
#  {'link': 'https://beszamel.se.pl/wegetarianskie/oszczedne-burgery-z-ciecierzycy-i-sera-feta,22291/',
#   'title': 'Oszczędne burgery z ciecierzycy i sera feta',
#   'portions': '4',
#   'photo_link': 'https://cdn22.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22307/oszczedne-burgery-z-ciecierzycy-i-sera-feta.jpg',
#   'ingredients': [['1 puszka ciecierzycy - całkowita waga 310 g, waga po odsączeniu 265 g'],
#    ['2 marchewki średniej wielkości - obrane i starte na drobne wiórki'],
#    ['20 g świeżych liści pietruszki, posiekanych - alternatywnie kolendra'],
#    ['150 g fety - rozdrobnionej'],
#    ['2 jajka - rozmiar M, roztrzepane'],
#    ['50 g mąki'],
#    ['1 łyżeczka proszku do pieczenia'],
#    ['1 łyżeczka soli lub więcej do smaku'],
#    ['1/4 łyżeczki pieprzu lub więcej do smaku'],
#    ['olej roślinny do smażenia']],
#   'preparation': 'Odsączoną ciecierzycę zmiksować w malakserze na puree.\nDo puree z ciecierzycy dodać startą marchew, ser feta, natkę pietruszki, rozmącone jajka, mąkę z proszkiem do pieczenia. Ewentualnie doprawić solą i pieprzem, pamiętając, że ser feta jest już słony.\xa0\nWszystko razem wymieszać.\xa0\nSmażyć na rozgrzanym tłuszczu, rumieniąc z obu stron.\xa0\nPodawać z warzywami jako samodzielne danie lub w bułce z dodatkami warzywnymi.\xa0',
#   'category': 'wegetarianskie'},
#  {'link': 'https://beszamel.se.pl/salatki-na-salacie/wiosenna-salatka-z-roszponki-i-sera-lazur-ze-smazonymi-ziemniakami-pieczarkami,22263/',
#   'title': 'Wiosenna sałatka z roszponki i sera lazur: ze smażonymi ziemniakami i pieczarkami',
#   'portions': '4',
#   'photo_link': 'https://cdn7.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22276/wiosenna-salatka-z-roszponki-i-sera-lazur-ze-smaz.jpg',
#   'ingredients': [['300 g młodych ziemniaków, ugotowanych'],
#    ['100 g pieczarek'],
#    ['1 łyżka oleju'],
#    ['1 cebula czerwona, pokrojona na półkola'],
#    ['50-100 g sera lazur'],
#    ['150 g roszponki'],
#    ['na dressing:'],
#    ['1 łyżka musztardy'],
#    ['1 łyżka soku z cytryny'],
#    ['2 łyżki miodu'],
#    ['3 łyżki oliwy']],
#   'preparation': 'Ziemniaki pokroić na połówki, a jeśli są większe od jajka kurzego, to pokroić na ćwiartki. Pieczarki przeciąć na pół.\nNa patelni rozgrzać olej. Na gorący olej kłaść ziemniaki przecięciem do dołu i smażyć do zrumienienia. Następnie usmażyć na rumiano pieczarki. Odstawić.\nZ podanych składników zmiksować dressing.\nNa głębokim półmisku lub w płytkiej dużej misce ułożyć roszponkę. Na sałacie rozłożyć usmażone ziemniaki i pieczarki. Posypać cebulą. Porozkładać kawałki pokruszonego sera typu lazur.\xa0\nSałatkę polać dressingiem tuż przed podaniem, ponieważ roszponka jest bardzo delikatna i szybko zwiędnie pod wpływem kwasów zawartych w dressingu.\xa0',
#   'category': 'salatki na salacie'},
#  {'link': 'https://beszamel.se.pl/ciasta-i-desery/ciasto-kruche-z-rabarbarem-truskawkami-daktylami-i-miodem-przepis-wideo,4597/',
#   'title': 'Ciasto kruche z rabarbarem, truskawkami, daktylami i miodem',
#   'portions': '6',
#   'photo_link': 'https://cdn22.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22375/ciasto-kruche-z-rabarbarem-truskawkami-daktylami.jpg',
#   'ingredients': [['<em>Na ciasto kruche:</ em>'],
#    ['150 g mąki pszennej'],
#    ['100 g mąki ziemniaczanej'],
#    ['50 g cukru'],
#    ['150 g masła'],
#    ['1 jajko'],
#    ['<em>Na nadzienie:</ em>'],
#    ['500 g rabarbaru'],
#    ['200 g truskawek'],
#    ['3 łyżki płynnego miodu'],
#    ['5 łyżek cukru'],
#    ['1 cukier wanilinowy'],
#    ['100 g suszonych daktyli'],
#    ['<em>Na kruszonkę:</ em>'],
#    ['150 g mąki pszennej'],
#    ['50 g mąki ziemniaczanej'],
#    ['50 g cukru'],
#    ['125 g schłodzonego masła'],
#    ['cukier puder']],
#   'preparation': 'Formę prostokątną posmaruj masłem i wyłóż papierem do pieczenia.\nDo miski przesiej obydwie mąki, dodaj cukier, pokrojone na kawałki masło i jajko. Rozcieraj palcami masło z resztą składników, szybko zagnieć ciasto, łącząc wszystko w jednolitą kulę.\nCiastem wyłóż dno i kawałek boku formy. Spód podziurkuj widelcem i wstaw do lodówki na pół godziny.\nPiekarnik nagrzej do 160 stopni Celjusza. Wstaw blaszkę z ciastem do piekarnika i piecz przez 25 minut na bladozłoty kolor.\nWyjmij ciasto, ale nie wyłączaj piekarnika - temperaturę nastaw na 180 stopni.\nRabarbar i truskawki pokrój na kawałki, wymieszaj z miodem, cukrem, cukrem wanilinowym oraz drobno posiekanymi daktylami.\nDo drugiej miski przesiej obydwie mąki, dodaj cukier i pokrojone na kawałeczki zimne masło. Rozcieraj palcami masło z resztą składników, aż powstanie kruszonka.\nNa podpieczony spód wyłóż przygotowane nadzienie z rabarbaru, wierzch posyp kruszonką i wstaw do piekarnika. Piecz przez 35-40 minut na lekko złoty kolor.\nPo upieczeniu posyp cukrem pudrem.',
#   'category': 'ciasta i desery'},
#  {'link': 'https://beszamel.se.pl/wegetarianskie/bezglutenowa-tarta-szpinakowa-sprawdzony-przepis,3600/',
#   'title': 'Bezglutenowa tarta szpinakowa - sprawdzony przepis',
#   'portions': '2',
#   'photo_link': 'https://cdn15.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/1970/tarta-szpinakowajpg.jpg',
#   'ingredients': [['pół kostki masła'],
#    ['szklankę mąki kukurydzianej'],
#    ['jedno jajko'],
#    ['kilka łyżek wody mineralnej niegazowanej'],
#    ['450 g mrożonego'],
#    ['200 g startego parmezanu'],
#    ['200 g mozzarelli'],
#    ['kilka suszonych pomidorów'],
#    ['trzy ząbki czosnku'],
#    ['przyprawy']],
#   'preparation': 'Masło, mąkę, jajko wraz z kilkoma łyżkami wody ugniatamy, aż powstaną sporej wielkości okruchy ciasta.\nŁączymy je w kulę, owijamy w folię aluminiową i wkładamy do lodówki na godzinę.\nKiedy ciasto się chłodzi, wrzucamy na patelnię trochę masła klarowanego, a następnie opakowanie szpinaku.\nPo kilku minutach mieszania dodajemy sól, pieprz oraz wyciskamy trzy ząbki czosnku.\nPo chwili zdejmujemy patelnię z ognia i zabieramy się za ciasto (jeśli upłynęła godzina leżakowania w lodówce).\nWałkujemy je na cieniutki placek i wkładamy do formy do pieczenia. Wystające brzegi odrywamy i nakłuwamy ciasto na całej powierzchni widelcem.\nPrzykrywamy je papierem do pieczenia i wkładamy do piekarnika na 10 minut w temp. 180 stopni.\nWyjmujemy formę, zdejmujemy papier i nakładamy na ciasto szpinak, posypując go parmezanem, pomidorami i rozdrobnioną mozzarellą.\nPonownie wkładamy wszystko do piekarnika na 20 minut i gotowe! Poczekaj chwilę, aż tarta ostygnie i zabieraj się do jedzenia.',
#   'category': 'wegetarianskie'},
#  {'link': 'https://beszamel.se.pl/kompoty/kompot-z-rabarbarem-i-gozdzikami,8508/',
#   'title': 'Kompot z rabarbarem i goździkami - pyszny napój na ciepłe dni',
#   'portions': '10',
#   'photo_link': 'https://cdn16.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/kompot-z-rabarbaru.jpg',
#   'ingredients': [['kilogram rabarbaru'],
#    ['szklanka cukru'],
#    ['2-3 litry wody'],
#    ['kilka goździków'],
#    ['sok z cytryny']],
#   'preparation': 'Umyte łodygi rabarbaru pokroić w plastry grubości 1 cm.\nDo garnka wlać wodę, wsypać cukier, dodać rabarbar i goździki.\nNa koniec wlać sok z cytryny.\nGotować przez około 20 min.\nPodawać na ciepło lub na zimno. Smacznego!',
#   'category': 'kompoty'},
#  {'link': 'https://beszamel.se.pl/ciasta-i-desery/szybkie-ciasto-z-truskawkami-i-rabarbarem-latwy-przepis,4599/',
#   'title': 'Szybkie ciasto z truskawkami i rabarbarem - łatwy przepis!',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/recipes/photo/ciasto-z-truskawkami-i-rabarbarem.jpg',
#   'ingredients': [['300 g rabarbaru'],
#    ['200 g truskawek'],
#    ['185 g masła'],
#    ['3 jajka'],
#    ['90 g mąki'],
#    ['230 g drobnego cukru'],
#    ['cukier puder do posypania'],
#    ['3/4 łyżeczki proszku do pieczenia'],
#    ['1/2 łyżeczki ekstraktu z wanilii']],
#   'preparation': 'Rabarbar obierz i pokrój na plasterki grubości ok. 5 mm.\nPokrojony rabarbar przełóż do miski i posyp cukrem (mniej więcej 1/3 cukru). Mieszaj co jakiś czas, aż zacznie puszczać soki. Następnie dokładnie odsącz rabarbar.\nDodaj do odsączonego rabarbaru pokrojone w kostkę truskawki.\nNagrzej piekarnik do temperatury 180 stopni. Blachę wyłóż papierem do pieczenia.\nUtrzyj masło z cukrem (1/3) oraz ekstraktem waniliowym na puszystą masę.\nPowoli dodaj jajka w równych odstępach czasu, dokładnie miksując. Przesiej mąkę z proszkiem do pieczenia. Całość przełóż do wcześniej ubitej masy i powoli wymieszaj.\nNastępnie wyłóż ciasto na blachę, ułóż warstwę rabarbaru z truskawkami i oprósz cukrem (1/3). Ciasto piecz około 30 minut, w momencie kiedy się zarumieni, wyciągnij.\nGdy ciasto lekko ostygnie, możesz je dodatkowo posypać cukrem pudrem.',
#   'category': 'ciasta i desery'},
#  {'link': 'https://beszamel.se.pl/salatki-i-surowki/salatka-ziemniaczana-z-kaparami-i-majerankiem,22393/',
#   'title': 'Sałatka ziemniaczana z kaparami i majerankiem',
#   'portions': '6',
#   'photo_link': 'https://cdn6.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22441/salatka-ziemniaczana-z-kaparami-i-majerankiem.jpg',
#   'ingredients': [['1 kg ziemniaków'],
#    ['3 kiszone ogórki'],
#    ['1 czerwona cebula'],
#    ['4 łyżki kaparów'],
#    ['5 łyżek sosu sojowego'],
#    ['5 łyżek oliwy'],
#    ['2 garście świeżego majeranku'],
#    ['pieprz']],
#   'preparation': 'Ziemniaki wyszorować i ugotować w mundurkach. Nie rozgotować.\nKiedy ziemniaki ostygną obrać je i pokroić w grubą kostkę. Zalać oliwą wymieszaną z sosem sojowym, wymieszać z drobno posiekanym majerankiem. Odstawić na 2 godziny do lodówki.\nOgórki i cebulę pokroić i dodać z kaparami do sałatki. Doprawić pieprzem.',
#   'category': 'salatki i surowki'},
#  {'link': 'https://beszamel.se.pl/salatki-z-burakow/pieczone-buraki-z-rabarbarem-mozzarella-i-octem-balsamicznym,8637/',
#   'title': 'Pieczone buraki z rabarbarem, mozzarellą i octem balsamicznym',
#   'portions': '8',
#   'photo_link': 'https://cdn8.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/PIeczoneBurakiIRabarbar_m.jpg',
#   'ingredients': [['1 kg obranych buraków'],
#    ['4 łodygi rabarbaru'],
#    ['500 g sera mozzarella'],
#    ['1 opakowanie gotowej mieszanki sałat'],
#    ['2 zielone cykorie'],
#    ['oliwa z oliwek'],
#    ['sól morska i wędzona'],
#    ['sok z 1 cytryny'],
#    ['ocet balsamiczny']],
#   'preparation': 'Umyte, obrane i pokrojone w cząstki buraki przełożyć na blachę, skropić oliwą z oliwek, oprószyć solą morską i piec 35–45 minut w piekarniku nagrzanym do 220°C.\nUmyty rabarbar pokroić w plastry grubości 0,5 cm, przełożyć na blachę, skropić oliwą z oliwek, sokiem z cytryny oraz octem balsamicznym i piec 15-20 minut w piekarniku nagrzanym do 220°C.\nMieszankę sałat połączyć z pokrojoną cykorią ułożyć na półmisku razem z upieczonymi burakami i rabarbarem oraz pokrojoną w „ćwiartki” mozzarellą.\nCałość skropić oliwą z oliwek i oprószyć solą morską lub wędzoną.',
#   'category': 'salatki z burakow'},
#  {'link': 'https://beszamel.se.pl/muffinki-i-babeczki/wytrawne-muffinki-ze-szpinakiem-i-serem-feta-latwy-przepis,3032/',
#   'title': 'Wytrawne muffinki ze szpinakiem i serem feta: łatwy przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn12.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/2130/muffinki-ze-szpinakiem-i-serem-feta-jak-zrobicjpg.jpg',
#   'ingredients': [['25 dag'],
#    ['25 dag sera feta'],
#    ['35 dag mąki'],
#    ['2 jajka'],
#    ['2 płaskie łyżeczki proszku do pieczenia'],
#    ['250 ml jogurtu naturalnego'],
#    ['60 ml oliwy z oliwek'],
#    ['sól i pieprz']],
#   'preparation': 'Umyty szpinak włożyć do rondla, podlać odrobiną wody, dodać szczyptę soli i pieprzu, dusić ok. 5 minut. Po wystudzeniu odcisnąć nadmiar wody, posiekać.\nPrzygotować dwie miski. Do jednej przesiać mąkę, proszek do pieczenia i 1/3 płaskiej łyżeczki soli. W drugiej ubić jajka z jogurtem i oliwą. Wlać do miski z suchymi składnikami i wymieszać. Dodać szpinak i fetę pokrojoną w drobną kostkę.\nForemki napełnić ciastem do 2/3 wysokości. Wstawić do piekarnika nagrzanego do temp. 180 st. C i piec przez ok. 20 minut. Podawać na ciepło lub na zimno.',
#   'category': 'muffinki i babeczki'},
#  {'link': 'https://beszamel.se.pl/faszerowane/pieczen-wolowa-faszerowana-jajecznica,22107/',
#   'title': 'Pieczeń wołowa faszerowana jajecznicą',
#   'portions': '5',
#   'photo_link': 'https://cdn5.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22101/pieczen-wolowa-faszerowana-jajecznica.jpg',
#   'ingredients': [['1 kg rostbefu'],
#    ['100 g baleronu'],
#    ['5 jajek'],
#    ['100 g słoniny'],
#    ['2 cebule'],
#    ['2 łyżki oleju'],
#    ['1 łyżeczka oregano'],
#    ['pieprz ziołowy i pieprz biały, sól']],
#   'preparation': 'Mięso pokroić wzdłuż włókien, tak aby po rozłożeniu powstał duży prostokąt. Słoninę pokroić na paseczki.\nBaleron pokroić w kostkę i podsmażyć na oleju, dodać roztrzepane jajka i usmażyć jajecznicę.\nMięso posolić, oprószyć majerankiem i pieprzem, a następnie posmarować jajecznicą.\nMięso zwinąć dość ciasno i obwiązać nitką, aby się nie rozwijało. Zrumienić z każdej strony na patelni z rozgrzanym tłuszczem.\nZ podsmażonego mięsa zdjąć nitkę i przełożyć je do brytfanny, obłożyć paskami słoniny i pokrojoną w talarki cebulą.\nWstawić do piekarnika nagrzanego do 180 st. C. na 1,5 godziny.',
#   'category': 'faszerowane'},
#  {'link': 'https://beszamel.se.pl/salatki-i-surowki/salatka-z-czerwonej-fasoli-i-rzymskiej-salaty-na-ostro,22244/',
#   'title': 'Niedroga sałatka z czerwonej fasoli i rzymskiej sałaty na ostro',
#   'portions': '4',
#   'photo_link': 'https://cdn16.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22255/salatka-z-czerwonej-fasoli-i-rzymskiej-salaty-na-o.jpg',
#   'ingredients': [['1 sałata (masłowa, lodowa, rzymska)'],
#    ['1 puszka czerwonej fasoli'],
#    ['2 średnie cebule'],
#    ['200 ml pikantnego keczupu'],
#    ['tabasco'],
#    ['1 czerwona papryka'],
#    ['50 g wędzonego boczku w cieniutkich plastrach'],
#    ['sól i pieprz']],
#   'preparation': 'Sałatę umyć, osuszyć i poszatkować. Paprykę umyć, oczyścić z nasion i pokroić w kosteczkę.\nFasolę i kukurydzę odcedzić z zalewy, opłukać i osączyć. Cebulę obrać i posiekać.\nNa suchej patelni zrumienić boczek na chrupko. Zdjąć boczek i na tłuszczu z niego zeszklić cebulę.\nPo chwili dodać keczup i zagotować. Przyprawić odrobiną tabasco.\nWarzywa wymieszać, polać sosem i odstawić na 15 min, następnie wymieszać.\nSałatkę podawać z ułożonymi na wierzchu plastrami chrupiącego boczku.',
#   'category': 'salatki i surowki'},
#  {'link': 'https://beszamel.se.pl/morskie/superoszczedne-kotlety-z-sardynki-w-oleju-przepis-na-pyszne-kotlety-rybne,22355/',
#   'title': 'Superoszczędne kotlety z sardynki w oleju: przepis na pyszne kotlety rybne',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22386/superoszczedne-kotlety-z-sardynki-w-oleju-przepis.jpg',
#   'ingredients': [['240 g sardynki w oleju'],
#    ['100 g ryżu surowego (1 torebka)'],
#    ['1 cebula duża'],
#    ['2 jajka'],
#    ['1 łyżka koperku posiekanego'],
#    ['sól i pieprz do smaku'],
#    ['8 łyżek tartej bułki'],
#    ['100 ml oleju do smażenia']],
#   'preparation': 'Ryż ugotuj w osolonym wrzątku zgodnie z instrukcją na opakowaniu.\nOdcedź szproty, pozostawiając trochę oleju na dnie puszki.\nWyjmij zawartość puszki do miski i rozgnieć widelcem.\nPosiekaną cebulę zrumień na rozgrzanym oleju.\nDo rozdrobnionej ryby dodaj ugotowany i ostudzony ryż, rozmącone jajka, posiekany koperek i zrumienioną cebulę. Wymieszaj wszystko na jednorodną masę.\nMasę podziel na 12 równych porcji. Z każdej uformuj kulę, a następnie ją spłaszcz na okrągły kotlet.\nKotlety panieruj w tartej bułce.\nSmaż kotlety na rozgrzanym oleju.\nPodawaj z surówką ze świeżej lub kiszonej kapusty.',
#   'category': 'morskie'},
#  {'link': 'https://beszamel.se.pl/pizza/chrupiaca-i-cienka-pizza-bez-drozdzy-i-proszku-do-pieczenia-latwe-ciasto-z-maki-jajek-i-mleka,22074/',
#   'title': 'Chrupiąca i cienka pizza bez drożdży i proszku do pieczenia: łatwe ciasto z mąki, jajek i mleka',
#   'portions': '4',
#   'photo_link': 'https://cdn28.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22057/chrupiaca-pizza-bez-drozdzy-i-proszku-do-pieczenia.jpg',
#   'ingredients': [['Na ciasto:'],
#    ['1 szklanka uniwersalnej mąki'],
#    ['1 łyżeczka soli'],
#    ['1 łyżeczka mieszanki włoskich ziół: oregano, bazylia, rozmaryn'],
#    ['⅛ łyżeczki pieprzu'],
#    ['2 jajka'],
#    ['⅔ szklanki mleka'],
#    ['Dodatki:'],
#    ['250 g białej kiełbasy wieprzowej, usmażony farsz bez skóry'],
#    ['1 szklanka plasterków pepperoni'],
#    ['⅓ szklanki gotowanej szynki pokrojonej w kostkę'],
#    ['2-4 pieczarki, pokrojone na plasterki'],
#    ['1½ szklanki sosu do pizzy'],
#    ['2 szklanki posiekanego sera mozzarella'],
#    ['½ papryki zielonej, pokrojonej na cienkie paseczki'],
#    ['½ cebuli czerwonej, pokrojonej na cienkie paseczki']],
#   'preparation': 'Rozgrzej piekarnik do 220ºC. Blachę do tarty o średnicy ok. 30 cm posmaruj tłuszczem i odłóż na bok.\nBiałą kiełbasę rozetnij i wyjmij zawartość flaka. Farsz kiełbasiany zrumień na patelni, cały czas mieszając, aby rozbić mięso na małe grudki.\xa0\nWymieszaj mąkę, sól, mieszankę włoskich ziół, pieprz, jajka i mleko.\nCiasto wylej do przygotowanej blachy do pieczenia. Na wierzchu ułóż kawałki kiełbasy, plasterki pepperoni i szynki oraz pieczarki.\nPiecz przez 20 minut.\nWyjmij z piekarnika. Sos do pizzy rozłóż równomiernie na pizzy i posyp mozzarellą. Na wierzch ułóż paseczki papryki i krążki cebuli.\xa0\nWłóż do piekarnika i piecz 10–15 minut, aż ser się rozpłynie i lekko przyrumieni.',
#   'category': 'pizza'},
#  {'link': 'https://beszamel.se.pl/przetwory-z-mleka/cytrusowy-twarozek-paneer-latwy-przepis-na-serek-smakowy,22371/',
#   'title': 'Cytrusowy twarożek paneer: łatwy przepis na serek smakowy',
#   'portions': '0',
#   'photo_link': 'https://cdn5.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22418/cytrusowy-twarozek-paneer-latwy-przepis-na-serek.jpg',
#   'ingredients': [['1 l mleka świeżego, poddanego mikrofiltracji i pasteryzacji 72-74°C'],
#    ['2 cytryny'],
#    ['4 pomarańcze']],
#   'preparation': 'Wycisnąć sok z owoców.\nMleko doprowadzić do zagotowania, zestawić, dać ostygnąć do 96°C.\nDodać sok z wyciśniętych\xa0owoców. Delikatnie mieszać aby równomiernie połączyć płyny. Pozostawić na 15 minut.\nNastępnie\xa0przelać utworzony skrzep na sito wyścielone gazą. Odciekać około jednej do dwóch godzin.\nWyjąć zgazy, schować do lodówki.',
#   'category': 'przetwory z mleka'},
#  {'link': 'https://beszamel.se.pl/ciasta-i-desery/ciasto-z-rabarbarem-truskawkami-i-rodzynkami-sprawdzony-przepis,4598/',
#   'title': 'Ciasto z rabarbarem, truskawkami i rodzynkami: sprawdzony przepis',
#   'portions': '6',
#   'photo_link': 'https://cdn9.beszamel.smcloud.net/t/thumbs/660/441/1/recipes/photo/ciasto-z-rabarbarem-truskawkami-i-rodzynkami-sprawdzony-przepis.jpg',
#   'ingredients': [['3 szklanki mąki pszennej'],
#    ['6 łyżek cukru pudru'],
#    ['szczypta soli'],
#    ['250 g masła'],
#    ['około 1/4 szklanki bardzo zimnej wody'],
#    ['Nadzienie:'],
#    ['700 g rabarbaru'],
#    ['200 g truskawek'],
#    ['50 g rodzynek'],
#    ['paczka cukru wanilinowego'],
#    ['1/2 szklanki cukru'],
#    ['1/3 szklanki mąki ziemniaczanej']],
#   'preparation': 'Mąkę wsyp do miski, dodaj cukier puder, sól, pokrojone w małą kosteczkę masło.\nMiksuj przez ok. 1 minutę, aż powstaną drobne okruszki ciasta (lub rozcieraj wszystko palcami).\nDodawaj stopniowo wodę i jeszcze przez chwilkę miksuj lub zagniataj ręką, aż ciasto będzie gładkie i zacznie łączyć się w jedną część.\nUformuj z niego kulę, podziel na 2 części, włóż w woreczek i wstaw do lodówki na godzinę.\nTortownicę o średnicy ok. 27 cm posmaruj grubo masłem.\nRabarbar opłucz, odetnij liście, łodygi pokrój na 1 cm kawałki.\xa0Truskawki pokrój w słupki. Rabarbar i truskawki włóż do dużej miski.\nFormę wylep jedną połówką ciasta - dno i około 2 cm boków. Ciasta nie trzeba rozwałkowywać, można wylepić palcami. Spód podziurkuj widelcem i wstaw do lodówki.\nDrugą część ciasta rozwałkuj na placek, podsypując mąką. Wytnij paski (radełkiem lub nożem) szerokości palca wskazującego.\nPiekarnik nagrzej do 190 stopni.\nDo rabarbaru i truskawek dodaj namoczone rodzynki, cukier, cukier wanilinowy i mąkę ziemniaczaną. Wszystko wymieszaj dłońmi i wyłóż na spodzie.\xa0Na wierzchu połóż paski z ciasta, układając z nich kratkę.\nWstaw do piekarnika i piecz przez 60 minut. Przestudź i posyp cukrem pudrem.',
#   'category': 'ciasta i desery'},
#  {'link': 'https://beszamel.se.pl/przetwory/domowy-twarog-z-kefiru-przepis-na-pyszny-twarozek-z-zapasow-kefiru,22347/',
#   'title': 'Domowy twaróg z kefiru: przepis na pyszny twarożek z zapasów kefiru',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22378/domowy-twarog-z-kefiru-przepis-na-pyszny-twarozek.jpg',
#   'ingredients': [['2 kg kefiru'],
#    ['1 szczypta soli'],
#    ['1 łyżeczka nasion czarnuszki, kminku lub maku']],
#   'preparation': 'Kefir wlać do garnka. Gotować na wolnym ogniu w kąpieli wodnej. Garnek umieścić w drugim dużym garnku napełnionym do 1/3 wysokości wodą.\nW trakcie gotowanie nie mieszać.\nGotować do temperatury 80°C. Czyli do chwili, gdy kefir będzie bardzo gorący i zacznie się oddzielać żółtawa serwatka. Nie dopuścić do zagotowania.\nZdjąć z ognia i pozostawić do przestygnięcia.\nCiepły skrzep przelać na gęste sito wyłożone wielokrotnie złożoną gazą lub muślinem (gęstym płótnem). Pozostawić na 1 godzinę do odcieknięcia.\nZawinąć rogi tkaniny do góry, mocno ścisnąć, aby pozbyć się resztek serwatki. Uformować ze skrzepu kulę. Rogi związać i twarożek zawiesić, podstawiając pod niego naczynie, do którego będzie skapywać serwatka. Pozostawić na noc.\xa0\nRano serek wyjąć z zawiniątka, rozdrobnić widelcem, dodać sól i ulubione nasiona, wymieszać. Gotowe!',
#   'category': 'przetwory'},
#  {'link': 'https://beszamel.se.pl/z-grilla/poledwiczki-z-kurczaka-na-patyku-soczyste-kaski-z-grilla,22265/',
#   'title': 'Polędwiczki z kurczaka na patyku: soczyste kąski z grilla',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22278/poledwiczki-z-kurczaka-na-patyku-soczyste-kaski-z.jpg',
#   'ingredients': [['500 g polędwiczek z piersi kurczaka'],
#    ['1/4 szklanki oliwy z oliwek'],
#    ['1/4 szklanki sosu sojowego'],
#    ['2 łyżki soku pomarańczowego lub 1 łyżka cytrynowego'],
#    ['1 łyżka musztardy sarepskiej lub dijon'],
#    ['1 łyżeczka czosnku w proszku'],
#    ['1 łyżeczka czarnego pieprzu'],
#    ['1/2 łyżeczki wędzonej papryki w proszku'],
#    ['oraz patyczki do szaszłyków']],
#   'preparation': 'Aby zrobić marynatę, wymieszaj oliwę z oliwek, sos sojowy, sok pomarańczowy, musztardę, sproszkowany czosnek, mielony pieprz i wędzoną paprykę suszoną.\nKażdą polędwiczkę nakłuj widelcem w kilku miejscach. Umieść polędwiczki w naczyniu lub torebce z suwakiem i zalej kurczaka marynatą, tak aby całkowicie ją przykryć. Marynuj co najmniej 30 minut lub do 4 godzin.\nKażdą polędwiczkę nadziej na patyczek do szaszłyków (wcześniej namoczony w wodzie).\nRozgrzej grill do średniego ciepła i posmaruj ruszt (lub powierzchnię patelni grillowej) olejem, aby zapobiec przywieraniu.\nUmieść polędwiczki z kurczaka na grillu i grilluj przez 4-6 minut z każdej strony, w zależności od grubości.\nPo zakończeniu zdejmij polędwiczki z kurczaka z grilla i pozwól im odpocząć przez 5 minut.\nNastępnie podawaj z zieloną sałatą i sosem jogurtowym.',
#   'category': 'z grilla'},
#  {'link': 'https://beszamel.se.pl/mielone/superoszczedne-mielone-nadziewane-pieczarkami-pyszny-obiad-dla-rodziny,22341/',
#   'title': 'Superoszczędne mielone nadziewane pieczarkami: pyszny obiad dla rodziny',
#   'portions': '4',
#   'photo_link': 'https://cdn10.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22372/superoszczedne-mielone-nadziewane-pieczarkami.jpg',
#   'ingredients': [['Na kotlety:'],
#    ['500 g mięsa mielonego wieprzowego, na przykład z łopatki, jest tańsze i bardziej tłuste, ale tłuszcz to nośnik smaku'],
#    ['1 cebula, drobno posiekana'],
#    ['2 ząbki czosnku, przeciśnięte przez praskę'],
#    ['3 kromki czerstwego chleba pszenno- żytniego, namoczonego i odciśniętego'],
#    ['1 jajko'],
#    ['sól i pieprz'],
#    ['Na nadzienie:'],
#    ['100 g pieczarek, startych na tarce o dużych otworach'],
#    ['1 cebula, drobno posiekana'],
#    ['1 pietruszka mała, starta na tarce o drobnych otworach'],
#    ['1 kawałek selera wielkości pudełka od zapałek, startego na tarce o drobnych otworach'],
#    ['oraz bułka tarta do obtoczenia kotletów'],
#    ['olej do smażenia (ewentualnie)']],
#   'preparation': 'Mięso wymieszać z cebulą, czosnkiem, namoczonym chlebem, rozmąconym jajkiem i przyprawami.\xa0\nPrzygotować nadzienie: na niewielkiej ilości tłuszczu usmażyć cebulę, czosnek, pieczarki, pietruszkę i seler.\xa0\nZ masy mięsnej formować okrągłe placuszki, na każdy nałożyć porcję nadzienia, zawinąć i formować w owalne kotlety.\nKotlety obtoczyć w tartej bułce i smażyć do\xa0 zrumienienia na rozgrzanym oleju lub piec w piekarniku 20 minut w 180°C w trybie termoobiegu.\xa0\nPodawać z makaronem lub kaszą gryczaną i sosem pomidorowym.\xa0',
#   'category': 'mielone'},
#  {'link': 'https://beszamel.se.pl/salatki-bez-majonezu/odchudzajaca-salatka-z-pieczarkami-i-szpinakiem-przepis,3769/',
#   'title': 'Odchudzająca sałatka z pieczarkami i szpinakiem: przepis',
#   'portions': '3',
#   'photo_link': 'https://cdn29.beszamel.smcloud.net/t/thumbs/660/441/1/recipes/photo/odchudzajaca-salatka-z-pieczarkami-i-szpinakiem-przepis.jpg',
#   'ingredients': [['6 pieczarek'],
#    ['1/2 kg szpinaku'],
#    ['czerwona cebula'],
#    ['ząbek czosnku'],
#    ['3 łyżki oliwy'],
#    ['sok z połowy cytryny'],
#    ['2 łyżki sosu sojowego'],
#    ['łyżka miodu'],
#    ['2 jajka ugotowane na twardo'],
#    ['sól, pieprz']],
#   'preparation': 'Pieczarki obrać, szpinak opłukać i wysuszyć.\nCzosnek rozetrzeć z solą.\nCebulę obrać i pokroić w talarki, obrane jajka pokroić na ćwiartki.\nPieczarki pokroić w plasterki i skropić sokiem z cytryny (zostawić łyżkę do sosu).\nSzpinak rozłożyć na półmisku, rozrzucić na nim pieczarki i cebulę.\nWymieszać oliwę\xa0 z sokiem z cytryny, sosem sojowym, miodem, przyprawami.\nPolać sałatkę. Na wierzchu ułożyć ćwiartki jajek.',
#   'category': 'salatki bez majonezu'},
#  {'link': 'https://beszamel.se.pl/dania-glowne-bezmiesne/zapiekanka-z-ryzu-i-szpinaku-pomysl-na-tani-i-zdrowy-obiad,3986/',
#   'title': 'Zapiekanka z ryżu i szpinaku - pomysł na tani i zdrowy obiad',
#   'portions': '3',
#   'photo_link': 'https://cdn7.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/3019/zapiekanka-z-ryzu-i-szpinaku-przepis-na-zapiekank.jpg',
#   'ingredients': [['2 kg'],
#    ['20 dkg ryżu (lub 2 torebki)'],
#    ['2 jajka'],
#    ['10 dkg masła'],
#    ['1 łyżkę mąki'],
#    ['2 szklanki mleka'],
#    ['2 ząbki czosnku'],
#    ['sól'],
#    ['pieprz']],
#   'preparation': 'Szpinak bardzo dokładnie płuczemy, przynajmniej raz zmieniając wodę. Obrywamy długie i twarde ogonki.\nSzpinak wrzucamy na wrzącą i osoloną wodę, gotujemy kilka minut bez przykrycia, bo inaczej straci swój wspaniały, zielony kolor.\nNastępnie go dokładnie odsączamy.\nRyż gotujemy 6 minut. Gdy już będzie odsączony, wkładamy go do garnka i dodajemy 3 dkg masła, przykrywamy i wstawiamy do gorącego (ok. 180 st) piekarnika na 25 minut.\nZ mąki i masła przygotowujemy sos beszamelowy - zasmażka z mąki rozprowadzona mlekiem, doprawiona solą i pieprzem oraz roztartym czosnkiem.\nSiekamy szpinak i dodajemy do niego sos, całość trzeba dobrze wymieszać.\nNaczynie żaroodporne smarujemy masłem i nakładamy kilkoma warstwami najpierw ryż wymieszany z rozmąconymi jajkami i szpinak.\nNa wierzchu układamy grudki masła.\nTak przygotowane danie wstawiamy na 25 minut do piekarnika. \xa0 \xa0',
#   'category': 'dania glowne bezmiesne'},
#  {'link': 'https://beszamel.se.pl/szparagi/szparagi-z-rabarbarowym-dressingiem,18603/',
#   'title': 'Szparagi z rabarbarowym dressingiem',
#   'portions': '2',
#   'photo_link': 'https://cdn29.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/ThinkstockPhotos-827359816.jpg',
#   'ingredients': [['pęczek białych szparagów'],
#    ['6 łodyg rabarbaru'],
#    ['2 łyżki łagodnego miodu (ewentualnie może być cukier)'],
#    ['łyżeczka skórki cytrynowej'],
#    ['kilka gałązek natki pietruszki'],
#    ['gałka muszkatołowa'],
#    ['sól']],
#   'preparation': 'Szparagi umyj, obierz i ugotuj w osolonej wodzie do miękkości\nRabarbar pokrój na male kawałki i ugotuj w niewielkiej ilości wody, dopraw miodem, skórką z cytryny i mieloną gałką muszkatołową\nLekko zblenduj sos do, pozostawiając pojedyncze kawałki rabarbaru, dodaj posiekana pietruszkę\nUgotowane szparagi wyłóż na talerz i polej ciepłym sosem',
#   'category': 'szparagi'},
#  {'link': 'https://beszamel.se.pl/ciasta-piaskowe/lesny-mech-ciasto-ze-szpinakiem-na-slodko-sprawdzony-przepis,3934/',
#   'title': 'Leśny mech – ciasto ze szpinakiem na słodko',
#   'portions': '12',
#   'photo_link': 'https://cdn15.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/2970/ciasto-lesny-mech-ciasto-ze-szpinakiem-zielone-c.jpg',
#   'ingredients': [['450 g mrożonego'],
#    ['250 g cukru'],
#    ['cukier wanilinowy'],
#    ['3 duże jajka'],
#    ['1 szklanki oleju'],
#    ['1 szklanka mąki tortowej'],
#    ['1 szklanki mąki krupczatki'],
#    ['3 łyżeczki proszku do pieczenia'],
#    ['300 ml śmietany kremówki 36% (masa)'],
#    ['2 opakowania śmietan- fixu (masa)'],
#    ['2 łyżki cukru pudru (masa)'],
#    ['owoc granatu do dekoracji (masa)']],
#   'preparation': 'szpinak rozmrozić, osączyć na sicie i odcisnąć z nadmiaru wody.\nDo miski wbić jajka, cukier i cukier waniliowy, zmiksować na puszystą masę.\nCiągle miksując, dodawać stopniowo olej.\nObydwie mąki przesiać, dodać do masy maślanej i dokładnie wymieszać.\nNa koniec dodać szpinak, całość delikatnie wymieszać.\nTortownicę o średnicy 25 cm wyłożyć papierem do pieczenia, nałożyć masę szpinakową. Piec 1 godzinę w piekarniku rozgrzanym do temperatury 180 St. C. Pod koniec pieczenia sprawdzić patyczkiem, czy ciasto jest suche. Wyjąć z tortownicy i ostudzić.\nśmietanę kremówkę ubić na sztywną pianę, pod koniec ubijania dodać śmietan fix i cukier puder.\nz ciasta odciąć wierzch i pokruszyć. Na krążek ciasta wyłożyć masę śmietanową, posypać obficie okruszkami i leciutko docisnąć dłonią, aby nie odpadały. Wierzch ciasta posypać pestkami granatu. Schłodzić w lodówce.',
#   'category': 'ciasta piaskowe'},
#  {'link': 'https://beszamel.se.pl/rolady/rolada-szpinakowa-przepis,4004/',
#   'title': 'Rolada szpinakowa - sprawdzony przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn6.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/3819/rolada-szpinakowa-rolada-ze-szpinaku-z-serem-rol.jpg',
#   'ingredients': [['30 dag mrożonego'],
#    ['3 jajka'],
#    ['3 łyżki mąki krupczatki'],
#    ['2 łyżki mleka'],
#    ['łyżka masła'],
#    ['50 dag ugotowanych ziemniaków'],
#    ['20 dag białego sera'],
#    ['cebula'],
#    ['sól'],
#    ['pieprz'],
#    ['olej'],
#    ['ewentualnie paczka łososia w plastrach']],
#   'preparation': 'Rozpocznij od przygotowania ciasta. Na początku ubij białka na sztywną pianę.\nNastępnie mąkę wymieszaj z mlekiem, solą oraz żółtkami.\nDodaj te składniki do rozmrożonego i odsączonego z wody szpinaku.\nMasę delikatnie połącz z ubitymi białkami.\nNa wysmarowaną tłuszczem i posypaną mąką dużą formę wylej szpinakowe ciasto i wstaw do gorącego piekarnika na 20 min.\nW tym czasie przygotuj nadzienie. Cebulę posiekaj w drobną kostkę i podsmaż na oleju.\nNastępnie dodaj ją do utłuczonych i wymieszanych z serem, ziemniaków. Dopraw do smaku solą i pieprzem.\nPo wyjęciu ciasta z piekarnika posmaruj je nadzieniem i zawiń póki jest ciepłe.\nNastępnie całość podgrzej lub podpiecz na patelni grillowej.',
#   'category': 'rolady'},
#  {'link': 'https://beszamel.se.pl/przetwory/liliowy-syrop-z-bzu-zwyczajnego-pyszny-i-zdrowy-dodatek-z-jadalnych-kwiatow-lilaka,22343/',
#   'title': 'Liliowy syrop z bzu zwyczajnego: pyszny i zdrowy dodatek z jadalnych kwiatów lilaka',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22374/liliowy-syrop-z-bzu-zwyczajnego-pyszny-i-zdrowy-d.jpg',
#   'ingredients': [['1 szklanka wody'],
#    ['1 szklanka cukru'],
#    ['1 szklanka kwiatów bzu'],
#    ['1 łyżka suszonych jagód lub dżemu jagodowego dla uzyskania koloru']],
#   'preparation': 'Oskub kwiatki bzu, przełóż do sitka i zanurz w wodzie. Dobrze wypłucz i odsącz.\nDodaj wodę i cukier do małego garnka, zagotuj mieszając, aż cukier się rozpuści.\nDoprowadź do wrzenia, a następnie dodaj kwiaty bzu i jagody.\nGotuj na wolnym ogniu przez 20 minut.\nPrzelej uzyskany płyn przez sito wyłożone gazą.\nPrzelej syrop do umytych i wyparzonych butelek lub słoików. Zakręć póki gorący.\nTak przygotowany syrop z kwiatów bzu można przechowywać do 1 roku. Po otwarciu przechowuj go w lodówce.',
#   'category': 'przetwory'},
#  {'link': 'https://beszamel.se.pl/sezonowe/mlode-ziemniaki-ze-smietana-i-koperkiem-genialny-przepis-z-podlasia,22261/',
#   'title': 'Młode ziemniaki ze śmietaną i koperkiem: genialny przepis z Podlasia',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22273/mlode-ziemniaki-z-kwasna-smietana-i-koperkiem-gen.jpg',
#   'ingredients': [['1 kg młodych ziemniaków'],
#    ['3-4 łyżki masła'],
#    ['1/2 szklanki kwaśnej śmietany lub 1/4 zwykłej śmietany i 1/4 jogurtu naturalnego'],
#    ['1 ząbek czosnku'],
#    ['1 chudy pęczek świeżego koperku'],
#    ['sól pieprz']],
#   'preparation': 'Nowe ziemniaki mają bardzo cienką skórkę, więc nie musisz obierać takich ziemniaków - po prostu je wyszoruj ścierną stroną gąbki lub plastikowym zmywakiem do szorowania garnków. Ziemniaki można również oskrobać nożem.\xa0\nJeśli ziemniaki mają wielkość małego jajka lub mniejszego - zostaw je w całości i większe\xa0 przekrój na połówki lub ćwiartki.\nUmieść ziemniaki w garnku, wlej tyle zimnej wody, aby przykryła ziemniaki i zagotuj.\nDo wrzącej wody dodaj około 1 łyżeczkę soli i gotuj około 10 minut lub do momentu, gdy ziemniaki dadzą się łatwo przekłuć widelcem.\nPosiekaj koperek. Czosnek przeciśnij przez praskę.\xa0\nOdcedź ziemniaki.\nDo gorących ziemniaków dodaj masło, śmietanę (lub mieszaninę słodkiej śmietany i jogurtu), rozdrobniony czosnek i posiekany koperek.\nPrzykryj garnek pokrywką i potrząśnij garnkiem (podrzucając zawartość w kierunku góra-dół), aby wszystko wymieszać.\nNatychmiast podawaj.',
#   'category': 'sezonowe'},
#  {'link': 'https://beszamel.se.pl/kluski-i-pyzy/kluski-z-ricotty-i-szpinaku-sprawdzony-przepis,3419/',
#   'title': 'Kluski z ricotty i szpinaku [sprawdzony przepis]',
#   'portions': '4',
# ...
#   'category': 'ciasteczka i pierniczki'},
#  {'link': 'https://beszamel.se.pl/tlusty-czwartek/blyskawiczne-paczki-z-jogurtem-greckim-sprawdzony-przepis-wideo,18416/',
#   'title': 'Błyskawiczne pączki z jogurtem greckim: sprawdzony przepis [WIDEO]',
#   'portions': '4',
#   'photo_link': 'https://cdn16.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/ThinkstockPhotos-872569434.jpg',
#   'ingredients': [['2 szklanki mąki pszennej tortowej'],
#    ['1 łyżeczka proszku do pieczenia'],
#    ['3 jajka'],
#    ['1 opakowanie cukru wanilinowego'],
#    ['250 g jogurtu greckiego'],
#    ['olej do smażenia'],
#    ['3 łyżki cukru pudru do dekoracji']],
#   'preparation': 'Do mąki dodać proszek do pieczenia, cukier puder, cukier waniliowy, jajka i\xa0jogurt. Wszystko dokładnie wymieszać łyżką.\nNa bardzo mocno rozgrzany olej kłaść za pomocą łyżeczki porcje ciasta. Pączki smażyć na rumiano z\xa0obu stron, odsączyć na papierowym ręczniku.\nGotowe pączki oprószyć cukrem pudrem lub polukrować.',
#   'category': 'tlusty czwartek'},
#  {'link': 'https://beszamel.se.pl/kuchnie-swiata/loukoumades-czyli-greckie-paczki-skapane-w-miodzie,18421/',
#   'title': 'Loukoumades, czyli greckie pączki skąpane w miodzie',
#   'portions': '4',
#   'photo_link': 'https://cdn14.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/16579/loukoumades.jpg',
#   'ingredients': [['Ciasto:'],
#    ['3 szklanki mąki pszennej'],
#    ['2 szklanki ciepłej wody (lub mleka)'],
#    ['50 g drożdży'],
#    ['1 łyżeczka cukru,'],
#    ['2 łyżki oliwy z oliwek,'],
#    ['szczypta soli'],
#    ['2 łyżeczki spirytusu lub 3 łyżeczki ouzo'],
#    ['tłuszcz do smażenia'],
#    ['Polewa:'],
#    ['filiżanka płynnego miodu'],
#    ['cynamon kruszony'],
#    ['orzechy lub ziarna sezamu']],
#   'preparation': 'Drożdże rozkruszyć, wymieszać z cukrem i zalać w misce ciepłą wodą\nMieszać, aż drożdże się rozpuszczą i pozostawić na 15 min\nDo rozczynu dodać stopniowo mąkę, oliwę, sól i alkohol. Składniki dokładnie połączyć, aż ciasto uzyska konsystencję gładkiej masy i pozostawić pod przykryciem do wyrośnięcia (ok. 2 h)\nW garnku rozgrzać tłuszcz. Niewielkie porcje ciasta nakładać łyżką formując kulki. Smażyć, aż się zarumienią. Wyjąć na papierowy ręcznik i odsączyć z tłuszczu\nPolać miodem, posypać cynamonem i pokruszonymi orzechami lub sezamem',
#   'category': 'kuchnie swiata'},
#  {'link': 'https://beszamel.se.pl/zapiekanki/najlepsze-ziemniaki-zapiekane-w-smietanie,21614/',
#   'title': 'Najlepsze ziemniaki zapiekane w śmietanie',
#   'portions': '4',
#   'photo_link': 'https://cdn18.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21498/najlepsze-ziemniaki-zapiekane-w-smietanie.jpg',
#   'ingredients': [['6-8 średnich ziemniaków'],
#    ['1 łyżka masła'],
#    ['0,5 szklanki mleka'],
#    ['1,5 szklanki śmietany 18%'],
#    ['2 łyżki mąki'],
#    ['3 ząbki czosnku, przeciśnięte przez praskę'],
#    ['1 łyżeczka soli'],
#    ['0,5 łyżeczki pieprzu mielonego'],
#    ['0,5 szklanki tartego sera'],
#    ['2 łyżki posiekanej natki pietruszki lub szczypiorku']],
#   'preparation': 'Ziemniaki wyszorować, nie obierać, pokroić na kawałki.\nFormę do zapiekania posmarować masłem i wypełnić pokrojonymi ziemniakami.\nMleko i śmietanę wymieszać razem z mąką, czosnkiem solą i pieprzem. Mieszaniną zalać ziemniaki.\nFormę okryć folią aluminiową lub zmoczonym pergaminem. Wstawić do piekarnika rozgrzanego do 200C i piec przez 30 minut.\nZdjąć przykrycie, posypać serem i zapiekać jeszcze 5 minut lub do chwili, gdy sera się rozpuści i lekko przyrumieni.',
#   'category': 'zapiekanki'},
#  {'link': 'https://beszamel.se.pl/gulasze-i-miesa-duszone/wieprzowy-gulasz-z-ziemniakami-i-kiszonym-ogorkiem-sprytne-danie-jednogarnkowe,21627/',
#   'title': 'Wieprzowy gulasz z ziemniakami i kiszonym ogórkiem: sprytne danie jednogarnkowe',
#   'portions': '4',
#   'photo_link': 'https://cdn8.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21514/wieprzowy-gulasz-z-ziemniakami-i-kiszonym-ogorkiem.jpg',
#   'ingredients': [['500 g mięsa wieprzowego z łopatki'],
#    ['500 g ziemniaków'],
#    ['1 cebula'],
#    ['1 ogórek kiszony, średnich rozmiarów lub 2 mniejsze'],
#    ['1 łyżka koncentratu pomidorowego'],
#    ['1 łyżka śmietany'],
#    ['1/2 łyżeczki papryki mielonej'],
#    ['1/2 łyżeczki pieprzu mielonego'],
#    ['1/2 łyżeczki czosnku granulowanego'],
#    ['2-4 ziarenka ziela angielskiego'],
#    ['1 łyżka oleju'],
#    ['1 łyżka mąki pszennej'],
#    ['sól do smaku']],
#   'preparation': 'Mięso pokroić w paski lub w kostkę. Ziemniaki pokroić w kostkę. Cebulę drobno posiekać. Ogórek zetrzeć na tarce.\xa0\nW rondlu rozgrzać tłuszcz dodać mięso i smażyć do lekkiego zrumienienia.\nDodać cebulę i smażyć do zeszklenia.\xa0\nDodać przyprawy: sól, pieprz, paprykę, czosnek, ziele angielskie. Wlać 1,5 szklanki wody i dusić na małym ogniu przez 30 minut.\xa0\nDodać pokrojone ziemniaki, w razie potrzeby uzupełnić wodą, aby płyn przykrywał ziemniaki. Gotować do miękkości.\nNa koniec dodać kiszone ogórki, koncentrat pomidorowy i śmietanę wymieszaną z mąką. Doprowadzić do wrzenia.\xa0\nSpróbować i ewentualnie doprawić solą.\xa0',
#   'category': 'gulasze i miesa duszone'},
#  {'link': 'https://beszamel.se.pl/przetwory-z-warzyw/warzywna-pasta-bulionowa-domowa-zdrowa-kostka-rosolowa-bez-zbednych-dodatkow,21637/',
#   'title': 'Warzywna pasta bulionowa – domowa, zdrowa kostka rosołowa bez zbędnych dodatków',
#   'portions': '6',
#   'photo_link': 'https://cdn31.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21539/warzywna-pasta-bulionowa-domowa-zdrowa-kostka-r.jpg',
#   'ingredients': [['2 małe liście laurowe'],
#    ['6 ziaren ziela angielskiego'],
#    ['1,5 g suszonych grzybów'],
#    ['10 kuleczek pieprzu'],
#    ['25 g liści lubczyku (może być mrożony)'],
#    ['1 gałązka rozmarynu'],
#    ['1/2 pęczka natki pietruszki'],
#    ['1/3 pęczka koperku'],
#    ['25 g parmezanu'],
#    ['250 g marchewki ( 2 średnie )'],
#    ['100 g selera korzeniowego'],
#    ['50 g białej części pora'],
#    ['1 mała pietruszka'],
#    ['1 średni dojrzały pomidor bez skórki i pestek'],
#    ['1 korzeń pasternaku'],
#    ['2 gałązki selera naciowego'],
#    ['1 duży ząbek czosnku'],
#    ['100 g soli'],
#    ['4 łyżki oleju'],
#    ['50 ml wody']],
#   'preparation': 'Liście laurowe, ziele angielskie, suszone grzyby i ziarna pieprzu zmielić w młynku lub utrzeć w moździerzu na pył.\nLubczyk, rozmaryn, natkę pietruszki i koperek drobno posiekać.\nParmezan zetrzeć na tarce o drobnych oczkach.\nWszystkie warzywa posiekać w malakserze lub zetrzeć na tarce o drobnych oczkach.\nSkładniki przełożyć do garnka z grubym dnem.Przykryć i doprowadzić do wrzenia.Odkryć i mieszając dość często gotować około godzinę, uważając, by mieszanina nie przywarła.\nJeśli warzywa się nie rozpadły w gotowaniu, należy na koniec zmiksować pastę na jednolita masę, przełożyć do słoika i po ostudzeniu trzymać w lodówce.',
#   'category': 'przetwory z warzyw'},
#  {'link': 'https://beszamel.se.pl/tlusty-czwartek/faworki-przepis-na-przysmak-kuchni-polskiej-na-tlusty-czwartek-wideo,16743/',
#   'title': 'Faworki: przepis na przysmak kuchni polskiej na tłusty czwartek [WIDEO]',
#   'portions': '6',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/13789/faworki-na-tlusty-czwartek.jpg',
#   'ingredients': [['2 szklanki mąki'],
#    ['4 żółtka Mrożenie białek - jak zamrozić białka jaj?'],
#    ['łyżka spirytusu lub octu'],
#    ['1/2 łyżeczki cukru'],
#    ['1/2 łyżeczki soli'],
#    ['mały kubeczek gęstej kwaśnej śmietany'],
#    ['olej do smażenia'],
#    ['cukier puder do posypania']],
#   'preparation': 'Mąkę wysyp na stolnicę i zrób w niej dołek.\nDodaj sól, cukier, żółtka, spirytus.\nMieszając widelcem wlej śmietanę.\nCiasto wyrób ręką, a następnie ubij drewnianym wałkiem.\nPodziel na 3-4 części i rozwałkuj jedną z nich.\nCiasto pokrój radełkiem w prostokąty.\nKażdy pasek natnij wzdłuż pośrodku i przewlecz przez otwór.\nSmaż na gorącym tłuszczu z obu stron, aż do uzyskania złotego koloru.\nOdsącz na ręczniku papierowym i posyp cukrem pudrem.',
#   'category': 'tlusty czwartek'},
#  {'link': 'https://beszamel.se.pl/tlusty-czwartek/faworki-puszyste-i-kruche-faworki-na-tlusty-czwartek-wideo,8382/',
#   'title': 'Kruche faworki ze śmietaną: przepis na tłusty czwartek [WIDEO]',
#   'portions': '8',
#   'photo_link': 'https://cdn30.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/ThinkstockPhotos-602297094.jpg',
#   'ingredients': [['2 szklanki mąki pszennej'],
#    ['3 żółtka'],
#    ['3-4 łyżki gęstej, kwaśnej śmietany'],
#    ['1 łyżka spirytusu lub wódki'],
#    ['1 łyżeczka proszku do pieczenia'],
#    ['0,5 l oleju roślinnego do smażenia'],
#    ['0,5 łyżeczki soli'],
#    ['cukier puder do posypania (można wymieszać z cukrem waniliowym)']],
#   'preparation': 'Mąkę przesiewamy przez sito i mieszamy w misce ze śmietaną.\nWbijamy żółtka, dodajemy proszek do pieczenia, sól i spirytus, a następnie zagniatamy ciasto.\nCiasto wałkujemy. Należy pamiętać, aby podsypywać je mąką jak najmniej, tylko jeśli naprawdę jest to konieczne.\nZ ciasta wykrawamy prostokąty o rozmiarach mniej więcej 3 cm na 15 cm i przekrawamy środek na długość 4-5 cm. Jeśli chcemy aby brzegi faworków miały falowany kształt, możemy w tym celu użyć specjalnej foremki lub samodzielnie ozdobić je, wykrawając ząbki szlaczka nożem.\nJeden brzeg prostokąta przewijamy przez otwór, tak aby uzyskać charakterystyczny dla faworków kształt.\nFaworki możemy smażyć po kilka, najlepiej na dużej patelni, na mocno rozgrzanym oleju. Smażymy krótko, aż się zezłocą i trochę wyrosną.\nPo zdjęciu z patelni należy odsączyć je na papierowym ręczniku lub bibule. Faworki posypujemy cukrem pudrem dopiero wtedy, gdy ostygną.',
#   'category': 'tlusty czwartek'},
#  {'link': 'https://beszamel.se.pl/przystawki-i-przekaski/faworki-z-ziemniakow-przepis-na-przekaske-imprezowa,18096/',
#   'title': 'Faworki z ziemniaków: przepis na przekąskę imprezową ',
#   'portions': '4',
#   'photo_link': 'https://cdn13.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21564/faworki-z-ziemniakow.jpg',
#   'ingredients': [['Na faworki:'],
#    ['1/2 kg ziemniaków'],
#    ['2 szklanki mąki pszennej'],
#    ['1 jajko'],
#    ['sól'],
#    ['olej'],
#    ['Na sos:'],
#    ['3 łyżki majonezu'],
#    ['3 łyżki jogurtu'],
#    ['3 ząbki czosnku'],
#    ['sól']],
#   'preparation': 'Obrane ziemniaki gotujemy do miękkości w osolonej wodzie.\nOdcedzamy przeciskamy przez praskę, dodajemy mąkę, jajko.\nCiasto wyrabiamy, wałkujemy, wycinamy paski.\nW środku paska robimy nacięcie. Przez nacięcie przekładamy faworek.\nSmażymy w dużej ilości oleju.\nPodajemy z sosem czosnkowym: łączymy zmiażdżony czosnek z jogurtem i majonezem, ewentualnie solimy do smaku.',
#   'category': 'przystawki i przekaski'},
#  {'link': 'https://beszamel.se.pl/ciasteczka-i-pierniczki/faworki-prosty-i-szybki-przepis-na-tlusty-czwartek-wideo,16757/',
#   'title': 'Faworki - szybko i bezproblemowo. Przepis na tłusty czwartek [WIDEO]',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/14819/faworki-szybko-i-bezproblemowo-przepis-na-tlust.jpg',
#   'ingredients': [['2 szklanki mąki pszennej'],
#    ['4 żółtka Mrożenie białek - jak zamrozić białka jaj?'],
#    ['łyżka spirytusu'],
#    ['łyżeczka cukru'],
#    ['szczypta soli'],
#    ['5 łyżek śmietany'],
#    ['olej do smażenia'],
#    ['cukier puder do posypania']],
#   'preparation': 'Mąkę mieszamy z cukrem i solą, dodajemy 4 żółtka, śmietanę i łyżkę spirytusu. Ciasto musimy teraz zagnieść na jednolitą masę, a także dobrze ,,zbić" ciasto wałkiem.\nCiasto cienko rozwałkowujemy (pamiętając o tym, by podsypywać je mąką), kroimy na paski, potem na prostokąty. W każdym kawałku robimy dziurkę w środku i jeden koniec przeplatamy przez nacięcie.\nFaworki smażymy tak, jak pączki - w temperaturze 180 st. C na szerokiej patelni do momentu, aż będą złote.',
#   'category': 'ciasteczka i pierniczki'},
#  {'link': 'https://beszamel.se.pl/salatki-z-burakow/gruzinska-przekaska-z-burakow-przepis-na-warzywne-phkali,21648/',
#   'title': 'Gruzińska przekąska z buraków: przepis na warzywne phkali',
#   'portions': '6',
#   'photo_link': 'https://cdn21.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21542/gruzinska-przekaska-z-burakow-przepis-na-warzywne.jpg',
#   'ingredients': [['250 g pieczonych buraków'],
#    ['150 g kapusty stożkowej lub pekińskiej'],
#    ['150 g orzechów włoskich'],
#    ['1 spora garść naci kolendry'],
#    ['3 ząbki czosnku, przeciśnięte przez praskę'],
#    ['3 łyżki oleju roślinnego'],
#    ['2 łyżki octu winnego'],
#    ['1/2 łyżeczki ziaren kolendry zmielonych'],
#    ['1/2 łyżeczki słodkiej papryki mielonej'],
#    ['1/2 łyżeczki kozieradki'],
#    ['1/2 łyżeczki tymianku'],
#    ['1/4 łyżeczki czarnego pieprzu zmielonego'],
#    ['sól i pieprz do smaku']],
#   'preparation': 'Buraki zetrzeć na tarce o bardzo małych oczkach.\xa0\nKapustę posiekać bardzo drobno lub zetrzeć na tarce. Posypać odrobiną soli i odstawić.\xa0\nOrzechy posiekać drobno lub zmielić. Nać kolendry również posiekać.\xa0\nW misce wymieszać starte buraki z odciśniętą kapustą, orzechami i wszystkimi pozostałymi składnikami.\xa0\nOdstawić na 30 minut, aby mieszanina przeszła smakami.\nZ sałatkowej mieszaniny formować kulki.\xa0\nUdekorować listkami kolendry i posiekanymi orzechami.\xa0',
#   'category': 'salatki z burakow'},
#  {'link': 'https://beszamel.se.pl/dania-glowne-rybne/przepyszny-pstrag-z-migdalami-klasyczny-przepis,21642/',
#   'title': 'Przepyszny pstrąg z migdałami - klasyczny przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn19.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21544/przepyszny-pstrag-z-migdalami-klasyczny-przepis.jpg',
#   'ingredients': [['4 pstrągi'],
#    ['szklanka mleka'],
#    ['3 łyżki mąki'],
#    ['3 łyżki oleju'],
#    ['3 łyżki masła'],
#    ['5 dag migdałów'],
#    ['sól i pieprz do smaku'],
#    ['cytryna i natka pietruszki']],
#   'preparation': 'Wypatroszone i umyte ryby posolić wewnątrz i na zewnątrz, a następnie na 20-30 minut zanurzyć w mleku.\nOsączyć z nadmiaru płynu, obtoczyć w mące i smażyć na oleju przez 5-7 minut - z każdej strony. Zdjąć na ogrzany półmisek.\nNa patelni rozgrzać masło i\xa0 zrumienić na jasnobrązowy kolor obrane i posiekane migdały. Maślano-migdałowym sosem polać ryby na półmisku. Doprawić do smaku solą i pieprzem.\nPodawać posypane natką pietruszki, z dodatkiem cząstek cytryn.',
#   'category': 'dania glowne rybne'},
#  {'link': 'https://beszamel.se.pl/dania-glowne-rybne/gulasz-rybny-z-groszkiem-swietny-sposob-na-rybe,21653/',
#   'title': 'Gulasz rybny z groszkiem - świetny sposób na rybę!',
#   'portions': '4',
#   'photo_link': 'https://cdn16.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/21559/gulasz-rybny-z-groszkiem-swietny-sposob-na-rybe.jpg',
#   'ingredients': [['75 dag\xa0 filetów z ryb morskich'],
#    ['5 dag mąki'],
#    ['10 dag cebuli'],
#    ['5 dag koncentratu pomidorowego'],
#    ['15 dag zielonego groszku'],
#    ['łyżeczka słodkiej pparyki'],
#    ['2 szklanki bulionu\xa0 warzywnego'],
#    ['2 łyżki oleju'],
#    ['sok z cytryny'],
#    ['sól i pieprz do smaku']],
#   'preparation': 'Filety skrapiamy sokiem z cytryny, solimy i pieprzymy. Kroimy w grubą kostkę, obtaczamy w połowie mąki.\nSmażymy na oleju i pozostawiamy w cieple.\nCebulę kroimy w kostkę, podsmażamy, oprószamy mąką i dodajemy koncentrat.\nWlewamy bulin, dodajemy groszek i gotujemy do miękkości.\nWkładamy rybę, doprawiamy papryką, solą i pieprzem.\xa0 Gotujemy kilka minut na bardzo małym ogniu. Podajemy z ryżem lub ziemniakami z wody.',
#   'category': 'dania glowne rybne'},
#  ...]

# %% [markdown]
# # Wyrazy kluczowe

# %%
temp = Sentence('jedzenie jednostka narzędzie')
emb.embed(temp)
jedzenie = temp[0].embedding
jednostka = temp[1].embedding
narzedzie = temp[2].embedding

# %% [markdown]
# # Przykładowy składnik

# %% [markdown]
# ### Przygotowanie

# %%
ingredient = Sentence(data[0]["ingredients"][0][0])

# %%
emb.embed(ingredient)
# Out:
# [Sentence: "1 kg pieczarek pokrojonych wzdłuż na plasterki" - 7 Tokens]

# %%
for i in ingredient:
    print(i, i.embedding[:5])
# Out:
# Token: 1 1 tensor([ 0.2346,  0.2216,  0.0498, -0.7787,  0.3949])
# Token: 2 kg tensor([ 0.5467,  0.3708,  0.1889, -0.9677,  0.4193])
# Token: 3 pieczarek tensor([ 0.2236, -0.0007, -0.3181, -0.6170,  0.3877])
# Token: 4 pokrojonych tensor([ 0.2358, -0.0906,  0.0420, -0.6892,  0.3711])
# Token: 5 wzdłuż tensor([-0.3330, -0.3095,  0.2327, -0.3966,  0.3435])
# Token: 6 na tensor([ 0.2342, -0.0429,  0.0537, -0.0767, -0.1966])
# Token: 7 plasterki tensor([-0.1074,  0.3050, -0.1940, -1.3618,  0.4897])

# %% [markdown]
# ### Odległość L2 od słowa "jedzenie"

# %%
for i in ingredient:
    print(torch.norm(i.embedding - jedzenie))
# Out:
# tensor(5.8111)
# tensor(6.8939)
# tensor(5.4464)
# tensor(5.0615)
# tensor(6.2661)
# tensor(5.0469)
# tensor(4.6938)

# %% [markdown]
# ###  Podobieństwo cosinusowe od słowa jedzenie

# %%
def cos(v,u): return (v @ u)/v.norm()/u.norm()

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, jedzenie))
# Out:
# Token: 1 1
# tensor(0.1270)
# Token: 2 kg
# tensor(0.2780)
# Token: 3 pieczarek
# tensor(0.3626)
# Token: 4 pokrojonych
# tensor(0.3954)
# Token: 5 wzdłuż
# tensor(0.1010)
# Token: 6 na
# tensor(0.1897)
# Token: 7 plasterki
# tensor(0.4819)

# %% [markdown]
# ###  Podobieństwo cosinusowe od słowa jednostka

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, jednostka))
# Out:
# Token: 1 1
# tensor(0.1691)
# Token: 2 kg
# tensor(0.1665)
# Token: 3 pieczarek
# tensor(0.0958)
# Token: 4 pokrojonych
# tensor(0.1662)
# Token: 5 wzdłuż
# tensor(0.2218)
# Token: 6 na
# tensor(0.1479)
# Token: 7 plasterki
# tensor(0.1248)

# %% [markdown]
# ### Pod. do narzędzie

# %%
for i in ingredient:
    if i.embedding.norm() > 0.001:
        print(i)
        print(cos(i.embedding, narzedzie))
# Out:
# Token: 1 1
# tensor(0.1972)
# Token: 2 kg
# tensor(0.0987)
# Token: 3 pieczarek
# tensor(0.2026)
# Token: 4 pokrojonych
# tensor(0.2689)
# Token: 5 wzdłuż
# tensor(0.0843)
# Token: 6 na
# tensor(0.1124)
# Token: 7 plasterki
# tensor(0.2210)

# %%
for d in data:
    for i in d['ingredients']:
        print(i[0].split())
# Out:
# ['1', 'kg', 'pieczarek', 'pokrojonych', 'wzdłuż', 'na', 'plasterki']
# ['2', 'łyżki', 'octu', 'balsamicznego']
# ['1', 'łyżka', 'sosu', 'sojowego']
# ['3', 'ząbki', 'czosnku,', 'posiekane']
# ['1/2', 'łyżeczki', 'tymianku', 'suszonego']
# ['sól', 'i', 'pieprz', 'do', 'smaku']
# ['1', 'łyżka', 'natki', 'pietruszki', 'posiekanej']
# ['2', 'szklanki', 'pąków', 'mniszka', 'lekarskiego']
# ['2/3', 'szklanki', 'octu']
# ['1/3', 'szklanki', 'wody']
# ['1', 'łyżeczka', 'soli']
# ['200', 'g', 'pomidorków', 'koktajlowych', '(ewentualnie', 'innych', 'pomidorów)']
# ['1', 'opakowanie', 'młodych', 'liści']
# ['5', 'świeżych', 'pokrojonych', 'w', 'cząstki']
# ['kilka', 'listków', 'świeżej', 'bazylii']
# ['czerwona', 'cebula', 'pokrojona', 'w', 'plastry']
# ['2-3', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1-2', 'łyżki', 'octu', 'balsamicznego']
# ['szczypta', 'soli', 'morskiej', 'do', 'smaku']
# ['1', 'duży', 'pęczek', 'buraków', '(około', '4-6', 'buraków)', 'z', 'bujnymi', 'zielonymi', 'liśćmi']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['2', 'duże', 'ząbki', 'czosnku,', 'cienko', 'krojone', 'lub', 'mielone']
# ['1', 'łyżeczka', 'świeżego', 'soku', 'z', 'cytryny']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'pieprz']
# ['250', 'g', 'truskawek']
# ['250', 'g', 'rabarbaru']
# ['1', 'paczka', 'biszkoptów']
# ['5', 'łyżek', 'syropu', 'truskawkowego']
# ['0,5', 'szklanki', 'cukru']
# ['5', 'łyżek', 'likieru', 'pomarańczowego']
# ['0,5', 'kg', 'mascarpone']
# ['250', 'g', 'twarogu']
# ['2', 'łyżki', 'cukru', 'waniliowego']
# ['500', 'g', 'mięsa', 'z', 'wędzonego', 'pstrąga']
# ['3', 'ząbki', 'czosnku']
# ['2', 'jajka']
# ['1', 'opakowanie', 'serka', 'śmietankowego', 'typu', 'Philadelfia']
# ['2', 'łyżki', 'oliwy']
# ['2', 'łyżki', 'soku', 'z', 'cytryny']
# ['1', 'łyżka', 'mielonej', 'słodkiej', 'papryki']
# ['pieprz', 'i', 'sól']
# ['0,5', 'pęczka', 'koperku']
# ['8', '<strong>ziemniaków</', 'strong>']
# ['2', 'cebule']
# ['2', 'ząbki', '<strong>czosnku</', 'strong>']
# ['450', 'g', 'mrożonego', 'w', 'liściach']
# ['gałka', 'muszkatołowa']
# ['szczypta', 'pieprzu']
# ['sól']
# ['koncentrat', 'pomidorowy']
# ['majonez']
# ['suszone', 'pomidory', 'w', 'oleju']
# ['800', 'g', 'świeżych', 'liści']
# ['5', 'ziemniaków']
# ['2', 'l', 'bulionu', 'warzywnego']
# ['śmietanka', 'do', 'zup']
# ['sól,', 'pieprz']
# ['1/2', 'opakowania']
# ['4', 'mandarynki', 'bądź', 'klementynki']
# ['1/2', 'owocu', 'granatu']
# ['1', 'dojrzałe', 'awokado']
# ['mieszanka', 'orzechów:', 'włoskich,', 'laskowych', 'i', 'migdałów']
# ['Na', 'sos:']
# ['5', 'łyżek', 'oliwy', 'z', 'oliwek']
# ['2', 'łyżeczki', 'ostrej', 'musztardy']
# ['2', 'łyżeczki', 'octu', 'balsamicznego']
# ['świeżo', 'zmielony', 'biały', 'pieprz']
# ['250', 'g', 'makaronu']
# ['150', 'g', 'szparagów,', 'obranych,', 'bez', 'zdrewniałych', 'końcówek,', 'pokrojonych', 'na', 'kawałki', 'długości', 'około', '3', 'cm']
# ['1', 'łyżka', 'oleju']
# ['250', 'g', 'pieczarek', 'pokrojonych', 'w', 'plastry']
# ['4', 'dymki,', 'pokrojone', 'w', 'plasterki']
# ['1', 'łyżeczka', 'mielonego', 'czosnku']
# ['180', 'ml', 'bulionu', 'warzywnego']
# ['180', 'ml', 'śmietany', '30%']
# ['100', 'g', '(1', 'szklanka)', 'startego', 'parmezanu']
# ['2-4', 'łyżeczki', 'soku', 'z', 'cytryny', 'lub', 'do', 'smaku']
# ['sól', 'i', 'świeżo', 'zmielony', 'czarny', 'pieprz']
# ['300', 'gr.', 'kwiatów', 'czarnego', 'bzu', '(ok.', '20', 'baldachów)']
# ['dwie', 'cytryny']
# ['0,7', 'kg', 'kilograma', 'cukru']
# ['0,7', 'litra', 'wody']
# ['4', 'białka']
# ['1/2', 'łyżeczki', 'cream', 'of', 'tartar', '(winian', 'potasu)']
# ['1', 'szklanka', 'cukru']
# ['20', 'truskawek']
# ['listki', 'melisy', 'lub', 'mięty']
# ['4', 'średnie', 'cukinie']
# ['3', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'koncentratu', 'pomidorowego']
# ['2', 'łyżki', 'tahini,', 'pasty', 'sezamowej']
# ['1', 'łyżeczka', 'kminku', 'mielonego']
# ['1/4', 'szklanki', 'świeżych', 'liści', 'kolendry,', 'plus', 'trochę', 'do', 'dekoracji']
# ['sól', 'i', 'czarny', 'pieprz']
# ['oliwa', 'z', 'oliwek,', 'w', 'razie', 'potrzeby', 'w', 'celu', 'rozcieńczenia', 'pasty', 'i', 'trochę', 'do', 'dekoracji']
# ['1', 'pęczek', 'botwinki,', 'około', '3-5', 'młodych', 'buraczków', 'z', 'nacią']
# ['1', 'pęczek', 'młodej', 'cebuli', 'ze', 'szczypiorem']
# ['3', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'masła']
# ['1', 'łyżka', 'oleju']
# ['4-6', 'szklanek', 'bulionu', 'warzywnego']
# ['3', 'ziemniaki,', 'średniej', 'wielkości']
# ['2', 'szklanki', 'zakwasu', 'buraczanego', 'lub', 'soku', 'z', 'cytryny', 'do', 'smaku']
# ['sól', 'i', 'cukier']
# ['3', 'łyżki', 'śmietany', '18%', 'lub', '30%']
# ['4', 'jajka', 'ugotowane', 'na', 'twardo']
# ['Na', 'kotlety:']
# ['500', 'g', 'mielonego', 'mięsa', 'drobiowego']
# ['100', 'g', 'białego', 'ryżu', 'o', 'krótkich', 'ziarnach']
# ['1', 'cebula']
# ['1', 'jajko']
# ['2', 'łyżki', 'posiekanej', 'natki', 'pietruszki']
# ['2', 'łyżki', 'posiekanej', 'mięty', 'pieprzowej']
# ['2', 'ząbki', 'czosnku']
# ['4', 'łyżki', 'bułki', 'tartej']
# ['sól', 'i', 'pieprz']
# ['Na', 'sos', 'pomidorowy:']
# ['500', 'ml', 'przecieru', 'pomidorowego']
# ['150', 'ml', 'wody']
# ['1', 'łyżeczka', 'oregano', 'suszonego']
# ['2', 'łyżki', 'posiekanej', 'mięty', 'pieprzowej']
# ['2', 'łyżeczki', 'cukru']
# ['1', 'łyżeczka', 'soli']
# ['100', 'g', 'czerwonej', 'soczewicy']
# ['500', 'g', 'przecieru', 'pomidorowego']
# ['1', 'l', 'bulionu', 'drobiowego', 'lub', 'warzywnego']
# ['1', 'batat,', 'słodki', 'ziemniak,', 'około', '100', 'g']
# ['1', 'cebula']
# ['6', 'ząbków', 'czosnku']
# ['1', 'cm', 'świeżego', 'imbiru']
# ['3', 'łyżki', 'oleju']
# ['przyprawy:', '1', 'łyżeczka', 'kurkumy,', '2', 'łyżeczki', 'przyprawy', 'curry', 'w', 'proszku,', '1/2', 'łyżeczki', 'ostrej', 'papryki']
# ['sól', 'i', 'pieprz']
# ['100', 'ml', 'pełnotłustego', 'mleka', 'kokosowego']
# ['300', 'g', 'mięsa', 'drobiowego']
# ['Na', 'krem:']
# ['100-150', 'g', 'twarogu', 'według', 'przepisu', 'na', 'Domowy', 'twaróg', 'z', 'mleka', 'kwaśnego', 'i', 'słodkiego']
# ['1-2', 'łyżki', 'śmietany,', 'jeśli', 'ser', 'jest', 'zbyt', 'suchy']
# ['2-4', 'łyżki', 'słodzonego', 'mleka', 'skondensowanego']
# ['50', 'g', 'masła,', 'miękkiego,', 'w', 'temperaturze', 'pokojowej']
# ['1', 'łyżeczka', 'ekstraktu', 'waniliowego', 'lub', '2', 'łyżeczki', 'cukru', 'wanilinowego']
# ['1/6', 'łyżeczki', 'soli', '(tajny', 'składniki,', 'który', 'reguluje', 'równowagę', 'słodyczy)']
# ['Na', 'biszkopt:']
# ['2', 'jajka', 'rozmiar', 'M']
# ['50', 'g', 'mąki']
# ['50', 'g', 'cukru']
# ['30', 'g', 'masła,', 'stopionego', 'i', 'przestudzonego']
# ['1/6', 'łyżeczki', 'soli']
# ['oraz']
# ['4-6', 'łyżek', 'dżemu', 'truskawkowego,', 'podgrzanego,', 'aby', 'się', 'nieco', 'rozpuścił']
# ['1', 'łyżka', 'cukru', 'pudru']
# ['6-8', 'truskawek', 'do', 'dekoracji']
# ['15', 'kwiatów', 'czarnego', 'bzu']
# ['2', 'jajka']
# ['2', 'szklanki', 'mleka']
# ['1/2', 'szklanki', 'mąki']
# ['szczypta', 'soli']
# ['1/2', 'łyżeczki', 'proszku', 'do', 'pieczenia']
# ['tłuszcz', 'do', 'smażenia']
# ['cukier', 'puder', 'do', 'posypania']
# ['500', 'g', 'mielonego', 'mięsa', 'indyczego']
# ['1', 'bułka']
# ['1', 'cebula']
# ['1', 'puszka', 'kukurydzy', 'konserwowej']
# ['2', 'łyżki', 'natki', 'pietruszki,', 'posiekanej']
# ['sól', 'i', 'pieprz']
# ['oraz', 'do', 'panierowania']
# ['2', 'jajka', 'rozmiar', 'S', 'rozmącone', 'z', '2', 'łyżkami', 'wody']
# ['mąka']
# ['tarta', 'bułka']
# ['45', 'baldachów', 'kwiatów', 'bzu', 'czarnego']
# ['2', 'cytryny']
# ['skórka', 'z', '2', 'cytryn']
# ['2', 'płaskie', 'łyżeczki', 'kwasku', 'cytrynowego']
# ['1,5', 'l', 'przegotowanej', 'wody']
# ['750', 'g', 'cukru']
# ['1', 'podwójny', 'filet', 'z', 'kurczaka']
# ['5', 'łyżek', 'oleju']
# ['200', 'g', 'prażonej', 'cebulki']
# ['przyprawa', 'do', 'drobiu']
# ['przyprawy:', 'sól,', 'pieprz,', 'papryka']
# ['250', 'g', 'ryżu', 'kleistego']
# ['1', 'litr', 'mleka']
# ['100', 'g', 'cukru']
# ['kilka', 'liści', 'mięty']
# ['1', 'x', 'cytryna']
# ['1', 'szczypta', 'soli']
# ['500', 'g', 'truskawek', 'świeżych']
# ['5', 'kostek', 'czekolady', 'gorzkiej']
# ['3', 'duże', 'placki', 'tortilli', 'pszennej']
# ['1', 'słoik', 'tuńczyka', 'w', 'oliwie']
# ['150', 'g', 'kukurydzy']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['300', 'g', 'marynowanych', 'ostrych', 'papryczek']
# ['150', 'g', 'tartej', 'mozzarelli', 'lub', 'sera', 'żółtego']
# ['4', 'łyżki', 'majonezu']
# ['2', 'łyżeczki', 'musztardy']
# ['400', 'g', '(puszka)', 'krojonych', 'pomidorów']
# ['1/4', 'zielonej', 'papryki']
# ['2', 'łyżki', 'marynowanej', 'papryczki', 'jalapeño']
# ['1/2', 'łyżeczki', 'sproszkowanego', 'czosnku']
# ['sól']
# ['pieprz']
# ['2', 'łyżki', 'cukru']
# ['3', 'łyżki', 'octu', 'spirytusowego']
# ['2', 'cebulki', 'szalotki']
# ['1', 'łyżeczka', 'mąki', 'ziemniaczanej']
# ['łyżka', 'posiekanej', 'kolendry']
# ['200', 'g', 'tofu']
# ['2', 'porcje', 'rukoli']
# ['1', 'awokado']
# ['sól']
# ['świeżo', 'zmielony', 'pieprz']
# ['oliwa', 'extra', 'virgine']
# ['sok', 'z', 'cytryny']
# ['2', 'łyżki', 'masła']
# ['3', 'jajka']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['grzanki', 'z', 'chleba', 'żytniego', 'posmarowane', 'masłem']
# ['340', 'g', 'mąki', 'z', 'orzechów', '(nerkowce', 'i', 'migdały)']
# ['1', 'łyżka', 'cynamonu', 'cejlońskiego']
# ['2', 'łyżeczki', 'sody', 'oczyszczonej', '/', 'lub', 'proszku', 'do', 'pieczenia']
# ['szczypta', 'soli', 'himalajskiej', '/', 'lub', 'morskiej']
# ['20-30', 'g', 'cukru', 'palmowego']
# ['175', 'g', 'musu', 'jabłkowego']
# ['50', 'g', 'oleju', 'rzepakowego']
# ['2', 'jajka']
# ['1', 'łyżeczka', 'cukru', 'waniliowego']
# ['2', 'ćwiartki', 'z', 'kurczaka']
# ['500', 'g', 'ryżu', 'kleistego', 'Q', 'Rice']
# ['15', 'g', 'imbiru']
# ['10', 'g', 'smażonej', 'cebuli']
# ['5', 'g', 'jagód', 'goji']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['1/2', 'łyżeczki', 'soli']
# ['1', 'łyżka', 'oleju', 'do', 'smażenia']
# ['2', 'łyżki', 'chińskiej', 'wódki', 'ryżowej', '/', 'lub', 'polskiej', 'czystej', 'wódki']
# ['300', 'ml', 'wody']
# ['1', 'szklanka', 'ryżu', 'kleistego']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['sok', 'wyciśnięty', 'z', '1', 'limonki']
# ['skórka', 'starta', 'z', '1', 'limonki']
# ['4', 'łyżki', 'cukru', 'trzcinowego']
# ['1', 'x', 'laska', 'wanilii']
# ['1', 'x', 'mango']
# ['kilka', 'listków', 'świeżej', 'mięty']
# ['3', 'łyżki', 'białego', 'sezamu']
# ['75', 'g', 'masła']
# ['75', 'g', 'mąki', 'orkiszowej']
# ['400', 'ml', 'bitej', 'śmietany']
# ['1', 'laska', 'wanilii']
# ['1', 'szklanka', 'puree', 'z', 'mango']
# ['opcjonalnie:', 'owoce', 'do', 'dekoracji', '(np.', 'truskawki,', 'ananas,', 'kiwi)']
# ['700', 'g', 'kalafiora']
# ['2', 'średnie', 'ziemniaki']
# ['2', 'kalarepy']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['kmin', 'rzymski']
# ['kolendra']
# ['sól']
# ['pieprz']
# ['oliwa', 'extra', 'virgin']
# ['1', 'litr', 'bulionu']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['200', 'ml', 'Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['100', 'ml', 'zielonej', 'herbaty']
# ['kilka', 'kostek', 'lodu']
# ['*świeże', 'mango', 'i', 'kilka', 'listków', 'mięty', 'do', 'dekoracji']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'zielonej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['60', 'g', 'bakłażana']
# ['150', 'g', 'polędwicy', 'wołowej']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['2', 'większe', 'pory', '(tylko', 'białe', 'części)']
# ['30', 'dag', 'piersi', 'z', 'kurczaka']
# ['15', 'dag', 'makaronu', 'udong']
# ['4', 'szklanki', 'bulionu', 'mięsnego']
# ['2', 'łyżki', 'masła']
# ['4', 'łyżki', 'jasnego', 'sosu', 'sojowego']
# ['1', 'łyżeczka', 'cukru']
# ['cytryna']
# ['250', 'g', 'fasoli', 'białej']
# ['500', 'g', 'żeberek', 'wieprzowych']
# ['250', 'g', 'wędzonego', 'boczku']
# ['2', 'marchewki']
# ['1', 'pietruszka']
# ['kawałek', 'selera']
# ['3', 'ziela', 'angielskie']
# ['1', 'listek', 'laurowy']
# ['1', 'duża', 'cebula']
# ['1', 'ząbek', 'czosnku']
# ['3', '-', '4', 'ziemniaki']
# ['1', 'łyżka', 'majeranku']
# ['1', 'paczka', 'zupy', 'AnSungTangMyun']
# ['50', 'g', 'pasty', 'do', 'sosów', 'Barilla', 'Arabiata']
# ['8', 'g', 'bazy', 'do', 'zupy', 'w', 'proszku']
# ['100', 'g', 'małży', 'z', 'krótkimi', 'szyjkami', '(4', 'szt.)']
# ['100', 'g', 'małży', '(4', 'szt.)']
# ['20', 'g', 'mątwy']
# ['60', 'g', 'krewetek', '(3', 'szt.)']
# ['2', 'g', 'ostrej', 'papryczki', 'chili', '(1/4', 'szt.)']
# ['6', 'pomidorków', 'koktajlowych']
# ['1', 'cały', 'ząbek', 'czosnku']
# ['18', 'ml', 'białego', 'wina']
# ['8', 'ml', 'oliwy', 'z', 'oliwek']
# ['300', 'ml', 'wody']
# ['natka', 'pietruszki']
# ['1', 'szklanka', 'fasoli']
# ['500', '-', '600', 'ml', 'bulionu', 'drobiowego', 'lub', 'jarzynowego']
# ['2', 'średnie', 'marchewki,', 'obrane', 'i', 'pokrojone', 'w', 'cienkie', 'plasterki']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'średnia', 'cebula,', 'pokrojona', 'w', 'drobną', 'kosteczkę']
# ['2', 'łyżki', 'mąki', 'pszennej']
# ['sól']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['Pesto:', '•', 'garść', 'rukoli', 'lub', 'bazylii']
# ['3', 'łyżki', 'tartego', 'parmezanu', '/', 'lub', 'grana', 'padano']
# ['1', 'łyżeczka', 'orzeszków', 'pinii', '/', 'lub', 'pestek', 'dyni']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek', 'extra', 'virgin']
# ['1/2', 'małego', 'ząbka', 'czosnku']
# ['sól']
# ['pieprz']
# ['200', 'g', 'makaronu', 'wieloziarnistego', 'Bali', 'Kitchen']
# ['2', 'łyżki', 'oleju', 'arachidowego']
# ['50', 'g', 'fasoli', 'czerwonej']
# ['50', 'g', 'liści', 'sałaty']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['50', 'g', 'wędzonego,', 'smażonego', 'Tofu', '(w', 'paski)']
# ['2', 'łyżki', 'Mirinu']
# ['2', 'łyżki', 'sosu', 'sojowego', 'słodkiego']
# ['1', 'łyżeczka', 'imbiru', 'w', 'proszku']
# ['według', 'uznania:', 'odrobina', 'soku', 'z', 'limetki', '/', 'sól', '/', 'pieprz']
# ['400', 'g', 'chudej', 'wołowiny']
# ['6', 'ząbków', 'czosnku']
# ['250', 'g', 'pędów', 'bambusa']
# ['4', 'łyżki', 'ciemnego', 'sosu', 'sojowego']
# ['3', 'łyżki', 'oleju']
# ['1', 'łyżka', 'mąki', 'ziemniaczanej']
# ['3', 'łyżki', 'sezamu', 'białego']
# ['3', 'łyżki', 'szczypiorku']
# ['4', 'łyżki', 'perełek', 'tapioki']
# ['10', 'łyżek', 'cytrynowego', 'syropu', 'do', 'kawy']
# ['2', 'saszetki', 'herbaty', 'malinowej']
# ['1', 'szklanka', 'mleka']
# ['Kilka', 'łyżek', 'miodu']
# ['mięta', 'do', 'dekoracji']
# ['12', 'tortilli', 'taco', '(kukurydziane/', 'pszenne/', 'razowe)']
# ['4', 'kacze', 'udka']
# ['125', 'ml', 'białego,', 'wytrawnego', 'wina']
# ['2', 'świeże', 'mango']
# ['1', 'limonka']
# ['1/2', 'ostrej', 'papryczki', 'chili']
# ['sałata', 'lodowa']
# ['sos', 'Hoisin', '(2-3', 'łyżki', 'stołowe)']
# ['sól']
# ['pieprz']
# ['100', 'g', 'makaronu', 'sojowego']
# ['12', 'ugotowanych', 'lub', 'usmażonych', 'krewetek']
# ['200', 'g', 'truskawek']
# ['4', 'łyżki', 'posiekanych', 'solonych', 'pistacji']
# ['1/3', 'szklanki', 'świeżych', 'listków', 'mięty']
# ['Sos:', '•', 'sok', 'z', '2', 'limonek']
# ['2', 'pełne', 'łyżki', 'miodu']
# ['1', 'łyżka', 'tartego', 'świeżego', 'imbiru']
# ['200', 'g', 'mielonej', 'wieprzowiny']
# ['20', 'g', 'drobno', 'posiekanej', 'cebuli', 'dymki']
# ['20', 'g', 'drobno', 'posiekanej', 'cebuli']
# ['20', 'g', 'małej', 'kukurydzy', 'groszkowej']
# ['20', 'g', 'selera', 'naciowego']
# ['20', 'g', 'grzybów', 'shiitake', '(namoczonych', 'w', 'wodzie)']
# ['20', 'g', 'marchwi']
# ['1', 'główka', 'sałaty', 'lodowej']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['1', 'drobno', 'posiekana', 'papryczka', 'chili', '(opcjonalnie)']
# ['Składniki', 'na', 'sos:', '•', '2', 'łyżki', 'stołowe', 'sosu', 'ostrygowego']
# ['2', 'łyżki', 'stołowe', 'sosu', 'po', 'pekińsku']
# ['2', 'łyżki', 'stołowe', 'wina', 'ryżowego']
# ['3', 'łyżki', 'stołowe', 'wody']
# ['350', 'g', 'udek', 'z', 'kurczaka']
# ['200', 'g', 'świeżego', 'makaronu', 'jajecznego']
# ['1/2', 'ogórka', 'pokrojonego', 'w', 'cienkie', 'paski']
# ['1', 'duża', 'marchew,', 'obrana', 'i', 'pokrojona', 'w', 'cienkie', 'paski']
# ['•', '2', 'łyżki', 'stołowe', 'sosu', 'ostrygowego', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'stołowe', 'sosu', 'sojowego', 'słodkiego', 'do', 'pierożków', 'Lee', 'Kum', 'Kee']
# ['50', 'g', 'kasztanów', 'jadalnych', 'z', 'puszki', 'w', 'wodzie,', 'pokrojonych', 'w', 'plastry', '(opcjonalnie)']
# ['•', '2', 'łyżki', 'stołowe', 'sosu', 'do', 'pierożków', 'Lee', 'Kum', 'Kee']
# ['120', 'g', 'makaronu', 'Mie', 'lub', 'z', 'warzywami']
# ['200', 'g', 'filetu', 'z', 'kurczaka']
# ['1', 'łyżka', 'mąki', 'pszennej']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['1/2', 'małego', 'brokuła']
# ['1', 'cebula']
# ['1', 'czerwona', 'papryka']
# ['1', 'mała', 'puszka', 'kukurydzy']
# ['1', 'łyżka', 'sezamu', 'czarnego']
# ['2-3', 'łyżki', 'stołowe', 'sosu', 'teriyaki', '(ilość', 'sosu', 'może', 'się', 'zmieniać', 'w', 'zależności', 'od', 'ilości', 'użytych', 'składników']
# ['100', 'g', 'makaronu', 'sojowego']
# ['200', 'g', 'krewetek', 'black', 'tiger', '/', 'lub', '150', 'g', 'pokrojonej', 'w', 'kosteczkę', 'piersi', 'kurczaka']
# ['1', 'mango']
# ['1,5', 'łyżki', 'startego', 'imbiru']
# ['2', 'duże', 'ząbki', 'czosnku']
# ['1', 'papryczka', 'chili']
# ['1', 'łyżka', 'oleju', 'kokosowego']
# ['3', 'łyżki', 'sezamu']
# ['0,5', 'szklanki', 'listków', 'mięty']
# ['1', 'łyżka', 'liści', 'kolendry']
# ['Sos:', '•', 'sok', 'z', '2', 'limonek']
# ['2', 'łyżki', 'cukru', 'trzcinowego']
# ['1', 'łyżka', 'sosu', 'ostrygowego', '/', 'lub', '2', 'łyżki', 'sojowego']
# ['Chińska', 'mieszanka', 'warzyw', '330', 'g']
# ['2', 'filety', 'z', 'piersi', 'kaczki']
# ['250', 'chińskiego', 'makaronu', 'jajecznego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['2', 'łyżki', 'octu']
# ['2', 'łyżki', 'oleju']
# ['1', 'łyżeczka', 'cukru']
# ['szczypta', 'imbiru', 'w', 'proszku']
# ['szczypta', 'ostrej', 'papryki']
# ['szczypta', 'słodkiej', 'papryki']
# ['szczypta', 'gałki', 'muszkatołowej']
# ['szczypta', 'cynamonu']
# ['sól']
# ['pieprz']
# ['80', 'g', 'makaronu', 'Chow', 'Mein']
# ['170', 'g', 'wołowiny']
# ['1', 'ząbek', 'czosnku']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1/4', 'pora']
# ['1/2', 'czerwonej', 'papryki']
# ['3', 'pieczarki']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['szczypta', 'cukru']
# ['3', 'łyżki', 'ciemnego', 'sosu', 'sojowego', '+', '2', 'łyżki', 'wody']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['5', 'łyżek', 'stołowych', 'sosu', 'hoisin']
# ['500', 'g', 'żeberek']
# ['1', 'łyżka', 'stołowa', 'sosu', 'sojowego', 'jasnego']
# ['250', 'g', 'piersi', 'z', 'kurczaka', 'pokrojonej', 'w', 'kostkę']
# ['1', 'zielona', 'papryka', 'pokrojona', 'w', 'kostkę']
# ['75', 'g', 'pieczarek', 'pokrojonych', 'w', 'kostkę']
# ['1', 'łyżka', 'oleju']
# ['50', 'g', 'sosu', 'stir-', 'fry', 'z', 'czarnej', 'fasoli', 'i', 'czosnku', 'Lee', 'Kum', 'Kee']
# ['250', 'g', 'pokrojonego', 'w', 'kostkę', 'kurczaka', '(pierś', 'lub', 'udko)']
# ['50', 'g', 'groszku', 'cukrowego']
# ['75', 'g', 'kolb', 'kukurydzy', 'baby']
# ['1', 'łyżka', 'oleju']
# ['70', 'g', 'sosu', 'stir-', 'fry', 'miodowo-', 'sojowego', 'Lee', 'Kum', 'Kee']
# ['1', 'filet', 'z', 'kurczaka']
# ['2', 'łyżki', 'mąki']
# ['2', 'łyżki', 'oleju']
# ['1', 'cebula']
# ['1', 'ząbek', 'czosnku']
# ['3', 'marchewki']
# ['1', 'papryka', 'czerwona', 'lub', 'zielona']
# ['mała', 'puszka', 'pędów', 'bambusa']
# ['1', 'łyżka', 'białego', 'octu', 'winnego']
# ['1', 'łyżka', 'cukru']
# ['2', 'łyżki', 'koncentratu', 'pomidorowego']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['sól']
# ['pieprz']
# ['250', 'g', 'pokrojonej', 'w', 'kostkę', 'piersi', 'kurczaka']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['4', 'cebulki', 'dymki,', 'posiekane']
# ['30', 'g', 'prażonych', 'orzechów', 'nerkowca']
# ['1', 'łyżka', 'oleju']
# ['60', 'g', 'sosu', 'stir-', 'fry', 'Kurczak', 'Kung', 'Pao', 'Lee', 'Kum', 'Kee']
# ['180', 'g', 'surowych,', 'obranych', 'krewetek', 'królewskich']
# ['1', 'łyżka', 'oleju']
# ['30', 'g', 'szparagów,', 'ciętych', '(4', 'cm)']
# ['70', 'g', 'sosu', 'stir-', 'fry', 'pomidorowo-', 'czosnkowego', 'Lee', 'Kum', 'Kee']
# ['4', 'całe', 'leszcze', 'morskie,', 'oczyszczone,', 'bez', 'płetw']
# ['400', 'g', 'średniej', 'wielkości', 'ziemniaków,', '(podgotowanych', 'w', 'gorącej', 'wodzie', '5-7', 'minut)']
# ['1', 'świeżo', 'posiekany', 'rozmaryn']
# ['4', 'łyżki', 'sosu', 'Teriyaki', 'Lee', 'Kum', 'Kee']
# ['4', 'łyżki', 'sosu', 'Chili', 'czosnkowego', 'Lee', 'Kum', 'Kee']
# ['3', 'łyżeczki', 'lekkiej', 'oliwy', 'z', 'oliwek']
# ['sól', 'i', 'pieprz']
# ['mały', 'pęczek', 'świeżego', 'koperku', '(niewielka', 'ilość', 'zarezerwowana', 'do', 'dekoracji)']
# ['2', 'opakowania', 'ekstra', 'mocnego', 'tofu', '(396', 'g', 'każde)']
# ['olej,', 'np.', 'słonecznikowy', 'albo', 'rzepakowy']
# ['Marynata']
# ['2', 'łyżki', 'sosu', 'sojowego', 'Light', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'oleju', 'sezamowego', 'Lee', 'Kum', 'Kee']
# ['2', 'średnie', 'ząbki', 'czosnku,', 'starte', 'lub', 'zmiażdżone']
# ['2', 'łyżki', 'startego', 'świeżego', 'imbiru']
# ['Glazura']
# ['2', 'łyżeczki', 'sosu', 'sojowego', 'Light', 'Lee', 'Kum', 'Kee']
# ['2', 'łyżki', 'sosu', 'chilli', 'czosnkowego', 'Lee', 'Kum', 'Kee']
# ['Do', 'podania']
# ['Ogórek,', 'mięta,', 'miękkie', 'bułeczki', 'i', 'liście', 'sałaty.']
# ['300', 'g', 'zielonej', 'fasolki', 'szparagowej']
# ['olej', 'arachidowy']
# ['75', 'g', 'mielonej', 'wieprzowiny']
# ['2', 'łyżki', 'wina', 'ryżowego', 'do', 'gotowania']
# ['1', 'łyżka', 'sosu', 'sojowego']
# ['1', 'papryczka', 'chili', '(drobno', 'pokrojona)']
# ['2', 'łyżki', 'posiekanej', 'chińskiej', 'kapusty', 'bok', 'choy']
# ['1,5', 'litra', 'bulionu', 'warzywnego']
# ['liść', 'laurowy']
# ['2', 'cm', 'kawałek', 'imbiru']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['2', 'łyżki', 'sosu', 'rybnego']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['szczypta', 'cukru']
# ['1/2', 'bulwy', 'kopru', 'włoskiego']
# ['150', 'g', 'pieczarek']
# ['1', 'kapustka', 'pak', 'choi', '(lub', 'garść', 'szpinaku)']
# ['100', 'g', 'makaronu', 'Chow', 'Mien', 'Bali', 'Kitchen']
# ['350', 'g', 'polędwicy', 'z', 'dorsza']
# ['1', 'łyżeczka', 'posiekanej', 'papryczki', 'chili']
# ['świeża', 'kolendra', '(lub', 'szczypiorek)']
# ['200', 'g', 'białego', 'ryżu']
# ['300', 'ml', 'mleczka', 'kokosowego']
# ['pół', 'łyżeczki', 'soli']
# ['100', 'g', 'makaronu', 'Mie', 'Goreng/', 'Chow', 'Mien/', 'z', 'mąką', 'z', 'fasoli', 'i', 'kukurydzy']
# ['1', 'pojedyncza', 'pierś', 'kurczaka']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['2', 'ząbki', 'czosnku']
# ['2', 'łyżki', 'oleju', 'roślinnego', '(kokosowego', 'lub', 'z', 'orzeszków', 'ziemnych)']
# ['8', 'szparagów']
# ['6', 'pieczarek']
# ['3', 'łyżki', 'posiekanej', 'dymki', 'lub', 'szczypiorku']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# ['Sos:', '•', '5', 'łyżek', 'sosu', 'sojowego', 'jasnego']
# ['3', 'łyżki', 'wody']
# ['3', 'łyżki', 'soku', 'z', 'limonki/', 'lub', 'cytryny/', 'lub', 'octu', 'ryżowego']
# ['3', 'łyżki', 'cukru']
# ['1/2', 'łyżeczki', 'mąki', 'ziemniaczanej']
# ['150', 'g', 'makaronu']
# ['150', 'g', 'krewetek']
# ['1/2', 'pęczka', 'szparagów']
# ['100', 'g', 'pomidorków', 'koktajlowych']
# ['3', 'ząbki', 'czosnku']
# ['1', 'łyżeczka', 'suszonego', 'oregano']
# ['3', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['2', 'łyżki', 'masła']
# ['4', 'łyżki', 'białego', 'wytrawnego', 'wina']
# ['świeża', 'bazylia/', 'natka', 'pietruszki/', 'lub', 'tymianek']
# ['tarty', 'parmezan']
# ['150', 'g', 'makaronu', 'z', 'warzywami', 'Bali', 'Kitchen']
# ['50', 'g', 'szpinaku']
# ['0,5', 'dojrzałego', 'dużego', 'awokado', '/', 'lub', '1', 'małe']
# ['2', 'łyżki', 'soku', 'z', 'limonki']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'ząbek', 'czosnku,', 'pokrojony', 'na', 'plasterki']
# ['3', 'łyżki', 'posiekanych', 'liści', 'świeżego', 'estragonu']
# ['2', '-', '3', 'czubate', 'łyżki', 'serka', 'mascarpone']
# ['tarty', 'Parmezan']
# ['pomidorki', 'koktajlowe']
# ['1', 'pojedynczy', 'filet', 'kurczaka']
# ['2', 'łyżeczki', 'mąki', 'ziemniaczanej']
# ['100', 'g', 'makaronu', 'Chow', 'Mien/', 'Mie', 'Bali', 'Kitchen']
# ['ćwiartka', 'cebuli']
# ['2', 'ząbki', 'czosnku']
# ['1/2', 'marchewki']
# ['1/2', 'brokuła']
# ['kawałek', 'papryczki', 'chili']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['3', 'łyżki', 'orzechów', 'nerkowca']
# ['1/4', 'szklanki', 'wody']
# ['3', 'łyżki', 'sosu', 'sojowego']
# ['1/2', 'łyżeczki', 'cukru', 'trzcinowego']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['200', 'g', 'makaronu', 'z', 'morinagą', 'Bali', 'Kitchen']
# ['200', 'g', 'krewetek']
# ['odrobinę', 'oleju', 'do', 'smażenia']
# ['1', 'posiekana', 'papryczka', 'chili']
# ['1', 'ząbek', 'czosnku,', 'posiekany']
# ['1/2', 'papryki', 'czerwonej', 'pokrojonej', 'w', 'kostkę']
# ['1/2', 'papryki', 'żółtej', 'pokrojonej', 'w', 'kostkę']
# ['1/2', 'papryki', 'zielonej', 'pokrojonej', 'w', 'kostkę']
# ['30', 'g', 'imbiru,', 'posiekanego']
# ['3', 'łyżki', 'słodkiego', 'sosu', 'sojowego']
# ['odrobina', 'soku', 'z', 'cytryny']
# ['odrobina', 'sosu', 'rybnego']
# ['1', 'łyżka', 'prażonego', 'sezamu']
# ['200', 'g', 'makaronu', 'z', 'czarnym', 'sezamem', 'Bali', 'Kitchen']
# ['2', 'łyżki', 'oleju', 'sezamowego', 'Diamond']
# ['2', 'łyżki', 'oleju', 'arachidowego']
# ['3', 'ząbki', 'czosnku,', 'posiekane']
# ['20', 'g', 'imbiru,', 'pokrojonego', 'w', 'małą', 'kostkę']
# ['200', 'g', 'ugotowanych', 'krewetek']
# ['1', 'czerwona', 'cebula']
# ['posiekane', 'liście', 'kolendry']
# ['1', 'łyżka', 'prażonych', 'nasion', 'czarnego', 'sezamu']
# ['sól', 'i', 'pieprz']
# ['około', '1,5', 'szklanki', 'truskawek']
# ['150', 'g', 'makaronu', 'chilli', 'Bali', 'Kitchen']
# ['1', 'łagodna', 'czerwona', 'papryczka', 'chili,', 'bez', 'pestek,', 'posiekana']
# ['2', 'łyżki', 'masła']
# ['1/3', 'szklanki', 'śmietanki', 'kremowej', '30%']
# ['0,5', 'szklanki', 'drobno', 'tartego', 'parmezanu']
# ['0,5', 'szklanki', 'liści', 'bazylii', 'i', 'mięty']
# ['1', 'łyżka', 'sosu', 'Worcester']
# ['80', 'g', 'makaronu', 'chili']
# ['170', 'g', 'wołowiny']
# ['1', 'ząbek', 'czosnku']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1/4', 'pora']
# ['1/2', 'czerwonej', 'papryki']
# ['3', 'pieczarki']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['szczypta', 'zmielonego', 'białego', 'pieprzu']
# ['szczypta', 'cukru']
# ['3', 'łyżki', 'ciemnego', 'sosu', 'sojowego', '+', '2', 'łyżki', 'wody']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['80', 'g', 'makaronu', 'pszennego', 'z', 'czarnym', 'sezamem']
# ['2', 'pomidory', 'malinowe']
# ['miseczka', 'kurek']
# ['2', 'ząbki', 'czosnku']
# ['5', 'łyżek', 'pokrojonej', 'w', 'kosteczkę', 'cebuli']
# ['2', 'łyżki', 'masła']
# ['2', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['sól']
# ['świeżo', 'zmielony', 'pieprz']
# ['150', 'g', 'filetu', 'z', 'dorsza']
# ['1', 'łyżka', 'roztopionego', 'masła']
# ['125', 'g', 'makaronu', 'pszennego', 'z', 'czarnym', 'sezamem']
# ['80', 'ml', 'śmietanki', 'kremówki']
# ['skórka', 'starta', 'z', '1', 'cytryny']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['garść', 'rukoli']
# ['cząstki', 'cytryny', 'do', 'podania']
# ['1/2', 'dużego', 'bakłażana']
# ['1/2', 'szklanki', 'kuskusu']
# ['1/2', 'szklanki', 'bulionu', 'warzywnego']
# ['sok', 'z', 'ćwiartki', 'cytryny']
# ['1', 'pełna', 'łyżka', 'posiekanej', 'świeżej', 'mięty']
# ['60', 'g', 'sera', 'koziego', 'pokrojonego', 'na', 'kawałki', '(lub', 'sera', 'feta)']
# ['100', 'g', 'pomidorków', 'koktajlowych,', 'przekrojonych', 'na', 'połówki']
# ['oliwa', 'z', 'oliwek']
# ['2', 'papryki', '(żółta', 'i', 'czerwona)']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1/3', 'szklanki', 'kuskusu']
# ['gorący', 'bulion', 'warzywny', '(około', '1/3', 'szklanki)']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['6', 'pomidorków', 'koktajlowych,', 'przekrojonych', 'na', 'połówki']
# ['2', '-', '3', 'łyżki', 'orzeszków', 'pinii,', 'grillowanych', 'na', 'suchej', 'patelni']
# ['8', 'kosteczek', 'sera', 'feta']
# ['2', 'kalmary']
# ['100', 'g', 'kiełbaski', 'chorizo']
# ['2', 'puszki', 'pomidorów', 'obranych,', 'pokrojonych']
# ['gałązka', 'rozmarynu']
# ['2', 'ząbki', 'czosnku']
# ['400', 'g', 'fasolki', 'białej']
# ['1', 'opakowanie', 'zupki', 'krewetkowej', 'w', 'kubku']
# ['150', 'ml', 'mleczka', 'kokosowego']
# ['owoce', 'lychee', '(wg', 'uznania)']
# ['1', 'opakowanie', 'zupki', 'Shin', 'Ramyun']
# ['1', 'opakowanie', 'sosu', 'serowego', 'do', 'nachosów']
# ['sos', 'do', 'salsy']
# ['100', 'g', 'sera', 'mozzarella']
# ['50', 'g', 'boczku']
# ['30', 'g', 'cebuli']
# ['50', 'g', 'kiełek']
# ['1', 'łyżeczka', 'kremu', 'balsamicznego']
# ['2', 'paczki', 'zupki', 'Neoguri', '(ostra', '/', 'łagodna)']
# ['1', 'szklanka', 'suszonych', 'krewetek']
# ['60', 'g', 'szpinaku']
# ['1/2', 'zielonej', 'cebuli']
# ['2', 'łyżeczki', 'pasty', 'sojowej']
# ['2-3', 'łyżeczki', 'rozdrobnionego', 'czosnku']
# ['6', 'szklanek', 'wody']
# ['jasny', 'sos', 'sojowy']
# ['0,5', 'szklanki', 'mąki', 'z', 'ryżu', 'kleistego']
# ['0,5', 'szklanki', 'zimnej', 'wody']
# ['2', 'łyżki', 'cukru']
# ['1', 'łyżka', 'słodkiego', 'kakao']
# ['tabliczka', 'czekolady', 'o', 'dużej', 'zawartości', 'kakao', '(60%', 'lub', 'więcej)']
# ['1/3', 'szklanki', 'śmietany', 'kremówki']
# ['2', 'łyżki', 'masła']
# ['1', 'kg', 'kapusty', 'pekińskiej']
# ['2', 'średnie', 'cebulę']
# ['pół', 'pęczka', 'szczypiorku']
# ['200', 'g', 'soli']
# ['250', 'ml', 'wody']
# ['Zaprawa:']
# ['30', 'g', 'płatków', 'chili']
# ['3', 'duże', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'startego', 'imbiru']
# ['1', 'łyżka', 'jasnego', 'sosu', 'sojowego']
# ['½', 'łyżki', 'sosu', 'rybnego']
# ['1', '½', 'łyżki', 'cukru']
# ['2', 'łyżki', 'prażonych', 'nasion', 'białego', 'sezamu']
# ['1', 'szklanka', 'ciepłego', 'mleka']
# ['2', 'szklanki', 'mąki']
# ['2', 'łyżki', 'cukru']
# ['2', 'łyżeczki', 'suszonych', 'drożdży']
# ['szczypta', 'soli']
# ['1', 'łyżka', 'oleju']
# ['brązowy', 'cukier']
# ['parę', 'łyżek', 'posiekanych', 'orzeszków', '(włoskich,', 'laskowych', 'lub', 'ziemnych)']
# ['1', 'łyżeczka', 'cynamonu']
# ['1', 'opakowanie', 'zupki', 'Chapaghetti']
# ['1', 'opakowanie', 'zupki', 'Neoguri', '(ostra', '/', 'łagodna)']
# ['6', 'szklanek', 'wody', '(ok.', '1,1', 'l)']
# ['500', 'g', 'ciecierzycy']
# ['1', 'czerwona', 'papryka']
# ['4', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['1/2', 'łyżeczki', 'cukru']
# ['3', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'łyżeczka', 'płatków', 'chili']
# ['mała', 'szczypta', 'soli']
# ['1/2', 'łyżeczki', 'mielonego', 'pieprzu']
# ['1', 'ząbek', 'czosnku']
# ['1/3', 'młodej', 'cebuli']
# ['1', 'pomidor']
# ['3', 'łyżki', 'posiekanego', 'koperku']
# ['4', 'łyżki', 'posiekanej', 'natki', 'pietruszki']
# ['2', 'łyżki', 'posiekanego', 'szczypiorku']
# ['kilka', 'listków', 'mięty']
# ['3', 'jajka']
# ['1/2', 'łyżeczki', 'soli']
# ['1', 'łyżeczka', 'cukru']
# ['2', 'garści', 'cebulki', 'dymki,', 'posiekanej']
# ['1/2', 'marchewki,', 'drobno', 'pokrojonej']
# ['3', 'łyżki', 'oleju']
# ['3', 'łyżki', 'naturalnego', 'jogurtu', 'lub', 'majonezu']
# ['1', 'łyżka', 'sosu', 'chili', 'ostrego']
# ['2', 'filety', 'śledziowe', '(w', 'oleju', '/', 'lub', 'marynowane', 'w', 'occie', '/', 'lub', 'wypłukanych', 'solonych)']
# ['2', 'łyżeczki', 'posiekanej', 'natki']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['1', 'łyżeczka', 'musztardy']
# ['1', 'łyżeczka', 'soku', 'z', 'cytryny']
# ['szczypta', 'brązowego', 'cukru']
# ['2', 'łyżki', 'marynowanej', 'ostrej', 'jalapeño']
# ['3', 'łyżki', 'marynowanych', 'podgrzybków']
# ['1', 'łyżka', 'cebulki', 'marynowanej']
# ['1', 'łyżka', 'posiekanego', 'szczypiorku']
# ['olej', 'lniany']
# ['700', 'g', 'drobnych', 'ziemniaków']
# ['200', 'ml', 'jogurtu', 'naturalnego']
# ['2', 'łyżki', 'pasty', 'harissa']
# ['30', 'ml', 'oliwy']
# ['2', 'łyżki', 'migdałów', 'w', 'słupkach']
# ['30', 'ml', 'soku', 'z', 'limonki']
# ['1/2', 'szklanki', 'nasion', 'granatu']
# ['2', 'szt.', 'zielonej', 'części', 'dymki']
# ['sól']
# ['pieprz']
# ['listki', 'mięty', 'do', 'dekoracji']
# ['jajka', '5', 'sztuk']
# ['soczewica', '100', 'g']
# ['cebula', 'czerwona', '50', 'g']
# ['papryczka', 'jalapeno', 'marynowana', '50', 'g']
# ['majonez', '1⁄2', 'szklanki']
# ['musztarda', 'Dijon', '10', 'g']
# ['sól']
# ['pieprz']
# ['natka', 'pietruszki']
# ['2', 'łyżeczki', 'oleju', 'rzepakowego']
# ['1', 'duża', 'cebula,', 'przekrojona', 'na', 'połowę', 'i', 'pokrojona', 'w', 'cienkie', 'plasterki']
# ['3', 'ząbki', 'czosnku,', 'pokrojone', 'w', 'plasterki']
# ['1', 'łyżka', 'harissy,', 'lub', 'innego', 'pikantnego', 'sosu', 'np.', 'tabasco']
# ['1', 'łyżeczka', 'mielonej', 'kolendry']
# ['150', 'ml', 'bulionu', 'warzywnego', 'lub', 'drobiowego']
# ['400', 'g', 'ciecierzycy', 'Doyal']
# ['800', 'g', 'krojonych', 'pomidorów']
# ['2', 'małe', 'cukinie,', 'pokrojone', 'w', 'drobną', 'kostkę']
# ['200', 'g', 'młodego', 'szpinaku']
# ['4', 'łyżki', 'posiekanych', 'listków', 'kolendry']
# ['4', 'duże', 'jajka']
# ['sól,', 'pieprz', 'i', 'cukier', 'do', 'smaku']
# ['1', 'papryka', 'czerwona']
# ['1', 'papryka', 'zielona']
# ['1', 'papryka', 'żółta']
# ['2', 'czerwone', 'cebule']
# ['4', 'łyżeczki', 'pasty', 'harissa']
# ['4', 'gałązki', 'świeżej', 'mięty']
# ['1', 'tuszka', 'kurczaka']
# ['sól', 'morska']
# ['pieprz', 'czarny']
# ['czerwony', 'ocet', 'winny']
# ['1', 'szklanka', 'ugotowanej', 'kaszy', 'jaglanej']
# ['1', 'szklanka', 'ciecierzycy']
# ['1', 'por', '(biała', 'część)']
# ['2', 'łyżki', 'oliwy']
# ['1/2', 'łyżeczki', 'soli']
# ['1/2', 'łyżeczki', 'kuminu']
# ['1/2', 'łyżeczki', 'papryki']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1', 'duży', 'ząbek', 'czosnku']
# ['kilka', 'gałązek', 'natki', 'pietruszki']
# ['Sos', 'pomidorowy:', '•', '400', 'g', 'krojonych', 'pomidorów']
# ['1', 'ząbek', 'czosnku']
# ['2', 'łyżeczki', 'oliwy']
# ['szczypta', 'soli']
# ['szczypta', 'cukru']
# ['szczypta', 'pieprzu']
# ['kawałek', 'papryczki', 'chili']
# ['kilka', 'liści', 'bazylii']
# ['Dodatkowo:', '•', '1', 'cukinia']
# ['2', 'łyżki', 'natki', 'pietruszki']
# ['2', 'małe', 'bataty']
# ['1', 'ząbek', 'czosnku']
# ['150', 'g', 'ciecierzycy']
# ['oliwa', 'extra', 'virgin']
# ['80', 'g', 'szpinaku']
# ['100', 'g', 'fety']
# ['2', 'łyżki', 'krojonych', 'pomidorów', 'z', 'puszki', '/', 'lub', '1/2', 'świeżego', 'pomidora']
# ['papryczka', 'chili']
# ['sól']
# ['pieprz']
# ['1', 'łyżeczka', 'kminu', 'rzymskiego']
# ['1/2', 'łyżeczki', 'suszonego', 'oregano']
# ['1/2', 'łyżeczki', 'czerwonej', 'papryki', 'słodkiej']
# ['1/3', 'łyżeczki', 'papryki', 'ostrej']
# ['1/3', 'łyżeczki', 'papryki', 'wędzonej']
# ['świeża', 'kolendra']
# ['jogurt', 'naturalny']
# ['4', 'filety', 'z', 'łososia', '(każdy', 'filet', 'po', 'około', '100', '-', '150', 'g)']
# ['pasta', 'harissa']
# ['oliwa', 'z', 'oliwek']
# ['sól']
# ['400-500', 'g', 'ciecierzycy']
# ['1', 'łyżka', 'oliwy', 'extra', 'virgin']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['1', 'łyżka', 'oleju', 'kokosowego', '/', 'lub', 'masła']
# ['2', 'ziemniaki']
# ['1', 'łyżeczka', 'mielonego', 'kminu', 'rzymskiego']
# ['500', 'ml', 'bulionu', 'lub', 'rosołu']
# ['50', 'ml', 'śmietanki', '30%']
# ['płatki', 'chili']
# ['mielony', 'kmin', 'rzymski']
# ['świeża', 'kolendra/', 'lub', 'natka', 'pietruszki']
# ['2', 'łyżki', 'oliwy', 'z', 'oliwek']
# ['1', 'mała', 'cebula,', 'pokrojona', 'w', 'drobną', 'kosteczkę']
# ['250', 'g', 'ziemniaków,', 'obranych', 'i', 'pokrojonych', 'w', 'około', '1,5', 'cm', 'kosteczkę']
# ['2', 'małe', 'ząbki', 'czosnku,', 'pokrojone', 'w', 'plasterki']
# ['1/2', 'łyżeczki', 'słodkiej', 'papryki', 'w', 'proszku']
# ['szczypta', 'pikantnego', 'pieprzu', 'cayenne']
# ['sok', 'z', '1/2', 'cytryny']
# ['200', 'g', 'pomidorów', 'wraz', 'z', 'sosem', 'pomidorowym', '(pokrojonych,', 'bez', 'skórek)']
# ['1/2', 'kostki', 'bulionowej', '(rybnej', 'lub', 'jarzynowej)']
# ['100', 'g', 'surowych,', 'obranych', 'krewetek']
# ['150', 'g', 'ciecierzycy,', 'odsączonej']
# ['250', 'g', 'filetów', 'soli', 'bez', 'ości', 'i', 'skóry,', 'pokrojonych', 'w', 'około', '5', 'cm', 'kawałki']
# ['2', 'łyżki', 'posiekanej', 'natki', 'pietruszki']
# ['1/2', 'cebuli']
# ['1/2', 'łyżki', 'masła']
# ['1/2', 'łyżki', 'oliwy']
# ['2', 'ząbki', 'czosnku']
# ['1', 'papryka']
# ['100', 'g', 'kaszy', 'bulgur']
# ['sól']
# ['pieprz']
# ['2', 'łyżeczki', 'słodkiej', 'papryki']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'szklanka', 'bulionu']
# ['400', 'g', 'białej', 'fasoli']
# ['1', 'puszka', 'krojonych', 'pomidorów']
# ['1/3', 'cukinii']
# ['1', 'łyżka', 'sosu', 'ostrygowego']
# ['2', 'garście', 'szpinaku']
# ['50', 'g', 'suszonych', 'grzybów']
# ['1', 'kg', 'kiszonej', 'kapusty']
# ['2', 'szklanki', 'bulionu']
# ['2', 'duże', 'cebule']
# ['400', 'g', 'białej', 'fasoli']
# ['olej', 'roślinny', '(np.', 'rzepakowy,', 'słonecznikowy)']
# ['sól']
# ['pieprz']
# ['2', 'listki', 'laurowe']
# ['4', 'ziela', 'angielskie']
# ['2', 'łyżki', 'suszonego', 'majeranku']
# ['1', 'łyżka', 'mąki']
# ['4', 'jajka']
# ['3', 'łyżki', 'marynowanej', 'zielonej', 'papryczki', 'jalapeño']
# ['1', 'łyżka', 'drobno', 'posiekanego', 'szczypiorku']
# ['1', 'łyżeczka', 'oliwy', 'extra', 'virgin']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['2', 'łyżki', 'majonezu']
# ['sól', 'morska']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['szczypta', 'cukru']
# ['majonez', '(dodatkowo', 'do', 'dekoracji)']
# ['szczypiorek', '(dodatkowo', 'do', 'dekoracji)']
# ['5', 'łyżek', 'sezamu']
# ['2', 'łyżki', 'oliwy']
# ['200', 'g', 'ciecierzycy', 'w', 'zalewie']
# ['2', 'ząbki', 'czosnku']
# ['sok', 'z', 'połówki', 'cytryny']
# ['100', 'ml', 'zimnej', 'zalewy', 'z', 'ciecierzycy']
# ['świeża', 'kolendra']
# ['pieprz,', 'sól,', 'papryka', 'słodka']
# ['3', 'łyżki', 'pasty', 'harissa']
# ['150', 'g', 'masła']
# ['200', 'g', 'sera', 'Mozarella']
# ['1', 'cebula']
# ['1', 'ciabatta']
# ['szczypiorek']
# ['250', 'g', 'filetu', 'z', 'dorsza']
# ['80', 'g', 'kiełbaski', 'chorizo']
# ['2', 'małe', 'szalotki']
# ['120', 'g', 'ciecierzycy']
# ['300', 'ml', 'pasaty', 'pomidorowej']
# ['sól']
# ['pieprz']
# ['szczypta', 'cukru']
# ['400', 'g', 'polędwiczek', 'kurczaka', '(lub', 'całych', 'filetów)']
# ['1', 'czerwona', 'cebula']
# ['1', 'czerwona', 'papryka']
# ['1', 'limonka']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['1', 'łyżeczka', 'wędzonej', 'papryki', 'w', 'proszku']
# ['1', 'łyżka', 'marynowanej', 'papryczki', 'jalapeño']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['Dodatki:', '•', '4', 'placki', 'Tortilli']
# ['Guacamole']
# ['1', 'pomidor']
# ['cebula']
# ['50', 'g', 'tartego', 'sera', 'cheddar']
# ['gęsta', 'kwaśna', 'śmietana']
# ['świeża', 'kolendra']
# ['2', 'duże', 'kromki', 'chleba', 'z', 'ziarnami', 'zbóż']
# ['10', 'mrożonych', 'lub', 'świeżych,', 'ugotowanych', '(różowych)', 'krewetek,', 'obranych', 'i', 'bez', 'ogonków']
# ['1', 'łyżeczka', 'oliwy', 'o', 'smaku', 'chilli']
# ['1', 'łyżka', 'oliwy', 'z', 'oliwek']
# ['1', 'ząbek', 'czosnku,', 'drobno', 'posiekany']
# ['1', 'łyżka', 'posiekanej', 'natki', 'pietruszki']
# ['1/2', 'puszki', 'białej', 'fasoli']
# ['sól']
# ['świeżo', 'zmielony', 'czarny', 'pieprz']
# ['500', 'g', 'suszonej', 'ciecierzycy']
# ['pęczek', 'zielonej', 'pietruszki']
# ['2', 'średnie', 'cebule']
# ['3', 'ząbki', 'czosnku']
# ['3', 'łyżki', 'przyprawy', 'do', 'falafela', '(kolendra,', 'kmin,', 'pieprz,', 'ziele', 'angielskie,', 'cynamon,', 'goździki,', 'imbir,', 'gałka', 'muszkatałowa,', 'mahlab)']
# ['łyżka', 'soli']
# ['łyżeczka', 'sody']
# ['kilka', 'łyżek', 'wody']
# ['olej', 'do', 'smażenia']
# ['2', 'cukinie']
# ['1', 'cebula']
# ['140', 'g', 'pomidorów', 'suszonych', 'w', 'zalewie']
# ['2', 'ząbki', 'czosnku']
# ['150', 'g', 'świeżego', 'szpinaku']
# ['200', 'g', 'koziego', 'sera', '(rolada)']
# ['450', 'g', 'pomidorów', 'z', 'puszki']
# ['szczypta', 'cynamonu']
# ['1', 'łyżeczka', 'suszonego', 'oregano']
# ['1/2', 'łyżeczki', 'wędzonej', 'słodkiej', 'papryki']
# ['brązowy', 'cukier']
# ['miód']
# ['syrop', 'z', 'agawy', '(opcjonalnie)']
# ['2', 'łyżki', 'harissy']
# ['sól']
# ['pieprz']
# ['oliwa', 'z', 'oliwek']
# ['300', 'g', 'cukinii']
# ['2', 'łyżki', 'oliwy', 'extra', 'virgin']
# ['1', 'ząbek', 'czosnku']
# ['1/2', 'łyżeczki', 'skórki', 'z', 'cytryny']
# ['150', 'ml', 'bulionu', 'jarzynowego', '/', 'lub', 'drobiowego']
# ['1', 'łyżka', 'soku', 'z', 'cytryny']
# ['150', 'g', 'kuskusu']
# ['1/3', 'szklanki', 'listków', 'mięty']
# ['100', 'g', 'sera', 'feta']
# ['1', 'szklanka', 'fasoli', 'białej', '(fasolę', 'wcześniej', 'namoczyć)']
# ['1/2', 'pora']
# ['1', 'łyżeczkę', 'mielonego', 'kminu']
# ['skórka', 'z', 'połowy', 'cytryny']
# ['olej']
# ['4', 'laski', 'selera']
# ['2', 'ziemniaki']
# ['2', 'łyżki', 'pasty', 'Harissa']
# ['2', 'liście', 'laurowe']
# ['1,5-2', 'l', 'bulionu']
# ['sok', 'z', 'połowy', 'cytryny']
# ['pęczek', 'kolendry']
# ['sól']
# ['pieprz', 'czarny']
# ['250', 'g', 'mielonej', 'wieprzowiny']
# ['¼', 'łyżeczki', 'sody', 'oczyszczonej']
# ['2', 'łyżki', 'pasty', 'harissa', 'Le', 'Phare', 'du', 'Cap', 'Bon']
# ['2', 'łyżki', 'posiekanej', 'kolendry']
# ['2', 'bułki', 'do', 'burgerów']
# ['majonez']
# ['sałata']
# ['plastry', 'pomidora']
# ['1', 'czerwona', 'cebula']
# ['sos', 'tzatziki', '/', 'sos', 'chili']
# ['sól', 'i', 'pieprz', 'do', 'smaku']
# ['panierka', 'Tempura']
# ['1', 'cukinia', '175', 'g']
# ['1', 'bakłażan', '250', 'g']
# ['150', 'g', 'małych', 'pieczarek']
# ['1', 'pęczek', 'dymki']
# ['1', 'l', 'oleju', 'słonecznikowego']
# ['sos', 'sojowy', '(do', 'maczania)']
# ['ryż', 'do', 'Sushi']
# ['algi', 'do', 'Sushi']
# ['sos', 'sojowy', 'japoński']
# ['ocet', 'ryżowy', 'do', 'sushi']
# ['imbir', 'do', 'sushi']
# ['pasta', 'wasabi']
# ['mata', 'bambusowa']
# ['warzywa,', 'ryby,', 'owoce', 'morza', '(wedle', 'uznania)']
# ['300', 'g', 'filetu', 'z', 'łososia']
# ['mały', 'pęczek', 'zielonych', 'szparagów']
# ['4', 'małe', 'dymki']
# ['3', 'łyżki', 'oliwy']
# ['duża', 'garść', 'małych', 'listków', 'botwinki', '/', 'lub', 'szpinaku']
# ['170', 'g', 'makaronu', 'Udong']
# ['2', 'łyżki', 'sezamu']
# ['2', 'łyżeczki', 'oleju', 'sezamowego']
# ['Marynata', 'i', 'sos', 'teriyaki:', '•', '6', 'łyżek', 'sosu', 'sojowego']
# ['2', 'łyżki', 'brązowego', 'cukru']
# ['1', 'łyżka', 'soku', 'z', 'limonki']
# ['3', 'łyżeczki', 'startego', 'imbiru']
# ['1', 'ząbek', 'czosnku,', 'drobno', 'starty']
# ['500', 'g', 'ryżu', 'do', 'sushi']
# ['1', 'opakowanie', 'alg', 'Nori', 'do', 'sushi']
# ['Zalewa', 'octowa:', '•', '8', 'łyżek', 'octu', 'ryżowego']
# ['3-4', 'łyżki', 'cukru']
# ['łyżka', 'sosu', 'sojowego']
# ['mata', 'bambusowa', 'do', 'sushi']
# ['Dodatki:', '•', '200', 'g', 'świeżego', '(najlepiej', 'surowego', 'lub', 'wędzonego)', 'filetu', 'z', 'łososia']
# ['dojrzały', 'owoc', 'awokadu']
# ['pęczek', 'szczypiorku']
# ['marynowany', 'imbir', '(ze', 'słoika)', 'według', 'uznania']
# ['pasta', 'wasabi']
# ['200', 'g', 'filetu', 'z', 'łososia', 'bez', 'skóry', 'i', 'ości']
# ['100', 'g', 'makaronu', 'ryżowego']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['1', 'papryczka', 'chili']
# ['1,5', 'łyżki', 'startego', 'imbiru']
# ['2', 'łyżki', 'sezamu']
# ['2', 'łyżki', 'pasty', 'miso']
# ['2', 'łyżki', 'sosu', 'sojowego']
# ['1', 'limonka']
# ['1/2', 'łyżeczki', 'cukru']
# ['1', 'łyżka', 'oleju', 'sezamowego']
# ['4', 'łyżki', 'posiekanego', 'szczypiorku']
# ['świeża', 'kolendra']
# ['Tempura', 'Samlip']
# ['olej', 'kokosowy']
# ['surowe', 'krewetki', '24', 'szt.']
# ['mąka', 'pszenna', '1', 'szklanka']
# ['sól']
# ['woda']
# ['Zupa', 'Tom', 'Yum', 'THAI', 'PRIDE']
# ['Pędy', 'bambusa', 'THAI', 'PRIDE']
# ['Grzyby', 'Shiitake', 'DIAMOND']
# ['Makaron', 'ryżowy', '3', 'mm', 'FARMER']
# ['Mleczko', 'kokosowe', 'AROY-', 'D']
# ['krewetki', 'lub', 'pierś', 'z', 'kurczaka', 'lub', 'filet', 'z', 'łososia']
# ['150', 'g', 'makaronu', 'Udong']
# ['150', 'g', 'mieszanki', 'surowych', 'owoców', 'morza', '(rozmrożonych', 'i', 'odcedzonych)']
# ['50', 'g', 'posiekanej', 'cebuli']
# ['50', 'g', 'posiekanej', 'marchwi']
# ['1', 'papryczka', 'chili,', 'pokrojona', 'w', 'plastry,', 'bez', 'nasion']
# ['1', 'łyżka', 'stołowa', 'oleju', 'roślinnego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'ostrygowego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'z', 'czarnym', 'pieprzem']
# ['1', 'pierś', 'z', 'kurczaka']
# ['400', 'g', 'makaronu', 'U-', 'Dong']
# ['330', 'g', 'chińskiej', 'mieszanki', 'warzyw']
# ['227', 'g', 'pędów', 'bambusa', '(w', 'plastrach)']
# ['165', 'ml', 'sosu', 'słodko-', 'kwaśnego', 'Lee', 'Kum', 'Kee']
# ['Bulion:', '•', '1', 'kg', 'kości', 'wieprzowych']
# ['1', 'kg', 'kości', 'drobiowych']
# ['4', 'cebulki', 'szalotki']
# ['10', 'cm', 'korzenia', 'imbiru']
# ['pół', 'główki', 'czosnku']
# ['2', 'marchewki']
# ['albi', 'Konbu', '(płat)']
# ['100', 'ml', 'sosu', 'sojowego']
# ['80', 'ml', 'wina', 'ryżowego', 'Sake']
# ['Dodatki:', '•', '300', 'g', 'suszonych', 'grzybów', 'Shiitake']
# ['500', 'g', 'świeżego', 'makaronu', 'Ramen']
# ['szczypiorek']
# ['6', 'jajek']
# ['algi', 'Nori']
# ['opcjonalnie:', '•', '200', 'g', 'kapusty', 'Bok', 'Choy', '•', 'kiełki', 'fasoli', 'mung']
# ['800', 'g', 'filetu', 'z', 'łososia']
# ['1', 'łyżka', 'oliwy']
# ['Marynata:']
# ['6', 'łyżek', 'sosu', 'sojowego']
# ['8', 'łyżek', 'sosu', 'teriyaki']
# ['2', 'łyżki', 'miodu', 'lipowego']
# ['1', 'czubata', 'łyżeczka', 'imbiru', '(mielonego', 'lub', 'świeżo', 'startego', '-', '1,5', 'cm)']
# ['2', 'duże', 'żabki', 'czosnku', '(przeciśnięte', 'przez', 'praskę', 'i', 'roztarte', 'z', 'solą)']
# ['sól', 'i', 'pieprz']
# ['500', 'g', 'łopatki', 'wieprzowej']
# ['1/2', 'papryki', 'czerwonej']
# ['1/2', 'papryki', 'zielonej']
# ['1', 'cebula']
# ['2', 'ząbki', 'czosnku']
# ['1/2', 'szklanki', 'pędów', 'bambusa']
# ['1', 'łyżeczka', 'pasty', 'curry', '(w', 'zależności', 'od', 'preferowanej', 'ostrości,', 'żółta', '-', 'najłagodniejsza)']
# ['olej', 'do', 'smażenia']
# ['Składniki', 'na', 'sos:', '•', '1', 'łyżka', 'sezamu', 'białego']
# ['2', 'łyżki', 'miodu']
# ['2', 'łyżki', 'ciemnego', 'sosu', 'sojowego']
# ['6', 'łyżek', 'wody']
# ['sok', 'z', '1', 'limonki']
# ['1', 'łyżeczka', 'mąki']
# ['Makaron:', '•100', 'g', 'makaronu', 'ryżowego', '(płaskiego', 'i', 'szerokiego,', '5', 'mm)']
# ['2', 'łyżki', 'oleju', 'roślinnego']
# ['3', 'ząbki', 'czosnku']
# ['1', 'pierś', 'kurczaka', 'pokrojona', 'w', 'małą', 'kosteczkę']
# ['2', 'jajka']
# ['1', 'szklanka', 'kiełków', 'fasoli', 'mung']
# ['2', 'cebule', 'dymka', 'lub', '1', 'pęczek', 'szczypiorku', '(biała', 'i', 'jasnozielona', 'część)']
# ['Sos:', '•', '4', 'łyżki', 'sosu', 'rybnego']
# ['2', 'łyżki', 'soku', 'z', 'limonki']
# ['2', 'łyżki', 'pasty', 'z', 'tamaryndowca']
# ['3', 'pełne', 'łyżki', 'cukru']
# ['1', 'łyżka', 'sosu', 'sriracha', '(lub', '1/2', 'łyżki', 'płatków', 'chili)']
# ['2', 'łyżki', 'prażonych', 'orzeszków', 'ziemnych']
# ['100', 'g', 'makarony', 'ryżowego', '(3', 'mm', '/', '5', 'mm)']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['3', 'ząbki', 'czosnku']
# ['1', 'pierś', 'z', 'kurczaka', 'lub', '8', 'krewetek', '(obranych)', 'lub', '100', 'g', 'tofu']
# ['2', 'jajka']
# ['100', 'ml', 'sosu', 'Pad', 'Thai']
# ['1', 'szklanka', 'kiełków', 'fasoli', 'mung', 'Diamond']
# ['2', 'cebule', 'dymka', 'lub', '1', 'pęczek', 'szczypiorku']
# ['2', 'płaskie', 'łyżeczki', 'żelatyny', 'w', 'proszku']
# ['2', 'łyżki', 'ciepłej', 'wody']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['40', 'g', 'cukru']
# ['2', 'łyżki', 'rumu']
# ['2', 'łyżki', 'białego', 'wina']
# ['0,5', 'kg', 'filetów', 'z', 'kurczaka']
# ['1', 'tajska', 'papryczka', 'chili', '(prik', 'chee', 'fa),', 'cienko', 'pokrojona']
# ['1', 'łyżka', 'stołowa', 'cukru']
# ['2', 'łyżki', 'stołowe', 'oleju', 'roślinnego']
# ['1', 'łyżka', 'stołowa', 'sosu', 'rybnego']
# ['1', 'filiżanka', 'mleczka', 'kokosowego']
# ['1/4', 'filiżanki', 'liści', 'słodkiej', 'bazylii']
# ['8', 'liści', 'limonki', 'kaffir,', 'drobno', 'posiekanych']
# ['1/3', 'łyżki', 'stołowej', 'jasnego', 'sosu', 'sojowego']
# ['2', 'łyżki', 'stołowe', 'pasty', 'curry', 'panang']
# ['1', 'szklanka', 'mleczka', 'kokosowego']
# ['1', 'szklanka', 'mleczka', 'migdałowego']
# ['1/3', 'szklanki', 'nasion', 'Chia']
# ['1/3', 'szklanki', 'płatków', 'kokosowych']
# ['4', 'łyżki', 'syropu', 'klonowego']
# ['2', 'szklanki', 'puree', 'z', 'mango', '(Kesar)']
# ['1', 'pierś', 'z', 'kurczaka']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['2', 'cm', 'imbiru']
# ['1', 'papryczka', 'chili']
# ['łodyga', 'trawy', 'cytrynowej']
# ['1/2', 'limonki']
# ['1', 'łyżka', 'zielonej', 'pasty', 'curry']
# ['2', 'łyżki', 'sosu', 'worcester']
# ['3', 'łyżki', 'sosu', 'rybnego']
# ['sól']
# ['pieprz', 'czarny']
# ['200', 'g', 'ryżu', 'kleistego', 'Q', 'Rice']
# ['100', 'g', 'cukru,']
# ['1', 'litr', 'mleka,']
# ['250', 'g', 'gorzkiej', 'czekolady,']
# ['szczypta', 'mielonego', 'cynamonu']
# ['3', 'piersi', 'z', 'kurczaka']
# ['100', 'ml', 'sosu', 'Satay']
# ['Oliwa', 'z', 'oliwek', 'extra', 'virgin']
# ['1', 'szklanka', 'płatków', 'owsianych', 'górskich']
# ['2', 'łyżki', 'wiórków', 'kokosowych']
# ['200', 'ml', 'mleczka', 'kokosowego']
# ['2', 'łyżki', 'cukru']
# ['50', 'g', 'czekolady', 'mlecznej', 'lub', 'deserowej']
# ['maliny']
# ['10', 'owoców', 'lychee']
# ['mix', 'sałat', '(1/2', 'opakowania)']
# ['1', 'kulka', 'sera', 'mozarella']
# ['oliwa', 'z', 'oliwek']
# ['miód']
# ['sól']
# ['ocet', 'jabłkowy']
# ['1/2', 'szklanki', 'oliwek', 'czarnych']
# ['Makaron:', '•', '200', 'g', 'makaronu', 'ryżowego']
# ['1', 'cukinia', 'pokrojona', 'na', 'kawałki']
# ['4', 'łyżki', 'orzeszków', 'ziemnych']
# ['1', '-', '2', 'duże', 'czerwone', 'papryczki', 'chili']
# ['2', 'gałązki', 'szczypiorku']
# ['listki', 'świeżej', 'mięty', 'i', 'kolendry', '(po', 'pół', 'szklanki)']
# ['Sos:', '•', '1', 'ząbek', 'czosnku,', 'drobno', 'starty']
# ['2', 'łyżki', 'sosu', 'rybnego', '(lub', 'sojowego)']
# ['sok', 'z', '1', 'limonki']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['1', 'łyżka', 'brązowego', 'cukru']
# ['100', 'g', 'makaronu', 'ryżowego']
# ['1', 'pęczek', 'botwinki', '(młodej', 'z', 'małymi', 'buraczkami)']
# ['2', 'łyżki', 'oleju', 'kokosowego']
# ['1', 'łyżka', 'startego', 'świeżego', 'imbiru']
# ['1', 'ząbek', 'czosnku']
# ['4', 'łyżki', 'sezamu']
# ['100', 'g', 'tofu']
# ['2', 'młode', 'cebule', 'ze', 'szczypiorem', '(dymki)']
# ['5', 'łyżek', 'sosu', 'sojowego']
# ['łyżeczka', 'syropu', 'klonowego']
# ['2', 'łyżki', 'oleju', 'sezamowego']
# ['1', 'łyżeczka', 'ostrego', 'sosu', 'Sriracha']
# ['garść', 'świeżej', 'mięty']
# ['1', 'pierś', 'z', 'kurczaa']
# ['3', 'liście', 'limonki', 'kafir']
# ['1-2', 'łyżki', 'pasty', 'Panang']
# ['1', 'łyżeczka', 'sosu', 'rybnego']
# ['1', 'łyżeczka', 'cukru', 'trzcinowego', 'lub', 'palmowego']
# ['1', 'łyżka', 'oleju']
# ['100', 'ml', 'mleczka', 'kokosowego']
# ['2', 'liście', 'limonki', 'kafir,', 'pocięte', 'w', 'paski']
# ['papryczka', 'chili,', 'pociętę', 'w', 'krążki']
# ['ryż', 'jaśminowy', 'do', 'podania']
# ['250', 'g', 'makaronu', 'ryżowego']
# ['200', 'ml', 'mleczka', 'kokosowego']
# ['3-4', 'świeże', 'grzyby', 'Shiitake']
# ['1', 'mango']
# ['3', 'łyżki', 'sosu', 'śliwkowego']
# ['2', 'piersi', 'z', 'kurczaka', '(umyte', 'i', 'oczyszczone', 'z', 'błon)']
# ['1', 'zielona', 'papryczka', 'chili']
# ['2', 'ząbki', 'czosnku']
# ['3-4', 'łyżki', 'oleju']
# ['kilka', 'listków', 'bazylii']
# ['200', 'g', 'makaronu', 'ryżowego']
# ['2', 'ząbki', 'czosnku']
# ['1', 'papryczka', 'chili']
# ['3-4', 'łyżki', 'sosu', 'sojowego']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['garść', 'posiekanej', 'kolendry']
# ['4', 'kawałki', 'mięsa', 'z', 'udek', 'z', 'kurczaka', '(bez', 'skóry', 'i', 'kości)']
# ['sól']
# ['pieprz']
# ['przyprawa', '5', 'smaków']
# ['słodki', 'sos', 'chili', '(1-2', 'łyżki', 'stołowe)']
# ['sezam', 'biały']
# ['kolendra', 'do', 'dekoracji', '(opcjonalnie)']
# ['Składniki', 'na', 'pudding:', '•', '800', 'ml', 'mleczka', 'kokosowego']
# ['1/3', 'szklanki', 'tapioki']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['szczypta', 'soli']
# ['Składniki', 'na', 'mus', 'truskawkowy:', '•', '2', 'szklanki', 'truskawek']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['sok', 'z', 'połowy', 'cytryny']
# ['2', 'podwójne', 'filety', 'z', 'kurczaka']
# ['2', 'łyżki', 'pasty', 'Tom', 'Yum', 'Thai', 'Pride']
# ['sos', 'sojowy', 'Lee', 'Kum', 'Kee']
# ['sos', 'rybny', 'Cock']
# ['mleko', 'kokosowe', 'Bonasia']
# ['papryka', 'chili']
# ['czosnek']
# ['makaron', 'ryżowy', '3', 'mm', 'Farmer']
# ['orzechy', 'pinii']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'żółtej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['60', 'g', 'ziemniaków']
# ['150', 'g', 'mięsa', 'drobiowego']
# ['60', 'g', 'cebuli']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['400', 'ml', 'mleka']
# ['80', 'g', 'tapioki']
# ['1', 'łyżeczka', 'pasty', 'z', 'wanilii', 'lub', 'ziarenka', 'z', '1', 'laski', 'wanilii']
# ['2', 'łyżki', 'cukru']
# ['konfitura', 'malinowa']
# ['300', 'ml', 'kawy', 'espresso']
# ['2', 'łyżki', 'żelatyny']
# ['cukier']
# ['1/2', 'szklanki', 'tapioki']
# ['2', 'szklanki', 'wody']
# ['konfitura', 'malinowa']
# ['800', 'ml', 'mleczka', 'kokosowego']
# ['1/3', 'szklanki', 'perełek', 'z', 'tapioki']
# ['1', 'łyżka', 'cukru', 'trzcinowego']
# ['szczypta', 'soli']
# ['1', 'mango']
# ['15', 'ml', 'oleju', 'do', 'woka', 'Thai', 'Pride']
# ['40', 'g', 'czerwonej', 'pasty', 'curry', 'Thai', 'Pride']
# ['40', 'ml', 'wody']
# ['150', 'g', 'mięsa', 'drobiowego']
# ['60', 'g', 'pędów', 'bambusa', 'Thai', 'Pride']
# ['160', 'ml', 'mleczka', 'kokosowego', 'Diamond']
# ['20', 'g', 'liści', 'bazylii']
# ['5', 'g', 'czerwonej', 'papryczki', 'chili']
# ['300', 'g', 'tofu']
# ['20', 'owoców', 'lychee']
# ['1', 'puszka', 'pomidorów']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['3', 'marchewki']
# ['2', 'szalotki']
# ['1', 'łyżeczka', 'nasion', 'kminku']
# ['1,5', 'łyżeczki', 'nasion', 'gorczycy']
# ['1', 'łyżeczka', 'nasion', 'kolendry']
# ['1', 'łyżeczka', 'kurkumy']
# ['1', 'łyżeczka', 'płatków', 'chili']
# ['1', 'łyżeczka', 'świeżego,', 'startego', 'imbiru']
# ['2', 'ząbki', 'czosnku']
# ['liść', 'laurowy']
# ['olej']
# ['sól']
# ['200', 'g', 'wiśni']
# ['100', 'ml', 'wody']
# ['2-3', 'łyżki', 'cukru', 'kokosowego']
# ['15', 'g', 'tapioki']
# ['szczypta', 'cynamonu']
# ['1', 'goździk']
# ['4-5', 'sztuk', 'kardamonu']
# ['340', 'g', 'tofu']
# ['200', 'g', 'gorzkiej', 'czekolady']
# ['1/2', 'szklanki', 'wody']
# ['1/2', 'szklanki', 'cukru']
# ['dodatki', 'smakowe', 'np.', '1', 'łyżeczka', 'ekstraktu', 'z', 'wanilii,', '1', 'łyżka', 'likieru', 'pomarańczowego,', '1/3', 'łyżeczki', 'cynamonu,', 'szczypta', 'ostrej', 'papryki']
# ['300', 'ml', 'jogurtu', 'naturalnego', '2%']
# ['10', 'owoców', 'lychee']
# ['2', 'banany']
# ['200', 'g', 'ananasa']
# ['1', 'szklanka', 'kruszonego', 'lodu']
# ['miód']
# ['3', 'łyżeczki', 'soku', 'z', 'limonki']
# ['1/2', 'szklanki', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['2', 'łyżki', 'miodu']
# ['2', 'łyżeczki', 'imbiru']
# ['1', 'szklanka', 'wody', 'kokosowej']
# ['1', 'szklanka', 'owoców', 'mango', '(świeżych', 'lub', 'mrożonych)']
# ['1', 'obrany', 'banan']
# ['200', 'g', 'jogurtu', 'greckiego']
# ['1', 'łyżka', 'cukru', 'brązowego']
# ['2', 'szklanki', 'puree', 'z', 'mango']
# ['1/2', 'szklanki', 'mleczka', 'kokosowego']
# ['2', 'łyżeczki', 'brązowego', 'cukru']
# ['1', 'szklanka', 'wody', 'mineralnej', 'niegazowanej']
# ['4', 'łyżki', 'stołowe', 'nasion', 'Chia']
# ['2', 'łyżeczki', 'soku', 'z', 'limonki']
# ['100', 'ml', 'wody', 'kokosowej']
# ['100', 'g', 'jogurtu', 'naturalnego']
# ['1/2', 'mango']
# ['150', 'g', 'truskawek']
# ['lód']
# ['Napój', 'Mango', 'Rubicon', 'Deluxe']
# ['1/2', 'cytryny']
# ['6', 'mandarynek']
# ['125', 'g', 'ananasa']
# ['1', 'szklanka', 'soku', 'jabłkowego']
# ['30', 'ml', 'Rumu', 'Tanduay']
# ['60', 'ml', 'Wina', 'Sake', '-', 'Gekkeikan', 'Haiku']
# ['30', 'ml', 'syropu', 'z', 'trawy', 'cytrynowej']
# ['90', 'ml', 'świeżo', 'zaparzonej', 'zielonej', 'herbaty']
# ['kilka', 'kostek', 'lodu']
# ['Dodatki', 'do', 'dekoracji:']
# ['imbir,', 'mięta,', 'cytryna']
# ['45', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['25', 'ml', 'świeżego', 'soku', 'z', 'limonki']
# ['30', 'ml', 'syropu', 'cukrowego']
# ['8-10', 'liście', 'tajskiej', 'bazylii']
# ['"kropla', 'wody"']
# ['20', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['30', 'ml', 'syropu', 'z', 'lychee']
# ['50', 'ml', 'wina', 'musującego']
# ['opcjonalnie:', 'szczypta', 'gazowanego', 'napoju', 'cytrynowego']
# ['45', 'ml', 'Mekhong', 'Thai', 'Spirit']
# ['15', 'ml', 'syropu', 'cynamonowego']
# ['60', 'ml', 'soku', 'pomarańczowego']
# ['60', 'ml', 'czerwonego', 'wina']
# ['"kropla', 'limonki"']
# ['150-200', 'ml', 'Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['80', 'ml', 'tequili']
# ['80', 'ml', 'likieru', 'pomarańczowego', 'triple', 'sec']
# ['sok', 'z', '1/2', 'limonki']
# ['1', 'łyżka', 'cukru']
# ['*dodatkowo', '2', 'łyżeczki', 'cukru', 'do', 'dekoracji']
# ['kilka', 'kostek', 'lodu']
# ['400', 'ml', 'mleczka', 'kokosowego']
# ['cukier']
# ['125', 'ml', 'spirytusu', '95%']
# ['500', 'ml', 'wody', 'kokosowej']
# ['2', 'szt.', 'limonki']
# ['2', 'szt.', 'grejpfruta', 'czerwonego']
# ['syrop', 'z', 'agawy']
# ['1', 'szt.', 'mango']
# ['1/2', 'melona']
# ['świeża', 'mięta']
# ['lód']
# ['200', 'g', 'ananasa', '(obranego', 'i', 'pokrojonego', 'w', 'kostkę)']
# ['1', 'dojrzałe', 'mango']
# ['100-150', 'g', 'truskawek']
# ['100', 'ml', 'wody', 'kokosowej', 'z', 'mango']
# ['kostki', 'lodu', '(opcjonalnie)']
# ['rabarbar', '4', 'łodygi']
# ['woda', '1', 'litr']
# ['cukier', 'palmowy', '50', 'g']
# ['cytryna', '1⁄2', 'sztuki']
# ['melisa']
# ['lód']
# ['1', 'banan']
# ['1', 'owoc', 'z', 'granatu']
# ['200', 'ml', 'wody', 'kokosowej', 'z', 'granatem']
# ['200', 'ml', 'wody', 'kokosowej', 'z', 'ananasem']
# ['100', 'ml', 'mleka']
# ['4', 'plastry', 'ananasa']
# ['1', 'łyżeczka', 'kakao']
# ['2', 'limonki']
# ['2', 'łyżki', 'stołowe', 'gruboziarnistego', 'cukru', 'lub', 'soli']
# ['2', 'szklanki', 'puree', 'z', 'mango']
# ['1', '1/2', 'szklanki', 'Tequili']
# ['1', '1/2', 'szklanki', 'likieru', 'Triple', 'Sec']
# ['1/4', 'szklanki', 'cukru']
# ['40', 'cl', 'czystej', 'wódki']
# ['sok', 'z', '1/2', 'limonki']
# ['Rubicon', 'Deluxe', 'Napój', 'Mango']
# ['grenadina']
# ['30', 'ml', 'ciemnego', 'rumu', 'lub', 'whisky']
# ['1', 'limonka']
# ['150', 'ml', 'Rubicon', 'Deluxe', 'Napój', 'Guawa']
# ['kilka', 'kostek', 'lodu']
# ['gazowana', 'woda', 'mineralna']
# ['2', 'szklanki', 'soku', 'ananasowego']
# ['1', 'szklanka', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['Sok', 'z', '1/2', 'pomarańczy']
# ['Sok', 'z', '1/2', 'limonki']
# ['1', 'cząstka', 'limonki']
# ['45', 'ml', 'Rumu', 'Malibu']
# ['45', 'ml', 'napoju', 'Rubicon', 'Deluxe', 'Lychee']
# ['45', 'ml', 'napoju', 'Rubicon', 'Deluxe', 'Guawa']
# ['1', 'cząstka', 'limonki']
# ['45', 'ml', 'wino', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['2', 'łyżeczki', 'brązowego', 'cukru']
# ['8', 'liści', 'mięty']
# ['1/2', 'limonki']
# ['kruszony', 'lód']
# ['100-150', 'ml', 'gazowanej', 'wody', 'mineralnej']
# ['15', 'ml', 'Wina', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['30', 'ml', 'czystej', 'wódki']
# ['15', 'ml', 'soku', 'z', 'limonki']
# ['140', 'ml', 'Wina', 'z', 'moreli', 'japońskiej', 'Choya', 'Silver']
# ['60', 'ml', 'ginu']
# ['3', 'dojrzałe', 'banany']
# ['250', 'ml', 'wody', 'kokosowej']
# ['1/2', 'cytryny']
# ['150', 'g', 'świeżego', 'ananasa']
# ['250', 'ml', 'wody', 'kokosowej']
# ['limonka']
# ['kilka', 'listków', 'mięty']
# ['lód']
# ['1', 'antrykot', 'wołowy']
# ['1', 'garść', 'migdałów']
# ['1', 'garść', 'białego', 'sezamu']
# ['1', 'papryka', 'czerwona']
# ['1', 'papryczka', 'chilli']
# ['1', 'ząbek', 'czosnku']
# ['kawałek', 'imbiru']
# ['1', 'sałata', 'rzymska']
# ['100', 'g', 'makaronu', 'ryżowego']
# ['1', 'garść', 'kiełków', 'fasoli', 'mung']
# ['1', 'łyżka', 'mielonej', 'trawy', 'cytrynowej']
# ['2-3', 'łyżki', 'sosu', 'teryiaki']
# ['olej', 'arachidowy']
# ['1', 'łyżka', 'sosu', 'rybnego']
# ['1', 'czerwona', 'cebula']
# ['2', 'łyżki', 'sosu', 'ostrygowego']
# ['1', 'łyżka', 'octu', 'ryżowego']
# ['świeża', 'kolendra']
# ['800', 'ml', 'mleczka', 'koksowego']
# ['¾', 'szklanki', 'tapioki']
# ['1', 'laska', 'wanilii']
# ['3-4', 'łyżki', 'cukru']
# ['2', 'płaskie', 'łyżeczki', 'agaru']
# ['szczypta', 'soli', 'himalajskiej', 'lub', 'morskiej']
# ['100', 'g', 'gorzkiej', 'czekolady', '90%']
# ['1', 'łyżeczka', 'oleju', 'kokosowego']
# ['1', 'łyżka', 'oleju', 'kokosowego']
# ['1', 'ząbek', 'czosnku']
# ['1/2', 'cebuli', 'cukrowej']
# ['łodyga', 'selera', 'naciowego', 'lub', 'pora']
# ['500', 'g', 'marchewki']
# ['2', 'łyżeczki', 'startego', 'imbiru']
# ['1', 'łyżka', 'masła', 'orzechowego']
# ['1/2', 'łyżeczki', 'chili', 'w', 'proszku']
# ['1/2', 'łyżeczki', 'kurkumy']
# ['1/2', 'łyżeczki', 'kminu', 'rzymskiego']
# ['szczypta', 'cynamonu']
# ['600', 'ml', 'bulionu', 'jarzynowego']
# ['250', 'ml', 'mleczka', 'kokosowego']
# ['100', 'g', 'tofu']
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Proof of concept

# %%
# %run words.py

# %%
nie_jednostki = [
    'jogurtu',
    'banany',
    'ostrej',
    'czerwonej',
    'piersi',
    'szparagów',
    'kapustka',
    'cukier',
    'świeżego',
    'dojrzałe',
    'Rumu',
    'dojrzałe',
    'czystej',
    'smakowe',
    'tequili',
    'limonki',
    'fasoli',
    'żeberek',
    "truskawek",
    'mąki',
    'pokrojonego',
    'cienkie',
    'cebuli',
    'kukurydzy',
    'bambusa',
    'posiekanych',
    'oleju',
    'oliwek',
    'papryczka',
    'szczypiorek',
    'kiełków',
    'orzeszków',
    'trawy',
    'ziemniaków',
    'pomidorów',
    'moreli',
    'mleczka',
    'wódki',
    'koktajlowe'
]

# %%
jednostki = Sentence(" ".join(jednostki))
nie_jednostki = Sentence(" ".join(nie_jednostki))
emb.embed(jednostki)
emb.embed(nie_jednostki)
# Out:
# [Sentence: "jogurtu banany ostrej czerwonej piersi szparagów kapustka cukier świeżego dojrzałe Rumu dojrzałe czystej smakowe tequili limonki fasoli żeberek truskawek mąki pokrojonego cienkie cebuli kukurydzy bambusa posiekanych oleju oliwek papryczka szczypiorek kiełków orzeszków trawy ziemniaków pomidorów moreli mleczka wódki koktajlowe" - 39 Tokens]

# %%
X_jed = torch.cat([j.embedding for j in jednostki]).reshape(len(jednostki),300)
X_njed = torch.cat([j.embedding for j in nie_jednostki]).reshape(len(nie_jednostki),300)

# %%
def knn(Y):
    mask = Y.norm(dim=1) != 0
    if not mask.any(): return torch.BoolTensor(mask)
    
    cos_sim_jed = X_jed @ Y[mask,:].T / (X_jed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)
    cos_sim_njed = X_njed @ Y[mask,:].T / (X_njed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)

    ret = torch.zeros(Y.shape[0], dtype=torch.bool).to(device)
    ret[mask] = (cos_sim_jed.max(0)[0] > cos_sim_njed.max(0)[0]) & (cos_sim_jed.max(0)[0] > 0.5)
    return ret

# %%
def sentenceToMat(s):
    s = Sentence(s)
    emb.embed(s)
    r = torch.cat([i.embedding for i in s])
    return r.reshape(int(r.shape[0]/300), 300), s

# %%
knn(sentenceToMat('1 łyżka bezalkoholowy z guawą i imbirem mega')[0])
# Out:
# tensor([False,  True, False, False, False, False, False, False])

# %%
knn(sentenceToMat('234 Łyżeczek kefiru')[0])
# Out:
# tensor([False,  True, False])

# %%
knn(sentenceToMat('rabarbar 4 łodygi')[0])
# Out:
# tensor([False, False,  True])

# %%
Unit = []
for d in data:
    rec = []
    for i in d['ingredients']:
        mat, s = sentenceToMat(i[0])
        mask = knn(mat)
        rec.append([s[i] for i in range(len(s)) if mask[i]])
    Unit.append(rec)

# %%
Units_per_recipe = [[" ".join([u.text for u in units]) for units in U] for U in Unit]

# %%
Unit
# Out:
# [[[Token: 7 plasterki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 ząbki],
#   [Token: 2 łyżeczki],
#   [],
#   [Token: 2 łyżka]],
#  [[Token: 2 szklanki, Token: 3 pąków],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 2 łyżeczka]],
#  [[Token: 2 g],
#   [Token: 2 opakowanie, Token: 4 liści],
#   [Token: 5 cząstki],
#   [Token: 2 listków],
#   [Token: 5 plastry],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 1 szczypta]],
#  [[Token: 11 liśćmi],
#   [Token: 2 łyżka],
#   [Token: 3 ząbki],
#   [Token: 2 łyżeczka, Token: 4 soku],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżek],
#   [Token: 2 szklanki],
#   [Token: 2 łyżek],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 ząbki],
#   [],
#   [Token: 2 opakowanie],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki, Token: 3 soku],
#   [Token: 2 łyżka],
#   [],
#   []],
#  [[],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 g, Token: 5 liściach],
#   [],
#   [Token: 1 szczypta],
#   [],
#   [],
#   [],
#   []],
#  [[Token: 2 g, Token: 4 liści], [], [Token: 2 l], [], []],
#  [[Token: 2 opakowania],
#   [],
#   [Token: 2 owocu],
#   [],
#   [],
#   [],
#   [Token: 2 łyżek],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g, Token: 6 zdrewniałych, Token: 10 kawałki],
#   [Token: 2 łyżka],
#   [Token: 2 g, Token: 6 plastry],
#   [Token: 5 plasterki],
#   [Token: 2 łyżeczka],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 łyżeczki, Token: 3 soku],
#   []],
#  [[Token: 3 kwiatów, Token: 5 bzu], [], [], [Token: 2 litra]],
#  [[], [Token: 2 łyżeczki], [Token: 2 szklanka], [], [Token: 1 listki]],
#  [[],
#   [Token: 2 ząbki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 2 szklanki, Token: 4 liści],
#   [],
#   [Token: 9 rozcieńczenia]],
#  [[],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka],
#   [Token: 2 szklanek],
#   [],
#   [Token: 2 szklanki, Token: 6 soku],
#   [],
#   [Token: 2 łyżki],
#   [Token: 3 ugotowane]],
#  [[],
#   [Token: 2 g],
#   [Token: 2 g, Token: 7 ziarnach],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 ząbki],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczka]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 l],
#   [Token: 7 g],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 3 łyżeczka, Token: 6 łyżeczki, Token: 12 łyżeczki],
#   [],
#   [Token: 2 ml],
#   [Token: 2 g]],
#  [[],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [Token: 2 łyżeczka, Token: 7 łyżeczki],
#   [Token: 2 łyżeczki],
#   [],
#   [],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżeczki],
#   [],
#   [Token: 2 łyżek],
#   [Token: 2 łyżka],
#   []],
#  [[Token: 2 kwiatów, Token: 4 bzu],
#   [],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 1 szczypta],
#   [Token: 2 łyżeczki],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 bułka],
#   [],
#   [Token: 2 puszka, Token: 4 konserwowej],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [Token: 8 łyżkami],
#   [],
#   [Token: 2 bułka]],
#  [[Token: 2 baldachów, Token: 3 kwiatów, Token: 4 bzu],
#   [],
#   [],
#   [Token: 3 łyżeczki],
#   [Token: 2 l],
#   [Token: 2 g]],
#  [[], [Token: 2 łyżek], [Token: 2 g], [], []],
#  [[Token: 2 g],
#   [Token: 2 litr],
#   [Token: 2 g],
#   [Token: 2 liści],
#   [],
#   [Token: 2 szczypta],
#   [Token: 2 g],
#   []],
#  [[],
#   [Token: 2 słoik],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 3 szalotki],
#   [Token: 2 łyżeczka],
#   [Token: 1 łyżka]],
#  [[Token: 2 g],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżka],
#   [Token: 1 grzanki, Token: 5 posmarowane]],
#  [[Token: 2 g],
#   [Token: 2 łyżka],
#   [Token: 2 łyżeczki],
#   [Token: 1 szczypta],
#   [Token: 2 g],
#   [Token: 2 g, Token: 4 jabłkowego],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżeczka]],
#  [[Token: 2 ćwiartki],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g, Token: 3 jagód],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 ml]],
#  [[Token: 2 szklanka],
#   [Token: 2 ml],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 4 wanilii],
#   [],
#   [Token: 2 listków],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 3 wanilii],
#   [Token: 2 szklanka],
#   [Token: 2 owoce]],
#  [[Token: 2 g],
#   [],
#   [],
#   [],
#   [Token: 2 ząbki],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [Token: 2 litr],
#   [Token: 2 ml]],
#  [[Token: 2 ml], [Token: 2 ml], [], [Token: 5 listków]],
#  [[Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 g, Token: 3 liści],
#   [Token: 2 g]],
#  [[],
#   [],
#   [],
#   [Token: 2 szklanki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [],
#   [],
#   [Token: 1 kawałek],
#   [],
#   [Token: 3 laurowy],
#   [],
#   [Token: 2 ząbek],
#   [],
#   [Token: 2 łyżka]],
#  [[],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g, Token: 3 krewetek],
#   [Token: 2 g],
#   [],
#   [Token: 3 ząbek],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   []],
#  [[Token: 2 szklanka],
#   [Token: 4 ml],
#   [Token: 9 plasterki],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [Token: 3 garść],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżki],
#   [Token: 3 ząbka],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [Token: 2 g, Token: 3 liści],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 4 soku]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 g, Token: 3 pędów],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki]],
#  [[Token: 2 łyżki],
#   [Token: 2 łyżek],
#   [Token: 2 saszetki],
#   [Token: 2 szklanka],
#   [Token: 2 łyżek, Token: 3 miodu],
#   []],
#  [[], [], [Token: 2 ml], [], [], [], [], [Token: 4 łyżki], [], []],
#  [[Token: 2 g],
#   [Token: 5 krewetek],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki, Token: 4 listków],
#   [],
#   [Token: 3 łyżki, Token: 4 miodu],
#   [Token: 2 łyżka]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 główka],
#   [Token: 2 łyżki, Token: 5 roślinnego],
#   [Token: 2 łyżki],
#   [],
#   [Token: 6 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [],
#   [],
#   [Token: 3 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 g, Token: 4 jadalnych, Token: 6 puszki, Token: 11 plastry],
#   [Token: 3 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [],
#   [],
#   [],
#   [Token: 3 puszka],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 g, Token: 3 krewetek, Token: 9 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 3 ząbki],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki, Token: 3 listków],
#   [Token: 2 łyżka, Token: 3 liści],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka, Token: 8 łyżki]],
#  [[Token: 5 g],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 ząbek],
#   [Token: 2 łyżka],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 2 łyżki, Token: 8 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżki]],
#  [[Token: 2 łyżek], [Token: 2 g], [Token: 2 łyżka]],
#  [[Token: 2 g], [], [Token: 2 g], [Token: 2 łyżka], [Token: 2 g]],
#  [[Token: 2 g], [Token: 2 g], [Token: 2 g], [Token: 2 łyżka], [Token: 2 g]],
#  [[],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 ząbek],
#   [],
#   [],
#   [Token: 2 puszka, Token: 3 pędów],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   []],
#  [[Token: 2 g], [], [], [Token: 2 g], [Token: 2 łyżka], [Token: 2 g]],
#  [[Token: 2 g, Token: 5 krewetek],
#   [Token: 2 łyżka],
#   [Token: 2 g],
#   [Token: 2 g]],
#  [[],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [],
#   []],
#  [[Token: 2 opakowania, Token: 7 g],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 3 ząbki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 4 bułeczki, Token: 6 liście]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżki]],
#  [[Token: 2 litra],
#   [Token: 1 liść, Token: 2 laurowy],
#   [Token: 3 kawałek],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka, Token: 3 soku],
#   [Token: 1 szczypta],
#   [Token: 2 bulwy],
#   [Token: 2 g],
#   [Token: 6 garść],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżeczka],
#   []],
#  [[Token: 2 g], [Token: 2 ml], [Token: 2 łyżeczki]],
#  [[Token: 2 g],
#   [],
#   [Token: 1 szczypta],
#   [Token: 2 ząbki],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 4 łyżek],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki, Token: 3 soku],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki]],
#  [[Token: 2 g],
#   [Token: 2 g, Token: 3 krewetek],
#   [],
#   [Token: 2 g],
#   [Token: 2 ząbki],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżki, Token: 3 soku],
#   [],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 ząbek, Token: 6 plasterki],
#   [Token: 2 łyżki, Token: 4 liści],
#   [Token: 5 łyżki],
#   [],
#   []],
#  [[],
#   [Token: 2 łyżeczki],
#   [Token: 2 g],
#   [Token: 1 ćwiartka],
#   [Token: 2 ząbki],
#   [],
#   [],
#   [Token: 1 kawałek],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 g, Token: 3 krewetek],
#   [],
#   [],
#   [Token: 2 ząbek],
#   [],
#   [],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 soku],
#   [],
#   [Token: 2 łyżka]],
#  [[Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 ząbki],
#   [Token: 2 g],
#   [Token: 2 g, Token: 4 krewetek],
#   [],
#   [Token: 2 liście],
#   [Token: 2 łyżka, Token: 4 nasion],
#   []],
#  [[Token: 3 szklanki],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki, Token: 4 kremowej],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki, Token: 3 liści],
#   [Token: 2 łyżka]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 ząbek],
#   [Token: 2 łyżka],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 2 łyżki, Token: 8 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [],
#   [Token: 1 miseczka],
#   [Token: 2 ząbki],
#   [Token: 2 łyżek],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 łyżka],
#   [Token: 2 g],
#   [Token: 2 ml, Token: 4 kremówki],
#   [],
#   [],
#   [],
#   [Token: 1 garść],
#   [Token: 1 cząstki]],
#  [[],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 3 ćwiartki],
#   [Token: 3 łyżka],
#   [Token: 2 g, Token: 7 kawałki],
#   [Token: 2 g, Token: 7 połówki],
#   []],
#  [[],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka],
#   [Token: 6 połówki],
#   [Token: 4 łyżki, Token: 10 patelni],
#   []],
#  [[],
#   [Token: 2 g],
#   [Token: 2 puszki],
#   [Token: 1 gałązka],
#   [Token: 2 ząbki],
#   [Token: 2 g]],
#  [[Token: 2 opakowanie, Token: 6 kubku], [Token: 2 ml], [Token: 1 owoce]],
#  [[Token: 2 opakowanie],
#   [Token: 2 opakowanie],
#   [],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżeczka]],
#  [[],
#   [Token: 2 szklanka, Token: 4 krewetek],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 szklanek],
#   []],
#  [[Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 szklanki, Token: 4 kremówki],
#   [Token: 2 łyżki]],
#  [[],
#   [],
#   [],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [],
#   [Token: 2 g, Token: 3 płatków],
#   [Token: 3 ząbki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 3 łyżki],
#   [Token: 2 łyżki, Token: 4 nasion]],
#  [[Token: 2 szklanka],
#   [Token: 2 szklanki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 1 szczypta],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżek],
#   [Token: 2 łyżeczka]],
#  [[Token: 2 opakowanie], [Token: 2 opakowanie], [Token: 2 szklanek]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka, Token: 3 soku],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczka, Token: 3 płatków],
#   [Token: 2 szczypta],
#   [Token: 2 łyżeczki],
#   [Token: 2 ząbek],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 listków]],
#  [[],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczka],
#   [Token: 2 garści],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka]],
#  [[],
#   [Token: 2 łyżeczki],
#   [],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżeczka, Token: 3 soku],
#   [Token: 1 szczypta],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka],
#   []],
#  [[Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 łyżki],
#   [Token: 2 ml],
#   [Token: 2 łyżki],
#   [Token: 2 ml, Token: 3 soku],
#   [Token: 2 szklanki, Token: 3 nasion],
#   [],
#   [],
#   [],
#   [Token: 1 listki]],
#  [[Token: 3 sztuk],
#   [Token: 3 g],
#   [Token: 4 g],
#   [Token: 5 g],
#   [Token: 3 szklanki],
#   [Token: 4 g],
#   [],
#   [],
#   []],
#  [[Token: 2 łyżeczki],
#   [Token: 11 plasterki],
#   [Token: 2 ząbki, Token: 6 plasterki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżeczka],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 g],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżki, Token: 4 listków],
#   [],
#   []],
#  [[], [], [], [], [Token: 2 łyżeczki], [Token: 2 gałązki], [], [], [], []],
#  [[Token: 2 szklanka],
#   [Token: 2 szklanka],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 3 ząbek],
#   [Token: 2 gałązek],
#   [Token: 5 g],
#   [Token: 2 ząbek],
#   [Token: 2 łyżeczki],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta],
#   [Token: 1 kawałek],
#   [Token: 2 liści],
#   [],
#   [Token: 2 łyżki]],
#  [[],
#   [Token: 2 ząbek],
#   [Token: 2 g],
#   [],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżki, Token: 6 puszki],
#   [],
#   [],
#   [],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [],
#   []],
#  [[], [], [], []],
#  [[Token: 2 g],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżeczka],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 1 płatki],
#   [],
#   []],
#  [[Token: 2 łyżki],
#   [],
#   [Token: 2 g],
#   [Token: 3 ząbki, Token: 7 plasterki],
#   [Token: 2 łyżeczki],
#   [Token: 1 szczypta],
#   [],
#   [Token: 2 g],
#   [],
#   [Token: 2 g, Token: 5 krewetek],
#   [Token: 2 g],
#   [Token: 2 g, Token: 14 kawałki],
#   [Token: 2 łyżki]],
#  [[],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 ząbki],
#   [],
#   [Token: 2 g],
#   [],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 szklanka],
#   [Token: 2 g],
#   [Token: 2 puszka],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 garście]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 szklanki],
#   [],
#   [Token: 2 g],
#   [Token: 2 roślinny],
#   [],
#   [],
#   [Token: 2 listki, Token: 3 laurowe],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka]],
#  [[],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [Token: 1 szczypta],
#   [],
#   []],
#  [[Token: 2 łyżek],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [Token: 2 ząbki],
#   [Token: 3 połówki],
#   [Token: 2 ml],
#   [],
#   []],
#  [[Token: 2 łyżki], [Token: 2 g], [Token: 2 g], [], [], []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 3 szalotki],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [],
#   [],
#   [Token: 1 szczypta]],
#  [[Token: 2 g],
#   [],
#   [],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [],
#   [],
#   [],
#   [],
#   [Token: 2 g],
#   [],
#   []],
#  [[Token: 3 kromki, Token: 6 ziarnami],
#   [Token: 11 ogonków],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżka],
#   [Token: 2 ząbek],
#   [Token: 2 łyżka],
#   [Token: 2 puszki],
#   [],
#   []],
#  [[Token: 2 g],
#   [],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 łyżki],
#   [Token: 1 łyżka],
#   [Token: 1 łyżeczka],
#   [Token: 2 łyżek],
#   []],
#  [[],
#   [],
#   [Token: 2 g],
#   [Token: 2 ząbki],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g, Token: 5 puszki],
#   [Token: 1 szczypta],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżeczki],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 ząbek],
#   [Token: 2 łyżeczki],
#   [Token: 2 ml],
#   [Token: 2 łyżka, Token: 3 soku],
#   [Token: 2 g],
#   [Token: 2 szklanki, Token: 3 listków],
#   [Token: 2 g]],
#  [[Token: 2 szklanka],
#   [],
#   [Token: 2 łyżeczkę],
#   [],
#   [],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 liście, Token: 3 laurowe],
#   [Token: 2 l],
#   [],
#   [],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [],
#   [Token: 1 plastry],
#   [],
#   [],
#   []],
#  [[],
#   [Token: 4 g],
#   [Token: 4 g],
#   [Token: 2 g],
#   [],
#   [Token: 2 l, Token: 4 słonecznikowego],
#   []],
#  [[], [], [], [], [], [], [], [Token: 3 owoce]],
#  [[Token: 2 g],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 garść, Token: 4 listków],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczki],
#   [Token: 7 łyżek],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka, Token: 3 soku],
#   [Token: 2 łyżeczki],
#   [Token: 2 ząbek]],
#  [[Token: 2 g],
#   [Token: 2 opakowanie],
#   [Token: 5 łyżek],
#   [Token: 2 łyżki],
#   [Token: 1 łyżka],
#   [],
#   [Token: 4 g],
#   [Token: 2 owoc],
#   [],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   []],
#  [[], [], [Token: 2 krewetki], [Token: 4 szklanka], [], []],
#  [[], [Token: 1 Pędy], [], [], [], [Token: 1 krewetki]],
#  [[Token: 2 g],
#   [Token: 2 g, Token: 5 owoców],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 8 nasion],
#   [Token: 2 łyżka, Token: 5 roślinnego],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka]],
#  [[], [Token: 2 g], [Token: 2 g], [Token: 2 g, Token: 3 pędów], [Token: 2 ml]],
#  [[],
#   [],
#   [Token: 3 szalotki],
#   [Token: 3 korzenia],
#   [Token: 2 główki],
#   [],
#   [],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 4 g],
#   [Token: 2 g],
#   [],
#   [],
#   [],
#   [Token: 4 g]],
#  [[Token: 2 g],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżek],
#   [Token: 2 łyżek],
#   [Token: 2 łyżki, Token: 3 miodu],
#   [Token: 3 łyżeczka],
#   [],
#   []],
#  [[Token: 2 g],
#   [],
#   [],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 szklanki, Token: 3 pędów],
#   [Token: 2 łyżeczka],
#   [],
#   [Token: 6 łyżka],
#   [Token: 2 łyżki, Token: 3 miodu],
#   [Token: 2 łyżki],
#   [Token: 2 łyżek],
#   [],
#   [Token: 2 łyżeczka]],
#  [[Token: 3 g],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [Token: 2 ząbki],
#   [],
#   [],
#   [Token: 2 szklanka],
#   [Token: 10 jasnozielona],
#   [Token: 4 łyżki],
#   [Token: 2 łyżki, Token: 3 soku],
#   [Token: 2 łyżki],
#   [Token: 3 łyżki],
#   [Token: 2 łyżka, Token: 7 łyżki, Token: 8 płatków],
#   [Token: 2 łyżki]],
#  [[Token: 2 g],
#   [Token: 2 łyżki, Token: 5 roślinnego],
#   [Token: 2 ząbki],
#   [Token: 7 krewetek, Token: 11 g],
#   [],
#   [Token: 2 ml],
#   [Token: 2 szklanka],
#   []],
#  [[Token: 3 łyżeczki, Token: 4 żelatyny],
#   [Token: 2 łyżki],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki]],
#  [[],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki, Token: 5 roślinnego],
#   [Token: 2 łyżka],
#   [Token: 2 filiżanka],
#   [Token: 2 filiżanki, Token: 3 liści],
#   [Token: 2 liści],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki]],
#  [[Token: 2 szklanka],
#   [Token: 2 szklanka],
#   [Token: 2 szklanki, Token: 3 nasion],
#   [Token: 2 szklanki, Token: 3 płatków],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki]],
#  [[],
#   [Token: 2 ml],
#   [],
#   [],
#   [Token: 1 łodyga],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 litr],
#   [Token: 2 g],
#   [Token: 1 szczypta]],
#  [[], [Token: 2 ml], []],
#  [[Token: 2 szklanka, Token: 3 płatków],
#   [Token: 2 łyżki],
#   [Token: 2 ml],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   []],
#  [[Token: 2 owoców], [], [], [], [], [], [], [Token: 2 szklanki]],
#  [[Token: 4 g],
#   [Token: 5 kawałki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 gałązki],
#   [Token: 1 listki],
#   [Token: 4 ząbek],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 łyżka]],
#  [[Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 ząbek],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżek],
#   [Token: 1 łyżeczka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 1 garść]],
#  [[],
#   [Token: 2 liście],
#   [Token: 2 łyżki],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżka],
#   [Token: 2 ml],
#   [Token: 2 liście],
#   [],
#   []],
#  [[Token: 2 g],
#   [Token: 2 ml],
#   [],
#   [],
#   [Token: 2 łyżki],
#   [],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 łyżki],
#   [Token: 2 listków]],
#  [[Token: 2 g],
#   [Token: 2 ząbki],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 1 garść],
#   [Token: 2 kawałki],
#   [],
#   [],
#   [],
#   [Token: 5 łyżki],
#   [],
#   []],
#  [[Token: 6 ml],
#   [Token: 2 szklanki],
#   [Token: 2 łyżka],
#   [Token: 1 szczypta],
#   [Token: 7 szklanki],
#   [Token: 2 łyżka],
#   []],
#  [[], [Token: 2 łyżki], [], [], [], [], [], [], []],
#  [[Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 g, Token: 3 liści],
#   [Token: 2 g]],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 łyżeczka, Token: 5 wanilii, Token: 7 ziarenka, Token: 11 wanilii],
#   [Token: 2 łyżki],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 łyżki, Token: 3 żelatyny],
#   [],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 szklanki],
#   [Token: 2 łyżka],
#   [Token: 1 szczypta],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 g, Token: 3 pędów],
#   [Token: 2 ml],
#   [Token: 2 g, Token: 3 liści],
#   [Token: 2 g]],
#  [[Token: 2 g],
#   [Token: 2 owoców],
#   [Token: 2 puszka],
#   [Token: 2 ml],
#   [],
#   [Token: 2 szalotki],
#   [Token: 2 łyżeczka, Token: 3 nasion],
#   [Token: 2 łyżeczki, Token: 3 nasion],
#   [Token: 2 łyżeczka, Token: 3 nasion],
#   [Token: 2 łyżeczka],
#   [Token: 2 łyżeczka, Token: 3 płatków],
#   [Token: 2 łyżeczka],
#   [Token: 2 ząbki],
#   [Token: 1 liść, Token: 2 laurowy],
#   [],
#   []],
#  [[Token: 2 g, Token: 3 wiśni],
#   [Token: 2 ml],
#   [Token: 2 łyżki],
#   [Token: 2 g],
#   [Token: 1 szczypta],
#   [],
#   [Token: 2 sztuk]],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 1 dodatki,
#    Token: 5 łyżeczka,
#    Token: 10 łyżka,
#    Token: 14 łyżeczki,
#    Token: 16 szczypta]],
#  [[Token: 2 ml], [Token: 2 owoców], [], [Token: 2 g], [Token: 2 szklanka], []],
#  [[Token: 2 łyżeczki, Token: 3 soku],
#   [Token: 2 szklanki],
#   [Token: 2 łyżki, Token: 3 miodu],
#   [Token: 2 łyżeczki]],
#  [[Token: 2 szklanka],
#   [Token: 2 szklanka, Token: 3 owoców],
#   [],
#   [Token: 2 g],
#   [Token: 2 łyżka]],
#  [[Token: 2 szklanki],
#   [Token: 2 szklanki],
#   [Token: 2 łyżeczki],
#   [Token: 2 szklanka],
#   [Token: 2 łyżki, Token: 4 nasion],
#   [Token: 2 łyżeczki, Token: 3 soku]],
#  [[Token: 2 ml], [Token: 2 g], [], [Token: 2 g], []],
#  [[],
#   [],
#   [],
#   [Token: 2 g],
#   [Token: 2 szklanka, Token: 3 soku, Token: 4 jabłkowego]],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [],
#   [Token: 1 Dodatki],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 ml, Token: 4 soku],
#   [Token: 2 ml],
#   [Token: 2 liście],
#   []],
#  [[Token: 2 ml], [Token: 2 ml], [Token: 2 ml], [Token: 2 szczypta]],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 ml, Token: 3 soku],
#   [Token: 2 ml],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [],
#   [Token: 2 łyżka],
#   [Token: 3 łyżeczki],
#   []],
#  [[Token: 2 ml], [], [Token: 2 ml]],
#  [[Token: 2 ml], [], [], [], [], [], [], []],
#  [[Token: 2 g], [], [Token: 2 g], [Token: 2 ml], []],
#  [[Token: 3 łodygi], [Token: 3 litr], [Token: 4 g], [Token: 3 sztuki], [], []],
#  [[], [Token: 2 owoc], [Token: 2 ml]],
#  [[Token: 2 ml], [Token: 2 ml], [Token: 2 plastry], [Token: 2 łyżeczka]],
#  [[],
#   [Token: 2 łyżki],
#   [Token: 2 szklanki],
#   [Token: 3 szklanki],
#   [Token: 3 szklanki],
#   [Token: 2 szklanki]],
#  [[], [], [], []],
#  [[Token: 2 ml], [], [Token: 2 ml], [], []],
#  [[Token: 2 szklanki, Token: 3 soku],
#   [Token: 2 szklanka],
#   [],
#   [],
#   [Token: 2 cząstka]],
#  [[Token: 2 ml], [Token: 2 ml], [Token: 2 ml], [Token: 2 cząstka]],
#  [[Token: 2 ml], [Token: 2 łyżeczki], [Token: 2 liści], [], [], [Token: 2 ml]],
#  [[Token: 2 ml], [Token: 2 ml], [Token: 2 ml, Token: 3 soku]],
#  [[Token: 2 ml], [Token: 2 ml]],
#  [[], [Token: 2 ml], []],
#  [[Token: 2 g], [Token: 2 ml], [], [Token: 2 listków], []],
#  [[],
#   [Token: 2 garść],
#   [Token: 2 garść],
#   [],
#   [],
#   [Token: 2 ząbek],
#   [Token: 1 kawałek],
#   [],
#   [Token: 2 g],
#   [Token: 2 garść],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżka],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 szklanki],
#   [Token: 3 wanilii],
#   [Token: 2 łyżki],
#   [Token: 3 łyżeczki],
#   [Token: 1 szczypta],
#   [Token: 2 g],
#   [Token: 2 łyżeczka]],
#  [[Token: 2 łyżka],
#   [Token: 2 ząbek],
#   [],
#   [Token: 1 łodyga],
#   [Token: 2 g],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 1 szczypta],
#   [Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 g],
#   [Token: 2 łyżka],
#   []],
#  [[Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 ml],
#   [Token: 2 łyżeczka],
#   [Token: 2 ząbki],
#   [],
#   [],
#   []],
#  [[Token: 3 papieru], [], [], [], [], [], []],
#  [[Token: 2 g],
#   [Token: 2 g],
#   [],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki],
#   [Token: 2 łyżeczki, Token: 3 płatków],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżki, Token: 4 roślinnego],
#   [Token: 2 ząbki],
#   [],
#   [Token: 2 gałązka],
#   [Token: 2 łyżki],
#   [Token: 2 łyżka],
#   [Token: 2 łyżeczki],
#   []],
#  [[Token: 2 g],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [],
#   [Token: 2 łyżki],
#   [Token: 2 łyżki],
#   [Token: 2 ząbki],
#   [],
#   [Token: 2 łyżka],
#   []],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [],
#   [],
#   [],
#   [Token: 2 ząbki],
#   [Token: 2 łyżka],
#   [Token: 1 szczypta],
#   [Token: 1 szczypta]],
#  [[Token: 2 ml],
#   [Token: 2 ml],
#   [Token: 2 g, Token: 3 płatków, Token: 4 żelatyny],
#   [Token: 2 g],
#   [Token: 2 g]],
#  [[Token: 2 szklanka],
#   [],
#   [Token: 2 łyżka],
#   [Token: 2 ząbek],
#   [Token: 2 g],
#   [Token: 2 szklanki],
#   [Token: 2 ml],
#   [Token: 1 garść],
#   [Token: 2 g],
#   []]]

# %% [markdown]
# # Full

# %%
przyprawy, warzywa, nabial, zboza, tluszcze, miesa;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-976-696a95573898> in <module>
# ----> 1 przyprawy, warzywa, nabial, zboza, tluszcze, miesa;
#
# NameError: name 'miesa' is not defined

# %%
def knn(Y, X_jed, X_njed, d):
    mask = Y.norm(dim=1) != 0
    if not mask.any(): return torch.BoolTensor(mask)
    
    cos_sim_jed = X_jed @ Y[mask,:].T / (X_jed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)
    cos_sim_njed = X_njed @ Y[mask,:].T / (X_njed.norm(dim=1, keepdim=True) * Y[mask,:].norm(dim=1, keepdim=True).T)

    ret = torch.zeros(Y.shape[0], dtype=torch.bool).to(device)
    
    ret[mask] = (d*cos_sim_jed.max(0)[0] > cos_sim_njed.max(0)[0]) & (cos_sim_jed.max(0)[0] > 0.5)
    return ret

# %%
def gen_knn(x, nx, d):
    x = Sentence(" ".join(x))
    nx = Sentence(" ".join(nx))
    emb.embed(x)
    emb.embed(nx)
    x = [xx for xx in x if xx.embedding.norm() > 0.001]
    nx = [xx for xx in nx if xx.embedding.norm() > 0.001]
    X_x = torch.cat([j.embedding for j in x]).reshape(len(x),300)
    X_nx = torch.cat([j.embedding for j in nx]).reshape(len(nx),300)
    return lambda Y: knn(Y, X_x, X_nx, d)

# %%
s = Sentence("lód asdf piwo")

# %%
emb.embed(s)
# Out:
# [Sentence: "lód asdf piwo" - 3 Tokens]

# %%
[sss.embedding for sss in [ss for ss in s if ss.embedding.norm() > 0.001]]
# Out:
# [tensor([-2.8112e-01, -5.0371e-02,  4.8964e-02, -6.7958e-01,  7.4694e-01,
#           2.0344e-01,  1.2213e-01, -1.9825e-01,  1.3946e-01,  5.3816e-01,
#           4.6904e-01,  9.8772e-02,  4.3799e-01,  2.9822e-01, -1.3622e-01,
#           5.4849e-01,  2.3856e-01,  2.7953e-01,  5.4909e-02, -1.3054e-01,
#          -3.9186e-01, -8.3339e-02, -6.2480e-01, -1.0207e-02, -4.2332e-01,
#           2.4943e-01, -2.0429e-01, -9.1938e-02, -2.8870e-01, -2.6780e-02,
#          -1.8569e-01, -1.5805e-01,  2.6072e-01, -2.9521e-01,  4.3091e-01,
#           5.5229e-01,  2.2313e-02,  2.3725e-01, -1.7151e-01, -9.3433e-04,
#          -3.3377e-01,  4.8355e-02, -1.1487e-01, -2.0072e-01,  2.6008e-01,
#          -8.1873e-01,  1.1706e-01, -2.3152e-01, -1.1688e-01, -1.7142e-01,
#           3.1835e-01, -8.2847e-02,  5.8493e-01,  3.5867e-01,  4.6979e-02,
#          -1.8964e-01, -1.6925e-01, -6.0271e-01,  4.0612e-01,  1.6662e-01,
#          -9.4596e-02, -2.0708e-01,  3.1231e-01, -1.7679e-01,  2.4070e-01,
#           6.0691e-02,  6.7991e-01,  1.4262e-03, -2.5475e-01,  3.8399e-01,
#           2.5489e-01, -4.4957e-01, -1.4698e-01, -2.4398e-01, -8.6927e-02,
#           1.8865e-01,  3.8134e-02,  5.0721e-02, -6.5163e-01,  6.5650e-01,
#          -3.7420e-02, -3.2362e-01,  3.1650e-01, -1.7237e-01, -1.3431e-01,
#          -7.5678e-01,  1.2801e-01,  9.3135e-02,  4.5401e-01,  1.5846e-01,
#           3.0481e-01, -1.7476e-01, -1.9128e-01,  2.3535e-01,  3.8701e-01,
#           9.8787e-01, -5.4730e-02, -3.2321e-01, -3.5087e-01, -2.3103e-01,
#          -1.8012e-01, -3.4703e-01,  4.2717e-01, -5.3927e-01,  4.0187e-01,
#          -9.9874e-03, -3.8693e-01, -5.4984e-01,  2.6308e-01, -5.0693e-02,
#           3.6108e-02,  4.5108e-01, -2.3609e-01, -3.3834e-01, -6.8369e-02,
#          -3.1667e-01,  4.6715e-01,  2.5007e-01,  4.3937e-01,  3.3783e-01,
#          -2.7385e-02, -3.5075e-02, -1.4460e-01,  1.6154e-01, -2.8489e-01,
#           4.8446e-01,  9.4153e-02, -3.5100e-02,  5.0568e-01, -8.6242e-02,
#           4.9188e-01, -2.9349e-01,  1.2088e-01,  2.6106e-01,  3.0338e-01,
#          -5.8619e-02,  4.6572e-01, -1.1679e-01, -1.1121e-01, -4.9841e-02,
#          -6.6748e-01, -3.0753e-01,  1.5624e-01, -2.2531e-01,  4.7711e-01,
#           2.3910e-01,  4.8012e-01, -2.7380e-01, -8.8993e-03, -5.7228e-01,
#           3.0501e-01, -3.7760e-01, -1.5157e-01,  4.1746e-01, -1.1231e-02,
#          -1.9491e-01, -3.7024e-01,  1.8388e-01, -1.9216e-01,  2.7787e-01,
#           2.6829e-01,  8.1557e-03,  3.1002e-01, -6.5859e-02,  1.0257e-01,
#           2.1385e-01,  2.3634e-02,  3.1787e-01, -1.5651e-01, -4.0530e-01,
#          -1.6581e-01, -5.1199e-02,  1.5990e-01,  3.7891e-01,  1.6506e-01,
#           1.2147e-01,  4.7166e-01, -1.9484e-01, -6.9172e-01,  3.3768e-01,
#           1.2975e-01, -8.2632e-02,  2.0090e-01,  2.1991e-01,  2.9672e-01,
#          -2.6274e-01, -5.2054e-01, -3.3787e-01, -5.5605e-02,  4.6745e-01,
#           4.0291e-01, -3.7088e-01, -1.4670e-01,  4.5294e-01,  3.5391e-02,
#           3.1208e-02, -4.8603e-01, -1.8718e-01,  1.5414e-01,  1.4973e-03,
#           2.3672e-01,  2.5911e-03,  7.4498e-01,  1.4740e-01, -1.7468e-01,
#           8.9571e-02, -5.0645e-02,  4.2388e-02, -2.8754e-01,  6.6053e-01,
#           4.1278e-01,  1.1203e-01,  1.0611e-01,  3.5140e-02,  3.8887e-01,
#           7.1897e-02, -1.6172e-02,  3.6071e-01,  4.0386e-01,  2.1794e-01,
#          -3.2486e-01,  3.6695e-02, -1.5202e-01,  1.5305e-01,  3.2429e-02,
#          -1.1552e-01,  3.5885e-01,  3.3108e-01, -8.3046e-01,  2.3958e-01,
#          -4.5144e-02,  1.7092e-01,  2.7035e-01,  2.1383e-01,  4.8339e-01,
#           5.0180e-01, -4.9038e-02, -1.5881e-01,  2.0844e-02,  6.0065e-01,
#           1.3906e-01,  1.9900e-01, -8.8736e-02, -1.4225e-02,  2.0692e-01,
#          -1.8422e-01,  2.4542e-02, -2.8711e-01, -2.0357e-01,  6.0534e-02,
#          -3.9321e-01, -5.5321e-01, -2.1522e-02, -2.5979e-01,  1.8476e-01,
#           3.1372e-01,  4.2581e-01,  4.4193e-01, -1.6761e-01,  3.9098e-01,
#          -6.4164e-02,  4.7148e-02,  3.9036e-01,  4.4575e-02, -1.3921e-03,
#          -1.9425e-01,  2.5745e-01, -1.4917e-01, -3.4536e-01,  5.6564e-02,
#           4.1447e-01, -1.3033e-02,  8.2084e-02, -3.7698e-01, -3.7744e-01,
#           1.2073e-01,  6.7634e-01,  3.8948e-01, -5.3912e-02,  2.5126e-01,
#          -2.4511e-01, -5.2294e-01,  4.3581e-01,  2.0280e-01,  1.3474e-01,
#           8.9073e-02, -3.1386e-02, -4.5887e-01,  8.0191e-02, -9.5723e-02,
#          -1.9802e-01,  1.2749e-01,  6.5170e-01,  5.4514e-01, -4.5123e-01,
#          -2.8769e-01, -1.8114e-01,  4.1718e-01, -2.1657e-01,  8.4611e-03]),
#  tensor([ 0.2770,  0.2863, -0.2565, -0.5928, -0.0559,  0.2807, -0.3324, -0.0201,
#           0.4337,  0.0572,  0.1514,  0.1211,  0.0245,  0.0514, -0.2491,  0.4064,
#           0.1137, -0.1266, -0.0486,  0.0134,  0.1723, -0.4884, -0.6641, -0.3733,
#           0.1793, -0.2668, -0.8747, -0.2997, -0.1193,  0.0169, -0.0327,  0.0762,
#          -0.2364,  0.0279,  0.4746,  0.1910,  0.3169,  0.2095, -0.0785,  0.0245,
#           0.0334,  0.0091, -0.0946, -0.2480,  0.2914, -0.5104,  0.1719,  0.1037,
#          -0.0102, -0.5224, -0.1870,  0.0687, -0.0460, -0.7033, -0.0025, -0.5558,
#          -0.0613, -0.5701,  0.4599,  0.2629, -0.5448, -0.2833, -0.1935, -0.1848,
#           0.4724,  0.2321, -0.0687,  0.7791, -0.2005,  0.3444,  0.1913, -0.1966,
#           0.0873, -0.3226,  0.7234,  0.9082, -0.1124, -0.1494, -0.4666,  0.6144,
#          -0.0545, -0.0658,  0.3842, -0.4037,  0.2116, -0.3699, -0.0749,  0.4587,
#           0.2359,  0.4170,  0.6191, -0.2196, -0.0517,  0.1167, -0.0110,  0.7959,
#          -0.3337,  0.2046,  0.3874, -0.4087, -0.1608, -0.8714,  0.0826,  0.5440,
#          -0.1279,  0.1176, -0.4494,  0.1465,  0.1182, -0.1692, -0.0701,  0.2234,
#           0.2275,  0.0886, -0.1690,  0.6661, -0.5224,  0.0661, -0.5308,  0.1395,
#          -0.6681, -0.2505, -0.0552,  0.3979,  0.4054,  0.0479,  0.3398, -0.0060,
#          -0.2890, -0.5233,  0.4949, -0.1877,  0.4215, -0.0381,  0.1401, -0.7913,
#          -0.1931,  0.8412, -0.1216, -0.6646,  0.2634,  0.2742,  0.2226,  0.2579,
#          -0.2694, -0.0539, -0.0877, -0.1626,  0.0989,  0.0057,  0.3032, -0.0637,
#           0.4732,  0.4571,  0.0901,  0.1309,  0.1728, -0.0575,  0.0298, -0.2382,
#          -0.3708, -0.2857, -0.2104,  0.3738,  0.3757, -0.3212, -0.1866,  0.2589,
#           0.2656,  0.0415,  0.3485,  0.0314, -0.3076,  0.1664,  0.7139,  0.1830,
#          -0.5529,  0.2246, -0.2231,  0.2292,  0.2050, -0.4000,  0.0681,  0.1964,
#           0.2600, -0.3173,  0.3880, -0.3304, -0.1150,  0.4583,  0.0114,  0.1524,
#           0.1224,  0.1791, -0.2718,  0.0831,  0.2483, -0.3928, -0.1797,  0.1176,
#          -0.0779, -0.2645,  0.0067, -0.4711, -0.0167, -0.3388, -0.1789,  0.2517,
#           0.2505,  0.1618,  0.7264,  0.0723,  0.0324, -0.1184,  0.2247, -0.1795,
#           0.2271, -0.0331, -0.5129, -0.9321,  0.1652, -0.1898, -0.2541,  0.7628,
#           0.6786,  0.4663, -0.1345,  0.2751, -0.1184, -0.2046,  0.1478, -0.2230,
#           0.2484, -0.5399,  0.0224,  0.3613,  0.6007,  0.3275,  0.0095, -0.1509,
#           0.3216, -0.1960, -0.0545,  0.2096,  0.3517, -0.6496, -0.4616, -0.6120,
#          -0.3348, -0.0585,  0.1364,  0.0216,  0.5309,  0.3122, -0.3446, -0.1009,
#          -0.2212, -0.0609, -0.2931,  0.4084,  0.5178, -0.1388,  0.0091,  0.1111,
#          -0.3647, -0.1805,  0.1113, -0.1385,  0.0580,  0.1300,  0.5498, -0.3438,
#           0.8505, -0.0971, -0.7451,  0.1847,  0.1414,  0.4107, -0.7403,  0.0756,
#          -0.1369, -0.2989,  0.5120,  0.1599, -0.2663, -0.0315, -0.4728, -0.1563,
#           0.6470, -0.2416,  0.1224,  0.3245,  0.3634,  0.4656, -0.1721, -0.0117,
#           0.1595,  0.2066, -0.4920, -0.0739])]

# %%
def predict(knn, data):
    Unit = []
    for d in data:
        rec = []
        for i in d['ingredients']:
            mat, s = sentenceToMat(i[0])
            mask = knn(mat)
            rec.append([s[i] for i in range(len(s)) if mask[i]])
        Unit.append(rec)
        
    return [[" ".join([u.text for u in units]) for units in U] for U in Unit]

# %% [markdown]
# # Jednostki

# %%
# %run words.py

# %%
knn_jednostki = gen_knn(jednostki, przyprawy + warzywa + nabial + zboza + tluszcze, 1)

# %%
predict(knn_jednostki, data)
# Out:
# [['plasterki', 'łyżki', 'łyżka', 'ząbki', 'łyżeczki', '', 'łyżka'],
#  ['szklanki pąków', 'szklanki', 'szklanki', 'łyżeczka'],
#  ['g',
#   'opakowanie liści',
#   'cząstki',
#   'listków',
#   'plastry',
#   'łyżki oliwek',
#   'łyżki',
#   'szczypta'],
#  ['liśćmi', 'łyżka oliwek', 'ząbki', 'łyżeczka soku', '', ''],
#  ['g truskawek', 'g', '', 'łyżek', 'szklanki', 'łyżek', '', 'g', 'łyżki'],
#  ['g mięsa',
#   'ząbki',
#   '',
#   'opakowanie',
#   'łyżki',
#   'łyżki soku',
#   'łyżka',
#   '',
#   ''],
#  ['', '', 'ząbki', 'g liściach', '', 'szczypta', '', '', '', ''],
#  ['g liści', '', 'l', '', ''],
#  ['opakowania',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'łyżek oliwek',
#   'łyżeczki',
#   'łyżeczki',
#   ''],
#  ['g',
#   'g zdrewniałych kawałki',
#   'łyżka',
#   'g plastry',
#   'plasterki',
#   'łyżeczka',
#   'ml',
#   'ml',
#   'g',
#   'łyżeczki soku',
#   ''],
#  ['', '', '', 'litra'],
#  ['', 'łyżeczki', 'szklanka', 'truskawek', ''],
#  ['', 'ząbki', 'łyżka', 'łyżki', 'łyżeczka', 'szklanki liści', '', ''],
#  ['',
#   '',
#   'ząbki',
#   'łyżka',
#   'łyżka',
#   'szklanek',
#   '',
#   'szklanki soku',
#   '',
#   'łyżki',
#   ''],
#  ['',
#   'g mięsa',
#   'g',
#   '',
#   '',
#   'łyżki',
#   'łyżki',
#   'ząbki',
#   'łyżki bułki tartej',
#   '',
#   '',
#   'ml',
#   'ml',
#   'łyżeczka',
#   'łyżki',
#   'łyżeczki',
#   'łyżeczka'],
#  ['g',
#   'g',
#   'l',
#   'g',
#   '',
#   'ząbków',
#   '',
#   'łyżki',
#   'łyżeczka łyżeczki łyżeczki',
#   '',
#   'ml',
#   'g mięsa'],
#  ['',
#   'g',
#   'łyżki',
#   'łyżki',
#   'g',
#   'łyżeczka łyżeczki',
#   'łyżeczki',
#   '',
#   '',
#   'g',
#   'g',
#   'g',
#   'łyżeczki',
#   '',
#   'łyżek',
#   'łyżka',
#   'truskawek'],
#  ['', '', 'szklanki', 'szklanki', 'szczypta', 'łyżeczki', '', ''],
#  ['g mięsa', 'bułka', '', 'puszka', 'łyżki', '', '', 'łyżkami', '', 'bułka'],
#  ['', '', '', 'łyżeczki', 'l przegotowanej', 'g'],
#  ['', 'łyżek', 'g', '', ''],
#  ['g', 'litr', 'g', 'liści', '', 'szczypta', 'g truskawek', ''],
#  ['', 'słoik', 'g', 'łyżki', 'g', 'g tartej', 'łyżki', 'łyżeczki'],
#  ['g',
#   '',
#   'łyżki',
#   'łyżeczki',
#   '',
#   '',
#   'łyżki',
#   'łyżki',
#   '',
#   'łyżeczka',
#   'łyżka'],
#  ['g', '', '', '', '', '', '', 'łyżki', '', 'łyżka', 'grzanki'],
#  ['g',
#   'łyżka',
#   'łyżeczki',
#   'szczypta',
#   'g',
#   'g jabłkowego',
#   'g',
#   '',
#   'łyżeczka'],
#  ['ćwiartki',
#   'g',
#   'g',
#   'g',
#   'g jagód',
#   'łyżki',
#   'łyżki',
#   'łyżeczki',
#   'łyżka',
#   'łyżki',
#   'ml'],
#  ['szklanka', 'ml mleczka', '', '', 'łyżki', '', '', 'listków', 'łyżki'],
#  ['g', 'g', 'ml', '', 'szklanka', ''],
#  ['g', '', '', '', 'ząbki', '', '', '', '', '', 'litr', 'ml mleczka'],
#  ['ml', 'ml', '', 'listków'],
#  ['ml', 'g', 'ml', 'g', 'g', 'ml mleczka', 'g liści', 'g'],
#  ['', '', '', 'szklanki', 'łyżki', 'łyżki', 'łyżeczka', ''],
#  ['g', 'g', 'g', '', '', 'kawałek', '', '', '', 'ząbek', '', 'łyżka'],
#  ['',
#   'g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'g krewetek',
#   'g',
#   '',
#   'ząbek',
#   'ml',
#   'ml oliwek',
#   'ml',
#   ''],
#  ['szklanka',
#   'ml',
#   'cienkie plasterki',
#   'łyżka oliwek',
#   '',
#   'łyżki',
#   '',
#   '',
#   'garść',
#   'łyżki',
#   'łyżeczka',
#   'łyżki oliwek',
#   'ząbka',
#   '',
#   ''],
#  ['g',
#   'łyżki',
#   'g',
#   'g liści',
#   'pokrojonej',
#   'g',
#   'łyżki',
#   'łyżki',
#   'łyżeczka',
#   'soku'],
#  ['g',
#   'ząbków',
#   'g pędów bambusa',
#   'łyżki',
#   'łyżki',
#   'łyżka',
#   'łyżki',
#   'łyżki'],
#  ['łyżki', 'łyżek', 'saszetki', 'szklanka', 'łyżek', ''],
#  ['', '', 'ml', '', '', '', '', 'łyżki', '', ''],
#  ['g',
#   'krewetek',
#   'g truskawek',
#   'łyżki',
#   'szklanki listków',
#   '',
#   'łyżki',
#   'łyżka'],
#  ['g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'główka',
#   'łyżki',
#   'łyżki',
#   '',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   'łyżki'],
#  ['g',
#   'g',
#   'cienkie',
#   'cienkie',
#   'łyżki',
#   'łyżki',
#   'g puszki plastry',
#   'łyżki'],
#  ['g', 'g', 'łyżka', 'łyżki', '', '', '', 'puszka', 'łyżka', 'łyżki'],
#  ['g',
#   'g krewetek g pokrojonej',
#   '',
#   'łyżki',
#   'ząbki',
#   '',
#   'łyżka',
#   'łyżki',
#   'szklanki listków',
#   'łyżka liści',
#   '',
#   'łyżki',
#   'łyżka łyżki'],
#  ['warzyw g',
#   '',
#   '',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   'łyżeczka',
#   'szczypta',
#   'szczypta',
#   'szczypta',
#   'szczypta',
#   'szczypta',
#   '',
#   ''],
#  ['g',
#   'g',
#   'ząbek',
#   'łyżka',
#   '',
#   '',
#   '',
#   'łyżki',
#   'szczypta',
#   'szczypta',
#   'łyżki łyżki',
#   'łyżeczki',
#   'łyżki'],
#  ['łyżek', 'g', 'łyżka'],
#  ['g pokrojonej', '', 'g', 'łyżka', 'g'],
#  ['g', 'g', 'g', 'łyżka', 'g'],
#  ['',
#   'łyżki',
#   'łyżki',
#   '',
#   'ząbek',
#   '',
#   '',
#   'puszka pędów bambusa',
#   'łyżka',
#   'łyżka',
#   'łyżki',
#   'łyżki',
#   '',
#   ''],
#  ['g pokrojonej', 'pokrojonej', '', 'g', 'łyżka', 'g'],
#  ['g krewetek', 'łyżka', 'g ciętych', 'g'],
#  ['', 'g', '', 'łyżki', 'łyżki', 'łyżeczki oliwek', '', ''],
#  ['opakowania g',
#   '',
#   '',
#   'łyżki',
#   'łyżki',
#   'ząbki',
#   'łyżki',
#   '',
#   'łyżeczki',
#   'łyżki',
#   '',
#   'bułeczki'],
#  ['g', '', 'g', 'łyżki', 'łyżka', '', 'łyżki'],
#  ['litra',
#   'liść',
#   'kawałek',
#   'łyżki',
#   'łyżki',
#   'łyżka soku',
#   'szczypta',
#   'bulwy kopru',
#   'g',
#   'garść',
#   'g',
#   'g',
#   'łyżeczka',
#   ''],
#  ['g', 'ml mleczka', 'łyżeczki'],
#  ['g',
#   '',
#   'szczypta',
#   'ząbki',
#   'łyżki',
#   '',
#   '',
#   'łyżki',
#   'łyżka',
#   'łyżek',
#   'łyżki',
#   'łyżki soku',
#   'łyżki',
#   'łyżeczki'],
#  ['g',
#   'g krewetek',
#   '',
#   'g',
#   'ząbki',
#   'łyżeczka',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   '',
#   ''],
#  ['g',
#   'g',
#   '',
#   'łyżki soku',
#   '',
#   '',
#   'łyżka oliwek',
#   'ząbek plasterki',
#   'łyżki liści',
#   'łyżki',
#   '',
#   ''],
#  ['',
#   'łyżeczki',
#   'g',
#   'ćwiartka',
#   'ząbki',
#   '',
#   '',
#   'kawałek',
#   'łyżki',
#   'łyżki',
#   'szklanki',
#   'łyżki',
#   'łyżeczki',
#   'łyżka',
#   'łyżki'],
#  ['g',
#   'g krewetek',
#   '',
#   '',
#   'ząbek',
#   'pokrojonej',
#   'pokrojonej',
#   'pokrojonej',
#   'g',
#   'łyżki',
#   'soku',
#   '',
#   'łyżka'],
#  ['g', 'łyżki', 'łyżki', 'ząbki', 'g', 'g krewetek', '', '', 'łyżka', ''],
#  ['szklanki truskawek',
#   'g',
#   '',
#   'łyżki',
#   'szklanki',
#   'szklanki',
#   'szklanki liści',
#   'łyżka'],
#  ['g',
#   'g',
#   'ząbek',
#   'łyżka',
#   '',
#   '',
#   '',
#   'łyżki',
#   'szczypta',
#   'szczypta',
#   'łyżki łyżki',
#   'łyżeczki',
#   'łyżki'],
#  ['g',
#   '',
#   'miseczka',
#   'ząbki',
#   'łyżek pokrojonej',
#   'łyżki',
#   'łyżki',
#   'łyżka',
#   '',
#   ''],
#  ['g', 'łyżka', 'g', 'ml kremówki', '', '', '', 'garść', 'cząstki'],
#  ['',
#   'szklanki',
#   'szklanki',
#   'ćwiartki',
#   'łyżka',
#   'g kawałki',
#   'g połówki',
#   'oliwek'],
#  ['',
#   'łyżki oliwek',
#   'szklanki',
#   '',
#   'łyżka',
#   'łyżka',
#   'połówki',
#   'łyżki patelni',
#   ''],
#  ['', 'g', 'puszki', 'gałązka', 'ząbki', 'g'],
#  ['opakowanie', 'ml mleczka', ''],
#  ['opakowanie', 'opakowanie', '', 'g', 'g', 'g', 'g', 'łyżeczka'],
#  ['', 'szklanka krewetek', 'g', '', 'łyżeczki', 'łyżeczki', 'szklanek', ''],
#  ['szklanki', 'szklanki', 'łyżki', 'łyżka', '', 'szklanki kremówki', 'łyżki'],
#  ['',
#   '',
#   '',
#   'g',
#   'ml',
#   '',
#   'g',
#   'ząbki',
#   'łyżka',
#   'łyżka',
#   'łyżki',
#   'łyżki',
#   'łyżki'],
#  ['szklanka',
#   'szklanki',
#   'łyżki',
#   'łyżeczki',
#   'szczypta',
#   'łyżka',
#   '',
#   'łyżek',
#   'łyżeczka'],
#  ['opakowanie', 'opakowanie', 'szklanek'],
#  ['g',
#   '',
#   'łyżki oliwek',
#   'łyżka soku',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczka',
#   'szczypta',
#   'łyżeczki',
#   'ząbek',
#   '',
#   '',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   'listków'],
#  ['',
#   'łyżeczki',
#   'łyżeczka',
#   'garści',
#   'pokrojonej',
#   'łyżki',
#   'łyżki',
#   'łyżka'],
#  ['',
#   'łyżeczki',
#   '',
#   'łyżeczka',
#   'łyżeczka soku',
#   'szczypta',
#   'łyżki',
#   'łyżki',
#   'łyżka',
#   'łyżka',
#   ''],
#  ['g', 'ml', 'łyżki', 'ml', 'łyżki', 'ml soku', 'szklanki', '', '', '', ''],
#  ['sztuk', 'g', 'g', 'g', 'szklanki', 'g', '', '', ''],
#  ['łyżeczki',
#   'cienkie plasterki',
#   'ząbki plasterki',
#   'łyżka',
#   'łyżeczka',
#   'ml',
#   'g',
#   'g',
#   '',
#   'g',
#   'łyżki listków',
#   '',
#   ''],
#  ['', '', '', '', 'łyżeczki', 'gałązki', '', '', '', ''],
#  ['szklanka',
#   'szklanka',
#   '',
#   'łyżki',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'ząbek',
#   'gałązek',
#   'g',
#   'ząbek',
#   'łyżeczki',
#   'szczypta',
#   'szczypta',
#   'szczypta',
#   'kawałek',
#   'liści',
#   '',
#   'łyżki'],
#  ['',
#   'ząbek',
#   'g',
#   '',
#   'g',
#   'g',
#   'łyżki puszki',
#   '',
#   '',
#   '',
#   'łyżeczka',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   '',
#   ''],
#  ['', '', 'oliwek', ''],
#  ['g', 'łyżka', '', 'ząbki', 'łyżka', '', 'łyżeczka', 'ml', 'ml', '', '', ''],
#  ['łyżki oliwek',
#   '',
#   'g',
#   'ząbki plasterki',
#   'łyżeczki',
#   'szczypta',
#   '',
#   'g',
#   '',
#   'g krewetek',
#   'g',
#   'g kawałki',
#   'łyżki'],
#  ['',
#   'łyżki',
#   'łyżki',
#   'ząbki',
#   '',
#   'g',
#   '',
#   '',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'szklanka',
#   'g',
#   'puszka',
#   '',
#   'łyżka',
#   'garście'],
#  ['g', '', 'szklanki', '', 'g', '', '', '', '', '', 'łyżki', 'łyżka'],
#  ['',
#   'łyżki',
#   'łyżka',
#   'łyżeczka',
#   'łyżka',
#   'łyżki',
#   '',
#   '',
#   'szczypta',
#   '',
#   ''],
#  ['łyżek', 'łyżki', 'g', 'ząbki', 'połówki', 'ml', '', ''],
#  ['łyżki', 'g', 'g', '', '', ''],
#  ['g', 'g', '', 'g', 'ml', '', '', 'szczypta'],
#  ['g',
#   '',
#   '',
#   '',
#   'łyżeczki',
#   'łyżeczka',
#   'łyżka',
#   'łyżki',
#   '',
#   '',
#   '',
#   '',
#   'g',
#   '',
#   ''],
#  ['', '', 'łyżeczka', 'łyżka oliwek', 'ząbek', 'łyżka', 'puszki', '', ''],
#  ['g', '', '', 'ząbki', 'łyżki', 'łyżka', 'łyżeczka', 'łyżek', ''],
#  ['',
#   '',
#   'g',
#   'ząbki',
#   'g',
#   'g',
#   'g puszki',
#   'szczypta',
#   'łyżeczka',
#   'łyżeczki',
#   '',
#   '',
#   '',
#   'łyżki',
#   '',
#   '',
#   'oliwek'],
#  ['g',
#   'łyżki',
#   'ząbek',
#   'łyżeczki',
#   'ml',
#   'łyżka soku',
#   'g',
#   'szklanki listków',
#   'g'],
#  ['szklanka',
#   '',
#   'łyżeczkę',
#   '',
#   '',
#   '',
#   '',
#   'łyżki',
#   '',
#   'l',
#   '',
#   '',
#   '',
#   ''],
#  ['g', 'łyżeczki', 'łyżki', 'łyżki', 'bułki', '', '', 'plastry', '', '', ''],
#  ['', 'g', 'g', 'g', '', 'l', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['g',
#   '',
#   '',
#   'łyżki',
#   'garść listków',
#   'g',
#   'łyżki',
#   'łyżeczki',
#   'łyżek',
#   'łyżki',
#   'łyżka soku',
#   'łyżeczki',
#   'ząbek'],
#  ['g', 'opakowanie', 'łyżek', 'łyżki', 'łyżka', '', 'g', '', '', '', ''],
#  ['g',
#   'g',
#   'łyżki',
#   '',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   'łyżki',
#   '',
#   'łyżeczki',
#   'łyżka',
#   'łyżki',
#   ''],
#  ['', '', '', 'szklanka', '', ''],
#  ['', 'Pędy bambusa', '', '', '', ''],
#  ['g', 'g owoców', 'g', 'g', '', 'łyżka', 'łyżka', 'łyżka'],
#  ['', 'g', 'g warzyw', 'g pędów bambusa', 'ml'],
#  ['', '', '', '', 'główki', '', '', 'ml', 'ml', 'g', 'g', '', '', '', 'g'],
#  ['g', 'łyżka', '', 'łyżek', 'łyżek', 'łyżki', 'łyżeczka', '', ''],
#  ['g',
#   '',
#   '',
#   '',
#   'ząbki',
#   'szklanki pędów bambusa',
#   'łyżeczka',
#   '',
#   'łyżka',
#   'łyżki',
#   'łyżki',
#   'łyżek',
#   '',
#   'łyżeczka'],
#  ['g',
#   'łyżki',
#   'ząbki',
#   '',
#   '',
#   'szklanka',
#   '',
#   'łyżki',
#   'łyżki soku',
#   'łyżki',
#   'łyżki',
#   'łyżka łyżki',
#   'łyżki'],
#  ['g', 'łyżki', 'ząbki', 'krewetek g', '', 'ml', 'szklanka', ''],
#  ['łyżeczki', 'łyżki', 'ml mleczka', 'g', 'łyżki', 'łyżki'],
#  ['',
#   '',
#   'łyżka',
#   'łyżki',
#   'łyżka',
#   'filiżanka mleczka',
#   'filiżanki liści',
#   'liści',
#   'łyżki',
#   'łyżki'],
#  ['szklanka mleczka',
#   'szklanka mleczka',
#   'szklanki',
#   'szklanki',
#   'łyżki',
#   'szklanki'],
#  ['', 'ml mleczka', '', '', '', '', 'łyżka', 'łyżki', 'łyżki', '', ''],
#  ['g', 'g', 'litr', 'g', 'szczypta'],
#  ['', 'ml', 'oliwek'],
#  ['szklanka', 'łyżki', 'ml mleczka', 'łyżki', 'g', ''],
#  ['owoców', '', '', 'oliwek', '', '', '', 'szklanki oliwek'],
#  ['g',
#   'kawałki',
#   'łyżki',
#   '',
#   'gałązki',
#   '',
#   'ząbek',
#   'łyżki',
#   '',
#   'łyżka',
#   'łyżka'],
#  ['g',
#   '',
#   'łyżki',
#   'łyżka',
#   'ząbek',
#   'łyżki',
#   'g',
#   '',
#   'łyżek',
#   'łyżeczka',
#   'łyżki',
#   'łyżeczka',
#   'garść'],
#  ['', '', 'łyżki', 'łyżeczka', 'łyżeczka', 'łyżka', 'ml mleczka', '', '', ''],
#  ['g', 'ml mleczka', '', '', 'łyżki', '', '', 'ząbki', 'łyżki', 'listków'],
#  ['g',
#   'ząbki',
#   '',
#   'łyżki',
#   'łyżka',
#   'garść',
#   'kawałki mięsa',
#   '',
#   '',
#   'smaków',
#   'łyżki',
#   '',
#   ''],
#  ['ml mleczka',
#   'szklanki',
#   'łyżka',
#   'szczypta',
#   'szklanki truskawek',
#   'łyżka',
#   ''],
#  ['', 'łyżki', '', '', '', '', '', '', ''],
#  ['ml', 'g', 'ml', 'g', 'g mięsa', 'g', 'ml mleczka', 'g liści', 'g'],
#  ['ml mleczka', 'ml', 'g', 'łyżeczka', 'łyżki', ''],
#  ['ml', 'łyżki', '', 'szklanki', 'szklanki', ''],
#  ['ml mleczka', 'szklanki', 'łyżka', 'szczypta', ''],
#  ['ml', 'g', 'ml', 'g mięsa', 'g pędów bambusa', 'ml mleczka', 'g liści', 'g'],
#  ['g',
#   'owoców',
#   'puszka',
#   'ml mleczka',
#   '',
#   '',
#   'łyżeczka',
#   'łyżeczki',
#   'łyżeczka',
#   'łyżeczka',
#   'łyżeczka',
#   'łyżeczka',
#   'ząbki',
#   'liść',
#   '',
#   ''],
#  ['g', 'ml', 'łyżki', 'g', 'szczypta', '', 'sztuk'],
#  ['g',
#   'g',
#   'szklanki',
#   'szklanki',
#   'dodatki łyżeczka łyżka łyżeczki szczypta'],
#  ['ml', 'owoców', '', 'g', 'szklanka', ''],
#  ['łyżeczki soku', 'szklanki', 'łyżki', 'łyżeczki'],
#  ['szklanka', 'szklanka owoców', '', 'g', 'łyżka'],
#  ['szklanki',
#   'szklanki mleczka',
#   'łyżeczki',
#   'szklanka',
#   'łyżki',
#   'łyżeczki soku'],
#  ['ml', 'g', '', 'g truskawek', ''],
#  ['', '', '', 'g', 'szklanka soku jabłkowego'],
#  ['ml', 'ml', 'ml', 'ml', '', 'Dodatki', ''],
#  ['ml', 'ml soku', 'ml', '', ''],
#  ['ml', 'ml', 'ml', 'szczypta'],
#  ['ml', 'ml', 'ml soku', 'ml', ''],
#  ['ml', 'ml', 'ml', '', 'łyżka', 'łyżeczki', ''],
#  ['ml mleczka', '', 'ml'],
#  ['ml', '', '', '', '', '', '', ''],
#  ['g', '', 'g truskawek', 'ml', ''],
#  ['łodygi', 'litr', 'g', 'sztuki', '', ''],
#  ['', '', 'ml'],
#  ['ml', 'ml', 'plastry', 'łyżeczka'],
#  ['', 'łyżki', 'szklanki', 'szklanki', 'szklanki', 'szklanki'],
#  ['', '', '', ''],
#  ['ml', '', 'ml', '', ''],
#  ['szklanki soku', 'szklanka', '', '', 'cząstka'],
#  ['ml', 'ml', 'ml', 'cząstka'],
#  ['ml', 'łyżeczki', 'liści', '', '', 'ml'],
#  ['ml', 'ml', 'ml soku'],
#  ['ml', 'ml'],
#  ['', 'ml', ''],
#  ['g', 'ml', '', 'listków', ''],
#  ['',
#   'garść',
#   'garść',
#   '',
#   '',
#   'ząbek',
#   'kawałek',
#   '',
#   'g',
#   'garść',
#   'łyżka',
#   'łyżki',
#   '',
#   'łyżka',
#   '',
#   'łyżki',
#   'łyżka',
#   ''],
#  ['ml mleczka',
#   'szklanki',
#   '',
#   'łyżki',
#   'łyżeczki',
#   'szczypta',
#   'g',
#   'łyżeczka'],
#  ['łyżka',
#   'ząbek',
#   '',
#   '',
#   'g',
#   'łyżeczki',
#   'łyżka',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'szczypta',
#   'ml',
#   'ml mleczka',
#   'g',
#   'łyżka',
#   ''],
#  ['g', '', 'łyżki', 'ml', 'łyżeczka', 'ząbki', '', '', ''],
#  ['papieru', '', '', '', '', '', ''],
#  ['g',
#   'g',
#   '',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżeczki',
#   'łyżki',
#   'łyżka',
#   'łyżki',
#   'ząbki',
#   'pokrojonej',
#   'gałązka',
#   'łyżki mleczka',
#   'łyżka',
#   'łyżeczki',
#   ''],
#  ['g', '', 'łyżki', 'łyżki', '', 'łyżki', 'łyżki', 'ząbki', '', 'łyżka', ''],
#  ['ml', 'ml mleczka', '', '', '', 'ząbki', 'łyżka', 'szczypta', 'szczypta'],
#  ['ml', 'ml', 'g', 'g', 'g'],
#  ['szklanka', '', 'łyżka', 'ząbek', 'g', 'szklanki', 'ml', 'garść', 'g', '']]

# %%
Sentence('• 2 łyżki stołowe sosu do pierożków Lee Kum Kee')
# Out:
# Sentence: "• 2 łyżki stołowe sosu do pierożków Lee Kum Kee" - 10 Tokens

# %%
nie_przyprawy = ['stołowa']

# %%
knn_przyprawy = gen_knn(przyprawy, jednostki + warzywa + nabial + zboza + tluszcze + nie_przyprawy, 1)

# %%
predict(knn_przyprawy, data)
# Out:
# [['', 'balsamicznego', '', '', 'tymianku', 'sól pieprz smaku', ''],
#  ['', '', '', ''],
#  ['', '', '', 'bazylii', '', '', 'balsamicznego', 'smaku'],
#  ['', '', '', 'cytryny', 'sól', 'pieprz'],
#  ['', '', '', '', 'cukru', '', 'mascarpone', '', 'cukru waniliowego'],
#  ['', '', '', '', '', 'cytryny', '', 'pieprz sól', 'koperku'],
#  ['', '', '', '', 'gałka muszkatołowa', 'pieprzu', 'sól', '', '', ''],
#  ['', '', '', '', 'pieprz'],
#  ['', '', 'granatu', '', 'migdałów', '', '', '', 'balsamicznego', 'pieprz'],
#  ['', 'bez', '', '', '', '', '', '', '', 'cytryny smaku', 'sól pieprz'],
#  ['', 'cytryny', 'cukru', ''],
#  ['', '', 'cukru', '', 'melisy mięty'],
#  ['', '', '', '', 'kminku', '', 'sól pieprz', ''],
#  ['', '', '', '', '', '', '', 'cytryny smaku', 'sól', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'mięty pieprzowej',
#   '',
#   '',
#   'sól pieprz',
#   'sos',
#   '',
#   '',
#   'oregano',
#   'mięty pieprzowej',
#   'cukru',
#   ''],
#  ['', '', '', 'słodki', '', '', 'imbiru', '', 'curry', 'sól pieprz', '', ''],
#  ['',
#   'twaróg',
#   '',
#   '',
#   '',
#   'waniliowego cukru',
#   '',
#   '',
#   '',
#   '',
#   'cukru',
#   '',
#   '',
#   '',
#   '',
#   'cukru',
#   ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'sól pieprz', '', '', '', ''],
#  ['', 'cytryny', 'cytryn', 'cytrynowego', '', 'cukru'],
#  ['', '', '', '', ''],
#  ['', '', 'cukru', 'mięty', 'cytryna', '', '', 'gorzkiej'],
#  ['', '', '', '', '', 'mozzarelli', '', ''],
#  ['', '', '', '', 'sól', 'pieprz', 'cukru', '', '', '', 'kolendry'],
#  ['', '', '', 'sól', 'pieprz', '', 'cytryny', '', '', '', ''],
#  ['', 'cynamonu', '', '', 'cukru', '', '', '', 'cukru waniliowego'],
#  ['', 'Rice', 'imbiru', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'cukru', 'wanilii', 'mango', 'mięty', ''],
#  ['', '', '', 'wanilii', 'mango', ''],
#  ['', '', '', '', '', 'kmin rzymski', 'kolendra', 'sól', 'pieprz', '', '', ''],
#  ['Mango', '', '', 'mango mięty'],
#  ['', 'curry', '', '', '', '', 'bazylii', ''],
#  ['', '', '', '', '', '', 'cukru', 'cytryna'],
#  ['', 'wieprzowych', '', '', '', 'selera', 'ziela', 'laurowy', '', '', '', ''],
#  ['', '', '', 'szyjkami', '', '', '', '', '', 'cały', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sól',
#   'pieprz',
#   'bazylii',
#   '',
#   '',
#   '',
#   '',
#   'sól',
#   'pieprz'],
#  ['', '', '', '', '', '', '', '', 'imbiru', 'sól pieprz'],
#  ['', '', '', '', '', '', '', ''],
#  ['tapioki', 'cytrynowego', '', '', '', 'mięta'],
#  ['', '', '', 'mango', 'limonka', '', '', 'sos', 'sól', 'pieprz'],
#  ['', '', '', '', 'mięty', 'limonek', '', 'imbiru'],
#  ['wieprzowiny', '', '', '', 'selera', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'kasztanów', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   'mango',
#   'imbiru',
#   '',
#   '',
#   '',
#   '',
#   'mięty',
#   'kolendry',
#   'limonek',
#   'cukru',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cukru',
#   'imbiru',
#   '',
#   '',
#   'gałki muszkatołowej',
#   'cynamonu',
#   'sól',
#   'pieprz'],
#  ['', '', '', 'imbiru', '', '', '', '', 'pieprzu', 'cukru', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'cukru', '', '', 'sól', 'pieprz'],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['bez', '', 'rozmaryn', '', '', '', 'sól pieprz', 'koperku'],
#  ['', '', '', '', '', '', 'imbiru', '', '', '', '', 'liście'],
#  ['', '', 'wieprzowiny', '', '', '', ''],
#  ['',
#   'laurowy',
#   'imbiru',
#   '',
#   '',
#   'cytryny',
#   'cukru',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kolendra'],
#  ['', '', ''],
#  ['', '', 'pieprzu', '', '', '', '', '', '', '', '', '', 'cukru', ''],
#  ['', '', '', '', '', 'oregano', '', '', '', 'tymianek', ''],
#  ['', '', '', '', 'sól', 'pieprz', '', '', 'estragonu', 'mascarpone', '', ''],
#  ['pojedynczy', '', '', '', '', '', '', '', '', '', '', '', 'cukru', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', 'cytryny', '', ''],
#  ['', '', '', '', '', '', '', 'liście kolendry', '', 'sól pieprz'],
#  ['', '', 'bez', '', '', '', 'bazylii mięty', ''],
#  ['', '', '', 'imbiru', '', '', '', '', 'pieprzu', 'cukru', '', '', ''],
#  ['', 'malinowe', '', '', '', '', '', '', 'sól', 'pieprz'],
#  ['', '', '', '', 'cytryny', 'sól', 'pieprz', '', 'cytryny'],
#  ['', '', '', 'cytryny', 'mięty', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'rozmarynu', '', ''],
#  ['', '', ''],
#  ['', '', 'sos', '', '', '', '', 'balsamicznego'],
#  ['', '', '', '', '', '', '', 'sos'],
#  ['', '', 'cukru', 'kakao', 'kakao', '', ''],
#  ['', '', '', '', '', '', '', '', 'imbiru', '', '', 'cukru', ''],
#  ['', '', 'cukru', '', '', '', '', '', 'cynamonu'],
#  ['', '', ''],
#  ['',
#   '',
#   '',
#   'cytryny',
#   'cukru',
#   'kminu rzymskiego',
#   '',
#   '',
#   'pieprzu',
#   '',
#   '',
#   '',
#   'koperku',
#   '',
#   '',
#   'mięty'],
#  ['', '', 'cukru', '', '', '', '', ''],
#  ['', '', 'pieprz', '', 'cytryny', 'cukru', '', '', '', '', ''],
#  ['', '', '', '', 'migdałów', '', 'granatu', '', 'sól', 'pieprz', 'mięty'],
#  ['', '', '', '', '', 'musztarda', 'sól', 'pieprz', ''],
#  ['',
#   '',
#   '',
#   '',
#   'kolendry',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kolendry',
#   '',
#   'pieprz smaku'],
#  ['', '', '', '', '', 'mięty', '', 'sól', 'pieprz', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kurkumy',
#   '',
#   '',
#   'Sos',
#   '',
#   '',
#   '',
#   'cukru',
#   'pieprzu',
#   '',
#   'bazylii',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sól',
#   'pieprz',
#   'kminu rzymskiego',
#   'oregano',
#   '',
#   '',
#   '',
#   'kolendra',
#   'naturalny'],
#  ['', '', '', 'sól'],
#  ['', '', '', '', '', '', 'kminu rzymskiego', '', '', '', 'kmin rzymski', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   'pieprzu cayenne',
#   'cytryny',
#   'bez',
#   '',
#   '',
#   '',
#   'bez',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sól',
#   'pieprz',
#   '',
#   'kurkumy',
#   'kminu rzymskiego',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', 'sól', 'pieprz', 'laurowe', 'ziela', '', ''],
#  ['', '', '', '', '', '', 'sól', 'pieprz', 'cukru', '', ''],
#  ['', '', '', '', 'cytryny', '', 'kolendra', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', 'sól', 'pieprz', 'cukru'],
#  ['',
#   '',
#   '',
#   'limonka',
#   'kminu rzymskiego',
#   '',
#   '',
#   '',
#   '',
#   'Guacamole',
#   '',
#   '',
#   '',
#   'kwaśna',
#   'kolendra'],
#  ['', 'bez', 'smaku', '', '', '', '', 'sól', 'pieprz'],
#  ['', '', '', '', 'ziele gałka', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cynamonu',
#   'oregano',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sól',
#   'pieprz',
#   ''],
#  ['', '', '', 'cytryny', '', 'cytryny', '', 'mięty', ''],
#  ['',
#   '',
#   'kminu',
#   'cytryny',
#   '',
#   'selera',
#   '',
#   '',
#   'liście laurowe',
#   '',
#   'cytryny',
#   'kolendry',
#   'sól',
#   'pieprz'],
#  ['wieprzowiny',
#   '',
#   '',
#   'kolendry',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sos sos',
#   'sól pieprz smaku'],
#  ['', '', '', '', '', '', 'sos'],
#  ['', '', 'sos', '', 'imbir', 'wasabi', '', ''],
#  ['', '', '', '', '', '', '', '', 'sos', 'cukru', '', 'imbiru', ''],
#  ['', '', '', 'cukru', '', '', '', '', '', 'imbir', 'wasabi'],
#  ['bez',
#   '',
#   '',
#   '',
#   'imbiru',
#   '',
#   '',
#   '',
#   'limonka',
#   'cukru',
#   '',
#   '',
#   'kolendra'],
#  ['', '', '', '', 'sól', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', 'bez', '', '', 'pieprzem'],
#  ['', '', '', '', ''],
#  ['wieprzowych', '', '', 'imbiru', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'czubata imbiru', '', 'sól pieprz'],
#  ['wieprzowej', '', '', '', '', '', 'curry', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'tamaryndowca', 'cukru', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', 'cukru', 'rumu', ''],
#  ['', '', 'cukru', '', '', '', 'bazylii', '', '', 'curry'],
#  ['', '', '', '', '', 'mango'],
#  ['',
#   '',
#   'imbiru',
#   '',
#   'trawy cytrynowej',
#   '',
#   'curry',
#   '',
#   '',
#   'sól',
#   'pieprz'],
#  ['Rice', '', '', 'gorzkiej', 'cynamonu'],
#  ['', '', ''],
#  ['', '', '', 'cukru', '', ''],
#  ['', '', '', '', '', 'sól', '', ''],
#  ['', '', '', '', '', 'mięty kolendry', '', '', '', '', 'cukru'],
#  ['', '', '', 'imbiru', '', '', '', '', '', '', '', '', 'mięty'],
#  ['', 'liście', '', '', 'cukru', '', '', 'liście', '', ''],
#  ['', '', '', 'mango', '', '', '', '', '', 'bazylii'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   'kolendry',
#   '',
#   'sól',
#   'pieprz',
#   '',
#   'słodki sos',
#   'sezam',
#   'kolendra'],
#  ['', 'tapioki', 'cukru', '', '', 'cukru', 'cytryny'],
#  ['', '', 'sos', 'sos', 'Bonasia', '', '', '', ''],
#  ['', 'curry', '', '', '', '', '', 'bazylii', ''],
#  ['', '', 'tapioki', 'wanilii wanilii', 'cukru', ''],
#  ['', '', '', 'tapioki', '', ''],
#  ['', 'tapioki', 'cukru', '', 'mango'],
#  ['', 'curry', '', '', '', '', 'bazylii', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kminku',
#   '',
#   'kolendry',
#   'kurkumy',
#   '',
#   'imbiru',
#   '',
#   'laurowy',
#   '',
#   'sól'],
#  ['', '', 'cukru', 'tapioki', 'cynamonu', 'goździk', 'kardamonu'],
#  ['', 'gorzkiej', '', 'cukru', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', 'imbiru'],
#  ['', 'mango', '', '', 'cukru'],
#  ['mango', '', 'cukru', '', '', ''],
#  ['', '', 'mango', '', ''],
#  ['Mango', 'cytryny', 'mandarynek', '', ''],
#  ['Rumu', '', 'trawy cytrynowej', '', '', '', 'cytryna'],
#  ['', '', '', 'liście bazylii', ''],
#  ['', '', '', 'cytrynowego'],
#  ['', 'cynamonowego', '', '', ''],
#  ['Mango', '', '', '', 'cukru', 'cukru', ''],
#  ['', '', ''],
#  ['', '', '', '', 'mango', '', 'mięta', ''],
#  ['', 'mango', '', 'mango', ''],
#  ['', '', '', 'cytryna', 'melisa', ''],
#  ['', 'granatu', ''],
#  ['ananasem', '', '', 'kakao'],
#  ['', 'cukru', 'mango', '', '', 'cukru'],
#  ['', '', 'Mango', ''],
#  ['rumu', 'limonka', '', '', 'mineralna'],
#  ['', '', 'pomarańczy', '', ''],
#  ['Rumu', '', '', ''],
#  ['', 'cukru', 'mięty', '', '', ''],
#  ['', '', ''],
#  ['', ''],
#  ['', '', 'cytryny'],
#  ['', '', 'limonka', 'mięty', ''],
#  ['',
#   'migdałów',
#   '',
#   '',
#   '',
#   '',
#   'imbiru',
#   'rzymska',
#   '',
#   '',
#   'trawy cytrynowej',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kolendra'],
#  ['', 'tapioki', 'wanilii', 'cukru', 'agaru', '', 'gorzkiej', ''],
#  ['',
#   '',
#   '',
#   'selera',
#   '',
#   'imbiru',
#   '',
#   '',
#   'kurkumy',
#   'kminu rzymskiego',
#   'cynamonu',
#   '',
#   '',
#   '',
#   '',
#   'kolendra'],
#  ['', '', 'cukru', '', '', '', '', 'pieprz', ''],
#  ['', '', '', '', '', 'sól pieprz smaku', ''],
#  ['',
#   '',
#   '',
#   'curry',
#   'kurkumy',
#   '',
#   '',
#   'cukru',
#   '',
#   '',
#   '',
#   'trawy cytrynowej',
#   '',
#   '',
#   '',
#   'sos'],
#  ['',
#   '',
#   'trawy cytrynowej',
#   '',
#   '',
#   '',
#   'cukru',
#   '',
#   '',
#   'curry',
#   'naturalny'],
#  ['', '', 'świeży', '', 'świeży cytryny', '', '', '', 'pieprzu'],
#  ['', '', '', 'mango', 'cukru'],
#  ['',
#   '',
#   'imbiru',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kurkuma kolendra cynamon kardamon']]

# %%
nie_warzywa = ['zupy', 'sosów', 'małży', 'smażonej', 'marynowanych', 'musztardy', 'chleba', 'świeże', 'ugotowanych', 'czarny', 'japońskiej']

# %%
knn_warzywa = gen_knn(warzywa, jednostki + przyprawy + nabial + zboza + tluszcze + nie_warzywa, 1)

# %%
predict(knn_warzywa, data)
# Out:
# [['pieczarek', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', 'rabarbaru', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'pomidorowy', '', 'pomidory'],
#  ['', 'ziemniaków', 'warzywnego', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'pieczarek', '', '', 'warzywnego', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['cukinie', '', 'pomidorowego', '', '', '', '', ''],
#  ['', '', '', '', '', 'warzywnego', '', 'buraczanego', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'pomidorowego',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['soczewicy',
#   'pomidorowego',
#   'warzywnego',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['baldachów', '', 'skórka', 'płaskie', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['placki', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'szalotki', 'ziemniaczanej', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'chińskiej', ''],
#  ['', '', '', 'skórka', 'trzcinowego', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['kalafiora', 'ziemniaki', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', 'bakłażana', '', '', '', ''],
#  ['', '', '', 'mięsnego', '', '', '', ''],
#  ['fasoli',
#   'żeberek',
#   '',
#   'marchewki',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ziemniaki',
#   ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', 'natka'],
#  ['fasoli', '', '', '', 'średnia', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'fasoli', 'sałaty', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'ziemniaczanej', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'sałata', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   'naciowego',
#   'grzybów shiitake',
#   'marchwi',
#   'sałaty',
#   '',
#   '',
#   '',
#   '',
#   'pekińsku',
#   '',
#   ''],
#  ['', '', 'ogórka', '', '', '', 'jadalnych', ''],
#  ['warzywami', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', 'trzcinowego', ''],
#  ['Chińska',
#   'filety',
#   'chińskiego',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', 'pieczarki', '', '', '', '', '', ''],
#  ['', 'żeberek', ''],
#  ['', '', 'pieczarek', '', 'fasoli'],
#  ['', 'cukrowego', '', '', ''],
#  ['', '', '', '', '', 'marchewki', '', '', '', '', 'pomidorowego', '', '', ''],
#  ['', '', '', '', '', 'Kurczak'],
#  ['', '', '', ''],
#  ['leszcze', 'ziemniaków,', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['fasolki szparagowej', '', '', '', '', '', 'chińskiej kapusty'],
#  ['warzywnego', '', '', '', '', '', '', '', 'pieczarek', '', '', '', '', ''],
#  ['', '', ''],
#  ['fasoli',
#   '',
#   '',
#   '',
#   '',
#   'szparagów',
#   'pieczarek',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'ziemniaczanej'],
#  ['', '', 'szparagów', '', '', '', '', '', '', 'natka', 'tarty parmezan'],
#  ['warzywami',
#   'szpinaku',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'tarty Parmezan',
#   ''],
#  ['',
#   'ziemniaczanej',
#   '',
#   '',
#   '',
#   'marchewki',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'trzcinowego',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'pieczarki', '', '', '', '', '', ''],
#  ['', 'pomidory', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'skórka', '', '', '', ''],
#  ['bakłażana', '', 'warzywnego', '', '', 'koziego', '', ''],
#  ['', '', '', 'warzywny', '', '', '', '', ''],
#  ['', '', '', '', '', 'fasolki'],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', 'szpinaku', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['kapusty', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['ciecierzycy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'pomidor',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', ''],
#  ['filety', '', '', '', '', '', '', 'podgrzybków', '', '', ''],
#  ['ziemniaków', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'soczewica', '', '', '', '', '', '', 'natka'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   'warzywnego',
#   'ciecierzycy',
#   '',
#   '',
#   'szpinaku',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['',
#   'ciecierzycy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cukinia',
#   ''],
#  ['bataty',
#   '',
#   'ciecierzycy',
#   '',
#   'szpinaku',
#   '',
#   'pomidora',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['filety', '', '', ''],
#  ['ciecierzycy', '', '', '', '', 'ziemniaki', '', '', '', '', '', 'natka'],
#  ['', '', 'ziemniaków,', '', '', '', '', 'pomidorowym', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'fasoli',
#   '',
#   'cukinii',
#   '',
#   'szpinaku'],
#  ['grzybów', 'kapusty', '', '', 'fasoli', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'ciecierzycy', '', '', 'ciecierzycy', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', 'szalotki', 'ciecierzycy', 'pomidorowej', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'placki', '', 'pomidor', '', '', '', ''],
#  ['', 'ogonków', '', '', '', '', 'fasoli', '', ''],
#  ['ciecierzycy', '', '', '', '', '', '', '', ''],
#  ['cukinie',
#   '',
#   '',
#   '',
#   'szpinaku',
#   'koziego',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['cukinii', '', '', '', '', '', '', '', ''],
#  ['fasoli', '', '', 'skórka', '', '', 'ziemniaki', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'sałata', 'pomidora', '', 'tzatziki', ''],
#  ['', 'cukinia', 'bakłażan', 'pieczarek', '', '', ''],
#  ['', '', 'japoński', '', '', '', 'bambusowa', ''],
#  ['',
#   'szparagów',
#   '',
#   '',
#   'botwinki szpinaku',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', 'bambusowa', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'miso', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'woda'],
#  ['', '', 'Grzyby Shiitake', '', '', ''],
#  ['', '', '', 'marchwi', '', '', '', ''],
#  ['', 'Dong', 'chińskiej', '', ''],
#  ['',
#   '',
#   'szalotki',
#   'korzenia',
#   '',
#   'marchewki',
#   '',
#   '',
#   '',
#   'grzybów Shiitake',
#   '',
#   '',
#   '',
#   '',
#   'kapusty fasoli'],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'fasoli', 'jasnozielona', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'fasoli', ''],
#  ['płaskie', '', '', '', '', ''],
#  ['', 'tajska', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', 'łodyga', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', 'Satay', ''],
#  ['', '', '', '', '', ''],
#  ['', 'sałat', '', '', '', '', '', ''],
#  ['', 'cukinia', '', '', '', '', '', '', '', '', ''],
#  ['', 'botwinki', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'trzcinowego', '', '', '', '', ''],
#  ['', '', 'grzyby Shiitake', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'trzcinowego', '', '', 'trzcinowego', ''],
#  ['filety', '', '', 'rybny', '', '', '', '', ''],
#  ['', '', '', 'ziemniaków', '', '', '', '', ''],
#  ['', '', '', '', '', 'konfitura'],
#  ['', '', '', '', '', 'konfitura'],
#  ['', '', 'trzcinowego', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   'marchewki',
#   'szalotki',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', 'cukrowego', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', 'melona', '', ''],
#  ['', '', '', '', ''],
#  ['rabarbar', 'woda', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', 'woda'],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['wołowy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sałata',
#   '',
#   'fasoli',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', 'płaskie', '', '', ''],
#  ['',
#   '',
#   'cukrowej',
#   'łodyga naciowego',
#   'marchewki',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', 'grzybów shiitake', '', ''],
#  ['', 'ogórek', '', '', '', '', ''],
#  ['', '', 'chińskie', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'ogórek', 'rzodkiewek', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['ciecierzycy', '', '', '', '', 'pomidorowej', '', 'szpinaku', '', '']]

# %%
nie_nabial = ['Napój', 'cukier', 'gazowanego', 'w', 'pasty', 'groszku', 'bulionu', 'kleistego', 'koktajlowych']

# %%
knn_nabial = gen_knn(nabial, jednostki + przyprawy + warzywa + zboza + tluszcze + nie_nabial, 0.9)

# %%
predict(knn_nabial, data)
# Out:
# [['', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'śmietankowego', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'śmietanka', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'śmietany', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'śmietany', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', 'mleka', ''],
#  ['',
#   'mleka',
#   'ser',
#   'mleka skondensowanego',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', 'mleka', '', '', 'proszku', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', 'mleka', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', 'sproszkowanego', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'proszku', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', 'śmietany', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'proszku', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'proszku', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', 'mleka', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'proszku', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'śmietanki', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'śmietanki', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'śmietany', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['mleka', '', '', 'drożdży', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'jogurtu', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'jogurtu', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'jogurt'],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'śmietanki', '', '', ''],
#  ['', '', '', '', 'proszku', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'proszku', '', '', '', '', '', '', '', 'śmietana', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['proszku', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', 'mlecznej', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', 'mleko', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', 'mleka', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['jogurtu', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', 'jogurtu', ''],
#  ['', '', '', '', '', ''],
#  ['', 'jogurtu', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', 'mleka', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'proszku', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', 'proszku', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['śmietany', '', '', '', ''],
#  ['', '', '', '', '', '', 'mleka', '', '', '']]

# %%
knn_zboza = gen_knn(zboza, jednostki + przyprawy + warzywa + nabial + tluszcze, 0.7)

# %%
predict(knn_zboza, data)
# Out:
# [['kg', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['bujnymi', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'kg', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'kg', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'mąka', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', 'makaronu', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'drobną', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'makaronu', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'makaronu', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', 'makaronu', '', '', ''],
#  ['', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', ''],
#  ['', 'makaronu', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'makaronu', '', '', '', '', '', ''],
#  ['', 'kuskusu', '', '', '', '', '', ''],
#  ['', '', 'kuskusu', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['kg', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'brązowy', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'brązowego', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'drobną', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'płatki', '', ''],
#  ['', 'drobną', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'bulgur', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'kg', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'brązowy',
#   'miód',
#   'syrop',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', 'kuskusu', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'makaronu', '', '', '', 'brązowego', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'makaronu', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'mąka pszenna', '', ''],
#  ['', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', ''],
#  ['', 'makaronu', '', '', ''],
#  ['kg', 'kg', '', '', '', '', '', '', '', '', 'makaronu', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['kg', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', 'miód', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', 'brązowego'],
#  ['makaronu', 'małymi', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', ''],
#  ['makaronu', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', 'miód'],
#  ['', '', '', ''],
#  ['', '', '', '', 'brązowego'],
#  ['', '', 'brązowego', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', 'syrop', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', ''],
#  ['', 'gruboziarnistego', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['', 'brązowego', '', '', '', ''],
#  ['', '', ''],
#  ['', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'makaronu',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', 'makaronu', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '']]

# %%
knn_tluszcze = gen_knn(tluszcze, zboza + jednostki + przyprawy + warzywa + nabial, 0.8)

# %%
predict(knn_tluszcze, data)
# Out:
# [['', '', '', '', '', '', ''],
#  ['lekarskiego', '', '', ''],
#  ['', '', '', '', '', 'oliwy', '', ''],
#  ['', 'oliwy', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'oliwy', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', 'awokado', 'laskowych', '', 'oliwy', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'oliwa'],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'tłuszcz', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', 'oliwie', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'awokado', '', '', 'oliwa', '', '', '', '', ''],
#  ['orzechów', '', '', 'himalajskiej', 'palmowego', '', 'rzepakowego', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', 'oliwa', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', 'oliwy', '', ''],
#  ['',
#   '',
#   '',
#   'oliwy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'orzeszków pestek dyni',
#   'oliwy',
#   '',
#   '',
#   ''],
#  ['', 'arachidowego', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'pistacji', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'roślinnego', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', 'roślinnego', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'roślinnego', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', 'czarnej'],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', 'orzechów', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', 'oliwy', '', ''],
#  ['', 'rzepakowy', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'olej arachidowy', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'włoskiego', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', 'roślinnego orzeszków', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'oliwy', '', '', '', ''],
#  ['', '', 'awokado', '', '', '', 'oliwy', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'roślinnego',
#   'orzechów',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', '', 'żółtej', '', '', '', '', '', ''],
#  ['', '', 'arachidowego', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'roślinnego', '', '', '', '', ''],
#  ['', '', '', '', '', '', 'oliwy', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'oliwa'],
#  ['', 'oliwy', '', '', '', '', '', 'orzeszków', ''],
#  ['', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'orzeszków laskowych', ''],
#  ['', '', ''],
#  ['', '', 'oliwy', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', 'olej lniany'],
#  ['', '', '', 'oliwy', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['rzepakowego', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['',
#   '',
#   '',
#   'oliwy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'oliwy',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', 'oliwa', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'oliwa', ''],
#  ['', 'oliwy', '', '', '', '', '', '', '', '', '', ''],
#  ['oliwy', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'oliwy', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', 'olej roślinny', '', '', '', '', '', ''],
#  ['', '', '', 'oliwy', '', '', '', '', '', '', ''],
#  ['', 'oliwy', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'roślinnego', '', '', '', '', '', '', ''],
#  ['', '', 'oliwy', 'oliwy', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', 'olej'],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'oliwa'],
#  ['', 'oliwy', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'olej', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', 'oliwy', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', 'roślinnego', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'olej', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', 'roślinnego', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'oliwy', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'olej', '', '', '', '', '', ''],
#  ['',
#   'roślinnego',
#   '',
#   '',
#   '',
#   'kiełków',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'orzeszków ziemnych'],
#  ['', 'roślinnego', '', '', '', '', 'kiełków', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', 'roślinnego', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', 'Oliwa'],
#  ['', '', '', '', '', ''],
#  ['', '', '', 'oliwa', '', '', '', ''],
#  ['', '', 'orzeszków ziemnych', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'palmowego', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', 'żółtej', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', 'gorczycy', '', '', '', '', '', '', 'olej', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', 'greckiego', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', 'tajskiej', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', 'palmowy', '', '', ''],
#  ['', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', ''],
#  ['moreli', '', '', '', '', ''],
#  ['moreli', '', ''],
#  ['moreli', ''],
#  ['', '', ''],
#  ['', '', '', '', ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'kiełków',
#   '',
#   '',
#   'olej arachidowy',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', '', '', '', '', 'himalajskiej', '', ''],
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['', 'olej', '', '', '', '', '', '', ''],
#  ['', '', '', '', 'awokado', '', 'olej'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'roślinnego',
#   '',
#   '',
#   '',
#   '',
#   'orzeszków',
#   '',
#   ''],
#  ['', '', '', '', '', 'arachidowego', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', '', ''],
#  ['', '', '', '', ''],
#  ['', '', '', '', 'dyni', '', '', '', '', '']]

# %%
knn_skladnik = gen_knn(tluszcze + zboza + przyprawy + warzywa + nabial, jednostki, 1)

# %%
predict(knn_skladnik, data)
# Out:
# [['kg pieczarek pokrojonych',
#   'octu balsamicznego',
#   'sosu sojowego',
#   'posiekane',
#   'tymianku suszonego',
#   'sól pieprz smaku',
#   'natki pietruszki posiekanej'],
#  ['mniszka lekarskiego', 'octu', '', 'soli'],
#  ['koktajlowych',
#   '',
#   'świeżych pokrojonych',
#   'bazylii',
#   'czerwona cebula pokrojona',
#   'oliwy',
#   'octu balsamicznego',
#   'soli smaku'],
#  ['pęczek buraków bujnymi zielonymi',
#   'oliwy',
#   'krojone mielone',
#   'cytryny',
#   'sól',
#   'zmielony pieprz'],
#  ['',
#   'rabarbaru',
#   'biszkoptów',
#   'syropu truskawkowego',
#   'cukru',
#   'likieru pomarańczowego',
#   'kg mascarpone',
#   'twarogu',
#   'cukru waniliowego'],
#  ['wędzonego',
#   'czosnku',
#   'jajka',
#   'śmietankowego',
#   'oliwy',
#   'cytryny',
#   'mielonej słodkiej papryki',
#   'pieprz sól',
#   'koperku'],
#  ['',
#   'cebule',
#   '',
#   'mrożonego',
#   'gałka muszkatołowa',
#   'pieprzu',
#   'sól',
#   'koncentrat pomidorowy',
#   'majonez',
#   'suszone pomidory oleju'],
#  ['świeżych', 'ziemniaków', 'bulionu warzywnego', 'śmietanka zup', 'pieprz'],
#  ['',
#   'mandarynki',
#   'owocu granatu',
#   'dojrzałe awokado',
#   'mieszanka laskowych migdałów',
#   '',
#   'oliwy',
#   'musztardy',
#   'octu balsamicznego',
#   'zmielony biały pieprz'],
#  ['makaronu',
#   'bez pokrojonych',
#   'oleju',
#   'pieczarek pokrojonych',
#   'pokrojone',
#   'mielonego czosnku',
#   'bulionu warzywnego',
#   'śmietany',
#   'parmezanu',
#   'cytryny smaku',
#   'sól zmielony czarny pieprz'],
#  ['kwiatów czarnego bzu', 'cytryny', 'kg kilograma cukru', ''],
#  ['białka', '', 'cukru', '', 'listki melisy mięty'],
#  ['cukinie',
#   'czosnku',
#   'koncentratu pomidorowego',
#   'pasty',
#   'kminku mielonego',
#   'świeżych',
#   'sól czarny pieprz',
#   'oliwa rozcieńczenia pasty'],
#  ['pęczek',
#   'pęczek cebuli',
#   'czosnku',
#   'masła',
#   'oleju',
#   'bulionu warzywnego',
#   '',
#   'zakwasu buraczanego cytryny smaku',
#   'sól cukier',
#   'śmietany',
#   'jajka ugotowane'],
#  ['',
#   'mielonego drobiowego',
#   'białego ryżu ziarnach',
#   'cebula',
#   '',
#   'posiekanej natki pietruszki',
#   'posiekanej mięty pieprzowej',
#   'czosnku',
#   '',
#   'sól pieprz',
#   'sos',
#   'przecieru pomidorowego',
#   '',
#   'oregano suszonego',
#   'posiekanej mięty pieprzowej',
#   'cukru',
#   'soli'],
#  ['soczewicy',
#   'przecieru pomidorowego',
#   'bulionu drobiowego warzywnego',
#   'słodki',
#   'cebula',
#   'czosnku',
#   'imbiru',
#   'oleju',
#   'przyprawy curry papryki',
#   'sól pieprz',
#   'mleka kokosowego',
#   'drobiowego'],
#  ['',
#   'twarogu twaróg mleka kwaśnego słodkiego',
#   'ser',
#   'słodzonego mleka skondensowanego',
#   'temperaturze',
#   'ekstraktu waniliowego cukru',
#   'soli',
#   '',
#   'jajka',
#   'mąki',
#   'cukru',
#   'stopionego',
#   'soli',
#   '',
#   'dżemu',
#   'cukru pudru',
#   ''],
#  ['kwiatów czarnego bzu',
#   'jajka',
#   'mleka',
#   'mąki',
#   'soli',
#   'proszku pieczenia',
#   'tłuszcz smażenia',
#   'cukier puder posypania'],
#  ['mielonego',
#   '',
#   'cebula',
#   'kukurydzy konserwowej',
#   'natki posiekanej',
#   'sól pieprz',
#   '',
#   'jajka',
#   'mąka',
#   'tarta'],
#  ['baldachów kwiatów bzu czarnego',
#   'cytryny',
#   'skórka cytryn',
#   'płaskie kwasku cytrynowego',
#   '',
#   'cukru'],
#  ['kurczaka', 'oleju', 'prażonej cebulki', 'przyprawa drobiu', 'papryka'],
#  ['ryżu kleistego',
#   'mleka',
#   'cukru',
#   'mięty',
#   'cytryna',
#   'soli',
#   'świeżych',
#   'kostek czekolady gorzkiej'],
#  ['placki tortilli pszennej',
#   'tuńczyka oliwie',
#   'kukurydzy',
#   'posiekanego szczypiorku',
#   'marynowanych papryczek',
#   'mozzarelli sera żółtego',
#   'majonezu',
#   'musztardy'],
#  ['krojonych pomidorów',
#   'papryki',
#   'marynowanej papryczki jalapeño',
#   'sproszkowanego czosnku',
#   'sól',
#   'pieprz',
#   'cukru',
#   'octu spirytusowego',
#   'cebulki szalotki',
#   'mąki ziemniaczanej',
#   'posiekanej kolendry'],
#  ['tofu',
#   '',
#   'awokado',
#   'sól',
#   'zmielony pieprz',
#   'oliwa',
#   'sok cytryny',
#   'masła',
#   'jajka',
#   'posiekanego szczypiorku',
#   'chleba żytniego posmarowane masłem'],
#  ['mąki orzechów',
#   'cynamonu cejlońskiego',
#   'sody proszku pieczenia',
#   'soli himalajskiej',
#   'cukru palmowego',
#   '',
#   'oleju rzepakowego',
#   'jajka',
#   'cukru waniliowego'],
#  ['kurczaka',
#   'ryżu kleistego Rice',
#   'imbiru',
#   'smażonej cebuli',
#   '',
#   'oleju sezamowego',
#   'sosu sojowego',
#   'soli',
#   'oleju smażenia',
#   'chińskiej wódki ryżowej wódki',
#   ''],
#  ['ryżu kleistego',
#   'kokosowego',
#   'sok wyciśnięty limonki',
#   'skórka limonki',
#   'cukru trzcinowego',
#   'wanilii',
#   'mango',
#   'mięty',
#   'białego sezamu'],
#  ['masła', 'mąki', 'śmietany', 'wanilii', 'puree mango', 'owoce'],
#  ['kalafiora',
#   'ziemniaki',
#   'kalarepy',
#   'cebula',
#   'czosnku',
#   'kmin rzymski',
#   'kolendra',
#   'sól',
#   'pieprz',
#   'oliwa',
#   'bulionu',
#   'kokosowego'],
#  ['Napój Mango', 'herbaty', 'kostek', 'mango mięty'],
#  ['oleju',
#   'pasty curry',
#   '',
#   'bakłażana',
#   'polędwicy',
#   'kokosowego',
#   'bazylii',
#   'papryczki chili'],
#  ['białe',
#   'kurczaka',
#   'makaronu',
#   'bulionu mięsnego',
#   'masła',
#   'sosu sojowego',
#   'cukru',
#   'cytryna'],
#  ['fasoli białej',
#   'żeberek wieprzowych',
#   'wędzonego boczku',
#   'marchewki',
#   'pietruszka',
#   'selera',
#   'ziela',
#   'laurowy',
#   'cebula',
#   'czosnku',
#   'ziemniaki',
#   'majeranku'],
#  ['zupy',
#   'pasty sosów',
#   'zupy proszku',
#   'małży szyjkami',
#   'małży',
#   '',
#   '',
#   'papryczki chili',
#   'koktajlowych',
#   'cały czosnku',
#   'białego wina',
#   'oliwy',
#   '',
#   'natka pietruszki'],
#  ['fasoli',
#   'bulionu drobiowego',
#   'obrane pokrojone',
#   'oliwy',
#   'średnia pokrojona drobną',
#   'mąki pszennej',
#   'sól',
#   'zmielony czarny pieprz',
#   'bazylii',
#   'parmezanu',
#   'orzeszków pinii pestek dyni',
#   'oliwy',
#   'czosnku',
#   'sól',
#   'pieprz'],
#  ['makaronu',
#   'oleju arachidowego',
#   'fasoli',
#   'sałaty',
#   'papryki',
#   'smażonego Tofu',
#   '',
#   'sosu sojowego słodkiego',
#   'imbiru proszku',
#   'sól pieprz'],
#  ['wołowiny',
#   'czosnku',
#   '',
#   'ciemnego sosu sojowego',
#   'oleju',
#   'mąki ziemniaczanej',
#   'sezamu białego',
#   'szczypiorku'],
#  ['tapioki', 'cytrynowego syropu kawy', 'herbaty', 'mleka', 'miodu', 'mięta'],
#  ['tortilli',
#   '',
#   'wytrawnego wina',
#   'świeże mango',
#   'limonka',
#   'papryczki chili',
#   'sałata',
#   'sos',
#   'sól',
#   'pieprz'],
#  ['makaronu sojowego',
#   'ugotowanych',
#   '',
#   'posiekanych solonych pistacji',
#   'świeżych mięty',
#   'sok limonek',
#   'miodu',
#   'imbiru'],
#  ['mielonej wieprzowiny',
#   'drobno posiekanej cebuli',
#   'drobno posiekanej cebuli',
#   'kukurydzy',
#   'selera naciowego',
#   'grzybów shiitake',
#   'marchwi',
#   'sałaty',
#   'oleju roślinnego',
#   'oleju sezamowego',
#   'drobno posiekana papryczka chili',
#   'Składniki sosu',
#   'sosu pekińsku',
#   'wina ryżowego',
#   ''],
#  ['kurczaka',
#   'makaronu',
#   'ogórka pokrojonego',
#   'pokrojona',
#   'sosu',
#   'sosu sojowego słodkiego pierożków',
#   'kasztanów jadalnych pokrojonych',
#   'sosu pierożków'],
#  ['makaronu warzywami',
#   'kurczaka',
#   'mąki pszennej',
#   'oleju roślinnego',
#   '',
#   'cebula',
#   'czerwona papryka',
#   'kukurydzy',
#   'sezamu czarnego',
#   'sosu teriyaki sosu składników'],
#  ['makaronu sojowego',
#   'kurczaka',
#   'mango',
#   'imbiru',
#   'czosnku',
#   'papryczka chili',
#   'oleju kokosowego',
#   'sezamu',
#   'mięty',
#   'kolendry',
#   'sok limonek',
#   'cukru trzcinowego',
#   'sosu sojowego'],
#  ['Chińska mieszanka',
#   'filety kaczki',
#   'chińskiego makaronu',
#   'sosu sojowego',
#   'octu',
#   'oleju',
#   'cukru',
#   'imbiru proszku',
#   'papryki',
#   'słodkiej papryki',
#   'gałki muszkatołowej',
#   'cynamonu',
#   'sól',
#   'pieprz'],
#  ['makaronu',
#   'wołowiny',
#   'czosnku',
#   'imbiru',
#   '',
#   'papryki',
#   'pieczarki',
#   'oleju roślinnego',
#   'zmielonego białego pieprzu',
#   'cukru',
#   'ciemnego sosu sojowego',
#   'oleju sezamowego',
#   'posiekanego szczypiorku'],
#  ['sosu', 'żeberek', 'stołowa sosu sojowego'],
#  ['kurczaka',
#   'zielona papryka pokrojona',
#   'pieczarek pokrojonych',
#   'oleju',
#   'sosu czarnej fasoli czosnku'],
#  ['pokrojonego kurczaka',
#   'groszku cukrowego',
#   'kukurydzy',
#   'oleju',
#   'sosu sojowego'],
#  ['kurczaka',
#   'mąki',
#   'oleju',
#   'cebula',
#   'czosnku',
#   'marchewki',
#   'papryka czerwona zielona',
#   '',
#   'białego octu',
#   'cukru',
#   'koncentratu pomidorowego',
#   'sosu sojowego',
#   'sól',
#   'pieprz'],
#  ['kurczaka',
#   'papryki',
#   'cebulki posiekane',
#   'prażonych orzechów nerkowca',
#   'oleju',
#   'sosu Kurczak'],
#  ['', 'oleju', '', 'sosu'],
#  ['leszcze bez',
#   'ziemniaków,',
#   'posiekany rozmaryn',
#   'sosu Teriyaki',
#   'sosu Chili',
#   'oliwy',
#   'sól pieprz',
#   'pęczek koperku'],
#  ['tofu',
#   'słonecznikowy rzepakowy',
#   'Marynata',
#   'sosu sojowego',
#   'oleju sezamowego',
#   'starte',
#   'imbiru',
#   '',
#   'sosu sojowego',
#   'sosu chilli',
#   '',
#   'liście'],
#  ['fasolki szparagowej',
#   'olej arachidowy',
#   'mielonej wieprzowiny',
#   'wina ryżowego gotowania',
#   'sosu sojowego',
#   'papryczka chili',
#   'posiekanej chińskiej kapusty'],
#  ['bulionu warzywnego',
#   'laurowy',
#   'imbiru',
#   'sosu sojowego',
#   'sosu rybnego',
#   'cytryny',
#   'cukru',
#   'włoskiego',
#   'pieczarek',
#   'kapustka',
#   'makaronu',
#   'polędwicy',
#   'posiekanej papryczki chili',
#   'świeża kolendra'],
#  ['białego ryżu', 'kokosowego', 'soli'],
#  ['makaronu mąką fasoli kukurydzy',
#   'kurczaka',
#   'zmielonego białego pieprzu',
#   'czosnku',
#   'oleju roślinnego orzeszków',
#   'szparagów',
#   'pieczarek',
#   'posiekanej szczypiorku',
#   'oleju sezamowego',
#   'sosu sojowego',
#   '',
#   'octu ryżowego',
#   'cukru',
#   'mąki ziemniaczanej'],
#  ['makaronu',
#   '',
#   'szparagów',
#   'koktajlowych',
#   'czosnku',
#   'suszonego oregano',
#   'oliwy',
#   'masła',
#   'białego wytrawnego wina',
#   'świeża natka tymianek',
#   'tarty parmezan'],
#  ['makaronu warzywami',
#   'szpinaku',
#   'awokado',
#   'limonki',
#   'sól',
#   'zmielony czarny pieprz',
#   'oliwy',
#   'pokrojony',
#   'posiekanych estragonu',
#   'mascarpone',
#   'tarty Parmezan',
#   'koktajlowe'],
#  ['pojedynczy kurczaka',
#   'mąki ziemniaczanej',
#   'makaronu',
#   'cebuli',
#   'czosnku',
#   'marchewki',
#   '',
#   'papryczki chili',
#   'oleju roślinnego',
#   'orzechów nerkowca',
#   '',
#   'sosu sojowego',
#   'cukru trzcinowego',
#   'oleju sezamowego',
#   'posiekanego szczypiorku'],
#  ['makaronu',
#   '',
#   'oleju smażenia',
#   'posiekana papryczka chili',
#   'posiekany',
#   'papryki',
#   'papryki żółtej',
#   'papryki',
#   'posiekanego',
#   'słodkiego sosu sojowego',
#   'cytryny',
#   'sosu rybnego',
#   'prażonego sezamu'],
#  ['makaronu czarnym sezamem',
#   'oleju sezamowego',
#   'oleju arachidowego',
#   'posiekane',
#   'pokrojonego',
#   'ugotowanych',
#   'czerwona cebula',
#   'posiekane liście kolendry',
#   'prażonych czarnego sezamu',
#   'sól pieprz'],
#  ['',
#   'makaronu chilli',
#   'czerwona papryczka bez posiekana',
#   'masła',
#   'śmietanki kremowej',
#   'drobno parmezanu',
#   'bazylii mięty',
#   'sosu'],
#  ['makaronu chili',
#   'wołowiny',
#   'czosnku',
#   'imbiru',
#   '',
#   'papryki',
#   'pieczarki',
#   'oleju roślinnego',
#   'zmielonego białego pieprzu',
#   'cukru',
#   'ciemnego sosu sojowego',
#   'oleju sezamowego',
#   'posiekanego szczypiorku'],
#  ['makaronu pszennego czarnym sezamem',
#   'pomidory malinowe',
#   '',
#   'czosnku',
#   'cebuli',
#   'masła',
#   'oliwy',
#   'posiekanej natki pietruszki',
#   'sól',
#   'zmielony pieprz'],
#  ['',
#   'roztopionego masła',
#   'makaronu pszennego czarnym sezamem',
#   'śmietanki',
#   'skórka cytryny',
#   'sól',
#   'zmielony czarny pieprz',
#   '',
#   'cytryny'],
#  ['bakłażana',
#   'kuskusu',
#   'bulionu warzywnego',
#   'sok cytryny',
#   'posiekanej mięty',
#   'sera koziego pokrojonego sera',
#   '',
#   'oliwa'],
#  ['papryki',
#   'oliwy',
#   'kuskusu',
#   'bulion warzywny',
#   'posiekanego szczypiorku',
#   'posiekanej natki pietruszki',
#   '',
#   'orzeszków grillowanych',
#   'sera'],
#  ['',
#   'kiełbaski chorizo',
#   'pomidorów pokrojonych',
#   'rozmarynu',
#   'czosnku',
#   'fasolki białej'],
#  ['zupki kubku', 'kokosowego', 'owoce'],
#  ['zupki Shin',
#   'sosu',
#   'sos',
#   'sera mozzarella',
#   'boczku',
#   'cebuli',
#   'kiełek',
#   'kremu balsamicznego'],
#  ['zupki',
#   'suszonych',
#   'szpinaku',
#   'cebuli',
#   'pasty sojowej',
#   'rozdrobnionego czosnku',
#   '',
#   'jasny sos sojowy'],
#  ['mąki ryżu kleistego',
#   '',
#   'cukru',
#   'słodkiego kakao',
#   'czekolady kakao',
#   'śmietany',
#   'masła'],
#  ['kg kapusty pekińskiej',
#   'cebulę',
#   'szczypiorku',
#   'soli',
#   '',
#   '',
#   'płatków chili',
#   'czosnku',
#   'imbiru',
#   'sosu sojowego',
#   'sosu rybnego',
#   'cukru',
#   'prażonych białego sezamu'],
#  ['mleka',
#   'mąki',
#   'cukru',
#   'suszonych drożdży',
#   'soli',
#   'oleju',
#   'brązowy cukier',
#   'posiekanych orzeszków laskowych',
#   'cynamonu'],
#  ['zupki', 'zupki', ''],
#  ['ciecierzycy',
#   'czerwona papryka',
#   'oliwy',
#   'cytryny',
#   'cukru',
#   'kminu rzymskiego',
#   'płatków chili',
#   'soli',
#   'mielonego pieprzu',
#   'czosnku',
#   'cebuli',
#   'pomidor',
#   'posiekanego koperku',
#   'posiekanej natki pietruszki',
#   'posiekanego szczypiorku',
#   'mięty'],
#  ['jajka',
#   'soli',
#   'cukru',
#   'cebulki posiekanej',
#   'drobno',
#   'oleju',
#   'jogurtu majonezu',
#   'sosu chili'],
#  ['filety śledziowe oleju marynowane occie wypłukanych',
#   'posiekanej natki',
#   'zmielony czarny pieprz',
#   'musztardy',
#   'cytryny',
#   'brązowego cukru',
#   'marynowanej jalapeño',
#   'marynowanych podgrzybków',
#   'cebulki marynowanej',
#   'posiekanego szczypiorku',
#   'olej lniany'],
#  ['drobnych ziemniaków',
#   'jogurtu',
#   'pasty harissa',
#   'oliwy',
#   'migdałów',
#   'limonki',
#   'granatu',
#   '',
#   'sól',
#   'pieprz',
#   'listki mięty'],
#  ['jajka',
#   'soczewica',
#   'cebula czerwona',
#   'papryczka marynowana',
#   'majonez',
#   'musztarda',
#   'sól',
#   'pieprz',
#   'natka pietruszki'],
#  ['oleju rzepakowego',
#   'pokrojona',
#   'pokrojone',
#   'pikantnego sosu',
#   'mielonej kolendry',
#   'bulionu warzywnego drobiowego',
#   'ciecierzycy',
#   'krojonych pomidorów',
#   'pokrojone drobną',
#   'szpinaku',
#   'posiekanych kolendry',
#   'jajka',
#   'pieprz cukier smaku'],
#  ['papryka czerwona',
#   'papryka zielona',
#   'papryka żółta',
#   'cebule',
#   'pasty harissa',
#   'mięty',
#   'kurczaka',
#   'sól',
#   'pieprz czarny',
#   'czerwony ocet'],
#  ['ugotowanej kaszy jaglanej',
#   'ciecierzycy',
#   'por',
#   'oliwy',
#   'soli',
#   '',
#   'papryki',
#   'kurkumy',
#   'czosnku',
#   'natki pietruszki',
#   'Sos krojonych pomidorów',
#   'czosnku',
#   'oliwy',
#   'soli',
#   'cukru',
#   'pieprzu',
#   'papryczki chili',
#   'bazylii',
#   'cukinia',
#   'natki pietruszki'],
#  ['bataty',
#   'czosnku',
#   'ciecierzycy',
#   'oliwa',
#   'szpinaku',
#   '',
#   'krojonych pomidorów pomidora',
#   'papryczka chili',
#   'sól',
#   'pieprz',
#   'kminu rzymskiego',
#   'suszonego oregano',
#   'papryki słodkiej',
#   'papryki',
#   'papryki wędzonej',
#   'świeża kolendra',
#   'jogurt naturalny'],
#  ['filety', 'pasta harissa', 'oliwa', 'sól'],
#  ['ciecierzycy',
#   'oliwy',
#   'cebula',
#   'czosnku',
#   'oleju kokosowego masła',
#   'ziemniaki',
#   'mielonego kminu rzymskiego',
#   'bulionu rosołu',
#   'śmietanki',
#   'płatki chili',
#   'mielony kmin rzymski',
#   'świeża natka pietruszki'],
#  ['oliwy',
#   'pokrojona drobną',
#   'ziemniaków, pokrojonych',
#   'pokrojone',
#   'słodkiej papryki proszku',
#   'pikantnego pieprzu cayenne',
#   'sok cytryny',
#   'pomidorów sosem pomidorowym bez',
#   '',
#   '',
#   '',
#   'filetów soli bez pokrojonych',
#   'posiekanej natki pietruszki'],
#  ['cebuli',
#   'masła',
#   'oliwy',
#   'czosnku',
#   'papryka',
#   'kaszy bulgur',
#   'sól',
#   'pieprz',
#   'słodkiej papryki',
#   'kurkumy',
#   'kminu rzymskiego',
#   'bulionu',
#   'białej fasoli',
#   'krojonych pomidorów',
#   'cukinii',
#   'sosu',
#   'szpinaku'],
#  ['suszonych grzybów',
#   'kg kiszonej kapusty',
#   'bulionu',
#   'cebule',
#   'białej fasoli',
#   'olej roślinny',
#   'sól',
#   'pieprz',
#   'listki laurowe',
#   'ziela',
#   'suszonego majeranku',
#   'mąki'],
#  ['jajka',
#   'marynowanej papryczki jalapeño',
#   'drobno posiekanego szczypiorku',
#   'oliwy',
#   'posiekanej natki pietruszki',
#   'majonezu',
#   'sól',
#   'zmielony czarny pieprz',
#   'cukru',
#   'majonez',
#   'szczypiorek'],
#  ['sezamu',
#   'oliwy',
#   'ciecierzycy',
#   'czosnku',
#   'sok cytryny',
#   'zalewy ciecierzycy',
#   'świeża kolendra',
#   'papryka słodka'],
#  ['pasty harissa', 'masła', 'sera', 'cebula', '', 'szczypiorek'],
#  ['',
#   'kiełbaski chorizo',
#   'szalotki',
#   'ciecierzycy',
#   'pomidorowej',
#   'sól',
#   'pieprz',
#   'cukru'],
#  ['kurczaka',
#   'czerwona cebula',
#   'czerwona papryka',
#   'limonka',
#   'kminu rzymskiego',
#   'wędzonej papryki proszku',
#   'marynowanej papryczki jalapeño',
#   'oleju roślinnego',
#   'placki Tortilli',
#   'Guacamole',
#   'pomidor',
#   'cebula',
#   'sera cheddar',
#   'kwaśna śmietana',
#   'świeża kolendra'],
#  ['kromki chleba ziarnami zbóż',
#   'mrożonych ugotowanych bez ogonków',
#   'oliwy smaku chilli',
#   'oliwy',
#   'drobno posiekany',
#   'posiekanej natki pietruszki',
#   'białej fasoli',
#   'sól',
#   'zmielony czarny pieprz'],
#  ['suszonej ciecierzycy',
#   'pęczek pietruszki',
#   'cebule',
#   'czosnku',
#   'przyprawy ziele gałka',
#   'soli',
#   'sody',
#   '',
#   'olej smażenia'],
#  ['cukinie',
#   'cebula',
#   'pomidorów suszonych',
#   'czosnku',
#   'szpinaku',
#   'koziego sera',
#   'pomidorów',
#   'cynamonu',
#   'suszonego oregano',
#   'wędzonej słodkiej papryki',
#   'brązowy cukier',
#   'miód',
#   'syrop agawy',
#   '',
#   'sól',
#   'pieprz',
#   'oliwa'],
#  ['cukinii',
#   'oliwy',
#   'czosnku',
#   'cytryny',
#   'bulionu drobiowego',
#   'cytryny',
#   'kuskusu',
#   'mięty',
#   'sera'],
#  ['fasoli białej',
#   '',
#   'mielonego kminu',
#   'skórka cytryny',
#   'olej',
#   'selera',
#   'ziemniaki',
#   'pasty Harissa',
#   'liście laurowe',
#   'bulionu',
#   'sok cytryny',
#   'pęczek kolendry',
#   'sól',
#   'pieprz czarny'],
#  ['mielonej wieprzowiny',
#   'sody',
#   'pasty harissa',
#   'posiekanej kolendry',
#   '',
#   'majonez',
#   'sałata',
#   'pomidora',
#   'czerwona cebula',
#   'sos tzatziki sos chili',
#   'sól pieprz smaku'],
#  ['',
#   'cukinia',
#   'bakłażan',
#   'pieczarek',
#   'pęczek',
#   'oleju słonecznikowego',
#   'sos sojowy'],
#  ['ryż Sushi',
#   'Sushi',
#   'sos sojowy japoński',
#   'ocet ryżowy sushi',
#   'imbir sushi',
#   'pasta wasabi',
#   'bambusowa',
#   'owoce'],
#  ['',
#   'pęczek szparagów',
#   '',
#   'oliwy',
#   'botwinki szpinaku',
#   'makaronu',
#   'sezamu',
#   'oleju sezamowego',
#   'Marynata sos sosu sojowego',
#   'brązowego cukru',
#   'limonki',
#   'imbiru',
#   'drobno'],
#  ['ryżu sushi',
#   'Nori sushi',
#   'octu ryżowego',
#   'cukru',
#   'sosu sojowego',
#   'bambusowa sushi',
#   '',
#   'owoc',
#   'pęczek szczypiorku',
#   'marynowany imbir',
#   'pasta wasabi'],
#  ['bez',
#   'makaronu ryżowego',
#   'oleju roślinnego',
#   'papryczka chili',
#   'imbiru',
#   'sezamu',
#   'pasty miso',
#   'sosu sojowego',
#   'limonka',
#   'cukru',
#   'oleju sezamowego',
#   'posiekanego szczypiorku',
#   'świeża kolendra'],
#  ['', 'olej kokosowy', 'krewetki', 'mąka pszenna', 'sól', 'woda'],
#  ['Zupa',
#   '',
#   'Grzyby Shiitake',
#   'Makaron ryżowy',
#   'Mleczko kokosowe',
#   'krewetki kurczaka'],
#  ['makaronu',
#   'mieszanki surowych',
#   'posiekanej cebuli',
#   'posiekanej marchwi',
#   'papryczka pokrojona bez',
#   'stołowa oleju roślinnego',
#   'stołowa sosu',
#   'stołowa sosu czarnym pieprzem'],
#  ['kurczaka', 'makaronu Dong', 'chińskiej mieszanki', '', 'sosu kwaśnego'],
#  ['kg wieprzowych',
#   'kg drobiowych',
#   'cebulki szalotki',
#   'korzenia imbiru',
#   'czosnku',
#   'marchewki',
#   '',
#   'sosu sojowego',
#   'wina ryżowego Sake',
#   'suszonych grzybów Shiitake',
#   'makaronu',
#   'szczypiorek',
#   'jajek',
#   'Nori',
#   'kapusty kiełki fasoli'],
#  ['',
#   'oliwy',
#   '',
#   'sosu sojowego',
#   'sosu teriyaki',
#   'miodu lipowego',
#   'czubata imbiru',
#   'czosnku roztarte',
#   'sól pieprz'],
#  ['wieprzowej',
#   'papryki',
#   'papryki',
#   'cebula',
#   'czosnku',
#   '',
#   'pasty curry żółta',
#   'olej smażenia',
#   'Składniki sezamu białego',
#   'miodu',
#   'ciemnego sosu sojowego',
#   '',
#   'sok limonki',
#   'mąki'],
#  ['makaronu ryżowego',
#   'oleju roślinnego',
#   'czosnku',
#   'kurczaka pokrojona',
#   'jajka',
#   'kiełków fasoli',
#   'cebule pęczek szczypiorku jasnozielona',
#   'sosu rybnego',
#   'limonki',
#   'pasty tamaryndowca',
#   'cukru',
#   'sosu płatków',
#   'prażonych orzeszków ziemnych'],
#  ['makarony ryżowego',
#   'oleju roślinnego',
#   'czosnku',
#   'kurczaka tofu',
#   'jajka',
#   'sosu',
#   'kiełków fasoli',
#   'cebule pęczek szczypiorku'],
#  ['płaskie żelatyny proszku',
#   '',
#   'kokosowego',
#   'cukru',
#   'rumu',
#   'białego wina'],
#  ['kg filetów kurczaka',
#   'tajska papryczka chili pokrojona',
#   'stołowa cukru',
#   'oleju roślinnego',
#   'stołowa sosu rybnego',
#   'kokosowego',
#   'słodkiej bazylii',
#   'limonki drobno posiekanych',
#   'sosu sojowego',
#   'pasty curry'],
#  ['kokosowego',
#   'migdałowego',
#   '',
#   'płatków kokosowych',
#   'syropu klonowego',
#   'puree mango'],
#  ['kurczaka',
#   'kokosowego',
#   'imbiru',
#   'papryczka chili',
#   'łodyga trawy cytrynowej',
#   'limonki',
#   'pasty curry',
#   'sosu',
#   'sosu rybnego',
#   'sól',
#   'pieprz czarny'],
#  ['ryżu kleistego Rice', 'cukru,', '', 'gorzkiej', 'mielonego cynamonu'],
#  ['kurczaka', 'sosu Satay', 'Oliwa'],
#  ['płatków owsianych',
#   'wiórków kokosowych',
#   'kokosowego',
#   'cukru',
#   'czekolady mlecznej',
#   'maliny'],
#  ['', 'sałat', 'sera', 'oliwa', 'miód', 'sól', 'ocet jabłkowy', 'czarnych'],
#  ['makaronu ryżowego',
#   'cukinia pokrojona',
#   'orzeszków ziemnych',
#   'papryczki chili',
#   'szczypiorku',
#   'listki mięty kolendry',
#   'drobno',
#   'sosu rybnego',
#   'sok limonki',
#   'octu ryżowego',
#   'brązowego cukru'],
#  ['makaronu ryżowego',
#   'pęczek botwinki małymi',
#   'oleju kokosowego',
#   'imbiru',
#   'czosnku',
#   'sezamu',
#   'tofu',
#   'młode cebule',
#   'sosu sojowego',
#   'syropu klonowego',
#   'oleju sezamowego',
#   'sosu',
#   'mięty'],
#  ['',
#   'liście limonki',
#   'pasty',
#   'sosu rybnego',
#   'cukru trzcinowego palmowego',
#   'oleju',
#   'kokosowego',
#   'liście limonki',
#   'papryczka',
#   'ryż jaśminowy'],
#  ['makaronu ryżowego',
#   'kokosowego',
#   'świeże grzyby Shiitake',
#   'mango',
#   'sosu',
#   'kurczaka oczyszczone',
#   'zielona papryczka chili',
#   'czosnku',
#   'oleju',
#   'bazylii'],
#  ['makaronu ryżowego',
#   'czosnku',
#   'papryczka chili',
#   'sosu sojowego',
#   'octu ryżowego',
#   'posiekanej kolendry',
#   'kurczaka',
#   'sól',
#   'pieprz',
#   'przyprawa',
#   'słodki sos chili',
#   'sezam biały',
#   'kolendra'],
#  ['Składniki kokosowego',
#   'tapioki',
#   'cukru trzcinowego',
#   'soli',
#   'Składniki mus',
#   'cukru trzcinowego',
#   'sok cytryny'],
#  ['filety kurczaka',
#   'pasty',
#   'sos sojowy',
#   'sos rybny',
#   'mleko kokosowe Bonasia',
#   'papryka chili',
#   'czosnek',
#   'makaron ryżowy',
#   'orzechy pinii'],
#  ['oleju',
#   'żółtej pasty curry',
#   '',
#   'ziemniaków',
#   'drobiowego',
#   'cebuli',
#   'kokosowego',
#   'bazylii',
#   'papryczki chili'],
#  ['kokosowego',
#   'mleka',
#   'tapioki',
#   'pasty wanilii ziarenka wanilii',
#   'cukru',
#   'konfitura malinowa'],
#  ['kawy', 'żelatyny', 'cukier', 'tapioki', '', 'konfitura malinowa'],
#  ['kokosowego', 'tapioki', 'cukru trzcinowego', 'soli', 'mango'],
#  ['oleju',
#   'pasty curry',
#   '',
#   'drobiowego',
#   '',
#   'kokosowego',
#   'bazylii',
#   'papryczki chili'],
#  ['tofu',
#   '',
#   'pomidorów',
#   'kokosowego',
#   'marchewki',
#   'szalotki',
#   'kminku',
#   'gorczycy',
#   'kolendry',
#   'kurkumy',
#   'płatków chili',
#   'imbiru',
#   'czosnku',
#   'laurowy',
#   'olej',
#   'sól'],
#  ['wiśni',
#   '',
#   'cukru kokosowego',
#   'tapioki',
#   'cynamonu',
#   'goździk',
#   'kardamonu'],
#  ['tofu',
#   'gorzkiej czekolady',
#   '',
#   'cukru',
#   'smakowe ekstraktu likieru papryki'],
#  ['jogurtu', '', 'banany', 'ananasa', '', 'miód'],
#  ['limonki', 'napoju', 'miodu', 'imbiru'],
#  ['kokosowej', 'mango', '', 'jogurtu greckiego', 'cukru brązowego'],
#  ['puree mango',
#   'kokosowego',
#   'brązowego cukru',
#   'niegazowanej',
#   '',
#   'limonki'],
#  ['kokosowej', 'jogurtu', 'mango', '', ''],
#  ['Napój Mango', 'cytryny', 'mandarynek', 'ananasa', ''],
#  ['Rumu',
#   'Wina Sake Gekkeikan',
#   'syropu trawy cytrynowej',
#   'herbaty',
#   'kostek',
#   '',
#   'cytryna'],
#  ['', 'limonki', 'syropu cukrowego', 'liście tajskiej bazylii', ''],
#  ['', 'syropu', 'wina musującego', 'gazowanego napoju cytrynowego'],
#  ['', 'syropu cynamonowego', 'pomarańczowego', 'wina', ''],
#  ['Napój Mango',
#   'tequili',
#   'likieru pomarańczowego',
#   'sok limonki',
#   'cukru',
#   'cukru',
#   'kostek'],
#  ['kokosowego', 'cukier', 'spirytusu'],
#  ['kokosowej',
#   'limonki',
#   'grejpfruta',
#   'syrop agawy',
#   'mango',
#   'melona',
#   'świeża mięta',
#   ''],
#  ['ananasa pokrojonego', 'dojrzałe mango', '', 'kokosowej mango', ''],
#  ['rabarbar', 'woda', 'cukier palmowy', 'cytryna', 'melisa', ''],
#  ['', 'owoc granatu', 'kokosowej'],
#  ['kokosowej ananasem', 'mleka', 'ananasa', 'kakao'],
#  ['limonki',
#   'gruboziarnistego cukru soli',
#   'puree mango',
#   'Tequili',
#   'likieru',
#   'cukru'],
#  ['wódki', 'sok limonki', 'Napój Mango', ''],
#  ['ciemnego rumu whisky',
#   'limonka',
#   'Napój',
#   'kostek',
#   'gazowana woda mineralna'],
#  ['ananasowego', 'napoju', 'Sok pomarańczy', 'Sok limonki', 'limonki'],
#  ['Rumu', 'napoju', 'napoju', 'limonki'],
#  ['wino moreli japońskiej',
#   'brązowego cukru',
#   'mięty',
#   'limonki',
#   'kruszony',
#   'gazowanej'],
#  ['Wina moreli japońskiej', 'wódki', 'limonki'],
#  ['Wina moreli japońskiej', 'ginu'],
#  ['dojrzałe banany', 'kokosowej', 'cytryny'],
#  ['ananasa', 'kokosowej', 'limonka', 'mięty', ''],
#  ['wołowy',
#   'migdałów',
#   'białego sezamu',
#   'papryka czerwona',
#   'papryczka chilli',
#   'czosnku',
#   'imbiru',
#   'sałata rzymska',
#   'makaronu ryżowego',
#   'kiełków fasoli',
#   'mielonej trawy cytrynowej',
#   'sosu',
#   'olej arachidowy',
#   'sosu rybnego',
#   'czerwona cebula',
#   'sosu',
#   'octu ryżowego',
#   'świeża kolendra'],
#  ['',
#   'tapioki',
#   'wanilii',
#   'cukru',
#   'płaskie agaru',
#   'soli himalajskiej',
#   'gorzkiej czekolady',
#   'oleju kokosowego'],
#  ['oleju kokosowego',
#   'czosnku',
#   'cebuli cukrowej',
#   'łodyga selera naciowego',
#   'marchewki',
#   'imbiru',
#   'masła orzechowego',
#   'chili proszku',
#   'kurkumy',
#   'kminu rzymskiego',
#   'cynamonu',
#   'bulionu',
#   'kokosowego',
#   'tofu',
#   'czarnego sezamu',
#   'świeża kolendra'],
#  ['tofu',
#   'olej smażenia',
#   'cukru',
#   'sosu sojowego',
#   'ciemnego sosu sojowego',
#   'czosnku',
#   'świeżych grzybów shiitake',
#   'czarny pieprz',
#   'chili'],
#  ['ryżowego',
#   'ogórek',
#   'papryka czerwona',
#   'papryka żółta',
#   'awokado',
#   'sól pieprz smaku',
#   'olej'],
#  ['wołowiny',
#   'makaronu sojowego',
#   'suszone grzybki chińskie',
#   'curry proszku',
#   'kurkumy',
#   'płatków chilli',
#   'sosu rybnego',
#   'cukru',
#   'oleju roślinnego',
#   'drobno posiekane',
#   'cebula drobno posiekanej',
#   'trawy cytrynowej bardzo drobno posiekana',
#   'kokosowego',
#   'orzeszków posiekanych',
#   'drobno pikantnej papryczki chilli',
#   'sos sojowy'],
#  ['kurczaka',
#   'cebula',
#   'trawy cytrynowej',
#   'sosu rybnego',
#   'papryczki chilli',
#   'oleju arachidowego',
#   'cukru',
#   'czosnku',
#   'szczypiorek',
#   'przyprawy curry',
#   'ryż jaśminowy naturalny'],
#  ['kokosowej',
#   'kokosowego',
#   'ogórek świeży',
#   'rzodkiewek',
#   'świeży sok cytryny',
#   'czosnku',
#   'posiekanego szczypiorku',
#   'soli',
#   'pieprzu'],
#  ['śmietany', 'kremu kokosowego', 'płatków żelatyny', 'puree mango', 'cukru'],
#  ['ciecierzycy',
#   'cebula',
#   'imbiru',
#   '',
#   'dyni',
#   'pasty pomidorowej',
#   'mleka kokosowego',
#   'szpinaku',
#   'koktajlowych',
#   'Przyprawy mielony kurkuma mielona kolendra mielony cynamon słodka papryka papryka kardamon zielony']]

# %%
[d['ingredients'] for d in data]
# Out:
# [[['1 kg pieczarek pokrojonych wzdłuż na plasterki'],
#   ['2 łyżki octu balsamicznego'],
#   ['1 łyżka sosu sojowego'],
#   ['3 ząbki czosnku, posiekane'],
#   ['1/2 łyżeczki tymianku suszonego'],
#   ['sól i pieprz do smaku'],
#   ['1 łyżka natki pietruszki posiekanej']],
#  [['2 szklanki pąków mniszka lekarskiego'],
#   ['2/3 szklanki octu'],
#   ['1/3 szklanki wody'],
#   ['1 łyżeczka soli']],
#  [['200 g pomidorków koktajlowych (ewentualnie innych pomidorów)'],
#   ['1 opakowanie młodych liści'],
#   ['5\xa0 świeżych  pokrojonych w cząstki'],
#   ['kilka listków świeżej bazylii'],
#   ['czerwona cebula pokrojona w plastry'],
#   ['2-3 łyżki oliwy z oliwek'],
#   ['1-2 łyżki octu balsamicznego'],
#   ['szczypta soli morskiej do smaku']],
#  [['1 duży pęczek buraków (około 4-6 buraków) z bujnymi zielonymi liśćmi'],
#   ['1 łyżka oliwy z oliwek'],
#   ['2 duże ząbki czosnku, cienko krojone lub mielone'],
#   ['1 łyżeczka świeżego soku z cytryny'],
#   ['sól morska'],
#   ['świeżo zmielony pieprz']],
#  [['250 g truskawek'],
#   ['250 g rabarbaru'],
#   ['1 paczka biszkoptów'],
#   ['5 łyżek syropu truskawkowego'],
#   ['0,5 szklanki cukru'],
#   ['5 łyżek likieru pomarańczowego'],
#   ['0,5 kg mascarpone'],
#   ['250 g twarogu'],
#   ['2 łyżki cukru waniliowego']],
#  [['500 g mięsa z wędzonego pstrąga'],
#   ['3 ząbki czosnku'],
#   ['2 jajka'],
#   ['1 opakowanie serka śmietankowego typu Philadelfia'],
#   ['2 łyżki oliwy'],
#   ['2 łyżki soku z cytryny'],
#   ['1 łyżka mielonej słodkiej papryki'],
#   ['pieprz i sól'],
#   ['0,5 pęczka koperku']],
#  [['8 <strong>ziemniaków</ strong>'],
#   ['2 cebule'],
#   ['2 ząbki <strong>czosnku</ strong>'],
#   ['450 g mrożonego  w liściach'],
#   ['gałka muszkatołowa'],
#   ['szczypta pieprzu'],
#   ['sól'],
#   ['koncentrat pomidorowy'],
#   ['majonez'],
#   ['suszone pomidory w oleju']],
#  [['800 g świeżych liści'],
#   ['5 ziemniaków'],
#   ['2 l bulionu warzywnego'],
#   ['śmietanka do zup'],
#   ['sól, pieprz']],
#  [['1/2 opakowania'],
#   ['4 mandarynki bądź klementynki'],
#   ['1/2 owocu granatu'],
#   ['1 dojrzałe awokado'],
#   ['mieszanka orzechów: włoskich, laskowych i migdałów'],
#   ['Na sos:'],
#   ['5 łyżek oliwy z oliwek'],
#   ['2 łyżeczki ostrej musztardy'],
#   ['2 łyżeczki octu balsamicznego'],
#   ['świeżo zmielony biały pieprz']],
#  [['250 g makaronu'],
#   ['150 g szparagów, obranych, bez zdrewniałych końcówek, pokrojonych na kawałki długości około 3 cm'],
#   ['1 łyżka oleju'],
#   ['250 g pieczarek pokrojonych w plastry'],
#   ['4 dymki, pokrojone w plasterki'],
#   ['1 łyżeczka mielonego czosnku'],
#   ['180 ml bulionu warzywnego'],
#   ['180 ml śmietany 30%'],
#   ['100 g (1 szklanka) startego parmezanu'],
#   ['2-4 łyżeczki soku z cytryny lub do smaku'],
#   ['sól i świeżo zmielony czarny pieprz']],
#  [['300 gr. kwiatów czarnego bzu (ok. 20 baldachów)'],
#   ['dwie cytryny'],
#   ['0,7 kg kilograma cukru'],
#   ['0,7 litra wody']],
#  [['4 białka'],
#   ['1/2 łyżeczki cream of tartar (winian potasu)'],
#   ['1 szklanka cukru'],
#   ['20 truskawek'],
#   ['listki melisy lub mięty']],
#  [['4 średnie cukinie'],
#   ['3 ząbki czosnku'],
#   ['1 łyżka koncentratu pomidorowego'],
#   ['2 łyżki tahini, pasty sezamowej'],
#   ['1 łyżeczka kminku mielonego'],
#   ['1/4 szklanki świeżych liści kolendry, plus trochę do dekoracji'],
#   ['sól i czarny pieprz'],
#   ['oliwa z oliwek, w razie potrzeby w celu rozcieńczenia pasty i trochę do dekoracji']],
#  [['1 pęczek botwinki, około 3-5 młodych buraczków z nacią'],
#   ['1\xa0 pęczek młodej cebuli ze szczypiorem'],
#   ['3 ząbki czosnku'],
#   ['1 łyżka masła'],
#   ['1 łyżka oleju'],
#   ['4-6 szklanek bulionu warzywnego'],
#   ['3 ziemniaki, średniej wielkości'],
#   ['2 szklanki zakwasu buraczanego lub soku z cytryny do smaku'],
#   ['sól i cukier'],
#   ['3 łyżki śmietany 18% lub 30%'],
#   ['4 jajka ugotowane na twardo']],
#  [['Na kotlety:'],
#   ['500 g mielonego mięsa drobiowego'],
#   ['100 g białego ryżu o krótkich ziarnach'],
#   ['1 cebula'],
#   ['1 jajko'],
#   ['2 łyżki posiekanej natki pietruszki'],
#   ['2 łyżki posiekanej mięty pieprzowej'],
#   ['2 ząbki czosnku'],
#   ['4 łyżki bułki tartej'],
#   ['sól i pieprz'],
#   ['Na sos pomidorowy:'],
#   ['500 ml przecieru pomidorowego'],
#   ['150 ml wody'],
#   ['1 łyżeczka oregano suszonego'],
#   ['2 łyżki posiekanej mięty pieprzowej'],
#   ['2 łyżeczki cukru'],
#   ['1 łyżeczka soli']],
#  [['100 g czerwonej soczewicy'],
#   ['500 g przecieru pomidorowego'],
#   ['1 l bulionu drobiowego lub warzywnego'],
#   ['1 batat, słodki ziemniak, około 100 g'],
#   ['1 cebula'],
#   ['6 ząbków czosnku'],
#   ['1 cm świeżego imbiru'],
#   ['3 łyżki oleju'],
#   ['przyprawy: 1 łyżeczka kurkumy, 2 łyżeczki przyprawy curry w proszku, 1/2 łyżeczki ostrej papryki'],
#   ['sól i pieprz'],
#   ['100 ml pełnotłustego mleka kokosowego'],
#   ['300 g mięsa drobiowego']],
#  [['Na krem:'],
#   ['100-150 g twarogu według przepisu na Domowy twaróg z mleka kwaśnego i słodkiego'],
#   ['1-2 łyżki śmietany, jeśli ser jest zbyt suchy'],
#   ['2-4 łyżki słodzonego mleka skondensowanego'],
#   ['50 g masła, miękkiego, w temperaturze pokojowej'],
#   ['1 łyżeczka ekstraktu waniliowego lub 2 łyżeczki cukru wanilinowego'],
#   ['1/6 łyżeczki soli (tajny składniki, który reguluje równowagę słodyczy)'],
#   ['Na biszkopt:'],
#   ['2 jajka rozmiar M'],
#   ['50 g mąki'],
#   ['50 g cukru'],
#   ['30 g masła, stopionego i przestudzonego'],
#   ['1/6 łyżeczki soli'],
#   ['oraz'],
#   ['4-6 łyżek dżemu truskawkowego, podgrzanego, aby się nieco rozpuścił'],
#   ['1 łyżka cukru pudru'],
#   ['6-8 truskawek do dekoracji']],
#  [['15 kwiatów czarnego bzu'],
#   ['2 jajka'],
#   ['2 szklanki mleka'],
#   ['1/2 szklanki mąki'],
#   ['szczypta soli'],
#   ['1/2 łyżeczki proszku do pieczenia'],
#   ['tłuszcz do smażenia'],
#   ['cukier puder do posypania']],
#  [['500 g mielonego mięsa indyczego'],
#   ['1 bułka'],
#   ['1 cebula'],
#   ['1 puszka kukurydzy konserwowej'],
#   ['2 łyżki natki pietruszki, posiekanej'],
#   ['sól i pieprz'],
#   ['oraz do panierowania'],
#   ['2 jajka rozmiar S rozmącone z 2 łyżkami wody'],
#   ['mąka'],
#   ['tarta bułka']],
#  [['45 baldachów kwiatów bzu czarnego'],
#   ['2 cytryny'],
#   ['skórka z 2 cytryn'],
#   ['2 płaskie łyżeczki kwasku cytrynowego'],
#   ['1,5 l przegotowanej wody'],
#   ['750 g cukru']],
#  [['1 podwójny filet z kurczaka'],
#   ['5 łyżek oleju'],
#   ['200 g prażonej cebulki'],
#   ['przyprawa do drobiu'],
#   ['przyprawy: sól, pieprz, papryka']],
#  [['250 g ryżu kleistego'],
#   ['1 litr mleka'],
#   ['100 g cukru'],
#   ['kilka liści mięty'],
#   ['1 x cytryna'],
#   ['1 szczypta soli'],
#   ['500 g truskawek świeżych'],
#   ['5 kostek czekolady gorzkiej']],
#  [['3 duże placki tortilli pszennej'],
#   ['1 słoik tuńczyka w oliwie'],
#   ['150 g kukurydzy'],
#   ['4 łyżki posiekanego szczypiorku'],
#   ['300 g marynowanych ostrych papryczek'],
#   ['150 g tartej mozzarelli lub sera żółtego'],
#   ['4 łyżki majonezu'],
#   ['2 łyżeczki musztardy']],
#  [['400 g (puszka) krojonych pomidorów'],
#   ['1/4 zielonej papryki'],
#   ['2 łyżki marynowanej papryczki jalapeño'],
#   ['1/2 łyżeczki sproszkowanego czosnku'],
#   ['sól'],
#   ['pieprz'],
#   ['2 łyżki cukru'],
#   ['3 łyżki octu spirytusowego'],
#   ['2 cebulki szalotki'],
#   ['1 łyżeczka mąki ziemniaczanej'],
#   ['łyżka posiekanej kolendry']],
#  [['200 g tofu'],
#   ['2 porcje rukoli'],
#   ['1 awokado'],
#   ['sól'],
#   ['świeżo zmielony pieprz'],
#   ['oliwa extra virgine'],
#   ['sok z cytryny'],
#   ['2 łyżki masła'],
#   ['3 jajka'],
#   ['1 łyżka posiekanego szczypiorku'],
#   ['grzanki z chleba żytniego posmarowane masłem']],
#  [['340 g mąki z orzechów (nerkowce i migdały)'],
#   ['1 łyżka cynamonu cejlońskiego'],
#   ['2 łyżeczki sody oczyszczonej / lub proszku do pieczenia'],
#   ['szczypta soli himalajskiej / lub morskiej'],
#   ['20-30 g cukru palmowego'],
#   ['175 g musu jabłkowego'],
#   ['50 g oleju rzepakowego'],
#   ['2 jajka'],
#   ['1 łyżeczka cukru waniliowego']],
#  [['2 ćwiartki z kurczaka'],
#   ['500 g ryżu kleistego Q Rice'],
#   ['15 g imbiru'],
#   ['10 g smażonej cebuli'],
#   ['5 g jagód goji'],
#   ['2 łyżki oleju sezamowego'],
#   ['2 łyżki sosu sojowego'],
#   ['1/2 łyżeczki soli'],
#   ['1 łyżka oleju do smażenia'],
#   ['2 łyżki chińskiej wódki ryżowej / lub polskiej czystej wódki'],
#   ['300 ml wody']],
#  [['1 szklanka ryżu kleistego'],
#   ['400 ml mleczka kokosowego'],
#   ['sok wyciśnięty z 1 limonki'],
#   ['skórka starta z 1 limonki'],
#   ['4 łyżki cukru trzcinowego'],
#   ['1 x laska wanilii'],
#   ['1 x mango'],
#   ['kilka listków świeżej mięty'],
#   ['3 łyżki białego sezamu']],
#  [['75 g masła'],
#   ['75 g mąki orkiszowej'],
#   ['400 ml bitej śmietany'],
#   ['1 laska wanilii'],
#   ['1 szklanka puree z mango'],
#   ['opcjonalnie: owoce do dekoracji (np. truskawki, ananas, kiwi)']],
#  [['700 g kalafiora'],
#   ['2 średnie ziemniaki'],
#   ['2 kalarepy'],
#   ['1 cebula'],
#   ['2 ząbki czosnku'],
#   ['kmin rzymski'],
#   ['kolendra'],
#   ['sól'],
#   ['pieprz'],
#   ['oliwa extra virgin'],
#   ['1 litr bulionu'],
#   ['250 ml mleczka kokosowego']],
#  [['200 ml Rubicon Deluxe Napój Mango'],
#   ['100 ml zielonej herbaty'],
#   ['kilka kostek lodu'],
#   ['*świeże mango i kilka listków mięty do dekoracji']],
#  [['15 ml oleju do woka Thai Pride'],
#   ['40 g zielonej pasty curry Thai Pride'],
#   ['40 ml wody'],
#   ['60 g bakłażana'],
#   ['150 g polędwicy wołowej'],
#   ['160 ml mleczka kokosowego Diamond'],
#   ['20 g liści bazylii'],
#   ['5 g czerwonej papryczki chili']],
#  [['2 większe pory (tylko białe części)'],
#   ['30 dag piersi z kurczaka'],
#   ['15 dag makaronu udong'],
#   ['4 szklanki bulionu mięsnego'],
#   ['2 łyżki masła'],
#   ['4 łyżki jasnego sosu sojowego'],
#   ['1 łyżeczka cukru'],
#   ['cytryna']],
#  [['250 g fasoli białej'],
#   ['500 g żeberek wieprzowych'],
#   ['250 g wędzonego boczku'],
#   ['2 marchewki'],
#   ['1 pietruszka'],
#   ['kawałek selera'],
#   ['3 ziela angielskie'],
#   ['1 listek laurowy'],
#   ['1 duża cebula'],
#   ['1 ząbek czosnku'],
#   ['3 - 4 ziemniaki'],
#   ['1 łyżka majeranku']],
#  [['1 paczka zupy AnSungTangMyun'],
#   ['50 g pasty do sosów Barilla Arabiata'],
#   ['8 g bazy do zupy w proszku'],
#   ['100 g małży z krótkimi szyjkami (4 szt.)'],
#   ['100 g małży (4 szt.)'],
#   ['20 g mątwy'],
#   ['60 g krewetek (3 szt.)'],
#   ['2 g ostrej papryczki chili (1/4 szt.)'],
#   ['6 pomidorków koktajlowych'],
#   ['1 cały ząbek czosnku'],
#   ['18 ml białego wina'],
#   ['8 ml oliwy z oliwek'],
#   ['300 ml wody'],
#   ['natka pietruszki']],
#  [['1 szklanka fasoli'],
#   ['500 - 600 ml bulionu drobiowego lub jarzynowego'],
#   ['2 średnie marchewki, obrane i pokrojone w cienkie plasterki'],
#   ['1 łyżka oliwy z oliwek'],
#   ['1 średnia cebula, pokrojona w drobną kosteczkę'],
#   ['2 łyżki mąki pszennej'],
#   ['sól'],
#   ['świeżo zmielony czarny pieprz'],
#   ['Pesto:  • garść rukoli lub bazylii'],
#   ['3 łyżki tartego parmezanu / lub grana padano'],
#   ['1 łyżeczka orzeszków pinii / lub pestek dyni'],
#   ['4 łyżki oliwy z oliwek extra virgin'],
#   ['1/2 małego ząbka czosnku'],
#   ['sól'],
#   ['pieprz']],
#  [['200 g makaronu wieloziarnistego Bali Kitchen'],
#   ['2 łyżki oleju arachidowego'],
#   ['50 g fasoli czerwonej'],
#   ['50 g liści sałaty'],
#   ['1/2 papryki czerwonej pokrojonej w kostkę'],
#   ['50 g wędzonego, smażonego Tofu (w paski)'],
#   ['2 łyżki Mirinu'],
#   ['2 łyżki sosu sojowego słodkiego'],
#   ['1 łyżeczka imbiru w proszku'],
#   ['według uznania: odrobina soku z limetki / sól / pieprz']],
#  [['400 g chudej wołowiny'],
#   ['6 ząbków czosnku'],
#   ['250 g pędów bambusa'],
#   ['4 łyżki ciemnego sosu sojowego'],
#   ['3 łyżki oleju'],
#   ['1 łyżka mąki ziemniaczanej'],
#   ['3 łyżki sezamu białego'],
#   ['3 łyżki szczypiorku']],
#  [['4 łyżki perełek tapioki'],
#   ['10 łyżek cytrynowego syropu do kawy'],
#   ['2 saszetki herbaty malinowej'],
#   ['1 szklanka mleka'],
#   ['Kilka łyżek miodu'],
#   ['mięta do dekoracji']],
#  [['12 tortilli taco (kukurydziane/ pszenne/ razowe)'],
#   ['4 kacze udka'],
#   ['125 ml białego, wytrawnego wina'],
#   ['2 świeże mango'],
#   ['1 limonka'],
#   ['1/2 ostrej papryczki chili'],
#   ['sałata lodowa'],
#   ['sos Hoisin (2-3 łyżki stołowe)'],
#   ['sól'],
#   ['pieprz']],
#  [['100 g makaronu sojowego'],
#   ['12 ugotowanych lub usmażonych krewetek'],
#   ['200 g truskawek'],
#   ['4 łyżki posiekanych solonych pistacji'],
#   ['1/3 szklanki świeżych listków mięty'],
#   ['Sos:   • sok z 2 limonek'],
#   ['2 pełne łyżki miodu'],
#   ['1 łyżka tartego świeżego imbiru']],
#  [['200 g mielonej wieprzowiny'],
#   ['20 g drobno posiekanej cebuli dymki'],
#   ['20 g drobno posiekanej cebuli'],
#   ['20 g małej kukurydzy groszkowej'],
#   ['20 g selera naciowego'],
#   ['20 g grzybów shiitake (namoczonych w wodzie)'],
#   ['20 g marchwi'],
#   ['1 główka sałaty lodowej'],
#   ['2 łyżki stołowe oleju roślinnego'],
#   ['2 łyżki oleju sezamowego'],
#   ['1 drobno posiekana papryczka chili (opcjonalnie)'],
#   ['Składniki na sos: • 2 łyżki stołowe sosu ostrygowego'],
#   ['2 łyżki stołowe sosu po pekińsku'],
#   ['2 łyżki stołowe wina ryżowego'],
#   ['3 łyżki stołowe wody']],
#  [['350 g udek z kurczaka'],
#   ['200 g świeżego makaronu jajecznego'],
#   ['1/2 ogórka pokrojonego w cienkie paski'],
#   ['1 duża marchew, obrana i pokrojona w cienkie paski'],
#   ['• 2 łyżki stołowe sosu ostrygowego Lee Kum Kee'],
#   ['2 łyżki stołowe sosu sojowego słodkiego do pierożków Lee Kum Kee'],
#   ['50 g kasztanów jadalnych z puszki w wodzie, pokrojonych w plastry (opcjonalnie)'],
#   ['• 2 łyżki stołowe sosu do pierożków Lee Kum Kee']],
#  [['120 g makaronu Mie lub z warzywami'],
#   ['200 g filetu z kurczaka'],
#   ['1 łyżka mąki pszennej'],
#   ['2 łyżki oleju roślinnego'],
#   ['1/2 małego brokuła'],
#   ['1 cebula'],
#   ['1 czerwona papryka'],
#   ['1 mała puszka kukurydzy'],
#   ['1 łyżka sezamu czarnego'],
#   ['2-3 łyżki stołowe sosu teriyaki (ilość sosu może się zmieniać w zależności od ilości użytych składników']],
#  [['100 g makaronu sojowego'],
#   ['200 g krewetek black tiger / lub 150 g pokrojonej w kosteczkę piersi kurczaka'],
#   ['1 mango'],
#   ['1,5 łyżki startego imbiru'],
#   ['2 duże ząbki czosnku'],
#   ['1 papryczka chili'],
#   ['1 łyżka oleju kokosowego'],
#   ['3 łyżki sezamu'],
#   ['0,5 szklanki listków mięty'],
#   ['1 łyżka liści kolendry'],
#   ['Sos:  • sok z 2 limonek'],
#   ['2 łyżki cukru trzcinowego'],
#   ['1 łyżka sosu ostrygowego / lub 2 łyżki sojowego']],
#  [['Chińska mieszanka warzyw 330 g'],
#   ['2 filety z piersi kaczki'],
#   ['250 chińskiego makaronu jajecznego'],
#   ['2 łyżki sosu sojowego'],
#   ['2 łyżki octu'],
#   ['2 łyżki oleju'],
#   ['1 łyżeczka cukru'],
#   ['szczypta imbiru w proszku'],
#   ['szczypta ostrej papryki'],
#   ['szczypta słodkiej papryki'],
#   ['szczypta gałki muszkatołowej'],
#   ['szczypta cynamonu'],
#   ['sól'],
#   ['pieprz']],
#  [['80 g makaronu Chow Mein'],
#   ['170 g wołowiny'],
#   ['1 ząbek czosnku'],
#   ['1 łyżka startego świeżego imbiru'],
#   ['1/4 pora'],
#   ['1/2 czerwonej papryki'],
#   ['3 pieczarki'],
#   ['2 łyżki oleju roślinnego'],
#   ['szczypta zmielonego białego pieprzu'],
#   ['szczypta cukru'],
#   ['3 łyżki ciemnego sosu sojowego + 2 łyżki wody'],
#   ['2 łyżeczki oleju sezamowego'],
#   ['2 łyżki posiekanego szczypiorku']],
#  [['5 łyżek stołowych sosu hoisin'],
#   ['500 g żeberek'],
#   ['1 łyżka stołowa sosu sojowego jasnego']],
#  [['250 g piersi z kurczaka pokrojonej w kostkę'],
#   ['1 zielona papryka pokrojona w kostkę'],
#   ['75 g pieczarek pokrojonych w kostkę'],
#   ['1 łyżka oleju'],
#   ['50 g sosu stir- fry z czarnej fasoli i czosnku Lee Kum Kee']],
#  [['250 g pokrojonego w kostkę kurczaka (pierś lub udko)'],
#   ['50 g groszku cukrowego'],
#   ['75 g kolb kukurydzy baby'],
#   ['1 łyżka oleju'],
#   ['70 g sosu stir- fry miodowo- sojowego Lee Kum Kee']],
#  [['1 filet z kurczaka'],
#   ['2 łyżki mąki'],
#   ['2 łyżki oleju'],
#   ['1 cebula'],
#   ['1 ząbek czosnku'],
#   ['3 marchewki'],
#   ['1 papryka czerwona lub zielona'],
#   ['mała puszka pędów bambusa'],
#   ['1 łyżka białego octu winnego'],
#   ['1 łyżka cukru'],
#   ['2 łyżki koncentratu pomidorowego'],
#   ['2 łyżki sosu sojowego'],
#   ['sól'],
#   ['pieprz']],
#  [['250 g pokrojonej w kostkę piersi kurczaka'],
#   ['1/2 papryki czerwonej pokrojonej w kostkę'],
#   ['4 cebulki dymki, posiekane'],
#   ['30 g prażonych orzechów nerkowca'],
#   ['1 łyżka oleju'],
#   ['60 g sosu stir- fry Kurczak Kung Pao Lee Kum Kee']],
#  [['180 g surowych, obranych krewetek królewskich'],
#   ['1 łyżka oleju'],
#   ['30 g szparagów, ciętych (4 cm)'],
#   ['70 g sosu stir- fry pomidorowo- czosnkowego Lee Kum Kee']],
#  [['4 całe leszcze morskie, oczyszczone, bez płetw'],
#   ['400 g średniej wielkości ziemniaków, (podgotowanych w gorącej wodzie 5-7 minut)'],
#   ['1 świeżo posiekany rozmaryn'],
#   ['4 łyżki sosu Teriyaki Lee Kum Kee'],
#   ['4 łyżki sosu Chili czosnkowego Lee Kum Kee'],
#   ['3 łyżeczki lekkiej oliwy z oliwek'],
#   ['sól i pieprz'],
#   ['mały pęczek świeżego koperku (niewielka ilość zarezerwowana do dekoracji)']],
#  [['2 opakowania ekstra mocnego tofu (396 g każde)'],
#   ['olej, np. słonecznikowy albo rzepakowy'],
#   ['Marynata'],
#   ['2 łyżki sosu sojowego Light Lee Kum Kee'],
#   ['2 łyżki oleju sezamowego Lee Kum Kee'],
#   ['2 średnie ząbki czosnku, starte lub zmiażdżone'],
#   ['2 łyżki startego świeżego imbiru'],
#   ['Glazura'],
#   ['2 łyżeczki sosu sojowego Light Lee Kum Kee'],
#   ['2 łyżki sosu chilli czosnkowego Lee Kum Kee'],
#   ['Do podania'],
#   ['Ogórek, mięta, miękkie bułeczki i liście sałaty.']],
#  [['300 g zielonej fasolki szparagowej'],
#   ['olej arachidowy'],
#   ['75 g mielonej wieprzowiny'],
#   ['2 łyżki wina ryżowego do gotowania'],
#   ['1 łyżka sosu sojowego'],
#   ['1 papryczka chili (drobno pokrojona)'],
#   ['2 łyżki posiekanej chińskiej kapusty bok choy']],
#  [['1,5 litra bulionu warzywnego'],
#   ['liść laurowy'],
#   ['2 cm kawałek imbiru'],
#   ['2 łyżki sosu sojowego'],
#   ['2 łyżki sosu rybnego'],
#   ['1 łyżka soku z cytryny'],
#   ['szczypta cukru'],
#   ['1/2 bulwy kopru włoskiego'],
#   ['150 g pieczarek'],
#   ['1 kapustka pak choi (lub garść szpinaku)'],
#   ['100 g makaronu Chow Mien Bali Kitchen'],
#   ['350 g polędwicy z dorsza'],
#   ['1 łyżeczka posiekanej papryczki chili'],
#   ['świeża kolendra (lub szczypiorek)']],
#  [['200 g białego ryżu'],
#   ['300 ml mleczka kokosowego'],
#   ['pół łyżeczki soli']],
#  [['100 g makaronu Mie Goreng/ Chow Mien/ z mąką z fasoli i kukurydzy'],
#   ['1 pojedyncza pierś kurczaka'],
#   ['szczypta zmielonego białego pieprzu'],
#   ['2 ząbki czosnku'],
#   ['2 łyżki oleju roślinnego  (kokosowego lub z orzeszków ziemnych)'],
#   ['8 szparagów'],
#   ['6 pieczarek'],
#   ['3 łyżki posiekanej dymki lub szczypiorku'],
#   ['1 łyżka oleju sezamowego'],
#   ['Sos:  • 5 łyżek sosu sojowego jasnego'],
#   ['3 łyżki wody'],
#   ['3 łyżki soku z limonki/ lub cytryny/ lub octu ryżowego'],
#   ['3 łyżki cukru'],
#   ['1/2 łyżeczki mąki ziemniaczanej']],
#  [['150 g makaronu'],
#   ['150 g krewetek'],
#   ['1/2 pęczka szparagów'],
#   ['100 g pomidorków koktajlowych'],
#   ['3 ząbki czosnku'],
#   ['1 łyżeczka suszonego oregano'],
#   ['3 łyżki oliwy extra virgin'],
#   ['2 łyżki masła'],
#   ['4 łyżki białego wytrawnego wina'],
#   ['świeża bazylia/ natka pietruszki/ lub tymianek'],
#   ['tarty parmezan']],
#  [['150 g makaronu z warzywami Bali Kitchen'],
#   ['50 g szpinaku'],
#   ['0,5 dojrzałego dużego awokado / lub 1 małe'],
#   ['2 łyżki soku z limonki'],
#   ['sól morska'],
#   ['świeżo zmielony czarny pieprz'],
#   ['1 łyżka oliwy z oliwek'],
#   ['1 ząbek czosnku, pokrojony na plasterki'],
#   ['3 łyżki posiekanych liści świeżego estragonu'],
#   ['2 - 3 czubate łyżki serka mascarpone'],
#   ['tarty Parmezan'],
#   ['pomidorki koktajlowe']],
#  [['1 pojedynczy filet kurczaka'],
#   ['2 łyżeczki mąki ziemniaczanej'],
#   ['100 g makaronu Chow Mien/ Mie Bali Kitchen'],
#   ['ćwiartka cebuli'],
#   ['2 ząbki czosnku'],
#   ['1/2 marchewki'],
#   ['1/2 brokuła'],
#   ['kawałek papryczki chili'],
#   ['2 łyżki oleju roślinnego'],
#   ['3 łyżki orzechów nerkowca'],
#   ['1/4 szklanki wody'],
#   ['3 łyżki sosu sojowego'],
#   ['1/2 łyżeczki cukru trzcinowego'],
#   ['1 łyżka oleju sezamowego'],
#   ['4 łyżki posiekanego szczypiorku']],
#  [['200 g makaronu z morinagą Bali Kitchen'],
#   ['200 g krewetek'],
#   ['odrobinę oleju do smażenia'],
#   ['1 posiekana papryczka chili'],
#   ['1 ząbek czosnku, posiekany'],
#   ['1/2 papryki czerwonej pokrojonej w kostkę'],
#   ['1/2 papryki żółtej pokrojonej w kostkę'],
#   ['1/2 papryki zielonej pokrojonej w kostkę'],
#   ['30 g imbiru, posiekanego'],
#   ['3 łyżki słodkiego sosu sojowego'],
#   ['odrobina soku z cytryny'],
#   ['odrobina sosu rybnego'],
#   ['1 łyżka prażonego sezamu']],
#  [['200 g makaronu z czarnym sezamem Bali Kitchen'],
#   ['2 łyżki oleju sezamowego Diamond'],
#   ['2 łyżki oleju arachidowego'],
#   ['3 ząbki czosnku, posiekane'],
#   ['20 g imbiru, pokrojonego w małą kostkę'],
#   ['200 g ugotowanych krewetek'],
#   ['1 czerwona cebula'],
#   ['posiekane liście kolendry'],
#   ['1 łyżka prażonych nasion czarnego sezamu'],
#   ['sól i pieprz']],
#  [['około 1,5 szklanki truskawek'],
#   ['150 g makaronu chilli Bali Kitchen'],
#   ['1 łagodna czerwona papryczka chili, bez pestek, posiekana'],
#   ['2 łyżki masła'],
#   ['1/3 szklanki śmietanki kremowej 30%'],
#   ['0,5 szklanki drobno tartego parmezanu'],
#   ['0,5 szklanki liści bazylii i mięty'],
#   ['1 łyżka sosu Worcester']],
#  [['80 g makaronu chili'],
#   ['170 g wołowiny'],
#   ['1 ząbek czosnku'],
#   ['1 łyżka startego świeżego imbiru'],
#   ['1/4 pora'],
#   ['1/2 czerwonej papryki'],
#   ['3 pieczarki'],
#   ['2 łyżki oleju roślinnego'],
#   ['szczypta zmielonego białego pieprzu'],
#   ['szczypta cukru'],
#   ['3 łyżki ciemnego sosu sojowego + 2 łyżki wody'],
#   ['2 łyżeczki oleju sezamowego'],
#   ['2 łyżki posiekanego szczypiorku']],
#  [['80 g makaronu pszennego z czarnym sezamem'],
#   ['2 pomidory malinowe'],
#   ['miseczka kurek'],
#   ['2 ząbki czosnku'],
#   ['5 łyżek pokrojonej w kosteczkę cebuli'],
#   ['2 łyżki masła'],
#   ['2 łyżki oliwy extra virgin'],
#   ['1 łyżka posiekanej natki pietruszki'],
#   ['sól'],
#   ['świeżo zmielony pieprz']],
#  [['150 g filetu z dorsza'],
#   ['1 łyżka roztopionego masła'],
#   ['125 g makaronu pszennego z czarnym sezamem'],
#   ['80 ml śmietanki kremówki'],
#   ['skórka starta z 1 cytryny'],
#   ['sól morska'],
#   ['świeżo zmielony czarny pieprz'],
#   ['garść rukoli'],
#   ['cząstki cytryny do podania']],
#  [['1/2 dużego bakłażana'],
#   ['1/2 szklanki kuskusu'],
#   ['1/2 szklanki bulionu warzywnego'],
#   ['sok z ćwiartki cytryny'],
#   ['1 pełna łyżka posiekanej świeżej mięty'],
#   ['60 g sera koziego pokrojonego na kawałki (lub sera feta)'],
#   ['100 g pomidorków koktajlowych, przekrojonych na połówki'],
#   ['oliwa z oliwek']],
#  [['2 papryki (żółta i czerwona)'],
#   ['4 łyżki oliwy z oliwek'],
#   ['1/3 szklanki kuskusu'],
#   ['gorący bulion warzywny (około 1/3 szklanki)'],
#   ['1 łyżka posiekanego szczypiorku'],
#   ['1 łyżka posiekanej natki pietruszki'],
#   ['6 pomidorków koktajlowych, przekrojonych na połówki'],
#   ['2 - 3 łyżki orzeszków pinii, grillowanych na suchej patelni'],
#   ['8 kosteczek sera feta']],
#  [['2 kalmary'],
#   ['100 g kiełbaski chorizo'],
#   ['2 puszki pomidorów obranych, pokrojonych'],
#   ['gałązka rozmarynu'],
#   ['2 ząbki czosnku'],
#   ['400 g fasolki białej']],
#  [['1 opakowanie zupki krewetkowej w kubku'],
#   ['150 ml mleczka kokosowego'],
#   ['owoce lychee (wg uznania)']],
#  [['1 opakowanie zupki Shin Ramyun'],
#   ['1 opakowanie sosu serowego do nachosów'],
#   ['sos do salsy'],
#   ['100 g sera mozzarella'],
#   ['50 g boczku'],
#   ['30 g cebuli'],
#   ['50 g kiełek'],
#   ['1 łyżeczka kremu balsamicznego']],
#  [['2 paczki zupki Neoguri (ostra / łagodna)'],
#   ['1 szklanka suszonych krewetek'],
#   ['60 g szpinaku'],
#   ['1/2 zielonej cebuli'],
#   ['2 łyżeczki pasty sojowej'],
#   ['2-3 łyżeczki rozdrobnionego czosnku'],
#   ['6 szklanek wody'],
#   ['jasny sos sojowy']],
#  [['0,5 szklanki mąki z ryżu kleistego'],
#   ['0,5 szklanki zimnej wody'],
#   ['2 łyżki cukru'],
#   ['1 łyżka słodkiego kakao'],
#   ['tabliczka czekolady o dużej zawartości kakao (60% lub więcej)'],
#   ['1/3 szklanki śmietany kremówki'],
#   ['2 łyżki masła']],
#  [['1 kg kapusty pekińskiej'],
#   ['2 średnie cebulę'],
#   ['pół pęczka szczypiorku'],
#   ['200 g soli'],
#   ['250 ml wody'],
#   ['Zaprawa:'],
#   ['30 g płatków chili'],
#   ['3 duże ząbki czosnku'],
#   ['1 łyżka startego imbiru'],
#   ['1 łyżka jasnego sosu sojowego'],
#   ['½ łyżki sosu rybnego'],
#   ['1 ½ łyżki cukru'],
#   ['2 łyżki prażonych nasion białego sezamu']],
#  [['1 szklanka ciepłego mleka'],
#   ['2 szklanki mąki'],
#   ['2 łyżki cukru'],
#   ['2 łyżeczki suszonych drożdży'],
#   ['szczypta soli'],
#   ['1 łyżka oleju'],
#   ['brązowy cukier'],
#   ['parę łyżek posiekanych orzeszków (włoskich, laskowych lub ziemnych)'],
#   ['1 łyżeczka cynamonu']],
#  [['1 opakowanie zupki Chapaghetti'],
#   ['1 opakowanie zupki Neoguri (ostra / łagodna)'],
#   ['6 szklanek wody (ok. 1,1 l)']],
#  [['500 g ciecierzycy'],
#   ['1 czerwona papryka'],
#   ['4 łyżki oliwy z oliwek'],
#   ['1 łyżka soku z cytryny'],
#   ['1/2 łyżeczki cukru'],
#   ['3 łyżeczki kminu rzymskiego'],
#   ['1 łyżeczka płatków chili'],
#   ['mała szczypta soli'],
#   ['1/2 łyżeczki mielonego pieprzu'],
#   ['1 ząbek czosnku'],
#   ['1/3 młodej cebuli'],
#   ['1 pomidor'],
#   ['3 łyżki posiekanego koperku'],
#   ['4 łyżki posiekanej natki pietruszki'],
#   ['2 łyżki posiekanego szczypiorku'],
#   ['kilka listków mięty']],
#  [['3 jajka'],
#   ['1/2 łyżeczki soli'],
#   ['1 łyżeczka cukru'],
#   ['2 garści cebulki dymki, posiekanej'],
#   ['1/2 marchewki, drobno pokrojonej'],
#   ['3 łyżki oleju'],
#   ['3 łyżki naturalnego jogurtu lub majonezu'],
#   ['1 łyżka sosu chili ostrego']],
#  [['2 filety śledziowe (w oleju / lub marynowane w occie / lub wypłukanych solonych)'],
#   ['2 łyżeczki posiekanej natki'],
#   ['świeżo zmielony czarny pieprz'],
#   ['1 łyżeczka musztardy'],
#   ['1 łyżeczka soku z cytryny'],
#   ['szczypta brązowego cukru'],
#   ['2 łyżki marynowanej ostrej jalapeño'],
#   ['3 łyżki marynowanych podgrzybków'],
#   ['1 łyżka cebulki marynowanej'],
#   ['1 łyżka posiekanego szczypiorku'],
#   ['olej lniany']],
#  [['700 g drobnych ziemniaków'],
#   ['200 ml jogurtu naturalnego'],
#   ['2 łyżki pasty harissa'],
#   ['30 ml oliwy'],
#   ['2 łyżki migdałów w słupkach'],
#   ['30 ml soku z limonki'],
#   ['1/2 szklanki nasion granatu'],
#   ['2 szt. zielonej części dymki'],
#   ['sól'],
#   ['pieprz'],
#   ['listki mięty do dekoracji']],
#  [['jajka 5 sztuk'],
#   ['soczewica 100 g'],
#   ['cebula czerwona 50 g'],
#   ['papryczka jalapeno marynowana 50 g'],
#   ['majonez 1⁄2 szklanki'],
#   ['musztarda Dijon 10 g'],
#   ['sól'],
#   ['pieprz'],
#   ['natka pietruszki']],
#  [['2 łyżeczki oleju rzepakowego'],
#   ['1 duża cebula, przekrojona na połowę i pokrojona w cienkie plasterki'],
#   ['3 ząbki czosnku, pokrojone w plasterki'],
#   ['1 łyżka harissy, lub innego pikantnego sosu np. tabasco'],
#   ['1 łyżeczka mielonej kolendry'],
#   ['150 ml bulionu warzywnego lub drobiowego'],
#   ['400 g ciecierzycy Doyal'],
#   ['800 g krojonych pomidorów'],
#   ['2 małe cukinie, pokrojone w drobną kostkę'],
#   ['200 g młodego szpinaku'],
#   ['4 łyżki posiekanych listków kolendry'],
#   ['4 duże jajka'],
#   ['sól, pieprz i cukier do smaku']],
#  [['1 papryka czerwona'],
#   ['1 papryka zielona'],
#   ['1 papryka żółta'],
#   ['2 czerwone cebule'],
#   ['4 łyżeczki pasty harissa'],
#   ['4 gałązki świeżej mięty'],
#   ['1 tuszka kurczaka'],
#   ['sól morska'],
#   ['pieprz czarny'],
#   ['czerwony ocet winny']],
#  [['1 szklanka ugotowanej kaszy jaglanej'],
#   ['1 szklanka ciecierzycy'],
#   ['1 por (biała część)'],
#   ['2 łyżki oliwy'],
#   ['1/2 łyżeczki soli'],
#   ['1/2 łyżeczki kuminu'],
#   ['1/2 łyżeczki papryki'],
#   ['1/2 łyżeczki kurkumy'],
#   ['1 duży ząbek czosnku'],
#   ['kilka gałązek natki pietruszki'],
#   ['Sos pomidorowy:  • 400 g krojonych pomidorów'],
#   ['1 ząbek czosnku'],
#   ['2 łyżeczki oliwy'],
#   ['szczypta soli'],
#   ['szczypta cukru'],
#   ['szczypta pieprzu'],
#   ['kawałek papryczki chili'],
#   ['kilka liści bazylii'],
#   ['Dodatkowo:  • 1 cukinia'],
#   ['2 łyżki natki pietruszki']],
#  [['2 małe bataty'],
#   ['1 ząbek czosnku'],
#   ['150 g ciecierzycy'],
#   ['oliwa extra virgin'],
#   ['80 g szpinaku'],
#   ['100 g fety'],
#   ['2 łyżki krojonych pomidorów z puszki / lub 1/2 świeżego pomidora'],
#   ['papryczka chili'],
#   ['sól'],
#   ['pieprz'],
#   ['1 łyżeczka kminu rzymskiego'],
#   ['1/2 łyżeczki suszonego oregano'],
#   ['1/2 łyżeczki czerwonej papryki słodkiej'],
#   ['1/3 łyżeczki papryki ostrej'],
#   ['1/3 łyżeczki papryki wędzonej'],
#   ['świeża kolendra'],
#   ['jogurt naturalny']],
#  [['4 filety z łososia (każdy filet po około 100 - 150 g)'],
#   ['pasta harissa'],
#   ['oliwa z oliwek'],
#   ['sól']],
#  [['400-500 g ciecierzycy'],
#   ['1 łyżka oliwy extra virgin'],
#   ['1 cebula'],
#   ['2 ząbki czosnku'],
#   ['1 łyżka oleju kokosowego / lub masła'],
#   ['2 ziemniaki'],
#   ['1 łyżeczka mielonego kminu rzymskiego'],
#   ['500 ml bulionu lub rosołu'],
#   ['50 ml śmietanki 30%'],
#   ['płatki chili'],
#   ['mielony kmin rzymski'],
#   ['świeża kolendra/ lub natka pietruszki']],
#  [['2 łyżki oliwy z oliwek'],
#   ['1 mała cebula, pokrojona w drobną kosteczkę'],
#   ['250 g ziemniaków, obranych i pokrojonych w około 1,5 cm kosteczkę'],
#   ['2 małe ząbki czosnku, pokrojone w plasterki'],
#   ['1/2 łyżeczki słodkiej papryki w proszku'],
#   ['szczypta pikantnego pieprzu cayenne'],
#   ['sok z 1/2 cytryny'],
#   ['200 g pomidorów wraz z sosem pomidorowym (pokrojonych, bez skórek)'],
#   ['1/2 kostki bulionowej (rybnej lub jarzynowej)'],
#   ['100 g surowych, obranych krewetek'],
#   ['150 g ciecierzycy, odsączonej'],
#   ['250 g filetów soli bez ości i skóry, pokrojonych w około 5 cm kawałki'],
#   ['2 łyżki posiekanej natki pietruszki']],
#  [['1/2 cebuli'],
#   ['1/2 łyżki masła'],
#   ['1/2 łyżki oliwy'],
#   ['2 ząbki czosnku'],
#   ['1 papryka'],
#   ['100 g kaszy bulgur'],
#   ['sól'],
#   ['pieprz'],
#   ['2 łyżeczki słodkiej papryki'],
#   ['1/2 łyżeczki kurkumy'],
#   ['1/2 łyżeczki kminu rzymskiego'],
#   ['1 szklanka bulionu'],
#   ['400 g białej fasoli'],
#   ['1 puszka krojonych pomidorów'],
#   ['1/3 cukinii'],
#   ['1 łyżka sosu ostrygowego'],
#   ['2 garście szpinaku']],
#  [['50 g suszonych grzybów'],
#   ['1 kg kiszonej kapusty'],
#   ['2 szklanki bulionu'],
#   ['2 duże cebule'],
#   ['400 g białej fasoli'],
#   ['olej roślinny (np. rzepakowy, słonecznikowy)'],
#   ['sól'],
#   ['pieprz'],
#   ['2 listki laurowe'],
#   ['4 ziela angielskie'],
#   ['2 łyżki suszonego majeranku'],
#   ['1 łyżka mąki']],
#  [['4 jajka'],
#   ['3 łyżki marynowanej zielonej papryczki jalapeño'],
#   ['1 łyżka drobno posiekanego szczypiorku'],
#   ['1 łyżeczka oliwy extra virgin'],
#   ['1 łyżka posiekanej natki pietruszki'],
#   ['2 łyżki majonezu'],
#   ['sól morska'],
#   ['świeżo zmielony czarny pieprz'],
#   ['szczypta cukru'],
#   ['majonez (dodatkowo do dekoracji)'],
#   ['szczypiorek (dodatkowo do dekoracji)']],
#  [['5 łyżek sezamu'],
#   ['2 łyżki oliwy'],
#   ['200 g ciecierzycy w zalewie'],
#   ['2 ząbki czosnku'],
#   ['sok z połówki cytryny'],
#   ['100 ml zimnej zalewy z ciecierzycy'],
#   ['świeża kolendra'],
#   ['pieprz, sól, papryka słodka']],
#  [['3 łyżki pasty harissa'],
#   ['150 g masła'],
#   ['200 g sera Mozarella'],
#   ['1 cebula'],
#   ['1 ciabatta'],
#   ['szczypiorek']],
#  [['250 g filetu z dorsza'],
#   ['80 g kiełbaski chorizo'],
#   ['2 małe szalotki'],
#   ['120 g ciecierzycy'],
#   ['300 ml pasaty pomidorowej'],
#   ['sól'],
#   ['pieprz'],
#   ['szczypta cukru']],
#  [['400 g polędwiczek kurczaka (lub całych filetów)'],
#   ['1 czerwona cebula'],
#   ['1 czerwona papryka'],
#   ['1 limonka'],
#   ['1/2 łyżeczki kminu rzymskiego'],
#   ['1 łyżeczka wędzonej papryki w proszku'],
#   ['1 łyżka marynowanej papryczki jalapeño'],
#   ['2 łyżki oleju roślinnego'],
#   ['Dodatki:  • 4 placki Tortilli'],
#   ['Guacamole'],
#   ['1 pomidor'],
#   ['cebula'],
#   ['50 g tartego sera cheddar'],
#   ['gęsta kwaśna śmietana'],
#   ['świeża kolendra']],
#  [['2 duże kromki chleba z ziarnami zbóż'],
#   ['10 mrożonych lub świeżych, ugotowanych (różowych) krewetek, obranych i bez ogonków'],
#   ['1 łyżeczka oliwy o smaku chilli'],
#   ['1 łyżka oliwy z oliwek'],
#   ['1 ząbek czosnku, drobno posiekany'],
#   ['1 łyżka posiekanej natki pietruszki'],
#   ['1/2 puszki białej fasoli'],
#   ['sól'],
#   ['świeżo zmielony czarny pieprz']],
#  [['500 g suszonej ciecierzycy'],
#   ['pęczek zielonej pietruszki'],
#   ['2 średnie cebule'],
#   ['3 ząbki czosnku'],
#   ['3 łyżki przyprawy do falafela (kolendra, kmin, pieprz, ziele angielskie, cynamon, goździki, imbir, gałka muszkatałowa, mahlab)'],
#   ['łyżka soli'],
#   ['łyżeczka sody'],
#   ['kilka łyżek wody'],
#   ['olej do smażenia']],
#  [['2 cukinie'],
#   ['1 cebula'],
#   ['140 g pomidorów suszonych w zalewie'],
#   ['2 ząbki czosnku'],
#   ['150 g świeżego szpinaku'],
#   ['200 g koziego sera (rolada)'],
#   ['450 g pomidorów z puszki'],
#   ['szczypta cynamonu'],
#   ['1 łyżeczka suszonego oregano'],
#   ['1/2 łyżeczki wędzonej słodkiej papryki'],
#   ['brązowy cukier'],
#   ['miód'],
#   ['syrop z agawy (opcjonalnie)'],
#   ['2 łyżki harissy'],
#   ['sól'],
#   ['pieprz'],
#   ['oliwa z oliwek']],
#  [['300 g cukinii'],
#   ['2 łyżki oliwy extra virgin'],
#   ['1 ząbek czosnku'],
#   ['1/2 łyżeczki skórki z cytryny'],
#   ['150 ml bulionu jarzynowego / lub drobiowego'],
#   ['1 łyżka soku z cytryny'],
#   ['150 g kuskusu'],
#   ['1/3 szklanki listków mięty'],
#   ['100 g sera feta']],
#  [['1 szklanka fasoli białej (fasolę wcześniej namoczyć)'],
#   ['1/2 pora'],
#   ['1 łyżeczkę mielonego kminu'],
#   ['skórka z połowy cytryny'],
#   ['olej'],
#   ['4 laski selera'],
#   ['2 ziemniaki'],
#   ['2 łyżki pasty Harissa'],
#   ['2 liście laurowe'],
#   ['1,5-2 l bulionu'],
#   ['sok z połowy cytryny'],
#   ['pęczek kolendry'],
#   ['sól'],
#   ['pieprz czarny']],
#  [['250 g mielonej wieprzowiny'],
#   ['¼ łyżeczki sody oczyszczonej'],
#   ['2 łyżki pasty harissa Le Phare du Cap Bon'],
#   ['2 łyżki posiekanej kolendry'],
#   ['2 bułki do burgerów'],
#   ['majonez'],
#   ['sałata'],
#   ['plastry pomidora'],
#   ['1 czerwona cebula'],
#   ['sos tzatziki / sos chili'],
#   ['sól i pieprz do smaku']],
#  [['panierka Tempura'],
#   ['1 cukinia 175 g'],
#   ['1 bakłażan 250 g'],
#   ['150 g małych pieczarek'],
#   ['1 pęczek dymki'],
#   ['1 l oleju słonecznikowego'],
#   ['sos sojowy (do maczania)']],
#  [['ryż do Sushi'],
#   ['algi do Sushi'],
#   ['sos sojowy japoński'],
#   ['ocet ryżowy do sushi'],
#   ['imbir do sushi'],
#   ['pasta wasabi'],
#   ['mata bambusowa'],
#   ['warzywa, ryby, owoce morza (wedle uznania)']],
#  [['300 g filetu z łososia'],
#   ['mały pęczek zielonych szparagów'],
#   ['4 małe dymki'],
#   ['3 łyżki oliwy'],
#   ['duża garść małych listków botwinki / lub szpinaku'],
#   ['170 g makaronu Udong'],
#   ['2 łyżki sezamu'],
#   ['2 łyżeczki oleju sezamowego'],
#   ['Marynata i sos teriyaki: • 6 łyżek sosu sojowego'],
#   ['2 łyżki brązowego cukru'],
#   ['1 łyżka soku z limonki'],
#   ['3 łyżeczki startego imbiru'],
#   ['1 ząbek czosnku, drobno starty']],
#  [['500 g ryżu do sushi'],
#   ['1 opakowanie alg Nori do sushi'],
#   ['Zalewa octowa: • 8 łyżek octu ryżowego'],
#   ['3-4 łyżki cukru'],
#   ['łyżka sosu sojowego'],
#   ['mata bambusowa do sushi'],
#   ['Dodatki: • 200 g świeżego (najlepiej surowego lub wędzonego) filetu z łososia'],
#   ['dojrzały owoc awokadu'],
#   ['pęczek szczypiorku'],
#   ['marynowany imbir (ze słoika) według uznania'],
#   ['pasta wasabi']],
#  [['200 g filetu z łososia bez skóry i ości'],
#   ['100 g makaronu ryżowego'],
#   ['2 łyżki oleju roślinnego'],
#   ['1 papryczka chili'],
#   ['1,5 łyżki startego imbiru'],
#   ['2 łyżki sezamu'],
#   ['2 łyżki pasty miso'],
#   ['2 łyżki sosu sojowego'],
#   ['1 limonka'],
#   ['1/2 łyżeczki cukru'],
#   ['1 łyżka oleju sezamowego'],
#   ['4 łyżki posiekanego szczypiorku'],
#   ['świeża kolendra']],
#  [['Tempura Samlip'],
#   ['olej kokosowy'],
#   ['surowe krewetki 24 szt.'],
#   ['mąka pszenna 1 szklanka'],
#   ['sól'],
#   ['woda']],
#  [['Zupa Tom Yum THAI PRIDE'],
#   ['Pędy bambusa THAI PRIDE'],
#   ['Grzyby Shiitake DIAMOND'],
#   ['Makaron ryżowy 3 mm FARMER'],
#   ['Mleczko kokosowe AROY- D'],
#   ['krewetki lub pierś z kurczaka lub filet z łososia']],
#  [['150 g makaronu Udong'],
#   ['150 g mieszanki surowych owoców morza (rozmrożonych i odcedzonych)'],
#   ['50 g posiekanej cebuli'],
#   ['50 g posiekanej marchwi'],
#   ['1 papryczka chili, pokrojona w plastry, bez nasion'],
#   ['1 łyżka stołowa oleju roślinnego'],
#   ['1 łyżka stołowa sosu ostrygowego'],
#   ['1 łyżka stołowa sosu z czarnym pieprzem']],
#  [['1 pierś z kurczaka'],
#   ['400 g makaronu U- Dong'],
#   ['330 g chińskiej mieszanki warzyw'],
#   ['227 g pędów bambusa (w plastrach)'],
#   ['165 ml sosu słodko- kwaśnego Lee Kum Kee']],
#  [['Bulion: • 1 kg kości wieprzowych'],
#   ['1 kg kości drobiowych'],
#   ['4 cebulki szalotki'],
#   ['10 cm korzenia imbiru'],
#   ['pół główki czosnku'],
#   ['2 marchewki'],
#   ['albi Konbu (płat)'],
#   ['100 ml sosu sojowego'],
#   ['80 ml wina ryżowego Sake'],
#   ['Dodatki: • 300 g suszonych grzybów Shiitake'],
#   ['500 g świeżego makaronu Ramen'],
#   ['szczypiorek'],
#   ['6 jajek'],
#   ['algi Nori'],
#   ['opcjonalnie: • 200 g kapusty Bok Choy • kiełki fasoli mung']],
#  [['800 g filetu z łososia'],
#   ['1 łyżka oliwy'],
#   ['Marynata:'],
#   ['6 łyżek sosu sojowego'],
#   ['8 łyżek sosu teriyaki'],
#   ['2 łyżki miodu lipowego'],
#   ['1 czubata łyżeczka imbiru (mielonego lub świeżo startego - 1,5 cm)'],
#   ['2 duże żabki czosnku (przeciśnięte przez praskę i roztarte z solą)'],
#   ['sól i pieprz']],
#  [['500 g łopatki wieprzowej'],
#   ['1/2 papryki czerwonej'],
#   ['1/2 papryki zielonej'],
#   ['1 cebula'],
#   ['2 ząbki czosnku'],
#   ['1/2 szklanki pędów bambusa'],
#   ['1 łyżeczka pasty curry (w zależności od preferowanej ostrości, żółta - najłagodniejsza)'],
#   ['olej do smażenia'],
#   ['Składniki na sos: • 1 łyżka sezamu białego'],
#   ['2 łyżki miodu'],
#   ['2 łyżki ciemnego sosu sojowego'],
#   ['6 łyżek wody'],
#   ['sok z 1 limonki'],
#   ['1 łyżeczka mąki']],
#  [['Makaron: •100 g makaronu ryżowego (płaskiego i szerokiego, 5 mm)'],
#   ['2 łyżki oleju roślinnego'],
#   ['3 ząbki czosnku'],
#   ['1 pierś kurczaka pokrojona w małą kosteczkę'],
#   ['2 jajka'],
#   ['1 szklanka kiełków fasoli mung'],
#   ['2 cebule dymka lub 1 pęczek szczypiorku (biała i jasnozielona część)'],
#   ['Sos: • 4 łyżki sosu rybnego'],
#   ['2 łyżki soku z limonki'],
#   ['2 łyżki pasty z tamaryndowca'],
#   ['3 pełne łyżki cukru'],
#   ['1 łyżka sosu sriracha (lub 1/2 łyżki płatków chili)'],
#   ['2 łyżki prażonych orzeszków ziemnych']],
#  [['100 g makarony ryżowego (3 mm / 5 mm)'],
#   ['2 łyżki stołowe oleju roślinnego'],
#   ['3 ząbki czosnku'],
#   ['1 pierś z kurczaka lub 8 krewetek (obranych) lub 100 g tofu'],
#   ['2 jajka'],
#   ['100 ml sosu Pad Thai'],
#   ['1 szklanka kiełków fasoli mung Diamond'],
#   ['2 cebule dymka lub 1 pęczek szczypiorku']],
#  [['2 płaskie łyżeczki żelatyny w proszku'],
#   ['2 łyżki ciepłej wody'],
#   ['250 ml mleczka kokosowego'],
#   ['40 g cukru'],
#   ['2 łyżki rumu'],
#   ['2 łyżki białego wina']],
#  [['0,5 kg filetów z kurczaka'],
#   ['1 tajska papryczka chili (prik chee fa), cienko pokrojona'],
#   ['1 łyżka stołowa cukru'],
#   ['2 łyżki stołowe oleju roślinnego'],
#   ['1 łyżka stołowa sosu rybnego'],
#   ['1 filiżanka mleczka kokosowego'],
#   ['1/4 filiżanki liści słodkiej bazylii'],
#   ['8 liści limonki kaffir, drobno posiekanych'],
#   ['1/3 łyżki stołowej jasnego sosu sojowego'],
#   ['2 łyżki stołowe pasty curry panang']],
#  [['1 szklanka mleczka kokosowego'],
#   ['1 szklanka mleczka migdałowego'],
#   ['1/3 szklanki nasion Chia'],
#   ['1/3 szklanki płatków kokosowych'],
#   ['4 łyżki syropu klonowego'],
#   ['2 szklanki puree z mango (Kesar)']],
#  [['1 pierś z kurczaka'],
#   ['400 ml mleczka kokosowego'],
#   ['2 cm imbiru'],
#   ['1 papryczka chili'],
#   ['łodyga trawy cytrynowej'],
#   ['1/2 limonki'],
#   ['1 łyżka zielonej pasty curry'],
#   ['2 łyżki sosu worcester'],
#   ['3 łyżki sosu rybnego'],
#   ['sól'],
#   ['pieprz czarny']],
#  [['200 g ryżu kleistego Q Rice'],
#   ['100 g cukru,'],
#   ['1 litr mleka,'],
#   ['250 g gorzkiej czekolady,'],
#   ['szczypta mielonego cynamonu']],
#  [['3 piersi z kurczaka'],
#   ['100 ml sosu Satay'],
#   ['Oliwa z oliwek extra virgin']],
#  [['1 szklanka płatków owsianych górskich'],
#   ['2 łyżki wiórków kokosowych'],
#   ['200 ml mleczka kokosowego'],
#   ['2 łyżki cukru'],
#   ['50 g czekolady mlecznej lub deserowej'],
#   ['maliny']],
#  [['10 owoców lychee'],
#   ['mix sałat (1/2 opakowania)'],
#   ['1 kulka sera mozarella'],
#   ['oliwa z oliwek'],
#   ['miód'],
#   ['sól'],
#   ['ocet jabłkowy'],
#   ['1/2 szklanki oliwek czarnych']],
#  [['Makaron: • 200 g makaronu ryżowego'],
#   ['1 cukinia pokrojona na kawałki'],
#   ['4 łyżki orzeszków ziemnych'],
#   ['1 - 2 duże czerwone papryczki chili'],
#   ['2 gałązki szczypiorku'],
#   ['listki świeżej mięty i kolendry (po pół szklanki)'],
#   ['Sos: • 1 ząbek czosnku, drobno starty'],
#   ['2 łyżki sosu rybnego (lub sojowego)'],
#   ['sok z 1 limonki'],
#   ['1 łyżka octu ryżowego'],
#   ['1 łyżka brązowego cukru']],
#  [['100 g makaronu ryżowego'],
#   ['1 pęczek botwinki (młodej z małymi buraczkami)'],
#   ['2 łyżki oleju kokosowego'],
#   ['1 łyżka startego świeżego imbiru'],
#   ['1 ząbek czosnku'],
#   ['4 łyżki sezamu'],
#   ['100 g tofu'],
#   ['2 młode cebule ze szczypiorem (dymki)'],
#   ['5 łyżek sosu sojowego'],
#   ['łyżeczka syropu klonowego'],
#   ['2 łyżki oleju sezamowego'],
#   ['1 łyżeczka ostrego sosu Sriracha'],
#   ['garść świeżej mięty']],
#  [['1 pierś z kurczaa'],
#   ['3 liście limonki kafir'],
#   ['1-2  łyżki pasty Panang'],
#   ['1 łyżeczka sosu rybnego'],
#   ['1 łyżeczka cukru trzcinowego lub palmowego'],
#   ['1 łyżka oleju'],
#   ['100 ml mleczka kokosowego'],
#   ['2 liście limonki kafir, pocięte w paski'],
#   ['papryczka chili, pociętę w krążki'],
#   ['ryż jaśminowy do podania']],
#  [['250 g makaronu ryżowego'],
#   ['200 ml mleczka kokosowego'],
#   ['3-4 świeże grzyby Shiitake'],
#   ['1 mango'],
#   ['3 łyżki sosu śliwkowego'],
#   ['2 piersi z kurczaka (umyte i oczyszczone z błon)'],
#   ['1 zielona papryczka chili'],
#   ['2 ząbki czosnku'],
#   ['3-4 łyżki oleju'],
#   ['kilka listków bazylii']],
#  [['200 g makaronu ryżowego'],
#   ['2 ząbki czosnku'],
#   ['1 papryczka chili'],
#   ['3-4 łyżki sosu sojowego'],
#   ['1 łyżka octu ryżowego'],
#   ['garść posiekanej kolendry'],
#   ['4 kawałki mięsa z udek z kurczaka (bez skóry i kości)'],
#   ['sól'],
#   ['pieprz'],
#   ['przyprawa 5 smaków'],
#   ['słodki sos chili (1-2 łyżki stołowe)'],
#   ['sezam biały'],
#   ['kolendra do dekoracji (opcjonalnie)']],
#  [['Składniki na pudding: • 800 ml mleczka kokosowego'],
#   ['1/3 szklanki tapioki'],
#   ['1 łyżka cukru trzcinowego'],
#   ['szczypta soli'],
#   ['Składniki na mus truskawkowy: • 2 szklanki truskawek'],
#   ['1 łyżka cukru trzcinowego'],
#   ['sok z połowy cytryny']],
#  [['2 podwójne filety z kurczaka'],
#   ['2 łyżki pasty Tom Yum Thai Pride'],
#   ['sos sojowy Lee Kum Kee'],
#   ['sos rybny Cock'],
#   ['mleko kokosowe Bonasia'],
#   ['papryka chili'],
#   ['czosnek'],
#   ['makaron ryżowy 3 mm Farmer'],
#   ['orzechy pinii']],
#  [['15 ml oleju do woka Thai Pride'],
#   ['40 g żółtej pasty curry Thai Pride'],
#   ['40 ml wody'],
#   ['60 g ziemniaków'],
#   ['150 g mięsa drobiowego'],
#   ['60 g cebuli'],
#   ['160 ml mleczka kokosowego Diamond'],
#   ['20 g liści bazylii'],
#   ['5 g czerwonej papryczki chili']],
#  [['400 ml mleczka kokosowego'],
#   ['400 ml mleka'],
#   ['80 g tapioki'],
#   ['1 łyżeczka pasty z wanilii lub ziarenka z 1 laski wanilii'],
#   ['2 łyżki cukru'],
#   ['konfitura malinowa']],
#  [['300 ml kawy espresso'],
#   ['2 łyżki żelatyny'],
#   ['cukier'],
#   ['1/2 szklanki tapioki'],
#   ['2 szklanki wody'],
#   ['konfitura malinowa']],
#  [['800 ml mleczka kokosowego'],
#   ['1/3 szklanki perełek z tapioki'],
#   ['1 łyżka cukru trzcinowego'],
#   ['szczypta soli'],
#   ['1 mango']],
#  [['15 ml oleju do woka Thai Pride'],
#   ['40 g czerwonej pasty curry Thai Pride'],
#   ['40 ml wody'],
#   ['150 g mięsa drobiowego'],
#   ['60 g pędów bambusa Thai Pride'],
#   ['160 ml mleczka kokosowego Diamond'],
#   ['20 g liści bazylii'],
#   ['5 g czerwonej papryczki chili']],
#  [['300 g tofu'],
#   ['20 owoców lychee'],
#   ['1 puszka pomidorów'],
#   ['400 ml mleczka kokosowego'],
#   ['3 marchewki'],
#   ['2 szalotki'],
#   ['1 łyżeczka nasion kminku'],
#   ['1,5 łyżeczki nasion gorczycy'],
#   ['1 łyżeczka nasion kolendry'],
#   ['1 łyżeczka kurkumy'],
#   ['1 łyżeczka płatków chili'],
#   ['1 łyżeczka świeżego, startego imbiru'],
#   ['2 ząbki czosnku'],
#   ['liść laurowy'],
#   ['olej'],
#   ['sól']],
#  [['200 g wiśni'],
#   ['100 ml wody'],
#   ['2-3 łyżki cukru kokosowego'],
#   ['15 g tapioki'],
#   ['szczypta cynamonu'],
#   ['1 goździk'],
#   ['4-5 sztuk kardamonu']],
#  [['340 g tofu'],
#   ['200 g gorzkiej czekolady'],
#   ['1/2 szklanki wody'],
#   ['1/2 szklanki cukru'],
#   ['dodatki smakowe np. 1 łyżeczka ekstraktu z wanilii, 1 łyżka likieru pomarańczowego, 1/3 łyżeczki cynamonu, szczypta ostrej papryki']],
#  [['300 ml jogurtu naturalnego 2%'],
#   ['10 owoców lychee'],
#   ['2 banany'],
#   ['200 g ananasa'],
#   ['1 szklanka kruszonego lodu'],
#   ['miód']],
#  [['3 łyżeczki soku z limonki'],
#   ['1/2 szklanki napoju Rubicon Deluxe Guawa'],
#   ['2 łyżki miodu'],
#   ['2 łyżeczki imbiru']],
#  [['1 szklanka wody kokosowej'],
#   ['1 szklanka owoców mango (świeżych lub mrożonych)'],
#   ['1 obrany banan'],
#   ['200 g jogurtu greckiego'],
#   ['1 łyżka cukru brązowego']],
#  [['2 szklanki puree z mango'],
#   ['1/2 szklanki mleczka kokosowego'],
#   ['2 łyżeczki brązowego cukru'],
#   ['1 szklanka wody mineralnej niegazowanej'],
#   ['4 łyżki stołowe nasion Chia'],
#   ['2 łyżeczki soku z limonki']],
#  [['100 ml wody kokosowej'],
#   ['100 g jogurtu naturalnego'],
#   ['1/2 mango'],
#   ['150 g truskawek'],
#   ['lód']],
#  [['Napój Mango Rubicon Deluxe'],
#   ['1/2 cytryny'],
#   ['6 mandarynek'],
#   ['125 g ananasa'],
#   ['1 szklanka soku jabłkowego']],
#  [['30 ml Rumu Tanduay'],
#   ['60 ml Wina Sake - Gekkeikan Haiku'],
#   ['30 ml syropu z trawy cytrynowej'],
#   ['90 ml świeżo zaparzonej zielonej herbaty'],
#   ['kilka kostek lodu'],
#   ['Dodatki do dekoracji:'],
#   ['imbir, mięta, cytryna']],
#  [['45 ml Mekhong Thai Spirit'],
#   ['25 ml świeżego soku z limonki'],
#   ['30 ml syropu cukrowego'],
#   ['8-10 liście tajskiej bazylii'],
#   ['"kropla wody"']],
#  [['20 ml Mekhong Thai Spirit'],
#   ['30 ml syropu z lychee'],
#   ['50 ml wina musującego'],
#   ['opcjonalnie: szczypta gazowanego napoju cytrynowego']],
#  [['45 ml Mekhong Thai Spirit'],
#   ['15 ml syropu cynamonowego'],
#   ['60 ml soku pomarańczowego'],
#   ['60 ml czerwonego wina'],
#   ['"kropla limonki"']],
#  [['150-200 ml Rubicon Deluxe Napój Mango'],
#   ['80 ml tequili'],
#   ['80 ml likieru pomarańczowego triple sec'],
#   ['sok z 1/2 limonki'],
#   ['1 łyżka cukru'],
#   ['*dodatkowo 2 łyżeczki cukru do dekoracji'],
#   ['kilka kostek lodu']],
#  [['400 ml mleczka kokosowego'], ['cukier'], ['125 ml spirytusu 95%']],
#  [['500 ml wody kokosowej'],
#   ['2 szt. limonki'],
#   ['2 szt. grejpfruta czerwonego'],
#   ['syrop z agawy'],
#   ['1 szt. mango'],
#   ['1/2 melona'],
#   ['świeża mięta'],
#   ['lód']],
#  [['200 g ananasa (obranego i pokrojonego w kostkę)'],
#   ['1 dojrzałe mango'],
#   ['100-150 g truskawek'],
#   ['100 ml wody kokosowej z mango'],
#   ['kostki lodu (opcjonalnie)']],
#  [['rabarbar 4 łodygi'],
#   ['woda 1 litr'],
#   ['cukier palmowy 50 g'],
#   ['cytryna 1⁄2 sztuki'],
#   ['melisa'],
#   ['lód']],
#  [['1 banan'], ['1 owoc z granatu'], ['200 ml wody kokosowej z granatem']],
#  [['200 ml wody kokosowej z ananasem'],
#   ['100 ml mleka'],
#   ['4 plastry ananasa'],
#   ['1 łyżeczka kakao']],
#  [['2 limonki'],
#   ['2 łyżki stołowe gruboziarnistego cukru lub soli'],
#   ['2 szklanki puree z mango'],
#   ['1 1/2 szklanki Tequili'],
#   ['1 1/2 szklanki likieru Triple Sec'],
#   ['1/4 szklanki cukru']],
#  [['40 cl czystej wódki'],
#   ['sok z 1/2 limonki'],
#   ['Rubicon Deluxe Napój Mango'],
#   ['grenadina']],
#  [['30 ml ciemnego rumu lub whisky'],
#   ['1 limonka'],
#   ['150 ml Rubicon Deluxe Napój Guawa'],
#   ['kilka kostek lodu'],
#   ['gazowana woda mineralna']],
#  [['2 szklanki  soku ananasowego'],
#   ['1 szklanka napoju Rubicon Deluxe Guawa'],
#   ['Sok z 1/2 pomarańczy'],
#   ['Sok z 1/2 limonki'],
#   ['1 cząstka limonki']],
#  [['45 ml Rumu Malibu'],
#   ['45 ml napoju Rubicon Deluxe Lychee'],
#   ['45 ml napoju Rubicon Deluxe Guawa'],
#   ['1 cząstka limonki']],
#  [['45 ml wino z moreli japońskiej Choya Silver'],
#   ['2 łyżeczki brązowego cukru'],
#   ['8 liści mięty'],
#   ['1/2 limonki'],
#   ['kruszony lód'],
#   ['100-150 ml gazowanej wody mineralnej']],
#  [['15 ml Wina z moreli japońskiej Choya Silver'],
#   ['30 ml czystej wódki'],
#   ['15 ml soku z limonki']],
#  [['140 ml Wina z moreli japońskiej Choya Silver'], ['60 ml ginu']],
#  [['3 dojrzałe banany'], ['250 ml wody kokosowej'], ['1/2 cytryny']],
#  [['150 g świeżego ananasa'],
#   ['250 ml wody kokosowej'],
#   ['limonka'],
#   ['kilka listków mięty'],
#   ['lód']],
#  [['1 antrykot wołowy'],
#   ['1 garść migdałów'],
#   ['1 garść białego sezamu'],
#   ['1 papryka czerwona'],
#   ['1 papryczka chilli'],
#   ['1 ząbek czosnku'],
#   ['kawałek imbiru'],
#   ['1 sałata rzymska'],
#   ['100 g makaronu ryżowego'],
#   ['1 garść kiełków fasoli mung'],
#   ['1 łyżka mielonej trawy cytrynowej'],
#   ['2-3 łyżki sosu teryiaki'],
#   ['olej arachidowy'],
#   ['1 łyżka sosu rybnego'],
#   ['1 czerwona cebula'],
#   ['2 łyżki sosu ostrygowego'],
#   ['1 łyżka octu ryżowego'],
#   ['świeża kolendra']],
#  [['800 ml mleczka koksowego'],
#   ['¾ szklanki tapioki'],
#   ['1 laska wanilii'],
#   ['3-4 łyżki cukru'],
#   ['2 płaskie łyżeczki agaru'],
#   ['szczypta soli himalajskiej lub morskiej'],
#   ['100 g gorzkiej czekolady 90%'],
#   ['1 łyżeczka oleju kokosowego']],
#  [['1 łyżka oleju kokosowego'],
#   ['1 ząbek czosnku'],
#   ['1/2 cebuli cukrowej'],
#   ['łodyga selera naciowego lub pora'],
#   ['500 g marchewki'],
#   ['2 łyżeczki startego imbiru'],
#   ['1 łyżka masła orzechowego'],
#   ['1/2 łyżeczki chili w proszku'],
#   ['1/2 łyżeczki kurkumy'],
#   ['1/2 łyżeczki kminu rzymskiego'],
#   ['szczypta cynamonu'],
#   ['600 ml bulionu jarzynowego'],
#   ['250 ml mleczka kokosowego'],
#   ['100 g tofu'],
#   ['1 łyżka czarnego sezamu'],
#   ['świeża kolendra']],
#  [['250 g tofu Mo- Ri'],
#   ['olej do smażenia'],
#   ['2 łyżki cukru'],
#   ['125 ml jasnego sosu sojowego'],
#   ['1 łyżeczka ciemnego sosu sojowego'],
#   ['2 ząbki czosnku'],
#   ['15 świeżych grzybów shiitake'],
#   ['czarny pieprz'],
#   ['1 małe czerwone chili']],
#  [['10 arkuszy papieru ryżowego'],
#   ['1 średniej wielkości ogórek'],
#   ['1 papryka czerwona'],
#   ['1 papryka żółta'],
#   ['1 awokado'],
#   ['sól i pieprz do smaku'],
#   ['olej']],
#  [['150 g wołowiny (np. z udźca)'],
#   ['80 g makaronu sojowego'],
#   ['4 suszone grzybki chińskie Mun'],
#   ['0,5 łyżeczki  curry w proszku'],
#   ['0,5 łyżeczki kurkumy'],
#   ['0,5 łyżeczki płatków chilli'],
#   ['2 łyżki sosu rybnego'],
#   ['1 łyżka cukru'],
#   ['2 łyżki oleju roślinnego'],
#   ['2 ząbki czosnku, drobno posiekane'],
#   ['1 cebula (pół drobno posiekanej i pół pokrojonej w "piórka")'],
#   ['1 gałązka trawy cytrynowej (biała część) bardzo drobno posiekana'],
#   ['3 łyżki mleczka kokosowego'],
#   ['1 łyżka orzeszków ziemnych, posiekanych'],
#   ['0,5 łyżeczki drobno posiekanej, pikantnej papryczki chilli'],
#   ['sos sojowy do podania']],
#  [['500 g piersi z kurczaka (pokrojona w kostkę)'],
#   ['1 cebula (pokrojona w kostkę)'],
#   ['3 łyżki trawy cytrynowej (posiekana)'],
#   ['2 łyżki sosu rybnego'],
#   ['2 papryczki chilli (drobno posiekana)'],
#   ['4 łyżki oleju arachidowego'],
#   ['3 łyżki cukru'],
#   ['4 ząbki czosnku (drobno posiekane)'],
#   ['1 szczypiorek (drobno posiekany)'],
#   ['1 łyżka przyprawy curry'],
#   ['ryż jaśminowy naturalny']],
#  [['200 ml wody kokosowej'],
#   ['200 ml mleczka kokosowego'],
#   ['1 ogórek świeży'],
#   ['6 rzodkiewek'],
#   ['świeży sok z połowy cytryny'],
#   ['2 ząbki czosnku'],
#   ['1 łyżka posiekanego szczypiorku'],
#   ['szczypta soli'],
#   ['szczypta pieprzu']],
#  [['200 ml bitej śmietany'],
#   ['30 ml kremu kokosowego'],
#   ['10 g płatków żelatyny'],
#   ['200 g puree z mango'],
#   ['50 g cukru']],
#  [['1 szklanka ciecierzycy'],
#   ['1 cebula'],
#   ['1 łyżka startego imbiru'],
#   ['1 ząbek czosnku, starty'],
#   ['300 g obranej dyni'],
#   ['1/2 szklanki pasty pomidorowej'],
#   ['150 ml mleka kokosowego'],
#   ['garść szpinaku'],
#   ['200 g pomidorków koktajlowych'],
#   ['Przyprawy (po łyżce): • mielony kminy • kurkuma • mielona kolendra • mielony cynamon • słodka papryka • ostra papryka • kardamon zielony']]]

# %%
data
# Out:
# [{'link': 'https://beszamel.se.pl/weganskie/balsamiczne-szaszlyki-z-pieczarek-pyszne-z-grilla-lub-piekarnika,22240/',
#   'title': 'Balsamiczne szaszłyki z pieczarek: pyszne z grilla lub piekarnika',
#   'portions': '4',
#   'photo_link': 'https://cdn26.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22241/balsamiczne-szaszlyki-z-pieczarek-pyszne-z-grilla.jpg',
#   'ingredients': [['1 kg pieczarek pokrojonych wzdłuż na plasterki'],
#    ['2 łyżki octu balsamicznego'],
#    ['1 łyżka sosu sojowego'],
#    ['3 ząbki czosnku, posiekane'],
#    ['1/2 łyżeczki tymianku suszonego'],
#    ['sól i pieprz do smaku'],
#    ['1 łyżka natki pietruszki posiekanej']],
#   'preparation': 'Z podanych składników przygotowujemy marynatę.\nMarynujemy grzyby w marynacie przez 30 minut.\nGrzyby nadziać wzdłuż (od kapelusza do nóżki) na patyczki do szaszłyków.\nSzaszłyki pieczemy w temperaturze 180°C lub\xa0grillujemy na średnim ogniu, aż będą miękkie i lekko zrumienione, około 2-3 minuty z każdej strony.\nPrzed podaniem posypujemy natką pietruszki.\xa0',
#   'category': 'weganskie'},
#  {'link': 'https://beszamel.se.pl/przetwory-z-warzyw/kapary-z-paczkow-mlecza-przepis-jak-zrobic-domowe-kapary-z-mniszka-lekarskiego,22318/',
#   'title': 'Kapary z pączków mlecza: przepis jak zrobić domowe kapary z mniszka lekarskiego',
#   'portions': '4',
#   'photo_link': 'https://cdn16.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22339/shutterstock-1394156285jpg.jpg',
#   'ingredients': [['2 szklanki pąków mniszka lekarskiego'],
#    ['2/3 szklanki octu'],
#    ['1/3 szklanki wody'],
#    ['1 łyżeczka soli']],
#   'preparation': 'Zagotuj wodę, ocet i sól i zamieszaj, aby rozpuścić sól.\nUmyte i przebrane pąki mniszka przełóż do słoików.\nWlej gorący roztwór octu i soli.\nZamknij i przechowuj w lodówce lub pasteryzuj w kąpieli wodnej lub piekarniku przez 10 minut. Pamiętaj o pozostawieniu około 2 cm wolnej przestrzeni do krawędzi słoika.',
#   'category': 'przetwory z warzyw'},
#  {'link': 'https://beszamel.se.pl/salaty/salata-z-pomidorami-figami-i-szpinakiem-przepis,12710/',
#   'title': 'Sałata z pomidorami, figami i szpinakiem: przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn10.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/9697/salata-z-pomidorami-figami-i-szpinakiem-przepis.jpg',
#   'ingredients': [['200 g pomidorków koktajlowych (ewentualnie innych pomidorów)'],
#    ['1 opakowanie młodych liści'],
#    ['5\xa0 świeżych  pokrojonych w cząstki'],
#    ['kilka listków świeżej bazylii'],
#    ['czerwona cebula pokrojona w plastry'],
#    ['2-3 łyżki oliwy z oliwek'],
#    ['1-2 łyżki octu balsamicznego'],
#    ['szczypta soli morskiej do smaku']],
#   'preparation': 'Pomidory pokroić w cząstki i ułożyć na talerzu razem z listkami szpinaku, figami i plastrami cebuli.\nCałość skropić oliwą z oliwek oraz octem balsamicznym, oprószyć solą morską i posypać świeżo pokrojoną bazylią.\nSałatka idealnie komponuje się z serem kozim lub serem feta.',
#   'category': 'salaty'},
#  {'link': 'https://beszamel.se.pl/wegetarianskie/duszona-botwinka-zdrowa-i-pyszna-jarzynka-na-cieplo-z-lisci-buraka,22415/',
#   'title': 'Duszona botwinka: zdrowa i pyszna jarzynka na ciepło z liści buraka',
#   'portions': '4',
#   'photo_link': 'https://cdn21.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22456/duszona-botwinka-zdrowa-i-pyszna-jarzynka-na-ciep.jpg',
#   'ingredients': [['1 duży pęczek buraków (około 4-6 buraków) z bujnymi zielonymi liśćmi'],
#    ['1 łyżka oliwy z oliwek'],
#    ['2 duże ząbki czosnku, cienko krojone lub mielone'],
#    ['1 łyżeczka świeżego soku z cytryny'],
#    ['sól morska'],
#    ['świeżo zmielony pieprz']],
#   'preparation': 'Odciąć liście buraków. Same buraczki zachować na zupę lub inne danie. Najlepiej przechować w lodówce.\nLiście umyć i osuszyć w wirówce do sałaty. Pokroić w poprzek na paski szerokości 2 cm.\xa0\nNa patelni rozgrzać oliwę, dodać przeciśnięty przez praskę czosnek i smażyć 1 minutę.\nDodać liście botwiny i dusić około 3 minut, kilkukrotnie przewracając je szczypcami.\nDodać cytrynę i wymieszać. Przyprawić solą i pieprzem.\nPodawać od razu.\xa0',
#   'category': 'wegetarianskie'},
#  {'link': 'https://beszamel.se.pl/ciasta-i-desery/tiramisu-z-rabarbarem-i-truskawkami-nie-sposob-mu-sie-oprzec,22372/',
#   'title': 'Tiramisu z rabarbarem i truskawkami - nie sposób mu się oprzeć',
#   'portions': '8',
#   'photo_link': 'https://cdn6.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22417/tiramisu-z-rabarbarem-i-truskawkami-nie-sposob-m.jpg',
#   'ingredients': [['250 g truskawek'],
#    ['250 g rabarbaru'],
#    ['1 paczka biszkoptów'],
#    ['5 łyżek syropu truskawkowego'],
#    ['0,5 szklanki cukru'],
#    ['5 łyżek likieru pomarańczowego'],
#    ['0,5 kg mascarpone'],
#    ['250 g twarogu'],
#    ['2 łyżki cukru waniliowego']],
#   'preparation': 'Pokrojony na nieduże kawałki rabarbar ugotuj w niewielkiej ilości wody z dodatkiem syropu truskawkowego.\nGdy rabarbar będzie miękki, dodaj truskawki i połowę cukru, wymieszaj, gotuj jeszcze chwilkę i zdejmij z ognia. Odstaw masę do ostygnięcia.\nMascarpone zmiksuj z twarogiem i resztą cukru.\nBlaszkę lub naczynie żaroodporne wyłóż biszkoptami, ciasteczka skrop likierem. Rozsmaruj na nich połowę masy owocowej.\nNa masie owocowej rozłóż połowę masy serowej. Następnie ułóż kolejną porcję biszkoptów, masę owocową i serową.\nWierzch udekoruj truskawkami. Wstaw deser na godzinę do lodówki.',
#   'category': 'ciasta i desery'},
#  {'link': 'https://beszamel.se.pl/ryby-i-owoce-morza/rewelacyjny-pasztet-z-wedzonej-ryby,22389/',
#   'title': 'Rewelacyjny pasztet z wędzonej ryby',
#   'portions': '6',
#   'photo_link': 'https://cdn20.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22437/pasztet-z-wedzonej-ryby.jpg',
#   'ingredients': [['500 g mięsa z wędzonego pstrąga'],
#    ['3 ząbki czosnku'],
#    ['2 jajka'],
#    ['1 opakowanie serka śmietankowego typu Philadelfia'],
#    ['2 łyżki oliwy'],
#    ['2 łyżki soku z cytryny'],
#    ['1 łyżka mielonej słodkiej papryki'],
#    ['pieprz i sól'],
#    ['0,5 pęczka koperku']],
#   'preparation': 'Rybę obrać z ości i skóry i wrzucić do sporej miski.\nCzosnek obrać, przecisnąć przez praskę i wrzucić na moment na rozgrzaną oliwę.\nGdy czosnek zacznie pachnieć dodajemy go razem z oliwą z patelni do ryby.\nDodajemy także sok z cytryny, jako, ser i przyprawy. Dokładnie ucieramy mikserem.\nNa koniec dodajemy posiekany czosnek, mieszamy i przekładamy do ceramicznego naczynia do zapiekania.\nPieczemy 20 minut w 180 st.C.',
#   'category': 'ryby i owoce morza'},
#  {'link': 'https://beszamel.se.pl/zapiekanki/zapiekanka-ze-szpinakiem-przepis-na-pyszne-danie-bez-miesa,16054/',
#   'title': 'Zapiekanka ze szpinakiem: przepis na pyszne danie bez mięsa',
#   'portions': '6',
#   'photo_link': 'https://cdn28.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/zapiekanka-ze-szpinakiem.jpg',
#   'ingredients': [['8 <strong>ziemniaków</ strong>'],
#    ['2 cebule'],
#    ['2 ząbki <strong>czosnku</ strong>'],
#    ['450 g mrożonego  w liściach'],
#    ['gałka muszkatołowa'],
#    ['szczypta pieprzu'],
#    ['sól'],
#    ['koncentrat pomidorowy'],
#    ['majonez'],
#    ['suszone pomidory w oleju']],
#   'preparation': 'Ugotowane w łupinach ziemniaki obrać i pokroić w plastry.\nPosiekaną cebulę i czosnek zeszklić na oleju.\nDołożyć szpinak, wymieszać i dusić kilka minut.\nPrzyprawić do smaku.\nDo wysmarowanej olejem formy na tartę kłaść warstwy: szpinaku, ziemniaków, szpinaku.\nWierzch posmarować cienko koncentratem pomidorowym. Zapiekać około 15 minut w temperaturze 180 st. C.\nUdekorować majonezem i suszonymi pomidorami.',
#   'category': 'zapiekanki'},
#  {'link': 'https://beszamel.se.pl/warzywne/zupa-szpinakowa-zrobisz-ja-w-10-minut,16783/',
#   'title': 'Zupa szpinakowa: zrobisz ją w 10 minut!',
#   'portions': '4',
#   'photo_link': 'https://cdn27.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/shutterstock_535900651.jpg',
#   'ingredients': [['800 g świeżych liści'],
#    ['5 ziemniaków'],
#    ['2 l bulionu warzywnego'],
#    ['śmietanka do zup'],
#    ['sól, pieprz']],
#   'preparation': ' dokładnie umyć\nZiemniaki obrać i pokroić w cienkie plastry lub dość drobną kostkę\nBulion zagotować, dorzucić do niego ziemniaki i szpinak.\nGotować przez około 10 minut.\nZmiksować, doprawić do smaku.\nPodawać zupę ze śmietaną. Można ją zastąpić ricottą albo serem pleśniowym o wyrazistym smaku.',
#   'category': 'warzywne'},
#  {'link': 'https://beszamel.se.pl/salatki-z-owocami/salatka-ze-szpinakiem-mandarynka-i-granatem,16942/',
#   'title': 'Sałatka ze szpinakiem, mandarynką i granatem',
#   'portions': '3',
#   'photo_link': 'https://cdn14.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/saatka-ze-szpinakiem-klementynkami-i-granatem.JPG',
#   'ingredients': [['1/2 opakowania'],
#    ['4 mandarynki bądź klementynki'],
#    ['1/2 owocu granatu'],
#    ['1 dojrzałe awokado'],
#    ['mieszanka orzechów: włoskich, laskowych i migdałów'],
#    ['Na sos:'],
#    ['5 łyżek oliwy z oliwek'],
#    ['2 łyżeczki ostrej musztardy'],
#    ['2 łyżeczki octu balsamicznego'],
#    ['świeżo zmielony biały pieprz']],
#   'preparation': 'Liście szpinaku opłukać, wysuszyć i rozłożyć na półmisku.\nMandarynki obrać, podzielić na cząstki, awokado obrać, odpestkować, pokroić w plasterki. Rozrzucić kawałki owoców na szpinaku.\nGranat rozkroić i wyłuskać z połowy owocu pestki. Ozdobić nimi sałatkę.\nPosypać mieszanką orzechów.\nSkładniki sosu dobrze wymieszać i polać sałatkę po wierzchu tuż przed podaniem.',
#   'category': 'salatki z owocami'},
#  {'link': 'https://beszamel.se.pl/makarony/makaron-ze-szparagami-i-pieczarkami-latwy-przepis-na-obiad-w-15-minut,22441/',
#   'title': 'Makaron ze szparagami i pieczarkami: łatwy przepis na obiad w 15 minut',
#   'portions': '4',
#   'photo_link': 'https://cdn27.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22511/makaron-ze-szparagami-i-pieczarkami.jpg',
#   'ingredients': [['250 g makaronu'],
#    ['150 g szparagów, obranych, bez zdrewniałych końcówek, pokrojonych na kawałki długości około 3 cm'],
#    ['1 łyżka oleju'],
#    ['250 g pieczarek pokrojonych w plastry'],
#    ['4 dymki, pokrojone w plasterki'],
#    ['1 łyżeczka mielonego czosnku'],
#    ['180 ml bulionu warzywnego'],
#    ['180 ml śmietany 30%'],
#    ['100 g (1 szklanka) startego parmezanu'],
#    ['2-4 łyżeczki soku z cytryny lub do smaku'],
#    ['sól i świeżo zmielony czarny pieprz']],
#   'preparation': 'Ugotuj makaron zgodnie ze wskazówkami na opakowaniu. Na 4 minuty przed końcem gotowania makaronu dodaj do garnka z makaronem szparagi. Odcedź i przełóż do garnka, odstaw.\nRozgrzej olej na patelni na średnim ogniu i smaż pieczarki przez około 10 minut, aż będą miękkie.\nDodaj cebulę razem ze szczypiorem i czosnek i smaż przez 2 minuty.\nZmniejsz ogień, dodaj bulion warzywny, a następnie śmietanę i mieszaj, aż się dobrze połączą, zagotuj. Dodaj parmezan i mieszaj, aż się stopi. Dopraw sokiem z cytryny, solą i pieprzem.\nWymieszaj makaron i szparagi z zawartością patelni.\nPodawaj od razu!',
#   'category': 'makarony'},
#  {'link': 'https://beszamel.se.pl/przyprawy-i-ziola/jak-zrobic-syrop-z-kwiatow-bzu-przepis,3902/',
#   'title': 'Jak zrobić syrop z kwiatów bzu? Podajemy sprawdzony przepis',
#   'portions': '12',
#   'photo_link': 'https://cdn2.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22522/syrop-z-kwiatow-czarnego-bzu.jpg',
#   'ingredients': [['300 gr. kwiatów czarnego bzu (ok. 20 baldachów)'],
#    ['dwie cytryny'],
#    ['0,7 kg kilograma cukru'],
#    ['0,7 litra wody']],
#   'preparation': 'Zebrane baldachy odkładamy na godzinkę w cieniu - uciekną niepożądani lokatorzy, mrówki i żuki. Odcinamy ogonki i co grubsze łodygi, odrzucamy uschnięte kawałki. Zalewamy kwiaty wrzątkiem, dodajemy sok z cytryny.\nGdy przestygnie, wstawiamy do lodówki na dobę. Następnie przelewamy przez sito, dodajemy cukier, gotujemy.\nZ gotującego się płynu zbieramy pianę. Syrop przelewamy do małych słoików albo buteleczek, pasteryzujemy kwadrans.',
#   'category': 'przyprawy i ziola'},
#  {'link': 'https://beszamel.se.pl/bezy/bezowe-kaski-z-truskawkami-czyli-pavlova-na-raz,22332/',
#   'title': 'Bezowe kąski z truskawkami, czyli pavlova na raz',
#   'portions': '4',
#   'photo_link': 'https://cdn32.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22362/bezowe-kaski-z-truskawkami-czyli-pavlova-na-jeden.jpg',
#   'ingredients': [['4 białka'],
#    ['1/2 łyżeczki cream of tartar (winian potasu)'],
#    ['1 szklanka cukru'],
#    ['20 truskawek'],
#    ['listki melisy lub mięty']],
#   'preparation': 'Przygotuj dwie blaszki wykładając je papierem. Piekarnik rozgrzej do 150 st.C.\nW wysokim naczyniu ubijaj białka na wysokich obrotach.\nGdy piana będzie sztywna nie przestając miksować dodaj winian potasu, a następnie dodawaj cukier po jednej łyżce.\nKolejną łyżkę cukru dodawaj dopiero po dokładnym rozpuszczeniu poprzedniej.\nNie śpiesz się, ta część przygotowywania bezy może trwać ok. 10 min.\nGotową pianę przełóż do rękawa cukierniczego z cienką końcówką.\nBezę wyciskaj na wyłożone papierem blaszki. Najpierw wyciśnij spód o średnicy ok 3 cm, a następnie, nie odrywając końcówki uformuj boki gniazdka.\nWstaw do uprzednio nagrzanego piekarnika i przez 10 minut piecz w 150 st C., następnie na kolejne 20 minut zmniejsz temperaturę do 120 st.C.\nGdy beziki będą już gotowe (mogą być lekko złote) wyłącz piekarnik, uchyl drzwiczki i pozostaw wewnątrz na godzinę do ostygnięcia.\nPodawaj wypełnione kawałkami truskawek i listkami melisy lub mięty.',
#   'category': 'bezy'},
#  {'link': 'https://beszamel.se.pl/pasty/odzywcza-pasta-z-cukinii-cummus-hummus-z-cukinii-do-warzyw-i-pieczywa,22397/',
#   'title': 'Odżywcza pasta z cukinii: cummus (hummus) z cukinii do warzyw i pieczywa',
#   'portions': '4',
#   'photo_link': 'https://cdn12.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22445/pasta-z-cukinii-i-pomidorow.jpg',
#   'ingredients': [['4 średnie cukinie'],
#    ['3 ząbki czosnku'],
#    ['1 łyżka koncentratu pomidorowego'],
#    ['2 łyżki tahini, pasty sezamowej'],
#    ['1 łyżeczka kminku mielonego'],
#    ['1/4 szklanki świeżych liści kolendry, plus trochę do dekoracji'],
#    ['sól i czarny pieprz'],
#    ['oliwa z oliwek, w razie potrzeby w celu rozcieńczenia pasty i trochę do dekoracji']],
#   'preparation': 'Cukinię pokroić wzdłuż na plastry. Posypać solą i pieprzem, spryskać oliwą.\nCukinię grillować lub upiec.\nDo kielicha miksera lub do misy malaksera dodać upieczoną, odparowaną cukinię, pokrojony czosnek, koncentrat pomidorowy, pastę tahini, liście kolendry, mielony kminek i pieprz oraz 1/2 łyżeczki soli.\xa0\nZmiksować na gładką pastę.\xa0\nPodawać do warzyw pokrojonych w słupki lub jako smarowidło do pieczywa.\xa0',
#   'category': 'pasty'},
#  {'link': 'https://beszamel.se.pl/warzywne/botwinka-z-ziemniakami-i-jajkiem-pyszna-zupa-bez-miesa,22433/',
#   'title': 'Botwinka z ziemniakami i jajkiem: pyszna zupa bez mięsa',
#   'portions': '4',
#   'photo_link': 'https://cdn10.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22498/botwinka-z-ziemniakami-i-jajkiem.jpg',
#   'ingredients': [['1 pęczek botwinki, około 3-5 młodych buraczków z nacią'],
#    ['1\xa0 pęczek młodej cebuli ze szczypiorem'],
#    ['3 ząbki czosnku'],
#    ['1 łyżka masła'],
#    ['1 łyżka oleju'],
#    ['4-6 szklanek bulionu warzywnego'],
#    ['3 ziemniaki, średniej wielkości'],
#    ['2 szklanki zakwasu buraczanego lub soku z cytryny do smaku'],
#    ['sól i cukier'],
#    ['3 łyżki śmietany 18% lub 30%'],
#    ['4 jajka ugotowane na twardo']],
#   'preparation': 'Botwinkę pokroić, oddzielnie buraczki na plasterki, łodygi na niewielkie kawałki, liście na paseczki.\xa0\nMłodą cebulę pokroić drobno, szczypior posiekać dość drobno. Czosnek przecisnąć przez praskę.\nZiemniaki wyszorować, ewentualnie obrać. Pokroić w kostkę.\xa0\nW garnku z grubym dnem rozgrzać masło i olej. Dodać cebulę oraz buraczki i smażyć do zeszklenia cebuli.\nDodać łodygi botwiny, czosnek i smażyć jeszcze 1 minutę.\nWlać 4 szklanki bulionu warzywnego i doprowadzić do wrzenia. Jeśli będziecie używać soku z cytryny dodajcie 6 szklanek bulionu. Dodać ziemniaki i gotować na wolnym ogniu, aż będą miękkie.\nDodać liście botwiny i szczypior, zagotować. Zdjąć z ognia.\xa0\nDodać zakwas buraczany lub soku z cytryny do smaku. Po dodaniu kwasu z buraków już nie wolno gotować zupy.\xa0\nSpróbować i przyprawić solą i cukrem.\xa0\nNa koniec dodać śmietany i wymieszać.\nPodawać z jajkiem ugotowanym na twardo.\xa0',
#   'category': 'warzywne'},
#  {'link': 'https://beszamel.se.pl/mielone/mielone-z-miesa-i-ryzu-pieczone-w-sosie-pomidorowym-z-mieta-przepis-na-tani-i-pyszny-obiad,22375/',
#   'title': 'Mielone z mięsa i ryżu pieczone w sosie pomidorowym z miętą: przepis na tani i pyszny obiad',
#   'portions': '4',
#   'photo_link': 'https://cdn9.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22422/mielone-z-miesa-i-ryzu-pieczone-w-sosie-pomidorowy.jpg',
#   'ingredients': [['Na kotlety:'],
#    ['500 g mielonego mięsa drobiowego'],
#    ['100 g białego ryżu o krótkich ziarnach'],
#    ['1 cebula'],
#    ['1 jajko'],
#    ['2 łyżki posiekanej natki pietruszki'],
#    ['2 łyżki posiekanej mięty pieprzowej'],
#    ['2 ząbki czosnku'],
#    ['4 łyżki bułki tartej'],
#    ['sól i pieprz'],
#    ['Na sos pomidorowy:'],
#    ['500 ml przecieru pomidorowego'],
#    ['150 ml wody'],
#    ['1 łyżeczka oregano suszonego'],
#    ['2 łyżki posiekanej mięty pieprzowej'],
#    ['2 łyżeczki cukru'],
#    ['1 łyżeczka soli']],
#   'preparation': 'Ryż lekko rozgotować, aby stał się bardziej kleisty.\xa0\nCebulę posiekać i zrumienić na oleju.\nMięso wymieszać z wystudzonym ryżem i cebulą, przeciśniętym przez praskę czosnkiem. Następnie dodać jajko oraz natkę pietruszki i miętę. Doprawić solą i pieprzem.\xa0\nWyrabiać przez 2 minuty na jednolitą masę, uformować owalne kotlety.\xa0\nPrzecier pomidorowy przelać do rondelka, dodać przyprawy i zioła, zagotować.\nKotlety ułożyć w naczyniu do zapiekania. Polać gorącym sosem.\nWstawić do piekarnika rozgrzanego do 180°C i piec 30 minut.\nPodawać z makaronem.',
#   'category': 'mielone'},
#  {'link': 'https://beszamel.se.pl/zupy-miesne-i-rybne/pozywna-zupa-z-czerwonej-soczewicy-z-klopsikami-sprytny-przepis,22387/',
#   'title': 'Pożywna zupa z czerwonej soczewicy z klopsikami: sprytny przepis',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22435/pozywna-zupa-z-czerwonej-soczewicy-z-klopsikami-s.jpg',
#   'ingredients': [['100 g czerwonej soczewicy'],
#    ['500 g przecieru pomidorowego'],
#    ['1 l bulionu drobiowego lub warzywnego'],
#    ['1 batat, słodki ziemniak, około 100 g'],
#    ['1 cebula'],
#    ['6 ząbków czosnku'],
#    ['1 cm świeżego imbiru'],
#    ['3 łyżki oleju'],
#    ['przyprawy: 1 łyżeczka kurkumy, 2 łyżeczki przyprawy curry w proszku, 1/2 łyżeczki ostrej papryki'],
#    ['sól i pieprz'],
#    ['100 ml pełnotłustego mleka kokosowego'],
#    ['300 g mięsa drobiowego']],
#   'preparation': 'W garnku z grubym dnem rozgrzać olej. Dodać starty imbir, posiekaną cebulę i przeciśnięty przez praskę czosnek oraz przyprawy. Smażyć 2 minuty.\nDodać starty batat (słodki ziemniak). Dusić 2-4 minuty.\nWlać bulion i dodać soczewicę. Doprowadzić do wrzenia, a następnie gotować na wolnym ogniu przez 20 minut.\xa0\nDodać przecier pomidorowy i mleczko kokosowe. Zagotować.\nZ mielonego mięsa wyrobionego z 4 łyżkami wody uformować klopsiki wielkości orzecha. Dodać je do gotującej zupy. Przykryć pokrywką i gotować 5 minut.\nPodawać od razu z kromką chrupiącego pieczywa.\xa0',
#   'category': 'zupy miesne i rybne'},
#  {'link': 'https://beszamel.se.pl/rolady/rolada-biszkoptowa-z-kremem-twarozkowym-i-truskawkami,22440/',
#   'title': 'Rolada biszkoptowa z kremem twarożkowym i truskawkami',
#   'portions': '4',
#   'photo_link': 'https://cdn1.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22510/rolada-biszkoptowa-z-kremem-twarozkowym-i-truskawk.jpg',
#   'ingredients': [['Na krem:'],
#    ['100-150 g twarogu według przepisu na Domowy twaróg z mleka kwaśnego i słodkiego'],
#    ['1-2 łyżki śmietany, jeśli ser jest zbyt suchy'],
#    ['2-4 łyżki słodzonego mleka skondensowanego'],
#    ['50 g masła, miękkiego, w temperaturze pokojowej'],
#    ['1 łyżeczka ekstraktu waniliowego lub 2 łyżeczki cukru wanilinowego'],
#    ['1/6 łyżeczki soli (tajny składniki, który reguluje równowagę słodyczy)'],
#    ['Na biszkopt:'],
#    ['2 jajka rozmiar M'],
#    ['50 g mąki'],
#    ['50 g cukru'],
#    ['30 g masła, stopionego i przestudzonego'],
#    ['1/6 łyżeczki soli'],
#    ['oraz'],
#    ['4-6 łyżek dżemu truskawkowego, podgrzanego, aby się nieco rozpuścił'],
#    ['1 łyżka cukru pudru'],
#    ['6-8 truskawek do dekoracji']],
#   'preparation': 'Należy zacząć od kremu twarożkowego. Twaróg przetrzeć przez sito, albo przecisnąć przez praskę do ziemniaków.\nDo rozdrobnionego twarogu, jeśli jest suchy dodać śmietany i wymieszać.\nDo masy twarogowej dodać mleko skondensowane, sól i wanilię, ubić wszystko na jednorodną masę.\nOddzielnie utrzeć masło i dodać do twarogu, ubić wszystko razem. Wstawić do lodówki.\nPora na biszkopt. Rozgrzać piekarnik do 220°C. Żółtka oddzielić od białka. Do żółtek dodać cukier i utrzeć lub ubić mikserem na jednorodną, puszystą masę.\nOddzielnie ubić białka ze szczyptą soli. Piana powinna być sztywna.\nDo żółtek dodać mąkę i stopione masło. Wymieszać. W 2-3 porcjach dodać ubitą pianę z białek, delikatnie wmieszać w ciasto.\nBlachę do pieczenia wyłożyć papierem do pieczenia. Na blachę wyłożyć ciasto, wyrównać. Piec 10 minut.\nGdy biszkopt się piecze, przygotować ściereczkę tych samych rozmiarów, co blacha. Ściereczkę lekko zwilżyć.\nUpieczony biszkopt wyłożyć na ściereczkę, spodem do góry, zdjąć papier do pieczenia. Zwinąć razem ze ściereczką w zgrabną roladę. Pozostawić do całkowitego ostygnięcia.\nGdy biszkopt jest już wystudzony, rozwinąć go, posmarować podgrzanym dżemem truskawkowym. Na to położyć krem i rozsmarować go po całej powierzchni.\nPonownie zwinąć roladę. Wstawić do lodówki co najmniej na 1 godzinę.\nPrzed podaniem oprószyć cukrem pudrem i udekorować połówkami świeżych truskawek.',
#   'category': 'rolady'},
#  {'link': 'https://beszamel.se.pl/ciasta-i-desery/kwiaty-czarnego-bzu-w-ciescie-przepis-na-jadalne-kwiaty,4254/',
#   'title': 'Kwiaty czarnego bzu w cieście - przepis na jadalne kwiaty',
#   'portions': '4',
#   'photo_link': 'https://cdn4.beszamel.smcloud.net/t/thumbs/660/441/1/recipes/photo/kwiaty-czarnego-bzu-w-ciescie-przepis-na-jadalne-kwiaty.jpg',
#   'ingredients': [['15 kwiatów czarnego bzu'],
#    ['2 jajka'],
#    ['2 szklanki mleka'],
#    ['1/2 szklanki mąki'],
#    ['szczypta soli'],
#    ['1/2 łyżeczki proszku do pieczenia'],
#    ['tłuszcz do smażenia'],
#    ['cukier puder do posypania']],
#   'preparation': 'Kwiaty czarnego bzu zerwać w czystym miejscu, pozostawić na kwadrans rozłożone, by wyszli z nich niepożądani goście \xa0- nie myć.\nW tym czasie przygotować ciasto - można użyć miksera.\nKwiaty zanurzać w cieście i smażyć na rozgrzanym tłuszczu.\nLekko zrumienić placuszki, podawać ciepłe posypane cukrem pudrem.',
#   'category': 'ciasta i desery'},
#  {'link': 'https://beszamel.se.pl/mielone/indycze-mielone-z-kukurydza-sprytny-przepis-na-pieczone-kotlety-z-indyka,22379/',
#   'title': 'Indycze mielone z kukurydzą: sprytny przepis na pieczone kotlety z indyka',
#   'portions': '4',
#   'photo_link': 'https://cdn11.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/22426/indycze-mielone-z-kukurydza-sprytny-przepis-na-pi.jpg',
#   'ingredients': [['500 g mielonego mięsa indyczego'],
#    ['1 bułka'],
#    ['1 cebula'],
#    ['1 puszka kukurydzy konserwowej'],
#    ['2 łyżki natki pietruszki, posiekanej'],
#    ['sól i pieprz'],
#    ['oraz do panierowania'],
#    ['2 jajka rozmiar S rozmącone z 2 łyżkami wody'],
#    ['mąka'],
#    ['tarta bułka']],
#   'preparation': 'Cebulę drobno posiekać. Bułkę namoczyć w ciepłej wodzie. Kukurydzę odsączyć.\xa0\nMięso mielone przełożyć do miski, dodać posiekaną cebulę, odciśniętą bułkę, przyprawić solą i pieprzem. Wymieszać, a następnie wyrabiać przez 2 minuty.\nDo masy mięsnej dodać odsączoną kukurydzę. Wymieszać na jednorodną mieszaninę.\xa0\nZ masy mięsnej formować jednakowe okrągłe kotlety, lekko je spłaszczyć.\nKotlety panierować w mące, rozmąconym jajku i bułce.\nKotlety ułożyć na blasze wyłożonej papierem do pieczenia.\nWstawić do piekarnika rozgrzanego do 180°C i piec 30 minut.\xa0\nPodawać z sałatką z pomidorów i papryki w stylu meksykańskim.\xa0',
#   'category': 'mielone'},
#  {'link': 'https://beszamel.se.pl/soki/sok-z-kwiatow-czarnego-bzu-sprawdzona-receptura,2923/',
#   'title': 'Sok z kwiatów czarnego bzu - sprawdzona receptura',
#   'portions': '9',
#   'photo_link': 'https://cdn9.beszamel.smcloud.net/t/thumbs/660/441/1/user_photos/elder-2381616_1920.jpg',
#   'ingredients': [['45 baldachów kwiatów bzu czarnego'],
#    ['2 cytryny'],
#    ['skórka z 2 cytryn'],
#    ['2 płaskie łyżeczki kwasku cytrynowego'],
#    ['1,5 l przegotowanej wody'],
#    ['750 g cukru']],
#   'preparation': 'Do słoika włożyć oczyszczone kwiaty bzu, przekładając je cytryną i skórką z cytryny. Wsypać kwasek cytrynowy i zalać chłodną, przegotowaną wodą. Słoik przykryć i odstawić w ciepłe, ciemne miejsce na 2 dni.\nPo upływie tego czasu odcedzić, kwiaty bzu czarnego wycisnąć. Do powstałego soku wsypać cukier, zamieszać i przelać do słoików. Szczelnie zakręcić, pasteryzować ok. 15 minut.\nTak przyrządzone przetwory umieścić w zacienionym, chłodnym miejscu.\xa0Bez pasteryzacji sok z kwiatów bzu można krótko przechowywać w lodówce.',
#   'category': 'soki'},
#  {'link': 'https://kkpolska.pl/przepis/69/zapiekany_filet_z_kurczaka_z_prazona_cebulka.html',
#   'title': 'Zapiekany filet z kurczaka z prażoną cebulką',
#   'portions': 0,
#   'photo_link': 'images/przepisy/zapiekany.jpg',
#   'ingredients': [['1 podwójny filet z kurczaka'],
#    ['5 łyżek oleju'],
#    ['200 g prażonej cebulki'],
#    ['przyprawa do drobiu'],
#    ['przyprawy: sól, pieprz, papryka']],
#   'preparation': '1. Filet z kurczaka dokładnie umyć i osuszyć. Podzielić na mniejsze kawałki (według uznania).\r\n2. Mięso rozbić delikatnie tłuczkiem owiniętym w folie.\r\n3. Rozbite mięso połączyć ze wszystkimi wybranymi przyprawami z obu stron, przykryć folią spożywczą i odstawić na bok.\r\n4. Na duży talerz wlać olej. Stronę, która ma być na wierzchu namoczyć obficie w oleju.\r\n5. Blachę do pieczenia wyłożyć papierem do pieczenia i ułożyć na niej mięso suchą stronę do dołu.\r\n6. Wierzch mięsa posypać obficie cebulką prażoną.\r\n7. Blachę wstawić do nagrzanego do 180 stopni piekarnika i zapiekać przez ok. 30 minut.\n\xa0\nUWAGA! Filet znakomieci smakuje z sałatką i frytkami.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/160/ryz_cytrynowo_-_mietowy_na_mleku_z_truskawkami_.html',
#   'title': 'Ryż cytrynowo - miętowy na mleku z truskawkami ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/p6166512.jpg',
#   'ingredients': [['250 g ryżu kleistego'],
#    ['1 litr mleka'],
#    ['100 g cukru'],
#    ['kilka liści mięty'],
#    ['1 x cytryna'],
#    ['1 szczypta soli'],
#    ['500 g truskawek świeżych'],
#    ['5 kostek czekolady gorzkiej']],
#   'preparation': 'Cytrynę wyszorować, ściąć z niej skórkę. Do garnka wlać mleko, wrzucić skórkę cytrynową i miętę. Gotować na wolnym ogniu do 10 minut, pilnować, by mleko nie wykipiało. Odcedzić na sicie i wlać ponownie do garnka, dodać cukier i zagotować. Ryż przepłukać na sicie i dodać do gotującego się mleka. Gotować na małym ogniu, często mieszać, ryż należy tak długo gotować, aż będzie miękki i kleisty.\xa0Truskawki umyć, odszypułkować, można pokroić w części. Do pucharków nakładać warstwę ryżu, truskawki, ryż i truskawki, górę deseru posypać startą gorzką czekoladą. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/134/roladki_z_tortilli_z_tunczykiem_i_jalapeno.html',
#   'title': 'Roladki z tortilli z tuńczykiem i Jalapeno',
#   'portions': 0,
#   'photo_link': 'images/przepisy/roladki_z_tortilli_01.jpg',
#   'ingredients': [['3 duże placki tortilli pszennej'],
#    ['1 słoik tuńczyka w oliwie'],
#    ['150 g kukurydzy'],
#    ['4 łyżki posiekanego szczypiorku'],
#    ['300 g marynowanych ostrych papryczek'],
#    ['150 g tartej mozzarelli lub sera żółtego'],
#    ['4 łyżki majonezu'],
#    ['2 łyżeczki musztardy']],
#   'preparation': 'Tuńczyka nieco odsączyć z oliwy, włożyć do miski, dodać odsączoną kukurydzę, posiekany szczypiorek, posiekane ostre papryczki, starty ser, majonez i musztardę. Doprawić solą i pieprzem, wymieszać. Rozsmarować na 3 tortillach, zwinąć w roladkę i pokroić na około 2 - 3 cm kawałki. Ułożyć na półmisku i udekorować natką. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/136/pikantna_salsa_pomidorowa.html',
#   'title': 'Pikantna salsa pomidorowa',
#   'portions': 0,
#   'photo_link': 'images/przepisy/salsa_do_chipsow_nachos_01.jpg',
#   'ingredients': [['400 g (puszka) krojonych pomidorów'],
#    ['1/4 zielonej papryki'],
#    ['2 łyżki marynowanej papryczki jalapeño'],
#    ['1/2 łyżeczki sproszkowanego czosnku'],
#    ['sól'],
#    ['pieprz'],
#    ['2 łyżki cukru'],
#    ['3 łyżki octu spirytusowego'],
#    ['2 cebulki szalotki'],
#    ['1 łyżeczka mąki ziemniaczanej'],
#    ['łyżka posiekanej kolendry']],
#   'preparation': '1. Do rondelka włożyć pomidory z puszki wraz z całą zalewą, dodać pokrojoną w małą kosteczkę zieloną paprykę, odcedzoną i posiekaną jalapeño, czosnek, szczyptę soli i szczyptę pieprzu, cukier oraz ocet.\r\n2. Zagotować, następnie gotować bez przykrycia przez około 10 minut, co chwilę mieszając.\r\n3. Dodać obraną i drobno posiekaną cebulkę i gotować jeszcze przez 2 minuty.\r\n4. Na koniec dodać mąkę ziemniaczaną (przez sitko), wymieszać i zagotować.\r\n5. Ostudzić przed podaniem. Dodać kolendrę. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/139/jajecznica_z_tofu.html',
#   'title': 'Jajecznica z tofu',
#   'portions': 0,
#   'photo_link': 'images/przepisy/jajecznica-tofu-awokado-01.jpg',
#   'ingredients': [['200 g tofu'],
#    ['2 porcje rukoli'],
#    ['1 awokado'],
#    ['sól'],
#    ['świeżo zmielony pieprz'],
#    ['oliwa extra virgine'],
#    ['sok z cytryny'],
#    ['2 łyżki masła'],
#    ['3 jajka'],
#    ['1 łyżka posiekanego szczypiorku'],
#    ['grzanki z chleba żytniego posmarowane masłem']],
#   'preparation': 'Tofu wyjąć z opakowania i odsączyć z wody jeśli jest wilgotne i bardzo miękkie. Rukolę opłukać, osuszyć i ułożyć na dwóch talerzykach. Awokado obrać, pokroić na kawałki, położyć na rukoli, skropić sokiem z cytryny, doprawić solą, pieprzem i polać oliwą extra vergine. W tosterze zrobić grzanki z chleba i po ostudzeniu posmarować masłem. Tofu pokroić w kosteczkę. Posypać solą, pieprzem i położyć na patelni z rozgrzanym masłem. Smażyć na niedużym ogniu przez około 1 - 2 minuty z każdej strony (jeśli chcemy, możemy je smażyć aż do zrumienienia). Tofu przesunąć na bok patelni, a w wolne miejsce wbić jajka, delikatnie zamieszać, doprawić solą, pieprzem i szczypiorkiem. Gdy jajka się zetną od razu odstawić patelnię z ognia. Zawartość patelni przełożyć na sałatkę z rukoli i awokado. Podawać z grzankami.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/156/_bezglutenowe_muffinki_z_orzechow_nerkowca_migdalow_i_prazonych_jablek.html',
#   'title': ' Bezglutenowe Muffinki z orzechów nerkowca, migdałów i prażonych jabłek',
#   'portions': 0,
#   'photo_link': 'images/przepisy/muffinki.jpg',
#   'ingredients': [['340 g mąki z orzechów (nerkowce i migdały)'],
#    ['1 łyżka cynamonu cejlońskiego'],
#    ['2 łyżeczki sody oczyszczonej / lub proszku do pieczenia'],
#    ['szczypta soli himalajskiej / lub morskiej'],
#    ['20-30 g cukru palmowego'],
#    ['175 g musu jabłkowego'],
#    ['50 g oleju rzepakowego'],
#    ['2 jajka'],
#    ['1 łyżeczka cukru waniliowego']],
#   'preparation': 'Do mąki z orzechów i migdałów dodać cynamon, sól, sodę, wymieszać. W osobnej misce zmiksować mus jabłkowy, jajka oraz cukier waniliowy, dodać mąkę wymieszaną wcześniej z cynamonem, solą i sodą, wymieszać. Ciasto przelać do foremek na Muffinki (do ok ¾ wysokości foremki). Piec w temperaturze 180 stopni C (grzałka góra-dół) przez ok. 25 min',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/157/smazony_ryz_kleisty_z_kurczakiem_i_olejem_sezamowym.html',
#   'title': 'Smażony ryż kleisty z kurczakiem i olejem sezamowym',
#   'portions': 0,
#   'photo_link': 'images/przepisy/ryz-kleisty-z-kurczakiem.jpg',
#   'ingredients': [['2 ćwiartki z kurczaka'],
#    ['500 g ryżu kleistego Q Rice'],
#    ['15 g imbiru'],
#    ['10 g smażonej cebuli'],
#    ['5 g jagód goji'],
#    ['2 łyżki oleju sezamowego'],
#    ['2 łyżki sosu sojowego'],
#    ['1/2 łyżeczki soli'],
#    ['1 łyżka oleju do smażenia'],
#    ['2 łyżki chińskiej wódki ryżowej / lub polskiej czystej wódki'],
#    ['300 ml wody']],
#   'preparation': 'Ryż przygotować według instrukcji na opakowaniu. Umyć kurczaka, usunąć kości i zbędne żyłki tłuszczu, osuszyć ręcznikiem papierowym, następnie delikatnie naciąć mięso na całej powierzchni (od strony wewnętrznej - nie od strony skóry), w ten sposób mięso na całej powierzchni będzie równej grubości. \n* Można wykorzystać mięso z indyka, które już jest bez kości. Należy pamiętać, by mięso nie było zbyt grube. \nImbir umyć, pokroić ze skórą na bardzo cienkie plasterki. Goję wymoczyć w ciepłej wodzie. \nRozgrzać patelnię, smażyć kurczaka do uzyskania złocistego koloru (smażyć obie strony), zdjąć kurczaka z patelni i pokroić na małe kawałki. Na patelnię wlać olej do smażenia (jeśli po smażeniu\xa0 kurczaka zostało wystarczająco dużo oleju do smażenia imbiru, to nie trzeba dolewać), rozgrzać, jak olej będzie ciepły, wrzucić imbir do smażenia, w tym czasie zmniejszyć ogień i spokojnie smażyć imbir, aż uzyska złocisty kolor (to jest bardzo ważny krok, ponieważ na tym polega cała sztuka w tym daniu). Włożyć kurczaka na patelnię, dolać olej sezamowy, wymieszać dokładnie, dolać wodę, przykryć pokrywką i dusić kurczaka przez 5 minut. Następnie odkryć pokrywkę, żeby woda trochę wyparowała (jeśli okazało się, że woda całkowicie już wyparowała, trzeba dolać 3 łyżki, żeby się nie przypaliło). Dodać smażoną cebulę, wymieszać dokładnie, wlać sos sojowy, wymieszać i próbować czy potrawa jest wystarczająco słona, jeśli nie - dosolić. Dolać wódkę, wymieszać i dodać jagody goji oraz ryż kleisty ugotowany, staranie wymieszać wszystkie składniki, żeby kawałki kurczaka były równomiernie wymieszane z ryżem. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/158/ryz_kleisty_na_mleczku_kokosowym_z_mango.html',
#   'title': 'Ryż kleisty na mleczku kokosowym z Mango',
#   'portions': 0,
#   'photo_link': 'images/przepisy/6487cf136b86-b0f4c2f7e3-kw_04_13892_s_163758_rgb_kokosowy_pudding_ryzowy_z_mango.jpg',
#   'ingredients': [['1 szklanka ryżu kleistego'],
#    ['400 ml mleczka kokosowego'],
#    ['sok wyciśnięty z 1 limonki'],
#    ['skórka starta z 1 limonki'],
#    ['4 łyżki cukru trzcinowego'],
#    ['1 x laska wanilii'],
#    ['1 x mango'],
#    ['kilka listków świeżej mięty'],
#    ['3 łyżki białego sezamu']],
#   'preparation': 'Ryż ugotować zgodnie z instrukcją na opakowaniu.\xa0Mleczko kokosowe zagotować w rondelku z cukrem, przekrojoną wzdłuż na pół laską wanilii, sokiem wyciśniętym z limonki i skórką startą z limonki. Pod koniec gotowania usunąć laskę wanilii. Ugotowany ryż zalać gorącym, przyprawionym mleczkiem i dokładnie mieszać, aż składniki się połączą. Miskę z ryżem owinąć folią spożywczą i umieścić pod ręcznikiem lub kocem na około godzinę, by ryż wchłonął cały płyn.\xa0Gotowy ryż rozłożyć do miseczek i podawać – na ciepło lub na zimno – z pokrojonym w kostkę mango, podprażonym sezamem oraz listkami świeżej mięty. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/50/puree_z_mango_z_kruszonym_ciastem.html',
#   'title': 'Puree z mango z kruszonym ciastem',
#   'portions': 0,
#   'photo_link': None,
#   'ingredients': [['75 g masła'],
#    ['75 g mąki orkiszowej'],
#    ['400 ml bitej śmietany'],
#    ['1 laska wanilii'],
#    ['1 szklanka puree z mango'],
#    ['opcjonalnie: owoce do dekoracji (np. truskawki, ananas, kiwi)']],
#   'preparation': '1. W misce wymieszać dokładnie masło, mąkę oraz cukier (najlepiej zrobić to dłońmi).\r\n2. Blachę wyłożyć papierem pergaminowym, następnie wyłożyć ciasto na blachę.\r\n3. Piekarnik rozgrzać do temperatury 200\xa0 stopni Celcjusza.\r\n4. Ciasto piec w piekarniku przez około 15-20 minut, następnie ostudzić, a puree z mango wymieszać z wanilią.\r\n5. Na dnie pucharka/słoiczka wsypać pokruszone ciasto, następnie dodać puree z mango, przykryć bitą śmietaną.\r\n6.\xa0Całość ewentualnie udekorować świeżymi owocami lub kruszonym ciastem, jeśli nie zostało wykorzystane w całości.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/111/zupa_z_pieczonego_kalafiora_i_kalarepy_z_mleczkiem_kokosowym_.html',
#   'title': 'Zupa z pieczonego kalafiora i kalarepy z mleczkiem kokosowym ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/zupa_kalafior_mleczko.jpg',
#   'ingredients': [['700 g kalafiora'],
#    ['2 średnie ziemniaki'],
#    ['2 kalarepy'],
#    ['1 cebula'],
#    ['2 ząbki czosnku'],
#    ['kmin rzymski'],
#    ['kolendra'],
#    ['sól'],
#    ['pieprz'],
#    ['oliwa extra virgin'],
#    ['1 litr bulionu'],
#    ['250 ml mleczka kokosowego']],
#   'preparation': '1. Piekarnik nagrzać do\xa0190 stopni C. Dużą blachę z wyłożyć papierem do pieczenia.\r\n2. Kalafiora pokroić na różyczki, ziemniaki obrać i pokroić w kosteczkę, kalarepki obrać i pokroić na kawałki, cebulę obrać i pokroić w większą kostkę, czosnek obrać i przepołowić.\r\n3. Warzywa włożyć do miski, doprawić solą, pieprzem, posypać łyżeczką kminu rzymskiego, dodać pół łyżeczki kolendry oraz skropić 2 łyżkami oliwy, wymieszać, wyłożyć na blaszkę. Piec przez\xa040 minut.\r\n5. Wszystkie upieczone warzywa włożyć do garnka, zalać gorącym bulionem i zagotować. Gotować przez około 3 minuty, następnie zmiksować z dodatkiem mleczka.\r\n6. Przelać do garnka, dodać około 2 łyżeczek kminu rzymskiego (lub więcej, zależnie od preferencji) i wymieszać. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/94/zielona_herbata_z_dodatkiem_napoju_mango_.html',
#   'title': 'Zielona herbata z dodatkiem napoju Mango ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/mangotea.png',
#   'ingredients': [['200 ml Rubicon Deluxe Napój Mango'],
#    ['100 ml zielonej herbaty'],
#    ['kilka kostek lodu'],
#    ['*świeże mango i kilka listków mięty do dekoracji']],
#   'preparation': 'Szklankę typu highball (long) napełnić lodem, dodać napój mango oraz zieloną herbatę i wymieszać. Dodać liście mięty oraz plaster świeżego mango do dekoracji. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/12/zielona_paste_curry_z_poledwica_wolowa.html',
#   'title': 'Zieloną pastę curry z polędwicą wołową',
#   'portions': 0,
#   'photo_link': None,
#   'ingredients': [['15 ml oleju do woka Thai Pride'],
#    ['40 g zielonej pasty curry Thai Pride'],
#    ['40 ml wody'],
#    ['60 g bakłażana'],
#    ['150 g polędwicy wołowej'],
#    ['160 ml mleczka kokosowego Diamond'],
#    ['20 g liści bazylii'],
#    ['5 g czerwonej papryczki chili']],
#   'preparation': '1. Polędwicę wołową pokroić w plastry i obsmażyć na rozgrzanym woku.\r\n2. Dodać zieloną pastę curry i wymieszać z mięsem.\r\n3. Następnie dodać wodę i zagotować.\r\n4. Pokroić bakłażana w plastry, dodać go do woka wraz z mleczkiem kokosowym, całość ponownie zagotować.\r\n5. Gotowe danie udekorować liśćmi bazyli oraz papryką chili.\r\n6. Danie można podawać z ryżem, makaronem ryżowym bądź z makaronem sojowym',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/129/zupa_z_pora_z_makaronem_udong.html',
#   'title': 'Zupa z pora z makaronem Udong',
#   'portions': 0,
#   'photo_link': 'images/przepisy/udon_pory.jpg',
#   'ingredients': [['2 większe pory (tylko białe części)'],
#    ['30 dag piersi z kurczaka'],
#    ['15 dag makaronu udong'],
#    ['4 szklanki bulionu mięsnego'],
#    ['2 łyżki masła'],
#    ['4 łyżki jasnego sosu sojowego'],
#    ['1 łyżeczka cukru'],
#    ['cytryna']],
#   'preparation': 'Cytrynę dokładnie wyszorować, ściąć ostrym nożem cienką skórkę i pokroić na cieniutkie paseczki. Z owocu wycisnąć sok. Pory dokładnie umyć pod bieżącą wodą i pokroić na cienkie, ukośne plasterki. Mięso kurczaka pokroić na cienkie paski. Zagotować 2 litry osolonej wody. Włożyć do niej makaron, zamieszać, doprowadzić do wrzenia i gotować 5 minut. Odcedzić, przelać zimną wodą, następnie przetrzeć dłonią. W rondlu rozgrzać masło, wrzucić pory i smażyć cały czas mieszając przez 3-4 minuty, aż się lekko zeszklą. Dodać sos sojowy, cukier i sok z cytryny. Wlać wrzący bulion, wrzucić mięso, zamieszać i gotować na średnim ogniu 10-15 minut, aż mięso i pory będą miękkie. Do ugotowanej zupy dodać makaron. Podawać ze skórką cytrynową. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/148/zupa_fasolowa.html',
#   'title': 'Zupa fasolowa',
#   'portions': 0,
#   'photo_link': 'images/przepisy/fasolowa_01_0.jpg',
#   'ingredients': [['250 g fasoli białej'],
#    ['500 g żeberek wieprzowych'],
#    ['250 g wędzonego boczku'],
#    ['2 marchewki'],
#    ['1 pietruszka'],
#    ['kawałek selera'],
#    ['3 ziela angielskie'],
#    ['1 listek laurowy'],
#    ['1 duża cebula'],
#    ['1 ząbek czosnku'],
#    ['3 - 4 ziemniaki'],
#    ['1 łyżka majeranku']],
#   'preparation': 'Odcedzić fasolę. Do dużego garnka włożyć pokrojone na 2 - 3 kawałki żeberka, wlać 2,5 litra wody, dodać fasolę oraz łyżeczkę soli. Zagotować, zszumować, zmniejszyć ogień i gotować pod przykryciem przez około 1 godzinę i 15 minut. Dodać 1 obraną marchewkę (drugą obrać, zetrzeć na tarce o dużych oczkach i odłożyć na później), obraną pietruszkę, kawałek korzenia selera oraz ziela angielskie i listek laurowy. Gotować przez 15 minut. Odkroić skórkę z boczku, wykroić białe chrząstki, pokroić w kosteczkę. Włożyć na patelnię i co chwilę mieszając podsmażyć na złoty kolor. Dodać pokrojoną w kosteczkę cebulę i mieszając smażyć przez 5 minut. Pod koniec dodać rozgnieciony czosnek. Przełożyć do garnka z wywarem wypłukując patelnię częścią wywaru. Do zupy dodać startą marchewkę, doprawić świeżo zmielonym pieprzem i w razie potrzeby solą. Gotować 10 minut. Ziemniaki obrać i pokroić w kosteczkę, dodać do zupy. Gotować przez 0,5 godziny. Na koniec dodać majeranek i chwilę gotować.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/54/zupa_ansungtangmyun_cioppino.html',
#   'title': 'Zupa AnSungTangMyun Cioppino',
#   'portions': 0,
#   'photo_link': None,
#   'ingredients': [['1 paczka zupy AnSungTangMyun'],
#    ['50 g pasty do sosów Barilla Arabiata'],
#    ['8 g bazy do zupy w proszku'],
#    ['100 g małży z krótkimi szyjkami (4 szt.)'],
#    ['100 g małży (4 szt.)'],
#    ['20 g mątwy'],
#    ['60 g krewetek (3 szt.)'],
#    ['2 g ostrej papryczki chili (1/4 szt.)'],
#    ['6 pomidorków koktajlowych'],
#    ['1 cały ząbek czosnku'],
#    ['18 ml białego wina'],
#    ['8 ml oliwy z oliwek'],
#    ['300 ml wody'],
#    ['natka pietruszki']],
#   'preparation': '1. Umyj małże w słonej wodzie i ugotowuj je. Przykryj pokrywką lub umieść je w miejscu z dala od światła słonecznego.\r\n2. Usuń skórkę z pomidorów koktajlowych i pokrój je na 4 równe części, a następnie posiekaj na kawałki o grubości 2 mm.\r\n3. Umyj i pokrój ostrą papryczkę i czosnek.\r\n4. Umyj i obierz krewetki. Wytnij mątwy w rozmiarze 1,5 x 6 cm.\r\n5. Nasmaruj garnek oliwą z oliwek. Podsmaż zmiażdżony czosnek i ostrą paprykę, a następnie smaż wszystko na małym ogniu przez około 1,5 minuty (aż poczujesz zapach).\r\n6. Usmaż małże, małże krótkoszyjne, mątwe i krewetki na dużym ogniu. Gdy małże się otworzą dodaj białe wino i smaż jeszcze przez 1 minutę.\r\n7. Dodaj 2 pomidorki cherry i sos Barilla Arabiata, a następnie smaż przez kolejną minutę.\r\n8. Gdy alkohol odparuje, wlej wodę (300ml) i zagotuj. Dodaj zupę AnSungTangMyun i bazę do zupy w proszku, gotuj przez 4 minuty.\r\n9. Przelej zupę do miski i polej oliwą, \xa0następnie pokrojoną natką pietruszki.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/150/zupa_fasolowa_z_pesto.html',
#   'title': 'Zupa fasolowa z pesto',
#   'portions': 0,
#   'photo_link': 'images/przepisy/fasolowa_z_pesto02.jpg',
#   'ingredients': [['1 szklanka fasoli'],
#    ['500 - 600 ml bulionu drobiowego lub jarzynowego'],
#    ['2 średnie marchewki, obrane i pokrojone w cienkie plasterki'],
#    ['1 łyżka oliwy z oliwek'],
#    ['1 średnia cebula, pokrojona w drobną kosteczkę'],
#    ['2 łyżki mąki pszennej'],
#    ['sól'],
#    ['świeżo zmielony czarny pieprz'],
#    ['Pesto:  • garść rukoli lub bazylii'],
#    ['3 łyżki tartego parmezanu / lub grana padano'],
#    ['1 łyżeczka orzeszków pinii / lub pestek dyni'],
#    ['4 łyżki oliwy z oliwek extra virgin'],
#    ['1/2 małego ząbka czosnku'],
#    ['sól'],
#    ['pieprz']],
#   'preparation': 'W garnku zagotować 500 ml bulionu i dodać marchewkę, ugotować ją do miękkości. Na małej patelni na oliwie zeszklić cebulę, dodać mąkę i chwilę razem podsmażyć mieszając. Zdjąć z ognia i dolewać po jednej łyżce bulionu (w sumie około 10 - 15 łyżek), mieszając aż mąka się w nim rozprowadzi. Zawartość patelni wlać do garnka z bulionem i marchewką, następnie dodać\xa0 fasolkę wraz z częścią zalewy. Zupę zagotować i doprawić solą oraz pieprzem. \nPesto: Zmiksować wszystkie składniki blenderem lub utrzeć w moździerzu. \nFasolową podawać gorącą, skropioną pesto i z dodatkiem pieczywa. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/77/salatka_azjatycka_z_makaronem.html',
#   'title': 'Sałatka azjatycka z makaronem',
#   'portions': 0,
#   'photo_link': 'images/przepisy/salatka.jpg',
#   'ingredients': [['200 g makaronu wieloziarnistego Bali Kitchen'],
#    ['2 łyżki oleju arachidowego'],
#    ['50 g fasoli czerwonej'],
#    ['50 g liści sałaty'],
#    ['1/2 papryki czerwonej pokrojonej w kostkę'],
#    ['50 g wędzonego, smażonego Tofu (w paski)'],
#    ['2 łyżki Mirinu'],
#    ['2 łyżki sosu sojowego słodkiego'],
#    ['1 łyżeczka imbiru w proszku'],
#    ['według uznania: odrobina soku z limetki / sól / pieprz']],
#   'preparation': '1. Makaron przygotować według sposobu przyrządzania podanego na opakowaniu.\r\n2. Wszystkie składniki wymieszać razem i według gustu przyprawić solą, pieprzem i sokiem z limetki.\r\n3. Gotowe!',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/41/wolowina_z_czosnkiem_i_pedami_bambusa.html',
#   'title': 'Wołowina z czosnkiem i pędami bambusa',
#   'portions': 0,
#   'photo_link': 'images/przepisy/wolowina_czosnek.jpg',
#   'ingredients': [['400 g chudej wołowiny'],
#    ['6 ząbków czosnku'],
#    ['250 g pędów bambusa'],
#    ['4 łyżki ciemnego sosu sojowego'],
#    ['3 łyżki oleju'],
#    ['1 łyżka mąki ziemniaczanej'],
#    ['3 łyżki sezamu białego'],
#    ['3 łyżki szczypiorku']],
#   'preparation': '1. Mięso opłukać, osuszyć, pokroić na cienkie paseczki.\r\n2. Czosnek obrać. 4 ząbki pokroić w cienkie plasterki, dodać do mięsa, zalać sosem sojowym, odstawić na 2 godziny. 2 pozostałe ząbki czosnku rozetrzeć.\r\n3. Rozgrzać olej na patelni, obsmażyć mięso, zmniejszyć ogień, dodać odsączone pędy bambusa, utarty czosnek, kilka łyżek wody. Dusić kilka minut.\r\n4. Mąkę wymieszać dokładnie ze szklanką wody i dodać do mięsa.\r\n5. Dusić wszystko razem kilka minut, jeśli istnieje taka potrzeba podlać niewielką ilością wody, doprawić sosem sojowym.\r\n6. Posypać uprażonymi nasionami sezamu i posiekanym szczypiorkiem.\n\xa0\nDanie podawać z ryżem lub z makaronem szklistym.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/9/tajwanska_herbata_z_tapioki_-_bubble_tea.html',
#   'title': 'Tajwańska herbata z tapioki - Bubble Tea',
#   'portions': 0,
#   'photo_link': 'images/przepisy/herbata z tapioki - Bubble Tea.jpg',
#   'ingredients': [['4 łyżki perełek tapioki'],
#    ['10 łyżek cytrynowego syropu do kawy'],
#    ['2 saszetki herbaty malinowej'],
#    ['1 szklanka mleka'],
#    ['Kilka łyżek miodu'],
#    ['mięta do dekoracji']],
#   'preparation': '1. Przed ugotowaniem, perełki tapioki zalej syropem cytrynowym i pozostaw na co najmniej 10 minut.\r\n2. Do wrzącej, posłodzonej wody wrzuć tapiokę.\r\n3. Kiedy kuleczki wypłyną na powierzchnie, gotuj je przez 15 minut (lub do czasu aż staną się przezroczyste).\r\n4. Odstaw na 15 minut do ostygnięcia i odcedź perełki.\r\n5. Zaparz herbatę (na jedną szklankę wody wykorzystaj przynajmniej 2 saszetki herbaty)\r\n6. Zaparzoną herbate wymieszaj z pozostałymi składnikami.\r\n7. Gotowy napój przelej do szklanek z tapioką\r\n8. Schłodź napój i gotowe!\nUWAGA: Przed podaniem napój można udekorować miętą oraz dodać do niego kilka kostek lodu.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/17/tacos_z_kaczka_salsa_mango_i_sosem_hoisin.html',
# ...
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/86/choya_kamikaze_drink.html',
#   'title': 'Choya Kamikaze Drink',
#   'portions': 0,
#   'photo_link': 'images/przepisy/Choya Kamikaze Drink.jpg',
#   'ingredients': [['15 ml Wina z moreli japońskiej Choya Silver'],
#    ['30 ml czystej wódki'],
#    ['15 ml soku z limonki']],
#   'preparation': '1.\xa0Wszystkie składniki wlać do shakera koktajlowego\r\n2. Dodać kilka kostek lodu i energicznie wymieszać.\r\n3.\xa0Drinka należy przecedzić i przelać do szklanki.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/87/choya_gin_drink.html',
#   'title': 'Choya Gin Drink',
#   'portions': 0,
#   'photo_link': 'images/przepisy/Choya Gin Drink.jpg',
#   'ingredients': [['140 ml Wina z moreli japońskiej Choya Silver'],
#    ['60 ml ginu']],
#   'preparation': '1. Wino Choya Silver oraz Gin wlać do kieliszka martini, wymieszać.\r\n2. Można podawać z kruszonym lodem',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/106/bananowe_smoothie_z_woda_kokosowa_.html',
#   'title': 'Bananowe smoothie z wodą kokosową ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/smoothie_banan.jpg',
#   'ingredients': [['3 dojrzałe banany'],
#    ['250 ml wody kokosowej'],
#    ['1/2 cytryny']],
#   'preparation': 'Banana obrać i pokroić na mniejsze kawałki i przy pomocy blendera zmiksować razem z wodą kokosową i wyciśniętym sokiem z cytryny na gładką, jednolitą masę. \n*banana możesz zastąpić innymi owocami np. pomarańczą, kiwi, truskawki, mango itd.\xa0 ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/103/ananasowy_koktajl_z_woda_kokosowa_.html',
#   'title': 'Ananasowy koktajl z wodą kokosową ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/ananas.jpg',
#   'ingredients': [['150 g świeżego ananasa'],
#    ['250 ml wody kokosowej'],
#    ['limonka'],
#    ['kilka listków mięty'],
#    ['lód']],
#   'preparation': 'Ananasa obrać i zmiksować na gładkie puree, następnie dodać wodę kokosową i miksować do momentu uzyskania jednolitego koktajlu. Podawać z plastrami limonki, listkami mięty oraz lodem. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/5/wolowina_z_makaronem_ryzowym_i_migdalami.html',
#   'title': 'Wołowina z makaronem ryżowym i migdałami',
#   'portions': 0,
#   'photo_link': 'images/przepisy/wietnamwolowina.png',
#   'ingredients': [['1 antrykot wołowy'],
#    ['1 garść migdałów'],
#    ['1 garść białego sezamu'],
#    ['1 papryka czerwona'],
#    ['1 papryczka chilli'],
#    ['1 ząbek czosnku'],
#    ['kawałek imbiru'],
#    ['1 sałata rzymska'],
#    ['100 g makaronu ryżowego'],
#    ['1 garść kiełków fasoli mung'],
#    ['1 łyżka mielonej trawy cytrynowej'],
#    ['2-3 łyżki sosu teryiaki'],
#    ['olej arachidowy'],
#    ['1 łyżka sosu rybnego'],
#    ['1 czerwona cebula'],
#    ['2 łyżki sosu ostrygowego'],
#    ['1 łyżka octu ryżowego'],
#    ['świeża kolendra']],
#   'preparation': '1. Zamarynować antrykot w sosie ostrygowym, sosie teryiaki, sosie rybnym oraz startym imbirze. Odstawić na 1-2 godziny.\xa0\r\n2. Pokroić paprykę czerwoną w paski, cebulę w piórka, a papryczkę chili i czosnek w małe plasterki.\r\n3. W moździerzu utrzeć migdały.\xa0\r\n4. Na patelni, na rozgrzanym oleju smażyć mięso, po 2 minutach smażenia obrócić na drugą stronę (mięso powinno pozostać wewnątrz krwiste).\xa0\r\n5. Mięso ponownie obtoczyć w marynacie, do której tym razem dosypać ziarna sezamu.\r\n6. Przełożyć wołowinę do naczynia żaroodpornego i włożyć do piekarnika rozgrzanego do temperatury 180°C.\xa0\r\n7. Piec około 7-10 minut, po czym wyjąć mięso i pozostawić je aby odpoczęło.\xa0\r\n8. Do rozgrzanego woka wlać olej arachidowy i smażyć cebulę, po chwili dodać migdały i czerwoną paprykę. Warzywa przyprawić sosem teryiaki, sosem ostrygowym i sosem rybnym. Smażyć intensywnie mieszając.\r\n9. Dodać do woka czosnek, chili, kiełki fasoli mung i skropić octem ryżowym.\xa0\r\n10. Dolać odrobinę wody, aby uzyskać sos.\xa0\r\n11. Dokładnie mieszać składniki i dodać trawę cytrynową.\xa0\r\n12. Dodać pokrojoną sałatę rzymską makaron ryżowy.\xa0\r\n13. Mieszać i smażyć pół minuty.\xa0\r\n14. Przed podaniem na talerz, pokroić wołowinę na plastry i posypać świeżą kolendrą.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/102/weganskie_kokosowe_ptasie_mleczko_z_tapioki.html',
#   'title': 'Wegańskie kokosowe ptasie mleczko z tapioki',
#   'portions': 0,
#   'photo_link': 'images/przepisy/pianka_ptasia.jpg',
#   'ingredients': [['800 ml mleczka koksowego'],
#    ['¾ szklanki tapioki'],
#    ['1 laska wanilii'],
#    ['3-4 łyżki cukru'],
#    ['2 płaskie łyżeczki agaru'],
#    ['szczypta soli himalajskiej lub morskiej'],
#    ['100 g gorzkiej czekolady 90%'],
#    ['1 łyżeczka oleju kokosowego']],
#   'preparation': '1. Mleczko kokosowe wlać do garnka z grubym dnem.\r\n2. Laskę wanilii przekroić na pół, wybierać ziarenka i wrzucić je do mleczka. Wsypać tapiokę, sól oraz cukier i gotować na małym ogniu, często mieszając.\r\n3. Po około 15 minutach od zagotowania mikstura powinna zgęstnieć, a tapioka stać się prawie miękka i wtedy należy wyjąć laskę wanilii i powoli wsypywać agar, cały czas mieszając.\r\n4. Tapiokę gotować przez kolejne 10 minut. Gdy stanie się bardzo gęsta przełożyć ją do małej keksówki (blacha) o wymiarach około 12 x 26 cm. Można wcześniej pokryć ją folią spożywczą.\xa0Odstawić do wystudzenia.\r\n5. Czekoladę rozpuścić razem z olejem kokosowym i polać nią ugotowaną tapiokę. Całość wstawić na kilka godzin do lodówki.\r\n6. Przed podaniem wyjąć na 15-30 minut\xa0 i podzielić na równe kawałki.\r\n7. Ptasie mleczko można posypać jadalnymi suszonymi kwiatami, np. różą.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/138/weganska_zupa_marchewkowa_z_tofu_.html',
#   'title': 'Wegańska zupa marchewkowa z tofu ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/weganska_zupa_marchewkowa_01.jpg',
#   'ingredients': [['1 łyżka oleju kokosowego'],
#    ['1 ząbek czosnku'],
#    ['1/2 cebuli cukrowej'],
#    ['łodyga selera naciowego lub pora'],
#    ['500 g marchewki'],
#    ['2 łyżeczki startego imbiru'],
#    ['1 łyżka masła orzechowego'],
#    ['1/2 łyżeczki chili w proszku'],
#    ['1/2 łyżeczki kurkumy'],
#    ['1/2 łyżeczki kminu rzymskiego'],
#    ['szczypta cynamonu'],
#    ['600 ml bulionu jarzynowego'],
#    ['250 ml mleczka kokosowego'],
#    ['100 g tofu'],
#    ['1 łyżka czarnego sezamu'],
#    ['świeża kolendra']],
#   'preparation': 'W garnku roztopić olej i zeszklić posiekany czosnek i cebulę. Dodać pokrojonego pora lub selera i smażyć jeszcze przez 1-2 minuty. Dodać obraną i pokrojoną na plasterki marchewkę, starty imbir, masło orzechowe oraz chili, smażyć co chwilę mieszając przez około 2 minuty, w międzyczasie można dodawać 1-2 łyżki wody lub bulionu, aby składniki się nie przypalały. Doprawić kurkumą, kminem i cynamonem. Wlać bulion i zagotować. Gotować pod przykryciem przez około 20 minut do czasu, aż marchewka będzie miękka. Zmiksować w blenderze stojącym na krem z dodatkiem mleczka. Sprawdzić doprawienie. Podawać z podsmażanym tofu, sezamem i kolendrą. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/14/tofu_z_grzybami_shiitake.html',
#   'title': 'Tofu z grzybami Shiitake',
#   'portions': 0,
#   'photo_link': 'images/przepisy/wietnamtofu.png',
#   'ingredients': [['250 g tofu Mo- Ri'],
#    ['olej do smażenia'],
#    ['2 łyżki cukru'],
#    ['125 ml jasnego sosu sojowego'],
#    ['1 łyżeczka ciemnego sosu sojowego'],
#    ['2 ząbki czosnku'],
#    ['15 świeżych grzybów shiitake'],
#    ['czarny pieprz'],
#    ['1 małe czerwone chili']],
#   'preparation': '1. Pokroić tofu na 6 równych kostek, odstawić do osuszenia.\xa0\r\n2. Do woka wlać szklankę oleju do smażenia, dobrze rozgrzać i usmażyć tofu w 2 partiach, aż zrobi się kruche.\r\n3. Osuszyć z oleju na papierze kuchennym.\r\n4. W małym garnku połączyć cukier, sosy sojowe, połowę drobno posiekanego czosnku, świeżo zmielony czarny pieprz, grzyby shiitake i tofu.\xa0\r\n5. Marynować 15 minut.\r\n6. Postawić garnek na ogień, dolać 2 szklanki wody i zagotować.\r\n7. Zredukować ogień i gotować powoli przez 15 minut.\r\n8. Zdjąć z ognia i dodać drugą część czosnku i jeszcze trochę świeżo zmielonego pieprzu.\xa0\r\n9. Przybrać plasterkami chili, podawać z ryżem jaśminowym',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/66/sajgonki_z_warzywami.html',
#   'title': 'Sajgonki z warzywami',
#   'portions': 0,
#   'photo_link': 'images/przepisy/sajgonkiii.png',
#   'ingredients': [['10 arkuszy papieru ryżowego'],
#    ['1 średniej wielkości ogórek'],
#    ['1 papryka czerwona'],
#    ['1 papryka żółta'],
#    ['1 awokado'],
#    ['sól i pieprz do smaku'],
#    ['olej']],
#   'preparation': '1. Papier ryżowy namoczyć w zimnej wodzie.\r\n2. Ogórek pokroić na cienkie paseczki, a papryki w drobną kostkę.\r\n3. Awokado obrać oraz usunąć pestkę, a następnie, za pomocą widelca, rozgnieść na puree.\r\n4. Składniki doprawić solą i pieprzem.\r\n5. Na arkuszu papieru ryżowego ułożyć wszystkie składniki, a następnie ciasno zwinąć arkusz.\r\n6. Gotowe sajgonki smażyć na głębokim oleju przez 3 minuty na złotawo-brązowy kolor.\r\n7. Sajgonki można podawać z ciemnym sosem sojowym bądź słodkim sosem chili',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/123/makaron_sojowy_po_wietnamsku_z_wolowina_i_kurkuma.html',
#   'title': 'Makaron sojowy po wietnamsku z wołowiną i kurkumą',
#   'portions': 0,
#   'photo_link': 'images/przepisy/makaron-sojowy-z-woka-02.jpg',
#   'ingredients': [['150 g wołowiny (np. z udźca)'],
#    ['80 g makaronu sojowego'],
#    ['4 suszone grzybki chińskie Mun'],
#    ['0,5 łyżeczki  curry w proszku'],
#    ['0,5 łyżeczki kurkumy'],
#    ['0,5 łyżeczki płatków chilli'],
#    ['2 łyżki sosu rybnego'],
#    ['1 łyżka cukru'],
#    ['2 łyżki oleju roślinnego'],
#    ['2 ząbki czosnku, drobno posiekane'],
#    ['1 cebula (pół drobno posiekanej i pół pokrojonej w "piórka")'],
#    ['1 gałązka trawy cytrynowej (biała część) bardzo drobno posiekana'],
#    ['3 łyżki mleczka kokosowego'],
#    ['1 łyżka orzeszków ziemnych, posiekanych'],
#    ['0,5 łyżeczki drobno posiekanej, pikantnej papryczki chilli'],
#    ['sos sojowy do podania']],
#   'preparation': 'Mięso pokroić na bardzo cieniutkie plasterki w poprzek włókien (najlepiej wcześniej włożyć je na 1-2 godziny do zamrażarki, aby łatwiej było pokroić - po pokrojeniu ocieplić w temperaturze pokojowej). Makaron sojowy moczyć w zimnej wodzie przez 10 minut, następnie umieścić na sicie i zalać wrzątkiem. Przepłukać zimną wodą i odcedzić, pokroić nożyczkami na około 10 cm kawałki. Grzybki zalać wrzątkiem i moczyć\xa0przez 5 minut, odcedzić, pokroić. Do jednej miseczki wsypać przyprawę curry, kurkumę i płatki chilli. Do drugiej wlać sos rybny, cukier, 2 łyżki wody i wymieszać, aż cukier się rozpuści. Rozgrzać wok na średnim ogniu. Dodać olej, czosnek, drobno posiekaną cebulę i trawę cytrynową, mieszając smażyć, aż zmiękną przez około 1 - 2 minuty. Zwiększyć ogień, dodać wołowinę i mieszankę z pierwszej miseczki (z przyprawą curry) i smażyć przez około 1 minutę, aż mięso tylko zmieni kolor z czerwonego na brązowy. Następnie dodać makaron, grzyby, cebulę pokrojoną w "piórka" oraz mieszankę z drugiej miseczki (z sosem rybnym). Dobrze wymieszać, wlać mleczko kokosowe i smażyć przez 2 minuty. Posypać orzeszkami ziemnymi, papryczką chilli i podawać z sosem sojowym. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/48/kurczak_z_trawa_cytrynowa.html',
#   'title': 'Kurczak z trawą cytrynową',
#   'portions': 0,
#   'photo_link': 'images/przepisy/wietnamtrawa.png',
#   'ingredients': [['500 g piersi z kurczaka (pokrojona w kostkę)'],
#    ['1 cebula (pokrojona w kostkę)'],
#    ['3 łyżki trawy cytrynowej (posiekana)'],
#    ['2 łyżki sosu rybnego'],
#    ['2 papryczki chilli (drobno posiekana)'],
#    ['4 łyżki oleju arachidowego'],
#    ['3 łyżki cukru'],
#    ['4 ząbki czosnku (drobno posiekane)'],
#    ['1 szczypiorek (drobno posiekany)'],
#    ['1 łyżka przyprawy curry'],
#    ['ryż jaśminowy naturalny']],
#   'preparation': '1. W miseczce wymieszać 2 łyżki sosu rybnego, 1 łyżkę cukru, 1 łyżkę przyprawy curry, 4 ząbki czosnku oraz niewielką ilość wody.\xa0\r\n2. Tak przygotowaną marynatą polać pokrojone piersi z kurczaka.\r\n3. Mięso w marynacie odstawić do lodówki na około 30 minut.\xa0\r\n4. W średnim garnku podgrzać 5 łyżek wody z 2 łyżkami cukru.\xa0\r\n5. Całość mieszać, aż do rozpuszczenia się cukru oraz powstania karmelu.\xa0\r\n6. Do karmelu dodać odrobinę wody.\xa0\r\n7. Całość po dokładnym wymieszaniu dodać do wcześniej zamarynowanego kurczaka.\r\n8. W woku rozgrzać 4 łyżki oleju arachidowego, na którym smażymy papryczki chilli, cebulę oraz trawę cytrynową. Całość smażyć mieszając, aż będzie wyczuwalny intensywny aromat.\xa0\r\n9. Do woka dodać kurczaka wraz z karmelem.\xa0\r\n10. Wszystkie składniki smażyć ciągle mieszając, aż do zarumienienia się mięsa oraz zgęstnienia sosu.\xa0\r\n11. Kurczaka podajemy z ryżem jaśminowym, przyozdobić szczypiorkiem.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/107/chlodnik_na_wodzie_kokosowej_z_ogorkiem_i_rzodkiewka_.html',
#   'title': 'Chłodnik na wodzie kokosowej z ogórkiem i rzodkiewką ',
#   'portions': 0,
#   'photo_link': 'images/przepisy/chodnik.jpg',
#   'ingredients': [['200 ml wody kokosowej'],
#    ['200 ml mleczka kokosowego'],
#    ['1 ogórek świeży'],
#    ['6 rzodkiewek'],
#    ['świeży sok z połowy cytryny'],
#    ['2 ząbki czosnku'],
#    ['1 łyżka posiekanego szczypiorku'],
#    ['szczypta soli'],
#    ['szczypta pieprzu']],
#   'preparation': 'Ogórek oraz rzodkiewki umyć, obrać i pokroić w kostkę. Do miski włożyć czosnek, dodać pieprz i sól, wlać wodę kokosową, mleczko kokosowe oraz sok z cytryny. Zawartość miski zmiksować na gładką masę. Następnie dodać ogórka i rzodkiewki, wstawić do lodówki na 1 godzinę. Przed podaniem oprószyć zupę szczypiorkiem. ',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/52/pianki_z_mango.html',
#   'title': 'Pianki z mango',
#   'portions': 0,
#   'photo_link': None,
#   'ingredients': [['200 ml bitej śmietany'],
#    ['30 ml kremu kokosowego'],
#    ['10 g płatków żelatyny'],
#    ['200 g puree z mango'],
#    ['50 g cukru']],
#   'preparation': '1. Krem kokosowy podgrzać z dodatkiem cukru.\r\n2. Płatki żelatyny namoczyć w zimnej wodzie, następnie odcisnąć z nich nadmiar wody i rozpuścić ją w kremie kokosowym. Dodać puree z mango, całość ochłodzić do temperatury pokojowej i przełożyć do foremek.\r\n3. Foremki wstawić do lodówki na tak długo, aż całość nabierze konsystencji pianki.\r\n4. Podawać z bitą śmietaną.',
#   'category': None},
#  {'link': 'https://kkpolska.pl/przepis/31/indyjskie_curry_z_dynia_ciecierzyca_i_szpinakiem.html',
#   'title': 'Indyjskie curry z dynią, ciecierzycą i szpinakiem',
#   'portions': 0,
#   'photo_link': 'images/przepisy/indie.png',
#   'ingredients': [['1 szklanka ciecierzycy'],
#    ['1 cebula'],
#    ['1 łyżka startego imbiru'],
#    ['1 ząbek czosnku, starty'],
#    ['300 g obranej dyni'],
#    ['1/2 szklanki pasty pomidorowej'],
#    ['150 ml mleka kokosowego'],
#    ['garść szpinaku'],
#    ['200 g pomidorków koktajlowych'],
#    ['Przyprawy (po łyżce): • mielony kminy • kurkuma • mielona kolendra • mielony cynamon • słodka papryka • ostra papryka • kardamon zielony']],
#   'preparation': '\xa0\n1. Ugotować ciecierzycę lub użyć ugotowanej już ciecierzycy z puszki.\r\n2. W szerokim garnku na łyżce mleka kokosowego poddusić pokrojoną w kosteczkę cebulę, dodać starty imbir i czosnek i chwilę podsmażyć.\r\n3. Dodać przyprawy i mieszając smażyć przez 2 - 3 minuty, dodając nieco więcej mleka kokosowego. Powstałą pastę smażyć jeszcze przez minutę.\r\n4. Dodać ciecierzycę wraz z kilkoma łyżkami zalewy, pokrojoną w kosteczkę dynię, passatę pomidorową oraz mleko kokosowe. Wlać pół szklanki wody, doprawić szczyptą soli i gotować pod przykryciem przez 20 minut. W międzyczasie raz przemieszać.\r\n5. Gotować aż sos będzie kremowy, gęsty, a dynia miękka. Dodać szpinak, przekrojone na połówki pomidorki, wymieszać, zagotować i odstawić z ognia.',
#   'category': None}]
